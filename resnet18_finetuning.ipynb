# %%
import optuna
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.models import resnet18
from torchmetrics import Precision, Recall
from dataset import ImageDataset
import numpy as np
import datetime
import random
import time
random.seed(2233)
torch.manual_seed(2233)

#After /255 so in loading dataset there are no division by 255 just this normalization
mean = [0.5006, 0.3526, 0.5495]
std = [0.1493, 0.1341, 0.1124]

from albumentations import (
    Compose,
    Resize,
    OneOf,
    RandomBrightness,
    RandomContrast,
    MotionBlur,
    MedianBlur,
    GaussianBlur,
    VerticalFlip,
    HorizontalFlip,
    ShiftScaleRotate,
    Normalize,
)

transform = Compose(
    [
        Normalize(mean=mean, std=std),
        OneOf([RandomBrightness(limit=0.1, p=1), RandomContrast(limit=0.1, p=0.8)]),
        OneOf([MotionBlur(blur_limit=3), MedianBlur(blur_limit=3), GaussianBlur(blur_limit=3),], p=0.7,),
        VerticalFlip(p=0.5),
        HorizontalFlip(p=0.5),
    ]
)

transform_test = Compose(
    [Normalize(mean=mean, std=std)]
)



def objective(trial):
    # Hyperparameters to be tuned
    batch_size = trial.suggest_int('batch_size', 64, 1024)
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
    dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.8)
    kernel_size = trial.suggest_int('kernel_size', 2, 7)

    # Data loaders
    trainset = ImageDataset(data_path='train_data', transform=transform)
    trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=3)
    
    testset = ImageDataset(data_path='validation_data', transform=transform_test)
    testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

    # Model setup
    model = resnet18()
    model.conv1 = nn.Conv2d(3, 64, kernel_size=(kernel_size, kernel_size), stride=(1, 1), padding=(kernel_size // 2, kernel_size // 2), bias=False)
    num_classes = 4
    model.fc = nn.Sequential(
        nn.Dropout(dropout_rate),
        nn.Linear(model.fc.in_features, num_classes)
    )
    model = model.to('cuda')

    # Custom model class
    class MyModel(nn.Module):
        def __init__(self, model, learning_rate):
            super(MyModel, self).__init__()
            self.model = model
            self.criterion = nn.CrossEntropyLoss()
            self.optimizer = optim.AdamW(model.parameters(), lr=learning_rate)
            self.metric_precision = Precision(task="multiclass", num_classes=num_classes, average=None).to('cuda')
            self.metric_recall = Recall(task="multiclass", num_classes=num_classes, average=None).to('cuda')
            self.train_loss = []
            self.valid_loss = []

        def forward(self, x):
            return self.model(x)

        def train_one_epoch(self, trainloader):
            self.train()
            for inputs, labels in trainloader:
                inputs, labels = inputs.to('cuda'), labels.to('cuda')
                self.optimizer.zero_grad()
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                loss.backward()
                self.optimizer.step()
                self.train_loss.append(loss.item())
            avg_loss = np.mean(self.train_loss)
            self.train_loss.clear()
            return avg_loss

        def evaluate(self, testloader):
            self.eval()
            with torch.no_grad():
                for inputs, labels in testloader:
                    inputs, labels = inputs.to('cuda'), labels.to('cuda')
                    outputs = self.model(inputs)
                    loss = self.criterion(outputs, labels)
                    self.valid_loss.append(loss.item())
            avg_loss = np.mean(self.valid_loss)
            self.valid_loss.clear()
            return avg_loss

    my_model = MyModel(model=model, learning_rate=learning_rate)
    my_model = my_model.to('cuda')
    early_stop_patience = 15
    num_epochs = 1
    best_val_loss = float('inf')
    for epoch in range(num_epochs):
        my_model.train_one_epoch(trainloader)
        val_loss = my_model.evaluate(testloader)
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
        else:
            patience_counter += 1


        if patience_counter >= early_stop_patience:
            print(f"Early stopping at epoch {epoch} with best validation loss {best_val_loss}")
            break
    return best_val_loss

# Start the optimization
study = optuna.create_study(direction='minimize',
                            storage="sqlite:///db.sqlite3",  
                            study_name="resnet18")
start = time.perf_counter()
study.optimize(objective, n_trials=50)
stop = time.perf_counter()
print(f"Best trial: {study.best_trial.value}")
print(f"Best hyperparameters: {study.best_trial.params}")
# Out:
# /home/adam/miniconda3/envs/cells/lib/python3.10/site-packages/albumentations/augmentations/transforms.py:1800: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(
# /home/adam/miniconda3/envs/cells/lib/python3.10/site-packages/albumentations/augmentations/transforms.py:1826: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(
# /home/adam/miniconda3/envs/cells/lib/python3.10/site-packages/albumentations/augmentations/transforms.py:1952: UserWarning: blur_limit and sigma_limit minimum value can not be both equal to 0. blur_limit minimum value changed to 3.
#   warnings.warn(
# [I 2024-05-19 19:46:10,188] A new study created in memory with name: no-name-53150768-550f-4a7b-8060-f8d352b778b8
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:46:37,329] Trial 0 finished with value: 0.9035879726173314 and parameters: {'batch_size': 708, 'learning_rate': 8.048857132353813e-05, 'dropout_rate': 0.5922472979077712, 'kernel_size': 4}. Best is trial 0 with value: 0.9035879726173314.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:47:04,729] Trial 1 finished with value: 1.0913209188729525 and parameters: {'batch_size': 961, 'learning_rate': 2.5158296372856758e-06, 'dropout_rate': 0.5853726633619498, 'kernel_size': 4}. Best is trial 0 with value: 0.9035879726173314.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:47:27,585] Trial 2 finished with value: 0.9033038200754108 and parameters: {'batch_size': 934, 'learning_rate': 1.7416522943709204e-05, 'dropout_rate': 0.4468865558864843, 'kernel_size': 7}. Best is trial 2 with value: 0.9033038200754108.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:47:50,086] Trial 3 finished with value: 1.0524621208508809 and parameters: {'batch_size': 883, 'learning_rate': 1.805421454592149e-06, 'dropout_rate': 0.10177745634068597, 'kernel_size': 7}. Best is trial 2 with value: 0.9033038200754108.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:48:12,673] Trial 4 finished with value: 0.8548276067948809 and parameters: {'batch_size': 906, 'learning_rate': 0.0017508191616530016, 'dropout_rate': 0.5811982225164003, 'kernel_size': 7}. Best is trial 4 with value: 0.8548276067948809.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:48:38,801] Trial 5 finished with value: 0.8222139719473958 and parameters: {'batch_size': 396, 'learning_rate': 0.00022111525884595593, 'dropout_rate': 0.4018440584941625, 'kernel_size': 6}. Best is trial 5 with value: 0.8222139719473958.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:49:01,715] Trial 6 finished with value: 0.9168690616554684 and parameters: {'batch_size': 205, 'learning_rate': 4.641542870237408e-06, 'dropout_rate': 0.30368638273704784, 'kernel_size': 3}. Best is trial 5 with value: 0.8222139719473958.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:49:24,405] Trial 7 finished with value: 0.9496222484111786 and parameters: {'batch_size': 462, 'learning_rate': 6.987981373009688e-06, 'dropout_rate': 0.4894216914762899, 'kernel_size': 3}. Best is trial 5 with value: 0.8222139719473958.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:49:56,361] Trial 8 finished with value: 0.8921541153807963 and parameters: {'batch_size': 81, 'learning_rate': 0.005397814873203556, 'dropout_rate': 0.6610067726310754, 'kernel_size': 4}. Best is trial 5 with value: 0.8222139719473958.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:50:23,173] Trial 9 finished with value: 1.085202653388508 and parameters: {'batch_size': 757, 'learning_rate': 1.3796826516143796e-06, 'dropout_rate': 0.5784053359721639, 'kernel_size': 4}. Best is trial 5 with value: 0.8222139719473958.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:50:49,215] Trial 10 finished with value: 0.8012819443573932 and parameters: {'batch_size': 390, 'learning_rate': 0.00039528165430957336, 'dropout_rate': 0.29514664433917626, 'kernel_size': 6}. Best is trial 10 with value: 0.8012819443573932.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:51:15,385] Trial 11 finished with value: 0.8180514060515017 and parameters: {'batch_size': 381, 'learning_rate': 0.0003909909055056532, 'dropout_rate': 0.28101779692392936, 'kernel_size': 6}. Best is trial 10 with value: 0.8012819443573932.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:51:41,367] Trial 12 finished with value: 0.8022003574233477 and parameters: {'batch_size': 314, 'learning_rate': 0.00045115778985702857, 'dropout_rate': 0.26087677516856805, 'kernel_size': 6}. Best is trial 10 with value: 0.8012819443573932.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:52:07,998] Trial 13 finished with value: 0.8284049713403506 and parameters: {'batch_size': 230, 'learning_rate': 0.0007113313541333815, 'dropout_rate': 0.22592022229938255, 'kernel_size': 6}. Best is trial 10 with value: 0.8012819443573932.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:52:30,492] Trial 14 finished with value: 0.9116960553786694 and parameters: {'batch_size': 591, 'learning_rate': 6.124551865286247e-05, 'dropout_rate': 0.17817368209077056, 'kernel_size': 5}. Best is trial 10 with value: 0.8012819443573932.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:52:53,316] Trial 15 finished with value: 1.1694577900019099 and parameters: {'batch_size': 196, 'learning_rate': 0.0020910590895913475, 'dropout_rate': 0.32852537895810296, 'kernel_size': 5}. Best is trial 10 with value: 0.8012819443573932.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:53:19,634] Trial 16 finished with value: 0.9624462604888377 and parameters: {'batch_size': 283, 'learning_rate': 0.008400327945945562, 'dropout_rate': 0.35879134353865777, 'kernel_size': 6}. Best is trial 10 with value: 0.8012819443573932.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:54:26,724] Trial 17 finished with value: 0.8510771591176269 and parameters: {'batch_size': 22, 'learning_rate': 2.621445341080819e-05, 'dropout_rate': 0.2220082859006212, 'kernel_size': 5}. Best is trial 10 with value: 0.8012819443573932.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:54:53,118] Trial 18 finished with value: 0.802738178430534 and parameters: {'batch_size': 564, 'learning_rate': 0.0001991624842050049, 'dropout_rate': 0.1035531332535633, 'kernel_size': 6}. Best is trial 10 with value: 0.8012819443573932.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:55:15,776] Trial 19 finished with value: 0.8227452927262243 and parameters: {'batch_size': 337, 'learning_rate': 0.000870704144327275, 'dropout_rate': 0.22989595184274225, 'kernel_size': 7}. Best is trial 10 with value: 0.8012819443573932.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:55:42,438] Trial 20 finished with value: 0.8445203686179827 and parameters: {'batch_size': 464, 'learning_rate': 0.002355655414153691, 'dropout_rate': 0.3728973927548211, 'kernel_size': 6}. Best is trial 10 with value: 0.8012819443573932.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:56:09,447] Trial 21 finished with value: 0.8507958812960263 and parameters: {'batch_size': 635, 'learning_rate': 0.00016510661636801957, 'dropout_rate': 0.10335798370207164, 'kernel_size': 6}. Best is trial 10 with value: 0.8012819443573932.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:56:31,970] Trial 22 finished with value: 0.7884603565898389 and parameters: {'batch_size': 509, 'learning_rate': 0.0003398961521851946, 'dropout_rate': 0.16261805981772864, 'kernel_size': 5}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:56:54,434] Trial 23 finished with value: 0.8637958248244956 and parameters: {'batch_size': 492, 'learning_rate': 0.0005054797311924687, 'dropout_rate': 0.16893396460512564, 'kernel_size': 5}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:57:17,165] Trial 24 finished with value: 0.8354850248481988 and parameters: {'batch_size': 319, 'learning_rate': 3.522319193801794e-05, 'dropout_rate': 0.16827197454266105, 'kernel_size': 5}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:57:41,317] Trial 25 finished with value: 0.8103491172714289 and parameters: {'batch_size': 134, 'learning_rate': 0.0003094266735996551, 'dropout_rate': 0.2711971283543718, 'kernel_size': 5}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:58:07,255] Trial 26 finished with value: 0.8131423365901893 and parameters: {'batch_size': 434, 'learning_rate': 0.0009838431568310504, 'dropout_rate': 0.24060055895952748, 'kernel_size': 6}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:58:29,874] Trial 27 finished with value: 0.8133438960427329 and parameters: {'batch_size': 549, 'learning_rate': 9.957457050395782e-05, 'dropout_rate': 0.1695988886771918, 'kernel_size': 7}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:58:56,713] Trial 28 finished with value: 0.8896352951077448 and parameters: {'batch_size': 671, 'learning_rate': 0.0013139677113438476, 'dropout_rate': 0.3373161993508832, 'kernel_size': 6}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:59:23,364] Trial 29 finished with value: 0.8460423151652018 and parameters: {'batch_size': 733, 'learning_rate': 5.789976470148918e-05, 'dropout_rate': 0.4435258518891856, 'kernel_size': 4}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 19:59:45,910] Trial 30 finished with value: 0.9018001648095938 and parameters: {'batch_size': 284, 'learning_rate': 0.0037666141593253005, 'dropout_rate': 0.2786395919311252, 'kernel_size': 5}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:00:12,344] Trial 31 finished with value: 0.896214154994849 and parameters: {'batch_size': 560, 'learning_rate': 0.0001639552307724802, 'dropout_rate': 0.13254741781720786, 'kernel_size': 6}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:00:34,815] Trial 32 finished with value: 0.8564437860883148 and parameters: {'batch_size': 515, 'learning_rate': 0.0005280936135895475, 'dropout_rate': 0.13887328502870744, 'kernel_size': 5}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:01:01,643] Trial 33 finished with value: 0.8485145268797063 and parameters: {'batch_size': 627, 'learning_rate': 0.0002547026792760386, 'dropout_rate': 0.21936607305027953, 'kernel_size': 6}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:01:23,947] Trial 34 finished with value: 0.855205988858716 and parameters: {'batch_size': 391, 'learning_rate': 0.00011468509316074449, 'dropout_rate': 0.135069452085902, 'kernel_size': 7}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:01:46,377] Trial 35 finished with value: 0.8170548682370462 and parameters: {'batch_size': 765, 'learning_rate': 0.0004424535160357439, 'dropout_rate': 0.20177992396080896, 'kernel_size': 7}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:02:12,445] Trial 36 finished with value: 0.8043672067395756 and parameters: {'batch_size': 346, 'learning_rate': 0.00015318438155228613, 'dropout_rate': 0.19672212633094097, 'kernel_size': 6}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:02:35,168] Trial 37 finished with value: 0.9063008817759427 and parameters: {'batch_size': 839, 'learning_rate': 1.3577590962061278e-05, 'dropout_rate': 0.2503697925662329, 'kernel_size': 5}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:02:57,739] Trial 38 finished with value: 0.832187572058211 and parameters: {'batch_size': 986, 'learning_rate': 0.00025837118539291215, 'dropout_rate': 0.10215708592939905, 'kernel_size': 7}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:03:23,690] Trial 39 finished with value: 0.8237674461828696 and parameters: {'batch_size': 416, 'learning_rate': 8.142236891886183e-05, 'dropout_rate': 0.39210059308704054, 'kernel_size': 6}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:03:49,933] Trial 40 finished with value: 0.9578297744420442 and parameters: {'batch_size': 524, 'learning_rate': 0.0011816286911324632, 'dropout_rate': 0.30660189426592455, 'kernel_size': 4}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:04:15,989] Trial 41 finished with value: 0.9194895493429761 and parameters: {'batch_size': 358, 'learning_rate': 0.00019034343697067863, 'dropout_rate': 0.18594579338074413, 'kernel_size': 6}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:04:42,188] Trial 42 finished with value: 0.8300355587686811 and parameters: {'batch_size': 253, 'learning_rate': 0.00015080518806341727, 'dropout_rate': 0.19913922272985654, 'kernel_size': 6}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:05:08,678] Trial 43 finished with value: 0.8099786459820942 and parameters: {'batch_size': 447, 'learning_rate': 0.0006654901062722136, 'dropout_rate': 0.14942083785872573, 'kernel_size': 6}. Best is trial 22 with value: 0.7884603565898389.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:05:31,534] Trial 44 finished with value: 0.7837750381893582 and parameters: {'batch_size': 165, 'learning_rate': 0.0003373644682198133, 'dropout_rate': 0.25628852484161074, 'kernel_size': 7}. Best is trial 44 with value: 0.7837750381893582.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:05:54,967] Trial 45 finished with value: 0.9065983004394582 and parameters: {'batch_size': 154, 'learning_rate': 0.00033279475507429164, 'dropout_rate': 0.3091631389694191, 'kernel_size': 7}. Best is trial 44 with value: 0.7837750381893582.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:06:20,875] Trial 46 finished with value: 0.8123602755117736 and parameters: {'batch_size': 103, 'learning_rate': 4.589253884822491e-05, 'dropout_rate': 0.2634900912306775, 'kernel_size': 7}. Best is trial 44 with value: 0.7837750381893582.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:06:43,460] Trial 47 finished with value: 0.9292819096800986 and parameters: {'batch_size': 207, 'learning_rate': 0.0016548229763337307, 'dropout_rate': 0.6649830113691737, 'kernel_size': 7}. Best is trial 44 with value: 0.7837750381893582.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:07:21,775] Trial 48 finished with value: 0.8067678054936656 and parameters: {'batch_size': 52, 'learning_rate': 0.0003869919595768776, 'dropout_rate': 0.5149290787821779, 'kernel_size': 3}. Best is trial 44 with value: 0.7837750381893582.
# /tmp/ipykernel_5904/1630752877.py:54: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-6, 1e-2)
# /tmp/ipykernel_5904/1630752877.py:55: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.7)
# [I 2024-05-19 20:07:44,534] Trial 49 finished with value: 0.9374949694043253 and parameters: {'batch_size': 281, 'learning_rate': 0.0006961786207945438, 'dropout_rate': 0.3391291052236688, 'kernel_size': 5}. Best is trial 44 with value: 0.7837750381893582.
# Best trial: 0.7837750381893582
# Best hyperparameters: {'batch_size': 165, 'learning_rate': 0.0003373644682198133, 'dropout_rate': 0.25628852484161074, 'kernel_size': 7}
