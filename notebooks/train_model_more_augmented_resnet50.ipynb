# %%
import time
import sys
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from pytorch_lightning import LightningModule, Trainer
from dataset import ImageDataset
import torch.nn as nn
from torch.utils.data import DataLoader
from torchmetrics import Precision, Recall
from torchvision.models import resnet18
import warnings
from collections import defaultdict
from pytorch_lightning.callbacks import ModelCheckpoint, LearningRateMonitor, EarlyStopping
import cv2
from pytorch_lightning import Callback
warnings.filterwarnings('ignore')
torch.set_float32_matmul_precision('medium')

from albumentations import (
    Compose,
    Resize,
    OneOf,
    RandomBrightness,
    RandomContrast,
    MotionBlur,
    MedianBlur,
    GaussianBlur,
    VerticalFlip,
    HorizontalFlip,
    ShiftScaleRotate,
    Normalize,
)
transform = Compose(
    [
        OneOf([RandomBrightness(limit=0.4, p=1), RandomContrast(limit=0.4, p=1)]),
        OneOf([MotionBlur(blur_limit=3), MedianBlur(blur_limit=3), GaussianBlur(blur_limit=3),], p=0.7,),
        VerticalFlip(p=0.5),
        HorizontalFlip(p=0.5),
    ]
)


class MyModel(LightningModule):
    def __init__(self, model, learning_rate=0.001, weight_decay=0.00005):
        super(MyModel, self).__init__()
        self.model = model
        self.learning_rate = learning_rate
        self.weight_decay = weight_decay
        self.criterion = nn.CrossEntropyLoss()
        self.metric_precision = Precision(task="multiclass", num_classes=4, average=None).to('cuda')
        self.metric_recall = Recall(task="multiclass", num_classes=4, average=None).to('cuda')
        self.train_loss = []
        self.valid_loss = []
        self.save_hyperparameters()


    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        inputs, labels = batch
        outputs = self.model(inputs)
        loss = self.criterion(outputs, labels)
        _, preds = torch.max(outputs, 1)
        _, labels = torch.max(labels, 1)
        self.metric_precision(preds, labels)
        self.metric_recall(preds, labels)
        self.train_loss.append(loss.item())
        self.log("train_loss", loss, prog_bar=True, on_epoch=True, on_step=False)

        return loss

    def validation_step(self, batch):
        inputs, labels = batch
        outputs = self.model(inputs)
        loss = self.criterion(outputs, labels)
        _, preds = torch.max(outputs, 1)
        _, labels = torch.max(labels, 1)
        self.metric_precision(preds, labels)
        self.metric_recall(preds, labels)
        self.valid_loss.append(loss.item())
        self.log('val_loss', loss, prog_bar=True, on_epoch=True, on_step=False)

        return loss

    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(self.parameters(), lr=self.learning_rate, weight_decay=self.weight_decay)
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", factor=0.1, patience=3, min_lr=5e-6, verbose=True)
        return {"optimizer": optimizer, "lr_scheduler": scheduler, "monitor": "val_loss"}

    def on_train_epoch_end(self):
        avg_loss = np.mean(self.train_loss)
        self.train_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        self.log('train_loss', avg_loss)


        self.log('train_precision 0', precision[0])
        self.log('train_recall 0 ', recall[0])

        self.log('train_precision 1', precision[1])
        self.log('train_recall 1' , recall[1])


        self.log('train_precision 2', precision[2])
        self.log('train_recall 2', recall[2])

        self.log('train_precision 3', precision[3])
        self.log('train_recall 3', recall[3])



        print(f'eloss: {avg_loss}')
    
    def on_validation_epoch_end(self):
        avg_loss = np.mean(self.valid_loss)
        self.valid_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        self.log('val_loss', avg_loss)


        self.log('val_precision 0', float(precision[0]))
        self.log('val_recall 0 ', recall[0])

        self.log('val_precision 1', precision[1])
        self.log('val_recall 1' , recall[1])


        self.log('val_precision 2', precision[2])
        self.log('val_recall 2', recall[2])

        self.log('valprecision 3', precision[3])
        self.log('tval_recall 3', recall[3])




        print(f'val_loss: {avg_loss} ')
    
torch.cuda.empty_cache()


batch_size = 64
trainset = ImageDataset(data_path='train_data', transform=transform)

trainloader = DataLoader(trainset, batch_size=batch_size,
                         shuffle=True, num_workers=5)


testset =ImageDataset(data_path='validation_data')

testloader = DataLoader(testset, batch_size=batch_size,
                        shuffle=False, num_workers=5)

learning_rate = 0.001
weight_decay = 0.00005

model = resnet18()

num_classes = 4
model.fc = nn.Sequential(
    nn.Dropout(0.2),  
    nn.Linear(model.fc.in_features, num_classes))
# Out:
# C:\Users\adame\AppData\Local\Temp\ipykernel_1272\1486057740.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
class MetricsCallback(Callback):
    def __init__(self):
        super().__init__()
        self.metrics = []
        
    def on_train_epoch_end(self, trainer, pl_module):
        self.metrics.append(trainer.logged_metrics.copy())

metrics_callback = MetricsCallback()

checkpoint = ModelCheckpoint(monitor="val_loss", mode="min")
lr_monitor = LearningRateMonitor("epoch")
early_stop = EarlyStopping(monitor="val_loss", mode="min", patience=10)


lightning_model = MyModel(model, learning_rate, weight_decay)
trainer = Trainer(max_epochs=100, log_every_n_steps=1, accelerator='cuda', callbacks=[metrics_callback, lr_monitor, checkpoint, early_stop])
trainer.fit(lightning_model, trainloader, testloader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name             | Type             | Params
# ------------------------------------------------------
# 0 | model            | ResNet           | 23.5 M
# 1 | criterion        | CrossEntropyLoss | 0
# 2 | metric_precision | Precision        | 0
# 3 | metric_recall    | Recall           | 0
# ------------------------------------------------------
# 23.5 M    Trainable params
# 0         Non-trainable params
# 23.5 M    Total params
# 94.065    Total estimated model params size (MB)

# %% [markdown]
# # Model loading - (this is the best model)

# %%
ckpt_path = checkpoint.best_model_path
model = MyModel.load_from_checkpoint(ckpt_path) 
print(ckpt_path)
# Out:
# c:\Users\adame\Desktop\cells_master_thesis\lightning_logs\version_6\checkpoints\epoch=35-step=120852.ckpt

# %%
metrics_dict = defaultdict(list)
for metrics in metrics_callback.metrics:
    for key, value in metrics.items():
        metrics_dict[key].append(value.item()) 

import matplotlib.pyplot as plt
# Plot loss
plt.plot(metrics_dict['train_loss'], label='Training Loss')
plt.plot(metrics_dict['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
from torch.utils.data import DataLoader
import numpy as np
import torch 
from torchvision.models import resnet18
import torch.nn as nn


def test_report(model, dataloader):
    """Prints confusion matrix for testing dataset
    dataloader should be of batch_size=1."""

    y_pred = []
    y_test = []
    model.eval()
    with torch.no_grad():
        for data, label in dataloader:
            output = model(data)
            label = label.numpy()
            output = output.numpy()

          

            y_pred.append(np.argmax(output))
            y_test.append(np.argmax(label))
        print(y_pred)
        print(y_test)
        print(confusion_matrix(y_test, y_pred))
        print(classification_report(y_test, y_pred))

testset =ImageDataset(data_path='test_data')
dataloader = DataLoader(testset, batch_size=1, shuffle=True)

test_report(model.to('cpu'), dataloader)
# Out:
# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Given NumPy array
arr = np.array([[177, 2, 1, 6],
                [2, 20, 6, 4],
                [1, 5, 219, 0],
                [6, 6, 0, 202]])

# Create a heatmap with values
sns.heatmap(arr, annot=True, fmt="d", cmap="YlGnBu")

# %%
train_data = open('train_data/data_inflamatory.txt', 'r')
train_data = train_data.read().split('\n')

# %%
train_data
# Out:
# ['cells_final/inflammatory/aug_22032_MoNuSAC_lymphocyte_TCGA-S3-AA11-01Z-00-DX1_4_annot_Lymphocyte_reg15.png',
#  'cells_final/inflammatory/MoNuSAC_neutrophil_TCGA-G7-A8LD-01Z-00-DX1_9_annot_Neutrophil_reg22.png',
#  'cells_final/inflammatory/aug_7904_MoNuSAC_lymphocyte_TCGA-V1-A9O9-01Z-00-DX1-1_annot_Lymphocyte_reg36.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2478_intensity_158.png',
#  'cells_final/inflammatory/aug_30741_MoNuSAC_lymphocyte_TCGA-EV-5903-01Z-00-DX1_2_annot_Lymphocyte_reg137.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_963_intensity_541.png',
#  'cells_final/inflammatory/aug_36946_PanNuke_inflamatory_img_296_intensity_172.png',
#  'cells_final/inflammatory/aug_15275_PanNuke_inflamatory_img_826_intensity_121.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2118_intensity_303.png',
#  'cells_final/inflammatory/aug_37484_PanNuke_inflamatory_img_2005_intensity_223.png',
#  'cells_final/inflammatory/aug_10999_PanNuke_inflamatory_img_967_intensity_738.png',
#  'cells_final/inflammatory/aug_3796_PanNuke_inflamatory_img_2460_intensity_1437.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_645_intensity_172.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-73-4668-01Z-00-DX1_004_annot_Lymphocyte_reg18.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-A2-A0ES-01Z-00-DX1_5_annot_Lymphocyte_reg4.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-DW-7963-01Z-00-DX1_1_annot_Lymphocyte_reg5.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2012_intensity_76.png',
#  'cells_final/inflammatory/aug_24588_PanNuke_inflamatory_img_1647_intensity_267.png',
#  'cells_final/inflammatory/aug_10967_MoNuSAC_lymphocyte_TCGA-BH-A18T-01Z-00-DX1_1_annot_Lymphocyte_reg262.png',
#  'cells_final/inflammatory/aug_5732_PanNuke_inflamatory_img_2249_intensity_950.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1193_intensity_1323.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-D8-A1X5-01Z-00-DX2_2_annot_Lymphocyte_reg14.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2608_intensity_159.png',
#  'cells_final/inflammatory/aug_33864_MoNuSAC_lymphocyte_TCGA-B9-A8YI-01Z-00-DX1_1_annot_Lymphocyte_reg12.png',
#  'cells_final/inflammatory/aug_22829_PanNuke_inflamatory_img_655_intensity_51.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2032_intensity_378.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1695_intensity_402.png',
#  'cells_final/inflammatory/aug_18319_MoNuSAC_lymphocyte_TCGA-P4-AAVK-01Z-00-DX1_1_annot_Lymphocyte_reg39.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1086_intensity_281.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1953_intensity_262.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_648_intensity_51.png',
#  'cells_final/inflammatory/aug_7269_PanNuke_inflamatory_img_1840_intensity_255.png',
#  'cells_final/inflammatory/aug_26367_MoNuSAC_lymphocyte_TCGA-DW-7838-01Z-00-DX1_1_annot_Lymphocyte_reg437.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-KK-A7AW-01Z-00-DX1-1_annot_Lymphocyte_reg267.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_857_intensity_529.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-KK-A59X-01Z-00-DX1-1_annot_Lymphocyte_reg110.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2034_intensity_706.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-V1-A9O9-01Z-00-DX1-1_annot_Lymphocyte_reg52.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-
png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2435_intensity_110.png',
#  'cells_final/inflammatory/aug_31605_PanNuke_inflamatory_img_2063_intensity_350.png',
#  'cells_final/inflammatory/aug_41110_PanNuke_inflamatory_img_688_intensity_243.png',
#  'cells_final/inflammatory/aug_44647_MoNuSAC_lymphocyte_TCGA-D8-A1X5-01Z-00-DX2_3_annot_Lymphocyte_reg50.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_581_intensity_18.png',
#  'cells_final/inflammatory/aug_15543_PanNuke_inflamatory_img_1528_intensity_358.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-VP-A87E-01Z-00-DX1_1_annot_Lymphocyte_reg94.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2291_intensity_298.png',
#  'cells_final/inflammatory/aug_9920_PanNuke_inflamatory_img_2663_intensity_1194.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-B6-A0WZ-01Z-00-DX1_6_annot_Lymphocyte_reg2.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1063_intensity_1322.png',
#  'cells_final/inflammatory/aug_18893_MoNuSAC_lymphocyte_TCGA-KK-A7AW-01Z-00-DX1-1_annot_Lymphocyte_reg196.png',
#  'cells_final/inflammatory/aug_31910_PanNuke_inflamatory_img_599_intensity_67.png',
#  'cells_final/inflammatory/aug_43059_PanNuke_inflamatory_img_119_intensity_306.png',
#  'cells_final/inflammatory/aug_43362_PanNuke_inflamatory_img_2611_intensity_1536.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2335_intensity_171.png',
#  'cells_final/inflammatory/aug_32152_PanNuke_inflamatory_img_1881_intensity_187.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2456_intensity_12.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_477_intensity_80.png',
#  'cells_final/inflammatory/aug_9711_PanNuke_inflamatory_img_2662_intensity_970.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-G9-6367-01Z-00-DX1_1_annot_Lymphocyte_reg293.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-A2-A0ES-01Z-00-DX1_2_annot_Lymphocyte_reg655.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-J4-A67Q-01Z-00-DX1-3_annot_Lymphocyte_reg93.png',
#  'cells_final/inflammatory/aug_16733_MoNuSAC_lymphocyte_TCGA-L4-A4E5-01Z-00-DX1_1_annot_Lymphocyte_reg120.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-V1-A9O9-01Z-00-DX1-2_annot_Lymphocyte_reg71.png',
#  'cells_final/inflammatory/aug_18210_PanNuke_inflamatory_img_2187_intensity_172.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-DW-7841-01Z-00-DX1_1_annot_Lymphocyte_reg6.png',
#  'cells_final/inflammatory/aug_5591_MoNuSAC_lymphocyte_TCGA-EW-A6SD-01Z-00-DX1_5_annot_Lymphocyte_reg183.png',
#  'cells_final/inflammatory/aug_19231_MoNuSAC_lymphocyte_TCGA-KK-A7AW-01Z-00-DX1-1_annot_Lymphocyte_reg123.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_764_intensity_632.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-73-4668-01Z-00-DX1_004_annot_Lymphocyte_reg117.png',
#  'cells_final/inflammatory/aug_3513_PanNuke_inflamatory_img_214_intensity_254.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-55-7573-01Z-00-DX1_003_annot_Lymphocyte_reg271.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-D8-A1X5-01Z-00-DX2_2_annot_Lymphocyte_reg368.png',
#  'cells_final/inflammatory/MoNuSAC_neutrophil_TCGA-MH-A55W-01Z-00-DX1_1_annot_Neutrophil_reg3.png',
#  'cells_final/inflammatory/aug_42614_PanNuke_inflamatory_img_1977_intensity_69.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-A2-A0ES-01Z-00-DX1_001_annot_Lymphocyte_reg75.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2609_intensity_1456.png',
#  'cells_final/inflammatory/aug_46207_MoNuSAC_lymphocyte_TCGA-A2-A04X-01Z-00-DX1_001_annot_Lymphocyte_reg68.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1225_intensity_462.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1519_intensity_2.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-D8-A1X5-01Z-00-DX2_3_annot_Lymphocyte_reg33.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-J4-A67T-01Z-00-DX1-5_annot_Lymphocyte_reg128.png',
#  'cells_final/inflammatory/aug_22540_PanNuke_inflamatory_img_848_intensity_823.png',
#  'cells_final/inflammatory/aug_37419_MoNuSAC_lymphocyte_TCGA-G9-6499-01Z-00-DX1-5_annot_Lymphocyte_reg28.png',
#  'cells_final/inflammatory/aug_33097_PanNuke_inflamatory_img_819_intensity_845.png',
#  'cells_final/inflammatory/aug_40486_PanNuke_inflamatory_img_2339_intensity_86.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1858_intensity_269.png',
#  'cells_final/inflammatory/aug_29587_PanNuke_inflamatory_img_782_intensity_205.png',
#  'cells_final/inflammatory/NuCLS_lymphocyte_ANCHFOV-4cell_11.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-78-7220-01Z-00-DX1_004_annot_Lymphocyte_reg67.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-YL-A9WY-01Z-00-DX1-3_annot_Lymphocyte_reg21.png',
#  'cells_final/inflammatory/aug_43141_MoNuSAC_neutrophil_TCGA-86-8672-01Z-00-DX1_1_annot_Neutrophil_reg1.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-EV-5903-01Z-00-DX1_2_annot_Lymphocyte_reg334.png',
#  'cells_final/inflammatory/aug_14539_PanNuke_inflamatory_img_63_intensity_341.png',
#  'cells_final/inflammatory/aug_16616_MoNuSAC_lymphocyte_TCGA-E2-A108-01Z-00-DX1_001_annot_Lymphocyte_reg358.png',
#  'cells_final/inflammatory/aug_5129_PanNuke_inflamatory_img_616_intensity_61.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1166_intensity_575.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-S3-AA11-01Z-00-DX1_3_annot_Lymphocyte_reg257.png',
#  'cells_final/inflammatory/aug_1619_NuCLS_lymphocyte_ANCHFOV-1cell_31.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-YL-A9WY-01Z-00-DX1-3_annot_Lymphocyte_reg49.png',
#  'cells_final/inflammatory/aug_23110_PanNuke_inflamatory_img_1993_intensity_699.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1895_intensity_896.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2515_intensity_175.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-A2-A04X-01Z-00-DX1_001_annot_Lymphocyte_reg3.png',
#  'cells_final/inflammatory/aug_37531_MoNuSAC_neutrophil_TCGA-EJ-5505-01Z-00-DX1-4_annot_Neutrophil_reg15.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-A2-A04X-01Z-00-DX1_001_annot_Lymphocyte_reg495.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-F9-A97G-01Z-00-DX1_3_annot_Lymphocyte_reg504.png',
#  'cells_final/inflammatory/MoNuSAC_neutrophil_TCGA-2Z-A9JG-01Z-00-DX1_2_annot_Neutrophil_reg2.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-MP-A4SY-01Z-00-DX1_3_annot_Lymphocyte_reg101.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-YL-A9WY-01Z-00-DX1-3_annot_Lymphocyte_reg44.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-EW-A6SD-01Z-00-DX1_5_annot_Lymphocyte_reg95.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-KK-A59X-01Z-00-DX1-1_annot_Lymphocyte_reg10.png',
#  'cells_final/inflammatory/aug_41610_PanNuke_inflamatory_img_1997_intensity_426.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2121_intensity_1032.png',
#  'cells_final/inflammatory/aug_30193_MoNuSAC_lymphocyte_TCGA-73-4662-01Z-00-DX1_001_annot_Lymphocyte_reg261.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2440_intensity_1031.png',
#  'cells_final/inflammatory/aug_7094_MoNuSAC_lymphocyte_TCGA-P4-AAVK-01Z-00-DX1_1_annot_Lymphocyte_reg71.png',
#  'cells_final/inflammatory/aug_22404_MoNuSAC_lymphocyte_TCGA-E2-A108-01Z-00-DX1_001_annot_Lymphocyte_reg306.png',
#  'cells_final/inflammatory/aug_45677_MoNuSAC_lymphocyte_TCGA-V1-A9O9-01Z-00-DX1-1_annot_Lymphocyte_reg251.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA
png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-B9-A8YI-01Z-00-DX1_3_annot_Lymphocyte_reg49.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_856_intensity_104.png',
#  'cells_final/inflammatory/aug_32379_PanNuke_inflamatory_img_1801_intensity_126.png',
#  'cells_final/inflammatory/MoNuSAC_neutrophil_TCGA-EJ-5517-01Z-00-DX1-1_annot_Neutrophil_reg1.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-A2-A0CV-01Z-00-DX1_4_annot_Lymphocyte_reg431.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2594_intensity_171.png',
#  'cells_final/inflammatory/aug_22919_PanNuke_inflamatory_img_117_intensity_328.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1624_intensity_329.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2436_intensity_211.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1340_intensity_960.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-DW-7838-01Z-00-DX1_1_annot_Lymphocyte_reg267.png',
#  'cells_final/inflammatory/aug_32725_PanNuke_inflamatory_img_2249_intensity_937.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_727_intensity_539.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1883_intensity_119.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_647_intensity_116.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2035_intensity_646.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-73-4662-01Z-00-DX1_001_annot_Lymphocyte_reg278.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1400_intensity_260.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-5P-A9K0-01Z-00-DX1_2_annot_Lymphocyte_reg113.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2354_intensity_472.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-J4-A67Q-01Z-00-DX1-3_annot_Lymphocyte_reg199.png',
#  'cells_final/inflammatory/aug_25178_PanNuke_inflamatory_img_2376_intensity_889.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-G9-6499-01Z-00-DX1-2_annot_Lymphocyte_reg229.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-73-4662-01Z-00-DX1_001_annot_Lymphocyte_reg83.png',
#  'cells_final/inflammatory/aug_37969_PanNuke_inflamatory_img_974_intensity_23.png',
#  'cells_final/inflammatory/aug_1289_PanNuke_inflamatory_img_1231_intensity_726.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-P4-AAVK-01Z-00-DX1_1_annot_Lymphocyte_reg98.png',
#  'cells_final/inflammatory/aug_26745_MoNuSAC_lymphocyte_TCGA-D8-A3Z6-01Z-00-DX2_001_annot_Lymphocyte_reg28.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-EW-A6SD-01Z-00-DX1_5_annot_Lymphocyte_reg275.png',
#  'cells_final/inflammatory/aug_39540_MoNuSAC_neutrophil_TCGA-G7-A8LD-01Z-00-DX1_8_annot_Neutrophil_reg2.png',
#  'cells_final/inflammatory/aug_9705_MoNuSAC_lymphocyte_TCGA-G9-6367-01Z-00-DX1_1_annot_Lymphocyte_reg189.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1958_intensity_617.png',
#  'cells_final/inflammatory/aug_12508_MoNuSAC_lymphocyte_TCGA-E2-A108-01Z-00-DX1_001_annot_Lymphocyte_reg111.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-S3-AA11-01Z-00-DX1_4_annot_Lymphocyte_reg267.png',
#  'cells_final/inflammatory/aug_5951_PanNuke_inflamatory_img_846_intensity_639.png',
#  'cells_final/inflammatory/aug_34120_PanNuke_inflamatory_img_2437_intensity_380.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-A2-A0CV-01Z-00-DX1_4_annot_Lymphocyte_reg332.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1175_intensity_170.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-DW-7841-01Z-00-DX1_1_annot_Lymphocyte_reg590.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-EV-5903-01Z-00-DX1_2_annot_Lymphocyte_reg169.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_582_intensity_746.png',
#  'cells_final/inflammatory/aug_12955_PanNuke_inflamatory_img_959_intensity_137.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1566_intensity_148.png',
#  'cells_final/inflammatory/aug_5128_MoNuSAC_lymphocyte_TCGA-YL-A9WY-01Z-00-DX1-3_annot_Lymphocyte_reg148.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-D8-A3Z6-01Z-00-DX2_001_annot_Lymphocyte_reg65.png',
#  'cells_final/inflammatory/aug_10712_PanNuke_inflamatory_img_856_intensity_56.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-S3-AA11-01Z-00-DX1_4_annot_Lymphocyte_reg35.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-E9-A22G-01Z-00-DX1_1_annot_Lymphocyte_reg367.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2662_intensity_328.png',
#  'cells_final/inflammatory/aug_39347_MoNuSAC_lymphocyte_TCGA-UZ-A9PO-01Z-00-DX1_1_annot_Lymphocyte_reg17.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-X4-A8KQ-01Z-00-DX8-1_annot_Lymphocyte_reg58.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2437_intensity_403.png',
#  'cells_final/inflammatory/aug_24091_PanNuke_inflamatory_img_728_intensity_377.png',
#  'cells_final/inflammatory/aug_6776_PanNuke_inflamatory_img_522_intensity_261.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-DW-7963-01Z-00-DX1_1_annot_Lymphocyte_reg37.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2662_intensity_495.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2647_intensity_19.png',
#  'cells_final/inflammatory/aug_9181_PanNuke_inflamatory_img_2276_intensity_1108.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-X4-A8KS-01Z-00-DX3_1_annot_Lymphocyte_reg78.png',
#  'cells_final/inflammatory/aug_26794_PanNuke_inflamatory_img_858_intensity_549.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-F9-A97G-01Z-00-DX1_3_annot_Lymphocyte_reg306.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1872_intensity_822.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-EJ-5495-01Z-00-DX1-2_annot_Lymphocyte_reg83.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1702_intensity_22.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-B6-A0WZ-01Z-00-DX1_5_annot_Lymphocyte_reg260.png',
#  'cells_final/inflammatory/aug_23718_MoNuSAC_lymphocyte_TCGA-BH-A18T-01Z-00-DX1_6_annot_Lymphocyte_reg8.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-EV-5903-01Z-00-DX1_2_annot_Lymphocyte_reg32.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-D8-A1X5-01Z-00-DX2_2_annot_Lymphocyte_reg106.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1865_intensity_5.png',
#  'cells_final/inflammatory/aug_21701_MoNuSAC_lymphocyte_TCGA-EJ-5517-01Z-00-DX1-4_annot_Lymphocyte_reg331.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_316_intensity_255.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2103_intensity_74.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-DW-7841-01Z-00-DX1_1_annot_Lymphocyte_reg216.png',
#  'cells_final/inflammatory/aug_9188_PanNuke_inflamatory_img_1346_intensity_1389.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1980_intensity_266.png',
#  'cells_final/inflammatory/aug_35402_PanNuke_inflamatory_img_967_intensity_738.png',
#  'cells_final/inflammatory/aug_44480_MoNuSAC_lymphocyte_TCGA-F9-A97G-01Z-00-DX1_3_annot_Lymphocyte_reg421.png',
#  'cells_final/inflammatory/aug_27682_PanNuke_inflamatory_img_2213_intensity_242.png',
#  'cells_final/inflammatory/aug_2823_PanNuke_inflamatory_img_959_intensity_94.png',
#  'cells_final/inflammatory/aug_27416_MoNuSAC_lymphocyte_TCGA-86-8672-01Z-00-DX1_1_annot_Lymphocyte_reg228.png',
#  'cells_final/inflammatory/aug_44416_MoNuSAC_lymphocyte_TCGA-E9-A22B-01Z-00-DX1_1_annot_Lymphocyte_reg95.png',
#  'cells_final/inflammatory/aug_25847_PanNuke_inflamatory_img_649_intensity_288.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-E9-A22B-01Z-00-DX1_1_annot_Lymphocyte_reg61.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1442_intensity_167.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_111_intensity_180.png',
#  'cells_final/inflammatory/MoNuSAC_neutrophil_TCGA-EJ-5505-01Z-00-DX1-6_annot_Neutrophil_reg22.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2634_intensity_56.png',
#  'cells_final/inflammatory/aug_25041_MoNuSAC_lymphocyte_TCGA-MP-A4T7-01Z-00-DX1_4_annot_Lymphocyte_reg95.png',
#  'cells_final/inflammatory/aug_6778_MoNuSAC_lymphocyte_TCGA-E2-A108-01Z-00-DX1_001_annot_Lymphocyte_reg133.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_894_intensity_516.png',
#  'cells_final/inflammatory/aug_7113_MoNuSAC_lymphocyte_TCGA-F9-A8NY-01Z-00-DX1_3_annot_Lymphocyte_reg45.png',
#  'cells_final/inflammatory/aug_11658_MoNuSAC_lymphocyte_TCGA-DW-7838-01Z-00-DX1_1_annot_Lymphocyte_reg403.png',
#  'cells_final/inflammatory/aug_24081_MoNuSAC_lymphocyte_TCGA-EV-5903-01Z-00-DX1_2_annot_Lymphocyte_reg122.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-J4-A67T-01Z-00-DX1-5_annot_Lymphocyte_reg103.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-G9-6367-01Z-00-DX1_1_annot_Lymphocyte_reg141.png',
#  'cells_final/inflammatory/aug_12189_PanNuke_inflamatory_img_2649_intensity_59.png',
#  'cells_final/inflammatory/aug_16092_PanNuke_inflamatory_img_893_intensity_29.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_747_intensity_484.png',
#  'cells_final/inflammatory/aug_17412_PanNuke_inflamatory_img_1717_intensity_472.png',
#  'cells_final/inflammatory/aug_29188_MoNuSAC_lymphocyte_TCGA-55-1594-01Z-00-DX1_002_annot_Lymphocyte_reg2.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-G9-6499-01Z-00-DX1-2_annot_Lymphocyte_reg33.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_607_intensity_25.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-G7-A8LD-01Z-00-DX1_9_annot_Lymphocyte_reg2.png',
#  'cells_final/inflammatory/aug_22392_PanNuke_inflamatory_img_1063_intensity_928.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-EW-A6SB-01Z-00-DX1_005_annot_Lymphocyte_reg113.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-BH-A18T-01Z-00-DX1_1_annot_Lymphocyte_reg606.png',
#  'cells_final/inflammatory/aug_7166_MoNuSAC_lymphocyte_TCGA-55-7573-01Z-00-DX1_003_annot_Lymphocyte_reg321.png',
#  'cells_final/inflammatory/aug_20776_MoNuSAC_lymphocyte_TCGA-P4-AAVK-01Z-00-DX1_2_annot_Lymphocyte_reg63.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2594_intensity_136.png',
#  'cells_final/inflammatory/aug_288_MoNuSAC_lymphocyte_TCGA-X4-A8KS-01Z-00-DX3_1_annot_Lymphocyte_reg298.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2113_intensity_35.png',
#  'cells_final/inflammatory/aug_25123_PanNuke_inflamatory_img_316_intensity_263.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_647_intensity_439.png',
#  'cells_final/inflammatory/aug_41422_PanNuke_inflamatory_img_651_intensity_184.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-DW-7841-01Z-00-DX1_1_annot_Lymphocyte_reg418.png',
#  'cells_final/inflammatory/aug_45662_PanNuke_inflamatory_img_1019_intensity_551.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-DW-7838-01Z-00-DX1_1_annot_Lymphocyte_reg346.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_515_intensity_227.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1352_intensity_145.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_805_intensity_668.png',
#  'cells_final/inflammatory/aug_27882_PanNuke_inflamatory_img_1465_intensity_279.png',
#  'cells_final/inflammatory/aug_45308_PanNuke_inflamatory_img_2032_intensity_506.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_46_intensity_151.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-X4-A8KS-01Z-00-DX3_1_annot_Lymphocyte_reg163.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-DW-7841-01Z-00-DX1_1_annot_Lymphocyte_reg569.png',
#  'cells_final/inflammatory/aug_5937_MoNuSAC_lymphocyte_TCGA-G9-6367-01Z-00-DX1_1_annot_Lymphocyte_reg510.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1638_intensity_436.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_326_intensity_105.png',
#  'cells_final/inflammatory/aug_4271_MoNuSAC_lymphocyte_TCGA-F9-A97G-01Z-00-DX1_3_annot_Lymphocyte_reg399.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-B9-A44B-01Z-00-DX1_1_annot_Lymphocyte_reg221.png',
#  'cells_final/inflammatory/aug_7716_PanNuke_inflamatory_img_777_intensity_928.png',
#  'cells_final/inflammatory/aug_23719_PanNuke_inflamatory_img_1626_intensity_423.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2609_intensity_1157.png',
#  'cells_final/inflammatory/aug_27489_PanNuke_inflamatory_img_1088_intensity_43.png',
#  'cells_final/inflammatory/aug_6075_MoNuSAC_lymphocyte_TCGA-F9-A97G-01Z-00-DX1_3_annot_Lymphocyte_reg375.png',
#  'cells_final/inflammatory/aug_35412_PanNuke_inflamatory_img_99_intensity_142.png',
#  'cells_final/inflammatory/aug_25580_PanNuke_inflamatory_img_639_intensity_130.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_745_intensity_36.png',
#  'cells_final/inflammatory/aug_38103_MoNuSAC_lymphocyte_TCGA-KK-A7AW-01Z-00-DX1-1_annot_Lymphocyte_reg38.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-A2-A0ES-01Z-00-DX1_2_annot_Lymphocyte_reg139.png',
#  'cells_final/inflammatory/aug_1692_PanNuke_inflamatory_img_1626_intensity_365.png',
#  'cells_final/inflammatory/aug_9754_PanNuke_inflamatory_img_2473_intensity_525.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2394_intensity_1198.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-DW-7838-01Z-00-DX1_2_annot_Lymphocyte_reg13.png',
#  'cells_final/inflammatory/aug_43324_PanNuke_inflamatory_img_1825_intensity_728.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-V1-A9O9-01Z-00-DX1-2_annot_Lymphocyte_reg40.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-B9-A44B-01Z-00-DX1_2_annot_Lymphocyte_reg11.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-BH-A18T-01Z-00-DX1_1_annot_Lymphocyte_reg731.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_1352_intensity_94.png',
#  'cells_final/inflammatory/aug_36017_PanNuke_inflamatory_img_1005_intensity_525.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-EW-A6SD-01Z-00-DX1_5_annot_Lymphocyte_reg285.png',
#  'cells_final/inflammatory/aug_2144_NuCLS_lymphocyte_ANCHFOV-31cell_15.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2414_intensity_254.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-J4-A67T-01Z-00-DX1-5_annot_Lymphocyte_reg101.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_291_intensity_102.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-86-8672-01Z-00-DX1_1_annot_Lymphocyte_reg187.png',
#  'cells_final/inflammatory/aug_29108_MoNuSAC_lymphocyte_TCGA-E9-A22G-01Z-00-DX1_1_annot_Lymphocyte_reg85.png',
#  'cells_final/inflammatory/aug_2214_MoNuSAC_lymphocyte_TCGA-A2-A0ES-01Z-00-DX1_001_annot_Lymphocyte_reg332.png',
#  'cells_final/inflammatory/aug_28962_PanNuke_inflamatory_img_1279_intensity_224.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_897_intensity_45.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_817_intensity_564.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-73-4668-01Z-00-DX1_004_annot_Lymphocyte_reg48.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_805_intensity_694.png',
#  'cells_final/inflammatory/MoNuSAC_lymphocyte_TCGA-DW-7963-01Z-00-DX1_1_annot_Lymphocyte_reg74.png',
#  'cells_final/inflammatory/PanNuke_inflamatory_img_2662_intensity_1541.png',
#  'cells_final/inflammatory/aug_19243_MoNuSAC_lymphocyte_TCGA-B9-A44B-01Z-00-DX1_1_annot_Lymphocyte_reg149.png',
#  'cells_final/inflammatory/aug_14257_MoNuSAC_lymphocyte_TCGA-EJ-5517-01Z-00-DX1-4_annot_Lymphocyte_reg14.png',
#  'cells_final/inflammatory/aug_44637_PanNuke_inflamatory_img_2629_intensity_22.png',
#  ...]
