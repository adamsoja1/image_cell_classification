# %%
batch_size = 279
learning_rate = 0.003483773601114058
dropout_rate = 0.2757656331185102

# %%
import time
import sys
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from dataset import ImageDataset
import torch.nn.functional as F
from torchmetrics import Precision, Recall
from torchvision.models import resnet18
import warnings
from collections import defaultdict
import wandb
import datetime
import os
import torchvision.models as models
import torch.nn as nn
#intecubic interpol

class EfficientNetB0(nn.Module):
    def __init__(self, num_classes=4):
        super(EfficientNetB0, self).__init__()
        self.base_model = models.efficientnet_b0(pretrained=False)
        num_ftrs = self.base_model.classifier[1].in_features
        self.base_model.classifier[1] = nn.Linear(num_ftrs, num_classes)

    def forward(self, x):
        return self.base_model(x)


warnings.filterwarnings('ignore')


run_name = f'efficient_net_b0_after_tune2{datetime.datetime.now()}'
run_path = f'training_checkpoints/{run_name}'

wandb.init(project="cells", 
           entity="adamsoja",
          name=run_name)

import random
random.seed(2233)
torch.manual_seed(2233)

mean = [0.5006, 0.3526, 0.5495]
std = [0.1493, 0.1341, 0.1124]


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(2233)



from albumentations import (
    Compose,
    Resize,
    OneOf,
    RandomBrightness,
    RandomContrast,
    MotionBlur,
    MedianBlur,
    GaussianBlur,
    VerticalFlip,
    HorizontalFlip,
    ShiftScaleRotate,
    Normalize,
)

transform = Compose(
    [
        Normalize(mean=mean, std=std),
        OneOf([RandomBrightness(limit=0.1, p=1), RandomContrast(limit=0.1, p=0.8)]),
        OneOf([MotionBlur(blur_limit=3), MedianBlur(blur_limit=3), GaussianBlur(blur_limit=3),], p=0.7,),
        VerticalFlip(p=0.5),
        HorizontalFlip(p=0.5),
    ]
)

transform_test = Compose(
    [Normalize(mean=mean, std=std)]
)

class MyModel(nn.Module):
    def __init__(self, model, learning_rate, weight_decay):
        super(MyModel, self).__init__()
        self.model = model
        self.learning_rate = learning_rate
        self.weight_decay = weight_decay
        self.criterion = nn.CrossEntropyLoss()
        self.metric_precision = Precision(task="multiclass", num_classes=4, average=None).to('cuda')
        self.metric_recall = Recall(task="multiclass", num_classes=4, average=None).to('cuda')
        self.train_loss = []
        self.valid_loss = []
        self.precision_per_epochs = []
        self.recall_per_epochs = []

        self.optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, mode="min", factor=0.1, patience=7, min_lr=5e-6)
        self.step = 0

    
    def forward(self, x):
        return self.model(x)

    def train_one_epoch(self, trainloader):
        self.step += 1
        self.train()
        for batch_idx, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()
            _, preds = torch.max(outputs, 1)
            _, labels = torch.max(labels, 1)
            self.metric_precision(preds, labels)
            self.metric_recall(preds, labels)
            self.train_loss.append(loss.item())


        

        
        avg_loss = np.mean(self.train_loss)
        self.train_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        self.precision_per_epochs.append(precision)
        self.recall_per_epochs.append(recall)
        print(f'train_loss: {avg_loss}')
        print(f'train_precision: {precision}')
        print(f'train_recall: {recall}')

        wandb.log({'loss': avg_loss},step=self.step)
        wandb.log({'Normal precision': precision[0].item()},step=self.step)
        wandb.log({'Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'Other precision': precision[3].item()},step=self.step)


        wandb.log({'Normal recall': recall[0].item()},step=self.step)
        wandb.log({'Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'Other recall': recall[3].item()},step=self.step)
        
        
        self.metric_precision.reset()
        self.metric_recall.reset()


    

    def evaluate(self, testloader):
        self.eval()
        with torch.no_grad():
            for batch_idx, (inputs, labels) in enumerate(testloader):
                inputs, labels = inputs.to('cuda'), labels.to('cuda')
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)
                _, labels = torch.max(labels, 1)
                self.metric_precision(preds, labels)
                self.metric_recall(preds, labels)
                self.valid_loss.append(loss.item())
    
        avg_loss = np.mean(self.valid_loss)
        self.scheduler.step(avg_loss)
        self.valid_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        print(f'val_loss: {avg_loss}')
        print(f'val_precision: {precision}')
        print(f'val_recall: {recall}')
        self.metric_precision.reset()
        self.metric_recall.reset()

        wandb.log({'val_loss': avg_loss}, step=self.step)
        
        wandb.log({'val_Normal precision': precision[0].item()},step=self.step)
        wandb.log({'val_Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'val_Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'val_Other precision': precision[3].item()},step=self.step)


        wandb.log({'val_Normal recall': recall[0].item()},step=self.step)
        wandb.log({'val_Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'val_Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'val_Other recall': recall[3].item()},step=self.step)


        for param_group in self.optimizer.param_groups:
            print(f"Learning rate: {param_group['lr']}")
        return avg_loss

torch.cuda.empty_cache()
trainset = ImageDataset(data_path='train_data', transform=transform, reduce=True)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=5)

testset = ImageDataset(data_path='validation_data', transform=transform_test, reduce=True)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=3)

weight_decay = 0.00001

model = EfficientNetB0()
model = model.to('cuda')


my_model = MyModel(model=model, learning_rate=learning_rate, weight_decay=weight_decay)
my_model = my_model.to('cuda')

num_epochs = 100
early_stop_patience = 15
best_val_loss = float('inf')
best_model_state_dict = None

for epoch in range(num_epochs):
    print('========================================')
    print(f'EPOCH: {epoch}') 
    time_start = time.perf_counter()
    my_model.train_one_epoch(trainloader)
    val_loss = my_model.evaluate(testloader)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_state_dict = my_model.state_dict()
        torch.save(best_model_state_dict, f'{run_path}.pth')
        
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch} with best validation loss {best_val_loss}")
        break
    time_epoch = time.perf_counter() - time_start
    print(f'epoch {epoch} time:  {time_epoch/60}')
    print('--------------------------------')

# Load the best model state dict
print(f'{run_path}.pth')
my_model.load_state_dict(torch.load(f'{run_path}.pth'))
# Out:
# wandb: Currently logged in as: adamsoja. Use `wandb login --relogin` to force relogin
# wandb version 0.17.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/adam/Desktop/cells_master_thesis/wandb/run-20240715_230137-gtm5kqz2</code>
# Syncing run <strong><a href='https://wandb.ai/adamsoja/cells/runs/gtm5kqz2' target="_blank">efficient_net_b0_after_tune22024-07-15 23:01:36.195288</a></strong> to <a href='https://wandb.ai/adamsoja/cells' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adamsoja/cells' target="_blank">https://wandb.ai/adamsoja/cells</a>
#  View run at <a href='https://wandb.ai/adamsoja/cells/runs/gtm5kqz2' target="_blank">https://wandb.ai/adamsoja/cells/runs/gtm5kqz2</a>
# ========================================
# EPOCH: 0
# train_loss: 1.0904135073142789
# train_precision: tensor([0.3979, 0.5591, 0.4624, 0.0084], device='cuda:0')
# train_recall: tensor([2.4603e-01, 7.5420e-01, 4.9935e-01, 2.5202e-04], device='cuda:0')
# val_loss: 1.0249288244680925
# val_precision: tensor([0.4883, 0.5935, 0.4355, 0.0000], device='cuda:0')
# val_recall: tensor([0.0083, 0.7432, 0.7536, 0.0000], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 0 time:  0.2878741121499994
# --------------------------------
# ========================================
# EPOCH: 1
# train_loss: 1.023477902298031
# train_precision: tensor([0.4299, 0.5824, 0.5276, 0.0000], device='cuda:0')
# train_recall: tensor([0.3286, 0.7868, 0.4978, 0.0000], device='cuda:0')
# val_loss: 1.0224532591296243
# val_precision: tensor([0.4859, 0.6222, 0.6302, 0.0000], device='cuda:0')
# val_recall: tensor([0.5060, 0.7731, 0.4980, 0.0000], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 1 time:  0.28538948363333627
# --------------------------------
# ========================================
# EPOCH: 2
# train_loss: 0.9460268854380012
# train_precision: tensor([0.5190, 0.6161, 0.6239, 0.0000], device='cuda:0')
# train_recall: tensor([0.4785, 0.7730, 0.5548, 0.0000], device='cuda:0')
# val_loss: 0.8559736336444641
# val_precision: tensor([0.5890, 0.6932, 0.6667, 0.0000], device='cuda:0')
# val_recall: tensor([0.5564, 0.7666, 0.6747, 0.0000], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 2 time:  0.28307982169999757
# --------------------------------
# ========================================
# EPOCH: 3
# train_loss: 0.8728675878030071
# train_precision: tensor([0.5793, 0.6702, 0.6408, 0.2750], device='cuda:0')
# train_recall: tensor([0.5229, 0.7689, 0.6478, 0.0028], device='cuda:0')
# val_loss: 0.8121654937317321
# val_precision: tensor([0.6239, 0.6865, 0.6758, 0.8929], device='cuda:0')
# val_recall: tensor([0.5161, 0.8262, 0.6930, 0.0147], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 3 time:  0.28197012199999943
# --------------------------------
# ========================================
# EPOCH: 4
# train_loss: 0.8458589504862475
# train_precision: tensor([0.5958, 0.6853, 0.6517, 0.4892], device='cuda:0')
# train_recall: tensor([0.5369, 0.7784, 0.6650, 0.0285], device='cuda:0')
# val_loss: 0.797284125239699
# val_precision: tensor([0.6529, 0.7672, 0.6123, 0.8667], device='cuda:0')
# val_recall: tensor([0.4554, 0.7513, 0.8316, 0.0764], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 4 time:  0.28078413369999755
# --------------------------------
# ========================================
# EPOCH: 5
# train_loss: 0.8394917413212549
# train_precision: tensor([0.5999, 0.6813, 0.6577, 0.5562], device='cuda:0')
# train_recall: tensor([0.5400, 0.7785, 0.6660, 0.0499], device='cuda:0')
# val_loss: 0.7807126422445257
# val_precision: tensor([0.6483, 0.7129, 0.6671, 0.6207], device='cuda:0')
# val_recall: tensor([0.5208, 0.8061, 0.7364, 0.1481], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 5 time:  0.2897872326666667
# --------------------------------
# ========================================
# EPOCH: 6
# train_loss: 0.8039407430738881
# train_precision: tensor([0.6160, 0.7037, 0.6696, 0.6045], device='cuda:0')
# train_recall: tensor([0.5540, 0.7908, 0.6880, 0.0948], device='cuda:0')
# val_loss: 0.7261420800969317
# val_precision: tensor([0.6813, 0.7562, 0.6661, 0.6724], device='cuda:0')
# val_recall: tensor([0.5200, 0.8118, 0.7911, 0.2544], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 6 time:  0.2972138132500011
# --------------------------------
# ========================================
# EPOCH: 7
# train_loss: 0.7825523416499148
# train_precision: tensor([0.6249, 0.7110, 0.6751, 0.6303], device='cuda:0')
# train_recall: tensor([0.5634, 0.7937, 0.6934, 0.1530], device='cuda:0')
# val_loss: 0.7093294331660638
# val_precision: tensor([0.6807, 0.7329, 0.7032, 0.7400], device='cuda:0')
# val_recall: tensor([0.5450, 0.8503, 0.7528, 0.2609], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 7 time:  0.2966829874333295
# --------------------------------
# ========================================
# EPOCH: 8
# train_loss: 0.7674926831268299
# train_precision: tensor([0.6312, 0.7171, 0.6811, 0.6605], device='cuda:0')
# train_recall: tensor([0.5706, 0.7985, 0.6987, 0.1789], device='cuda:0')
# val_loss: 0.7050014309116177
# val_precision: tensor([0.6757, 0.7965, 0.6657, 0.9028], device='cuda:0')
# val_recall: tensor([0.5508, 0.7819, 0.8221, 0.2456], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 8 time:  0.29727997338332746
# --------------------------------
# ========================================
# EPOCH: 9
# train_loss: 0.7528945118233539
# train_precision: tensor([0.6398, 0.7242, 0.6875, 0.6832], device='cuda:0')
# train_recall: tensor([0.5792, 0.8040, 0.7059, 0.1978], device='cuda:0')
# val_loss: 0.6974906467057608
# val_precision: tensor([0.6894, 0.7955, 0.6677, 0.9009], device='cuda:0')
# val_recall: tensor([0.5300, 0.8033, 0.8356, 0.2350], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 9 time:  0.29587746535000103
# --------------------------------
# ========================================
# EPOCH: 10
# train_loss: 0.7463769371184273
# train_precision: tensor([0.6430, 0.7279, 0.6888, 0.7182], device='cuda:0')
# train_recall: tensor([0.5832, 0.8049, 0.7084, 0.2203], device='cuda:0')
# val_loss: 0.786755810459177
# val_precision: tensor([0.6567, 0.7889, 0.6391, 0.8851], device='cuda:0')
# val_recall: tensor([0.5373, 0.7282, 0.8222, 0.2761], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 10 time:  0.29001271660000233
# --------------------------------
# ========================================
# EPOCH: 11
# train_loss: 0.7580344097903822
# train_precision: tensor([0.6403, 0.7215, 0.6824, 0.6808], device='cuda:0')
# train_recall: tensor([0.5769, 0.8003, 0.7035, 0.2059], device='cuda:0')
# val_loss: 0.6687361316664235
# val_precision: tensor([0.6822, 0.7613, 0.7239, 0.8963], device='cuda:0')
# val_recall: tensor([0.5970, 0.8480, 0.7591, 0.2844], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 11 time:  0.29681422368333493
# --------------------------------
# ========================================
# EPOCH: 12
# train_loss: 0.7269895469052144
# train_precision: tensor([0.6510, 0.7383, 0.6956, 0.7115], device='cuda:0')
# train_recall: tensor([0.5937, 0.8071, 0.7192, 0.2412], device='cuda:0')
# val_loss: 0.6902721740982749
# val_precision: tensor([0.6759, 0.7347, 0.7208, 0.7281], device='cuda:0')
# val_recall: tensor([0.5462, 0.8645, 0.7487, 0.3619], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 12 time:  0.2909701008166697
# --------------------------------
# ========================================
# EPOCH: 13
# train_loss: 0.7196174768851079
# train_precision: tensor([0.6573, 0.7412, 0.6982, 0.6976], device='cuda:0')
# train_recall: tensor([0.5962, 0.8126, 0.7222, 0.2482], device='cuda:0')
# val_loss: 0.6503162248568102
# val_precision: tensor([0.7308, 0.7563, 0.7075, 0.8067], device='cuda:0')
# val_recall: tensor([0.5401, 0.8595, 0.8095, 0.3678], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 13 time:  0.29851370838333274
# --------------------------------
# ========================================
# EPOCH: 14
# train_loss: 0.7184665543564792
# train_precision: tensor([0.6611, 0.7410, 0.7019, 0.6876], device='cuda:0')
# train_recall: tensor([0.5985, 0.8141, 0.7256, 0.2429], device='cuda:0')
# val_loss: 0.6432275234402477
# val_precision: tensor([0.7186, 0.7307, 0.7521, 0.8964], device='cuda:0')
# val_recall: tensor([0.5855, 0.8906, 0.7533, 0.3049], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 14 time:  0.29650231598332843
# --------------------------------
# ========================================
# EPOCH: 15
# train_loss: 0.701202193568314
# train_precision: tensor([0.6617, 0.7499, 0.7090, 0.6953], device='cuda:0')
# train_recall: tensor([0.6127, 0.8147, 0.7263, 0.2674], device='cuda:0')
# val_loss: 0.6336194391434009
# val_precision: tensor([0.6526, 0.8064, 0.7688, 0.7103], device='cuda:0')
# val_recall: tensor([0.7033, 0.8236, 0.7187, 0.4019], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 15 time:  0.2965162164666632
# --------------------------------
# ========================================
# EPOCH: 16
# train_loss: 0.69447579528617
# train_precision: tensor([0.6682, 0.7525, 0.7143, 0.7120], device='cuda:0')
# train_recall: tensor([0.6205, 0.8187, 0.7284, 0.2797], device='cuda:0')
# val_loss: 0.6372245170853355
# val_precision: tensor([0.6695, 0.8359, 0.7192, 0.8633], device='cuda:0')
# val_recall: tensor([0.6593, 0.7829, 0.8009, 0.3414], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 16 time:  0.28927767700000306
# --------------------------------
# ========================================
# EPOCH: 17
# train_loss: 0.6875999480530597
# train_precision: tensor([0.6730, 0.7543, 0.7164, 0.7163], device='cuda:0')
# train_recall: tensor([0.6229, 0.8188, 0.7341, 0.2863], device='cuda:0')
# val_loss: 0.62557749669035
# val_precision: tensor([0.7230, 0.8053, 0.7056, 0.8233], device='cuda:0')
# val_recall: tensor([0.6039, 0.8202, 0.8253, 0.3696], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 17 time:  0.29724925536666735
# --------------------------------
# ========================================
# EPOCH: 18
# train_loss: 0.6804872404510293
# train_precision: tensor([0.6753, 0.7595, 0.7170, 0.7145], device='cuda:0')
# train_recall: tensor([0.6256, 0.8215, 0.7354, 0.3072], device='cuda:0')
# val_loss: 0.6348166265687742
# val_precision: tensor([0.7026, 0.8618, 0.6817, 0.7749], device='cuda:0')
# val_recall: tensor([0.6076, 0.7552, 0.8704, 0.3843], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 18 time:  0.28962840493333414
# --------------------------------
# ========================================
# EPOCH: 19
# train_loss: 0.6765092994677073
# train_precision: tensor([0.6761, 0.7600, 0.7196, 0.7057], device='cuda:0')
# train_recall: tensor([0.6290, 0.8204, 0.7367, 0.3065], device='cuda:0')
# val_loss: 0.628652416742765
# val_precision: tensor([0.7588, 0.7792, 0.6929, 0.7196], device='cuda:0')
# val_recall: tensor([0.5310, 0.8633, 0.8311, 0.4283], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 19 time:  0.2893426294833337
# --------------------------------
# ========================================
# EPOCH: 20
# train_loss: 0.6771237924359906
# train_precision: tensor([0.6771, 0.7607, 0.7219, 0.7147], device='cuda:0')
# train_recall: tensor([0.6316, 0.8192, 0.7392, 0.3112], device='cuda:0')
# val_loss: 0.6059148563788488
# val_precision: tensor([0.7265, 0.7980, 0.7290, 0.7988], device='cuda:0')
# val_recall: tensor([0.6177, 0.8442, 0.8125, 0.3966], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 20 time:  0.2970955982000002
# --------------------------------
# ========================================
# EPOCH: 21
# train_loss: 0.6764627957808739
# train_precision: tensor([0.6766, 0.7626, 0.7214, 0.7263], device='cuda:0')
# train_recall: tensor([0.6339, 0.8186, 0.7388, 0.3102], device='cuda:0')
# val_loss: 0.5954678691142089
# val_precision: tensor([0.6909, 0.8175, 0.7641, 0.8573], device='cuda:0')
# val_recall: tensor([0.6970, 0.8336, 0.7707, 0.3707], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 21 time:  0.29513023316666626
# --------------------------------
# ========================================
# EPOCH: 22
# train_loss: 0.6620322624067853
# train_precision: tensor([0.6831, 0.7670, 0.7270, 0.7218], device='cuda:0')
# train_recall: tensor([0.6391, 0.8248, 0.7428, 0.3276], device='cuda:0')
# val_loss: 0.6020512765312528
# val_precision: tensor([0.7505, 0.8150, 0.7061, 0.8472], device='cuda:0')
# val_recall: tensor([0.5835, 0.8433, 0.8512, 0.4072], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 22 time:  0.2871760328833337
# --------------------------------
# ========================================
# EPOCH: 23
# train_loss: 0.6588564132643246
# train_precision: tensor([0.6846, 0.7695, 0.7270, 0.7294], device='cuda:0')
# train_recall: tensor([0.6400, 0.8232, 0.7471, 0.3342], device='cuda:0')
# val_loss: 0.5826784767262585
# val_precision: tensor([0.7356, 0.7908, 0.7630, 0.8376], device='cuda:0')
# val_recall: tensor([0.6492, 0.8739, 0.7936, 0.4031], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 23 time:  0.29685006211667164
# --------------------------------
# ========================================
# EPOCH: 24
# train_loss: 0.6552824625100332
# train_precision: tensor([0.6868, 0.7717, 0.7305, 0.7255], device='cuda:0')
# train_recall: tensor([0.6468, 0.8233, 0.7475, 0.3410], device='cuda:0')
# val_loss: 0.6064008786961749
# val_precision: tensor([0.7340, 0.8218, 0.7149, 0.6029], device='cuda:0')
# val_recall: tensor([0.6169, 0.8214, 0.8276, 0.5147], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 24 time:  0.28978955758332936
# --------------------------------
# ========================================
# EPOCH: 25
# train_loss: 0.6545449651699552
# train_precision: tensor([0.6862, 0.7691, 0.7315, 0.7380], device='cuda:0')
# train_recall: tensor([0.6463, 0.8245, 0.7451, 0.3400], device='cuda:0')
# val_loss: 0.584328492413034
# val_precision: tensor([0.7092, 0.8249, 0.7566, 0.8441], device='cuda:0')
# val_recall: tensor([0.6908, 0.8311, 0.7938, 0.4136], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 25 time:  0.28992940064999856
# --------------------------------
# ========================================
# EPOCH: 26
# train_loss: 0.6512379125765954
# train_precision: tensor([0.6880, 0.7696, 0.7322, 0.7271], device='cuda:0')
# train_recall: tensor([0.6465, 0.8243, 0.7469, 0.3546], device='cuda:0')
# val_loss: 0.5798606530769722
# val_precision: tensor([0.7273, 0.7984, 0.7630, 0.8731], device='cuda:0')
# val_recall: tensor([0.6645, 0.8666, 0.7883, 0.3801], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 26 time:  0.2973724074166663
# --------------------------------
# ========================================
# EPOCH: 27
# train_loss: 0.6656884296365764
# train_precision: tensor([0.6817, 0.7672, 0.7263, 0.6945], device='cuda:0')
# train_recall: tensor([0.6411, 0.8223, 0.7416, 0.3105], device='cuda:0')
# val_loss: 0.6146072659875963
# val_precision: tensor([0.6961, 0.8299, 0.7404, 0.6547], device='cuda:0')
# val_recall: tensor([0.6842, 0.8116, 0.7841, 0.4277], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 27 time:  0.289855473549998
# --------------------------------
# ========================================
# EPOCH: 28
# train_loss: 0.6483595269373332
# train_precision: tensor([0.6902, 0.7727, 0.7305, 0.7167], device='cuda:0')
# train_recall: tensor([0.6458, 0.8244, 0.7505, 0.3526], device='cuda:0')
# val_loss: 0.61089639178106
# val_precision: tensor([0.7087, 0.8398, 0.7114, 0.7471], device='cuda:0')
# val_recall: tensor([0.6630, 0.7783, 0.8218, 0.4565], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 28 time:  0.29053710606666905
# --------------------------------
# ========================================
# EPOCH: 29
# train_loss: 0.6433003468849491
# train_precision: tensor([0.6897, 0.7762, 0.7370, 0.7146], device='cuda:0')
# train_recall: tensor([0.6532, 0.8273, 0.7499, 0.3566], device='cuda:0')
# val_loss: 0.582798460146764
# val_precision: tensor([0.7200, 0.8426, 0.7293, 0.7558], device='cuda:0')
# val_recall: tensor([0.6624, 0.8071, 0.8302, 0.4765], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 29 time:  0.2906642585333354
# --------------------------------
# ========================================
# EPOCH: 30
# train_loss: 0.642875944835314
# train_precision: tensor([0.6909, 0.7753, 0.7366, 0.7179], device='cuda:0')
# train_recall: tensor([0.6525, 0.8270, 0.7503, 0.3637], device='cuda:0')
# val_loss: 0.6376010415020522
# val_precision: tensor([0.7230, 0.8284, 0.6879, 0.7243], device='cuda:0')
# val_recall: tensor([0.6026, 0.7878, 0.8416, 0.4753], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 30 time:  0.2895437212833334
# --------------------------------
# ========================================
# EPOCH: 31
# train_loss: 0.6849095718613987
# train_precision: tensor([0.6762, 0.7531, 0.7164, 0.6901], device='cuda:0')
# train_recall: tensor([0.6280, 0.8168, 0.7306, 0.3065], device='cuda:0')
# val_loss: 0.5917338070335921
# val_precision: tensor([0.7317, 0.7966, 0.7506, 0.9136], device='cuda:0')
# val_recall: tensor([0.6507, 0.8577, 0.8028, 0.3167], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 31 time:  0.29063087709999613
# --------------------------------
# ========================================
# EPOCH: 32
# train_loss: 0.644317308287213
# train_precision: tensor([0.6923, 0.7728, 0.7353, 0.7265], device='cuda:0')
# train_recall: tensor([0.6529, 0.8256, 0.7493, 0.3609], device='cuda:0')
# val_loss: 0.5947669460014864
# val_precision: tensor([0.7395, 0.8514, 0.7064, 0.7910], device='cuda:0')
# val_recall: tensor([0.6448, 0.7911, 0.8577, 0.4536], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 32 time:  0.28986354661666763
# --------------------------------
# ========================================
# EPOCH: 33
# train_loss: 0.6416365740181267
# train_precision: tensor([0.6899, 0.7751, 0.7362, 0.7267], device='cuda:0')
# train_recall: tensor([0.6538, 0.8260, 0.7485, 0.3672], device='cuda:0')
# val_loss: 0.5674300740857224
# val_precision: tensor([0.7262, 0.8418, 0.7429, 0.7994], device='cuda:0')
# val_recall: tensor([0.6719, 0.8268, 0.8283, 0.4401], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 33 time:  0.2974766129000045
# --------------------------------
# ========================================
# EPOCH: 34
# train_loss: 0.6388019952012681
# train_precision: tensor([0.6949, 0.7754, 0.7387, 0.7226], device='cuda:0')
# train_recall: tensor([0.6543, 0.8282, 0.7533, 0.3657], device='cuda:0')
# val_loss: 0.5849222135502141
# val_precision: tensor([0.7348, 0.8186, 0.7323, 0.7841], device='cuda:0')
# val_recall: tensor([0.6421, 0.8387, 0.8235, 0.3948], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 34 time:  0.2928424723166624
# --------------------------------
# ========================================
# EPOCH: 35
# train_loss: 0.6444982325119236
# train_precision: tensor([0.6909, 0.7754, 0.7340, 0.7304], device='cuda:0')
# train_recall: tensor([0.6520, 0.8249, 0.7502, 0.3679], device='cuda:0')
# val_loss: 0.590062573031112
# val_precision: tensor([0.7089, 0.8614, 0.7247, 0.7942], device='cuda:0')
# val_recall: tensor([0.6676, 0.7857, 0.8463, 0.4330], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 35 time:  0.29031328888333974
# --------------------------------
# ========================================
# EPOCH: 36
# train_loss: 0.6310832813672577
# train_precision: tensor([0.6957, 0.7791, 0.7427, 0.7214], device='cuda:0')
# train_recall: tensor([0.6617, 0.8286, 0.7528, 0.3851], device='cuda:0')
# val_loss: 0.5918709354383962
# val_precision: tensor([0.7476, 0.8529, 0.6928, 0.8733], device='cuda:0')
# val_recall: tensor([0.6103, 0.8068, 0.8719, 0.3766], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 36 time:  0.28848242849999983
# --------------------------------
# ========================================
# EPOCH: 37
# train_loss: 0.6271585522294938
# train_precision: tensor([0.6981, 0.7800, 0.7422, 0.7293], device='cuda:0')
# train_recall: tensor([0.6587, 0.8284, 0.7582, 0.3964], device='cuda:0')
# val_loss: 0.5841280729412199
# val_precision: tensor([0.6687, 0.8207, 0.8112, 0.7913], device='cuda:0')
# val_recall: tensor([0.7609, 0.8319, 0.7189, 0.4501], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 37 time:  0.2896797132333328
# --------------------------------
# ========================================
# EPOCH: 38
# train_loss: 0.6257796236600118
# train_precision: tensor([0.7011, 0.7798, 0.7428, 0.7354], device='cuda:0')
# train_recall: tensor([0.6619, 0.8313, 0.7560, 0.3929], device='cuda:0')
# val_loss: 0.5822968749733238
# val_precision: tensor([0.7574, 0.8458, 0.7054, 0.7931], device='cuda:0')
# val_recall: tensor([0.6223, 0.8159, 0.8628, 0.4976], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 38 time:  0.29090274898333063
# --------------------------------
# ========================================
# EPOCH: 39
# train_loss: 0.628159606787397
# train_precision: tensor([0.6979, 0.7809, 0.7418, 0.7185], device='cuda:0')
# train_recall: tensor([0.6608, 0.8304, 0.7546, 0.3911], device='cuda:0')
# val_loss: 0.5875481771422433
# val_precision: tensor([0.7458, 0.8499, 0.7089, 0.8606], device='cuda:0')
# val_recall: tensor([0.6308, 0.8055, 0.8700, 0.3989], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 39 time:  0.2892529609999959
# --------------------------------
# ========================================
# EPOCH: 40
# train_loss: 0.6229663692314228
# train_precision: tensor([0.7005, 0.7830, 0.7464, 0.7340], device='cuda:0')
# train_recall: tensor([0.6656, 0.8313, 0.7583, 0.3949], device='cuda:0')
# val_loss: 0.5657998441190987
# val_precision: tensor([0.7052, 0.7930, 0.8095, 0.8057], device='cuda:0')
# val_recall: tensor([0.7245, 0.8729, 0.7317, 0.4653], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 40 time:  0.29659965699999397
# --------------------------------
# ========================================
# EPOCH: 41
# train_loss: 0.6201833579493784
# train_precision: tensor([0.7029, 0.7845, 0.7465, 0.7333], device='cuda:0')
# train_recall: tensor([0.6679, 0.8326, 0.7582, 0.4047], device='cuda:0')
# val_loss: 0.5657133579879374
# val_precision: tensor([0.7300, 0.8233, 0.7548, 0.7147], device='cuda:0')
# val_recall: tensor([0.6690, 0.8453, 0.8069, 0.5182], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 41 time:  0.29481417805000093
# --------------------------------
# ========================================
# EPOCH: 42
# train_loss: 0.6189736970092939
# train_precision: tensor([0.7013, 0.7838, 0.7463, 0.7305], device='cuda:0')
# train_recall: tensor([0.6648, 0.8324, 0.7592, 0.3982], device='cuda:0')
# val_loss: 0.5642345055833563
# val_precision: tensor([0.6913, 0.8257, 0.7889, 0.8954], device='cuda:0')
# val_recall: tensor([0.7275, 0.8468, 0.7585, 0.4025], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 42 time:  0.29648972664999745
# --------------------------------
# ========================================
# EPOCH: 43
# train_loss: 0.6158003082339731
# train_precision: tensor([0.7050, 0.7845, 0.7484, 0.7381], device='cuda:0')
# train_recall: tensor([0.6667, 0.8343, 0.7617, 0.4062], device='cuda:0')
# val_loss: 0.5655672375138823
# val_precision: tensor([0.7224, 0.8436, 0.7483, 0.8279], device='cuda:0')
# val_recall: tensor([0.6817, 0.8189, 0.8305, 0.4436], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 43 time:  0.2894011636166624
# --------------------------------
# ========================================
# EPOCH: 44
# train_loss: 0.6147251198852973
# train_precision: tensor([0.7042, 0.7837, 0.7492, 0.7325], device='cuda:0')
# train_recall: tensor([0.6687, 0.8332, 0.7590, 0.4168], device='cuda:0')
# val_loss: 0.5568001304681485
# val_precision: tensor([0.7038, 0.8579, 0.7657, 0.9040], device='cuda:0')
# val_recall: tensor([0.7231, 0.8113, 0.8135, 0.3984], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 44 time:  0.2957495841000006
# --------------------------------
# ========================================
# EPOCH: 45
# train_loss: 0.6142594215126409
# train_precision: tensor([0.7032, 0.7854, 0.7494, 0.7432], device='cuda:0')
# train_recall: tensor([0.6694, 0.8330, 0.7594, 0.4252], device='cuda:0')
# val_loss: 0.5696973192108261
# val_precision: tensor([0.7410, 0.8193, 0.7475, 0.7759], device='cuda:0')
# val_recall: tensor([0.6524, 0.8562, 0.8166, 0.4659], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 45 time:  0.2899724553833342
# --------------------------------
# ========================================
# EPOCH: 46
# train_loss: 0.6159641248979668
# train_precision: tensor([0.7041, 0.7843, 0.7496, 0.7241], device='cuda:0')
# train_recall: tensor([0.6705, 0.8342, 0.7572, 0.4128], device='cuda:0')
# val_loss: 0.5529267183550588
# val_precision: tensor([0.7032, 0.8383, 0.7881, 0.7699], device='cuda:0')
# val_recall: tensor([0.7347, 0.8324, 0.7789, 0.4877], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 46 time:  0.29634785616666853
# --------------------------------
# ========================================
# EPOCH: 47
# train_loss: 0.6132663804730554
# train_precision: tensor([0.7064, 0.7865, 0.7511, 0.7361], device='cuda:0')
# train_recall: tensor([0.6724, 0.8332, 0.7623, 0.4183], device='cuda:0')
# val_loss: 0.5607833292309221
# val_precision: tensor([0.6628, 0.8434, 0.8292, 0.8565], device='cuda:0')
# val_recall: tensor([0.7972, 0.8236, 0.7182, 0.4313], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 47 time:  0.2896087166999981
# --------------------------------
# ========================================
# EPOCH: 48
# train_loss: 0.6094525300938151
# train_precision: tensor([0.7076, 0.7867, 0.7521, 0.7289], device='cuda:0')
# train_recall: tensor([0.6719, 0.8356, 0.7623, 0.4221], device='cuda:0')
# val_loss: 0.5621457186403808
# val_precision: tensor([0.7491, 0.8209, 0.7544, 0.7097], device='cuda:0')
# val_recall: tensor([0.6568, 0.8528, 0.8237, 0.5358], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 48 time:  0.2936256004499986
# --------------------------------
# ========================================
# EPOCH: 49
# train_loss: 0.6073554565255967
# train_precision: tensor([0.7068, 0.7881, 0.7533, 0.7355], device='cuda:0')
# train_recall: tensor([0.6737, 0.8338, 0.7635, 0.4345], device='cuda:0')
# val_loss: 0.549773410171062
# val_precision: tensor([0.7146, 0.8355, 0.7809, 0.7151], device='cuda:0')
# val_recall: tensor([0.7225, 0.8427, 0.7782, 0.5441], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 49 time:  0.29619279886666544
# --------------------------------
# ========================================
# EPOCH: 50
# train_loss: 0.6063500877799302
# train_precision: tensor([0.7070, 0.7878, 0.7541, 0.7443], device='cuda:0')
# train_recall: tensor([0.6732, 0.8347, 0.7638, 0.4408], device='cuda:0')
# val_loss: 0.5418048088367169
# val_precision: tensor([0.7482, 0.8084, 0.7764, 0.8858], device='cuda:0')
# val_recall: tensor([0.6670, 0.8806, 0.8117, 0.4465], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 50 time:  0.2974708960333373
# --------------------------------
# ========================================
# EPOCH: 51
# train_loss: 0.6068247792156025
# train_precision: tensor([0.7072, 0.7883, 0.7532, 0.7384], device='cuda:0')
# train_recall: tensor([0.6759, 0.8336, 0.7626, 0.4254], device='cuda:0')
# val_loss: 0.5798636495650231
# val_precision: tensor([0.7337, 0.8703, 0.7089, 0.8797], device='cuda:0')
# val_recall: tensor([0.6514, 0.7943, 0.8672, 0.3954], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 51 time:  0.2904139814666678
# --------------------------------
# ========================================
# EPOCH: 52
# train_loss: 0.6034645635238115
# train_precision: tensor([0.7103, 0.7883, 0.7560, 0.7380], device='cuda:0')
# train_recall: tensor([0.6768, 0.8369, 0.7632, 0.4430], device='cuda:0')
# val_loss: 0.5571469982395639
# val_precision: tensor([0.7070, 0.8029, 0.8120, 0.7627], device='cuda:0')
# val_recall: tensor([0.7264, 0.8725, 0.7378, 0.5458], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 52 time:  0.28939588671666266
# --------------------------------
# ========================================
# EPOCH: 53
# train_loss: 0.6026769800968971
# train_precision: tensor([0.7090, 0.7896, 0.7562, 0.7401], device='cuda:0')
# train_recall: tensor([0.6765, 0.8372, 0.7643, 0.4327], device='cuda:0')
# val_loss: 0.5654538733350647
# val_precision: tensor([0.7036, 0.8775, 0.7487, 0.8850], device='cuda:0')
# val_recall: tensor([0.7160, 0.7830, 0.8393, 0.4207], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 53 time:  0.29105950926666535
# --------------------------------
# ========================================
# EPOCH: 54
# train_loss: 0.6018569143279561
# train_precision: tensor([0.7111, 0.7897, 0.7561, 0.7298], device='cuda:0')
# train_recall: tensor([0.6759, 0.8357, 0.7672, 0.4446], device='cuda:0')
# val_loss: 0.5693771384812735
# val_precision: tensor([0.6827, 0.8878, 0.7641, 0.9239], device='cuda:0')
# val_recall: tensor([0.7738, 0.7636, 0.8001, 0.4066], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 54 time:  0.2930381682666697
# --------------------------------
# ========================================
# EPOCH: 55
# train_loss: 0.6013041057329307
# train_precision: tensor([0.7082, 0.7898, 0.7577, 0.7377], device='cuda:0')
# train_recall: tensor([0.6796, 0.8361, 0.7625, 0.4423], device='cuda:0')
# val_loss: 0.6095924113805478
# val_precision: tensor([0.6883, 0.7523, 0.8807, 0.6233], device='cuda:0')
# val_recall: tensor([0.7558, 0.9049, 0.6326, 0.5717], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 55 time:  0.2901423287333349
# --------------------------------
# ========================================
# EPOCH: 56
# train_loss: 0.598971160946936
# train_precision: tensor([0.7120, 0.7890, 0.7578, 0.7448], device='cuda:0')
# train_recall: tensor([0.6782, 0.8394, 0.7640, 0.4413], device='cuda:0')
# val_loss: 0.5865875937930354
# val_precision: tensor([0.7696, 0.8714, 0.6830, 0.8456], device='cuda:0')
# val_recall: tensor([0.5933, 0.7980, 0.9025, 0.4794], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 56 time:  0.2920964057500062
# --------------------------------
# ========================================
# EPOCH: 57
# train_loss: 0.5966119917257615
# train_precision: tensor([0.7131, 0.7909, 0.7581, 0.7361], device='cuda:0')
# train_recall: tensor([0.6817, 0.8360, 0.7652, 0.4619], device='cuda:0')
# val_loss: 0.5566279296274785
# val_precision: tensor([0.6904, 0.7943, 0.8485, 0.7192], device='cuda:0')
# val_recall: tensor([0.7468, 0.8923, 0.6966, 0.5358], device='cuda:0')
# Learning rate: 0.003483773601114058
# epoch 57 time:  0.290047164483326
# --------------------------------
# ========================================
# EPOCH: 58
# train_loss: 0.5937375004949241
# train_precision: tensor([0.7110, 0.7924, 0.7607, 0.7389], device='cuda:0')
# train_recall: tensor([0.6833, 0.8368, 0.7653, 0.4579], device='cuda:0')
# val_loss: 0.5914398991353028
# val_precision: tensor([0.7189, 0.7300, 0.8664, 0.6716], device='cuda:0')
# val_recall: tensor([0.6907, 0.9287, 0.6770, 0.5817], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 58 time:  0.28880204478333177
# --------------------------------
# ========================================
# EPOCH: 59
# train_loss: 0.5680692106530048
# train_precision: tensor([0.7250, 0.8014, 0.7707, 0.7834], device='cuda:0')
# train_recall: tensor([0.6937, 0.8458, 0.7777, 0.5058], device='cuda:0')
# val_loss: 0.5087983738500755
# val_precision: tensor([0.7422, 0.8666, 0.7798, 0.7648], device='cuda:0')
# val_recall: tensor([0.7308, 0.8303, 0.8345, 0.5787], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 59 time:  0.29655949128333153
# --------------------------------
# ========================================
# EPOCH: 60
# train_loss: 0.5577329044220508
# train_precision: tensor([0.7313, 0.8059, 0.7747, 0.7702], device='cuda:0')
# train_recall: tensor([0.7013, 0.8483, 0.7813, 0.5126], device='cuda:0')
# val_loss: 0.49945782875264444
# val_precision: tensor([0.7529, 0.8399, 0.7996, 0.7720], device='cuda:0')
# val_recall: tensor([0.7234, 0.8625, 0.8198, 0.5887], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 60 time:  0.2983198862833281
# --------------------------------
# ========================================
# EPOCH: 61
# train_loss: 0.5535067175549904
# train_precision: tensor([0.7317, 0.8064, 0.7775, 0.7710], device='cuda:0')
# train_recall: tensor([0.7016, 0.8481, 0.7841, 0.5244], device='cuda:0')
# val_loss: 0.502418319974746
# val_precision: tensor([0.7598, 0.8516, 0.7788, 0.7861], device='cuda:0')
# val_recall: tensor([0.7042, 0.8536, 0.8435, 0.5699], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 61 time:  0.2906184401833343
# --------------------------------
# ========================================
# EPOCH: 62
# train_loss: 0.5533476828456462
# train_precision: tensor([0.7338, 0.8062, 0.7780, 0.7808], device='cuda:0')
# train_recall: tensor([0.7041, 0.8489, 0.7836, 0.5260], device='cuda:0')
# val_loss: 0.4993127143674797
# val_precision: tensor([0.7672, 0.8308, 0.7956, 0.7673], device='cuda:0')
# val_recall: tensor([0.7027, 0.8753, 0.8270, 0.6046], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 62 time:  0.2971148222333341
# --------------------------------
# ========================================
# EPOCH: 63
# train_loss: 0.5502211003378592
# train_precision: tensor([0.7333, 0.8081, 0.7798, 0.7767], device='cuda:0')
# train_recall: tensor([0.7048, 0.8500, 0.7847, 0.5295], device='cuda:0')
# val_loss: 0.4975354431809245
# val_precision: tensor([0.7623, 0.8398, 0.7955, 0.7891], device='cuda:0')
# val_recall: tensor([0.7163, 0.8668, 0.8279, 0.5893], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 63 time:  0.29712627374999556
# --------------------------------
# ========================================
# EPOCH: 64
# train_loss: 0.5493794595194363
# train_precision: tensor([0.7349, 0.8078, 0.7806, 0.7755], device='cuda:0')
# train_recall: tensor([0.7053, 0.8516, 0.7841, 0.5388], device='cuda:0')
# val_loss: 0.4980417563990279
# val_precision: tensor([0.7612, 0.8468, 0.7876, 0.7716], device='cuda:0')
# val_recall: tensor([0.7123, 0.8585, 0.8351, 0.5993], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 64 time:  0.2901971421833347
# --------------------------------
# ========================================
# EPOCH: 65
# train_loss: 0.5487410081648219
# train_precision: tensor([0.7353, 0.8093, 0.7792, 0.7657], device='cuda:0')
# train_recall: tensor([0.7062, 0.8490, 0.7856, 0.5370], device='cuda:0')
# val_loss: 0.4975729435682297
# val_precision: tensor([0.7640, 0.8344, 0.7956, 0.7953], device='cuda:0')
# val_recall: tensor([0.7102, 0.8710, 0.8272, 0.5823], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 65 time:  0.28973016884999653
# --------------------------------
# ========================================
# EPOCH: 66
# train_loss: 0.545915414502417
# train_precision: tensor([0.7386, 0.8094, 0.7806, 0.7864], device='cuda:0')
# train_recall: tensor([0.7070, 0.8513, 0.7875, 0.5484], device='cuda:0')
# val_loss: 0.5043640215913733
# val_precision: tensor([0.7721, 0.8545, 0.7663, 0.8040], device='cuda:0')
# val_recall: tensor([0.6893, 0.8499, 0.8605, 0.5711], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 66 time:  0.29211412258333286
# --------------------------------
# ========================================
# EPOCH: 67
# train_loss: 0.5447589918144461
# train_precision: tensor([0.7373, 0.8109, 0.7814, 0.7805], device='cuda:0')
# train_recall: tensor([0.7084, 0.8512, 0.7870, 0.5512], device='cuda:0')
# val_loss: 0.49598951043782535
# val_precision: tensor([0.7705, 0.8364, 0.7910, 0.7744], device='cuda:0')
# val_recall: tensor([0.7045, 0.8709, 0.8340, 0.5911], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 67 time:  0.29693936676666605
# --------------------------------
# ========================================
# EPOCH: 68
# train_loss: 0.5438458091583567
# train_precision: tensor([0.7381, 0.8109, 0.7814, 0.7758], device='cuda:0')
# train_recall: tensor([0.7075, 0.8513, 0.7883, 0.5502], device='cuda:0')
# val_loss: 0.4954524599797242
# val_precision: tensor([0.7634, 0.8490, 0.7877, 0.8182], device='cuda:0')
# val_recall: tensor([0.7167, 0.8580, 0.8395, 0.5658], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 68 time:  0.2996568687499954
# --------------------------------
# ========================================
# EPOCH: 69
# train_loss: 0.5433455507705237
# train_precision: tensor([0.7372, 0.8107, 0.7811, 0.7689], device='cuda:0')
# train_recall: tensor([0.7082, 0.8511, 0.7866, 0.5441], device='cuda:0')
# val_loss: 0.4960136119719152
# val_precision: tensor([0.7333, 0.8565, 0.8127, 0.7981], device='cuda:0')
# val_recall: tensor([0.7608, 0.8464, 0.8076, 0.5828], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 69 time:  0.28876113396666675
# --------------------------------
# ========================================
# EPOCH: 70
# train_loss: 0.5412433460645233
# train_precision: tensor([0.7382, 0.8128, 0.7824, 0.7746], device='cuda:0')
# train_recall: tensor([0.7095, 0.8511, 0.7888, 0.5605], device='cuda:0')
# val_loss: 0.4929894647606603
# val_precision: tensor([0.7606, 0.8340, 0.8069, 0.7822], device='cuda:0')
# val_recall: tensor([0.7241, 0.8746, 0.8171, 0.5928], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 70 time:  0.2961268151666673
# --------------------------------
# ========================================
# EPOCH: 71
# train_loss: 0.5417617007174056
# train_precision: tensor([0.7390, 0.8092, 0.7835, 0.7833], device='cuda:0')
# train_recall: tensor([0.7087, 0.8528, 0.7869, 0.5592], device='cuda:0')
# val_loss: 0.4938933641968907
# val_precision: tensor([0.7437, 0.8546, 0.8027, 0.7901], device='cuda:0')
# val_recall: tensor([0.7446, 0.8497, 0.8197, 0.5817], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 71 time:  0.28793511488333173
# --------------------------------
# ========================================
# EPOCH: 72
# train_loss: 0.5395199366059081
# train_precision: tensor([0.7396, 0.8109, 0.7848, 0.7882], device='cuda:0')
# train_recall: tensor([0.7120, 0.8512, 0.7894, 0.5524], device='cuda:0')
# val_loss: 0.49928287078033795
# val_precision: tensor([0.7369, 0.8670, 0.7952, 0.8016], device='cuda:0')
# val_recall: tensor([0.7514, 0.8327, 0.8250, 0.5817], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 72 time:  0.29153579208333064
# --------------------------------
# ========================================
# EPOCH: 73
# train_loss: 0.5386787601586046
# train_precision: tensor([0.7397, 0.8122, 0.7848, 0.7906], device='cuda:0')
# train_recall: tensor([0.7119, 0.8527, 0.7890, 0.5595], device='cuda:0')
# val_loss: 0.4921581050107529
# val_precision: tensor([0.7543, 0.8439, 0.8058, 0.7720], device='cuda:0')
# val_recall: tensor([0.7315, 0.8631, 0.8211, 0.6146], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 73 time:  0.2974806198833297
# --------------------------------
# ========================================
# EPOCH: 74
# train_loss: 0.5380981934928465
# train_precision: tensor([0.7393, 0.8122, 0.7847, 0.7782], device='cuda:0')
# train_recall: tensor([0.7103, 0.8514, 0.7904, 0.5640], device='cuda:0')
# val_loss: 0.4928967185787388
# val_precision: tensor([0.7524, 0.8521, 0.7984, 0.7823], device='cuda:0')
# val_recall: tensor([0.7331, 0.8531, 0.8281, 0.6016], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 74 time:  0.2915220823000027
# --------------------------------
# ========================================
# EPOCH: 75
# train_loss: 0.5390842422016379
# train_precision: tensor([0.7398, 0.8128, 0.7835, 0.7915], device='cuda:0')
# train_recall: tensor([0.7123, 0.8518, 0.7890, 0.5577], device='cuda:0')
# val_loss: 0.4916494853429861
# val_precision: tensor([0.7549, 0.8327, 0.8174, 0.7614], device='cuda:0')
# val_recall: tensor([0.7327, 0.8758, 0.8079, 0.6263], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 75 time:  0.296605565883336
# --------------------------------
# ========================================
# EPOCH: 76
# train_loss: 0.536437977959906
# train_precision: tensor([0.7391, 0.8133, 0.7839, 0.7832], device='cuda:0')
# train_recall: tensor([0.7119, 0.8520, 0.7887, 0.5645], device='cuda:0')
# val_loss: 0.49522164912073763
# val_precision: tensor([0.7709, 0.8472, 0.7822, 0.7920], device='cuda:0')
# val_recall: tensor([0.7035, 0.8594, 0.8464, 0.6040], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 76 time:  0.2895992883666622
# --------------------------------
# ========================================
# EPOCH: 77
# train_loss: 0.5369800909169611
# train_precision: tensor([0.7386, 0.8125, 0.7848, 0.7860], device='cuda:0')
# train_recall: tensor([0.7137, 0.8514, 0.7872, 0.5645], device='cuda:0')
# val_loss: 0.4991414450056903
# val_precision: tensor([0.7578, 0.8602, 0.7803, 0.7826], device='cuda:0')
# val_recall: tensor([0.7171, 0.8436, 0.8448, 0.6069], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 77 time:  0.28996211564999613
# --------------------------------
# ========================================
# EPOCH: 78
# train_loss: 0.5382313839141755
# train_precision: tensor([0.7417, 0.8125, 0.7856, 0.7845], device='cuda:0')
# train_recall: tensor([0.7135, 0.8527, 0.7895, 0.5698], device='cuda:0')
# val_loss: 0.49347178637981415
# val_precision: tensor([0.7690, 0.8281, 0.8050, 0.7916], device='cuda:0')
# val_recall: tensor([0.7131, 0.8809, 0.8219, 0.6005], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 78 time:  0.2888562929833294
# --------------------------------
# ========================================
# EPOCH: 79
# train_loss: 0.537008038703827
# train_precision: tensor([0.7403, 0.8120, 0.7855, 0.7694], device='cuda:0')
# train_recall: tensor([0.7132, 0.8527, 0.7880, 0.5549], device='cuda:0')
# val_loss: 0.494218894339108
# val_precision: tensor([0.7555, 0.8568, 0.7904, 0.7995], device='cuda:0')
# val_recall: tensor([0.7290, 0.8463, 0.8383, 0.5928], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 79 time:  0.2912886644333336
# --------------------------------
# ========================================
# EPOCH: 80
# train_loss: 0.5352800987113541
# train_precision: tensor([0.7411, 0.8141, 0.7832, 0.7882], device='cuda:0')
# train_recall: tensor([0.7123, 0.8521, 0.7900, 0.5701], device='cuda:0')
# val_loss: 0.4946895602282944
# val_precision: tensor([0.7548, 0.8176, 0.8274, 0.7567], device='cuda:0')
# val_recall: tensor([0.7302, 0.8906, 0.7899, 0.6269], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 80 time:  0.28945783308333073
# --------------------------------
# ========================================
# EPOCH: 81
# train_loss: 0.5364397955441225
# train_precision: tensor([0.7389, 0.8134, 0.7857, 0.7829], device='cuda:0')
# train_recall: tensor([0.7135, 0.8525, 0.7884, 0.5643], device='cuda:0')
# val_loss: 0.4909926830054997
# val_precision: tensor([0.7500, 0.8515, 0.8018, 0.7908], device='cuda:0')
# val_recall: tensor([0.7378, 0.8533, 0.8237, 0.6128], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 81 time:  0.2964749178666655
# --------------------------------
# ========================================
# EPOCH: 82
# train_loss: 0.5330073811571816
# train_precision: tensor([0.7410, 0.8136, 0.7869, 0.7924], device='cuda:0')
# train_recall: tensor([0.7148, 0.8516, 0.7909, 0.5764], device='cuda:0')
# val_loss: 0.49308405879077377
# val_precision: tensor([0.7447, 0.8377, 0.8223, 0.7125], device='cuda:0')
# val_recall: tensor([0.7444, 0.8694, 0.7958, 0.6669], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 82 time:  0.2915737815833305
# --------------------------------
# ========================================
# EPOCH: 83
# train_loss: 0.5337404506853496
# train_precision: tensor([0.7422, 0.8143, 0.7868, 0.7803], device='cuda:0')
# train_recall: tensor([0.7146, 0.8539, 0.7905, 0.5683], device='cuda:0')
# val_loss: 0.49509682667838945
# val_precision: tensor([0.7830, 0.8276, 0.7922, 0.7815], device='cuda:0')
# val_recall: tensor([0.6904, 0.8826, 0.8387, 0.6157], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 83 time:  0.28955547293333744
# --------------------------------
# ========================================
# EPOCH: 84
# train_loss: 0.5336323885814004
# train_precision: tensor([0.7413, 0.8123, 0.7865, 0.7866], device='cuda:0')
# train_recall: tensor([0.7131, 0.8531, 0.7898, 0.5723], device='cuda:0')
# val_loss: 0.49139559831652607
# val_precision: tensor([0.7493, 0.8404, 0.8132, 0.7705], device='cuda:0')
# val_recall: tensor([0.7380, 0.8669, 0.8103, 0.6134], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 84 time:  0.2883196532500051
# --------------------------------
# ========================================
# EPOCH: 85
# train_loss: 0.5341314042079216
# train_precision: tensor([0.7413, 0.8130, 0.7866, 0.7897], device='cuda:0')
# train_recall: tensor([0.7148, 0.8515, 0.7902, 0.5764], device='cuda:0')
# val_loss: 0.4948167377835387
# val_precision: tensor([0.7668, 0.8510, 0.7854, 0.7603], device='cuda:0')
# val_recall: tensor([0.7102, 0.8570, 0.8424, 0.6281], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 85 time:  0.291445015749999
# --------------------------------
# ========================================
# EPOCH: 86
# train_loss: 0.5322222788741385
# train_precision: tensor([0.7414, 0.8149, 0.7871, 0.7811], device='cuda:0')
# train_recall: tensor([0.7153, 0.8537, 0.7900, 0.5728], device='cuda:0')
# val_loss: 0.4914707465396894
# val_precision: tensor([0.7517, 0.8529, 0.8024, 0.7416], device='cuda:0')
# val_recall: tensor([0.7392, 0.8549, 0.8192, 0.6510], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 86 time:  0.2908391040499964
# --------------------------------
# ========================================
# EPOCH: 87
# train_loss: 0.5313379248042872
# train_precision: tensor([0.7419, 0.8163, 0.7872, 0.7854], device='cuda:0')
# train_recall: tensor([0.7162, 0.8530, 0.7911, 0.5822], device='cuda:0')
# val_loss: 0.4922280816973506
# val_precision: tensor([0.7434, 0.8602, 0.8034, 0.7818], device='cuda:0')
# val_recall: tensor([0.7512, 0.8422, 0.8227, 0.6146], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 87 time:  0.28887372186666954
# --------------------------------
# ========================================
# EPOCH: 88
# train_loss: 0.5322006641031205
# train_precision: tensor([0.7432, 0.8143, 0.7872, 0.7833], device='cuda:0')
# train_recall: tensor([0.7167, 0.8531, 0.7907, 0.5713], device='cuda:0')
# val_loss: 0.4899853578397444
# val_precision: tensor([0.7486, 0.8597, 0.8030, 0.7548], device='cuda:0')
# val_recall: tensor([0.7451, 0.8455, 0.8271, 0.6404], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 88 time:  0.2875714846000013
# --------------------------------
# ========================================
# EPOCH: 89
# train_loss: 0.530787114305296
# train_precision: tensor([0.7432, 0.8139, 0.7884, 0.7765], device='cuda:0')
# train_recall: tensor([0.7151, 0.8552, 0.7905, 0.5736], device='cuda:0')
# val_loss: 0.4898342750706039
# val_precision: tensor([0.7455, 0.8511, 0.8116, 0.7754], device='cuda:0')
# val_recall: tensor([0.7502, 0.8540, 0.8148, 0.6146], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 89 time:  0.2849869248833329
# --------------------------------
# ========================================
# EPOCH: 90
# train_loss: 0.5297382132581685
# train_precision: tensor([0.7424, 0.8165, 0.7864, 0.7915], device='cuda:0')
# train_recall: tensor([0.7170, 0.8536, 0.7905, 0.5769], device='cuda:0')
# val_loss: 0.49178167792050154
# val_precision: tensor([0.7615, 0.8582, 0.7881, 0.7522], device='cuda:0')
# val_recall: tensor([0.7255, 0.8470, 0.8401, 0.6387], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 90 time:  0.2816568882833356
# --------------------------------
# ========================================
# EPOCH: 91
# train_loss: 0.5298900958569511
# train_precision: tensor([0.7430, 0.8147, 0.7858, 0.7957], device='cuda:0')
# train_recall: tensor([0.7155, 0.8537, 0.7900, 0.5811], device='cuda:0')
# val_loss: 0.4906457540663806
# val_precision: tensor([0.7533, 0.8438, 0.8086, 0.7774], device='cuda:0')
# val_recall: tensor([0.7353, 0.8663, 0.8166, 0.6116], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 91 time:  0.278525061549999
# --------------------------------
# ========================================
# EPOCH: 92
# train_loss: 0.5308745889917486
# train_precision: tensor([0.7415, 0.8147, 0.7859, 0.7830], device='cuda:0')
# train_recall: tensor([0.7147, 0.8549, 0.7881, 0.5748], device='cuda:0')
# val_loss: 0.4885507112408018
# val_precision: tensor([0.7393, 0.8513, 0.8172, 0.7893], device='cuda:0')
# val_recall: tensor([0.7598, 0.8547, 0.8043, 0.6163], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 92 time:  0.283786121549997
# --------------------------------
# ========================================
# EPOCH: 93
# train_loss: 0.5287150660197417
# train_precision: tensor([0.7443, 0.8166, 0.7877, 0.7836], device='cuda:0')
# train_recall: tensor([0.7172, 0.8553, 0.7916, 0.5766], device='cuda:0')
# val_loss: 0.4909823411828154
# val_precision: tensor([0.7614, 0.8515, 0.7924, 0.7634], device='cuda:0')
# val_recall: tensor([0.7214, 0.8551, 0.8365, 0.6293], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 93 time:  0.2837430488500028
# --------------------------------
# ========================================
# EPOCH: 94
# train_loss: 0.5290782244755946
# train_precision: tensor([0.7447, 0.8145, 0.7874, 0.7873], device='cuda:0')
# train_recall: tensor([0.7165, 0.8551, 0.7904, 0.5791], device='cuda:0')
# val_loss: 0.49078679710001377
# val_precision: tensor([0.7500, 0.8632, 0.7967, 0.7760], device='cuda:0')
# val_recall: tensor([0.7458, 0.8414, 0.8297, 0.6310], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 94 time:  0.28015808416666915
# --------------------------------
# ========================================
# EPOCH: 95
# train_loss: 0.5276868475609455
# train_precision: tensor([0.7441, 0.8144, 0.7878, 0.7997], device='cuda:0')
# train_recall: tensor([0.7172, 0.8536, 0.7905, 0.5955], device='cuda:0')
# val_loss: 0.4911116762803151
# val_precision: tensor([0.7579, 0.8224, 0.8261, 0.7450], device='cuda:0')
# val_recall: tensor([0.7310, 0.8870, 0.7971, 0.6504], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 95 time:  0.28027907199999996
# --------------------------------
# ========================================
# EPOCH: 96
# train_loss: 0.5284037140534557
# train_precision: tensor([0.7430, 0.8156, 0.7891, 0.7860], device='cuda:0')
# train_recall: tensor([0.7194, 0.8534, 0.7901, 0.5814], device='cuda:0')
# val_loss: 0.4977180745218184
# val_precision: tensor([0.7594, 0.8672, 0.7781, 0.7883], device='cuda:0')
# val_recall: tensor([0.7237, 0.8358, 0.8514, 0.5928], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 96 time:  0.2816155359666709
# --------------------------------
# ========================================
# EPOCH: 97
# train_loss: 0.5255954650299124
# train_precision: tensor([0.7455, 0.8150, 0.7891, 0.7973], device='cuda:0')
# train_recall: tensor([0.7164, 0.8545, 0.7938, 0.5907], device='cuda:0')
# val_loss: 0.48973029633085213
# val_precision: tensor([0.7457, 0.8619, 0.8036, 0.7973], device='cuda:0')
# val_recall: tensor([0.7546, 0.8433, 0.8241, 0.5987], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 97 time:  0.2816355378666685
# --------------------------------
# ========================================
# EPOCH: 98
# train_loss: 0.5271500336087268
# train_precision: tensor([0.7464, 0.8134, 0.7913, 0.7823], device='cuda:0')
# train_recall: tensor([0.7189, 0.8550, 0.7926, 0.5751], device='cuda:0')
# val_loss: 0.4868800298317329
# val_precision: tensor([0.7620, 0.8360, 0.8095, 0.7890], device='cuda:0')
# val_recall: tensor([0.7271, 0.8752, 0.8189, 0.6063], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 98 time:  0.29186290043333735
# --------------------------------
# ========================================
# EPOCH: 99
# train_loss: 0.5281641293858839
# train_precision: tensor([0.7449, 0.8161, 0.7886, 0.7847], device='cuda:0')
# train_recall: tensor([0.7174, 0.8541, 0.7927, 0.5887], device='cuda:0')
# val_loss: 0.4920355152416896
# val_precision: tensor([0.7544, 0.8603, 0.7888, 0.8588], device='cuda:0')
# val_recall: tensor([0.7353, 0.8436, 0.8409, 0.5358], device='cuda:0')
# Learning rate: 0.00034837736011140584
# epoch 99 time:  0.28269758281667234
# --------------------------------
# training_checkpoints/efficient_net_b0_after_tune22024-07-15 23:01:36.195288.pth
# <All keys matched successfully>

# %%
from sklearn.metrics import confusion_matrix, classification_report
from torch.utils.data import DataLoader
import numpy as np
import torch 
import torch.nn as nn
my_model.load_state_dict(torch.load(f'{run_path}.pth'))

def test_report(model, dataloader):
    """Prints confusion matrix for testing dataset
    dataloader should be of batch_size=1."""

    y_pred = []
    y_test = []
    model.eval()
    with torch.no_grad():
        for data, label in dataloader:
            output = model(data)
            label = label.numpy()
            output = output.numpy()
            y_pred.append(np.argmax(output))
            y_test.append(np.argmax(label))
        print(confusion_matrix(y_test, y_pred))
        print(classification_report(y_test, y_pred))

testset =ImageDataset(data_path='test_data', transform=transform_test, reduce=True)
dataloader = DataLoader(testset, batch_size=1, shuffle=True)

test_report(my_model.to('cpu'), dataloader)
# Out:
# [[602  88 151   4]
#  [ 79 767  43   0]
#  [114  41 752   1]
#  [  7   5  10  36]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.71      0.73       845
#            1       0.85      0.86      0.86       889
#            2       0.79      0.83      0.81       908
#            3       0.88      0.62      0.73        58
#
#     accuracy                           0.80      2700
#    macro avg       0.82      0.76      0.78      2700
# weighted avg       0.80      0.80      0.80      2700
