# %%
import time
import sys
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from dataset import ImageDataset
import torch.nn.functional as F
from torchmetrics import Precision, Recall
from torchvision.models import resnet18
import warnings
from collections import defaultdict
import wandb
import datetime
import os
import torchvision.models as models
import torch.nn as nn
warnings.filterwarnings('ignore')
torch.set_float32_matmul_precision('high')
#intecubic interpol

run_name = f'efficient_norm_b0_16batch{datetime.datetime.now()}'
run_path = f'training_checkpoints/{run_name}'

wandb.init(project="cells", 
           entity="adamsoja",
          name=run_name)

import random
random.seed(2233)
torch.manual_seed(2233)

#After /255 so in loading dataset there are no division by 255 just this normalization
mean = [0.5006, 0.3526, 0.5495]
std = [0.1493, 0.1341, 0.1124]


from albumentations import (
    Compose,
    Resize,
    OneOf,
    RandomBrightness,
    RandomContrast,
    MotionBlur,
    MedianBlur,
    GaussianBlur,
    VerticalFlip,
    HorizontalFlip,
    ShiftScaleRotate,
    Normalize,
)

transform = Compose(
    [
        Normalize(mean=mean, std=std),
        OneOf([RandomBrightness(limit=0.1, p=1), RandomContrast(limit=0.1, p=1)]),
        OneOf([MotionBlur(blur_limit=3), MedianBlur(blur_limit=3), GaussianBlur(blur_limit=3),], p=0.7,),
        VerticalFlip(p=0.5),
        HorizontalFlip(p=0.5),
    ]
)

transform_test = Compose(
    [Normalize(mean=mean, std=std)]
)

class EfficientNetB0(nn.Module):
    def __init__(self, num_classes=4):
        super(EfficientNetB0, self).__init__()
        self.base_model = models.efficientnet_b0(pretrained=False)
        num_ftrs = self.base_model.classifier[1].in_features
        self.base_model.classifier[1] = nn.Linear(num_ftrs, num_classes)

    def forward(self, x):
        return self.base_model(x)



class MyModel(nn.Module):
    def __init__(self, model, learning_rate, weight_decay):
        super(MyModel, self).__init__()
        self.model = model
        self.learning_rate = learning_rate
        self.weight_decay = weight_decay
        self.criterion = nn.CrossEntropyLoss()
        self.metric_precision = Precision(task="multiclass", num_classes=4, average=None).to('cuda')
        self.metric_recall = Recall(task="multiclass", num_classes=4, average=None).to('cuda')
        self.train_loss = []
        self.valid_loss = []
        self.precision_per_epochs = []
        self.recall_per_epochs = []

        self.optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, mode="min", factor=0.05, patience=4, min_lr=5e-6, verbose=True)
        self.step = 0

    
    def forward(self, x):
        return self.model(x)

    def train_one_epoch(self, trainloader):
        self.step += 1
        self.train()
        for batch_idx, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()
            _, preds = torch.max(outputs, 1)
            _, labels = torch.max(labels, 1)
            self.metric_precision(preds, labels)
            self.metric_recall(preds, labels)
            self.train_loss.append(loss.item())


        

        
        avg_loss = np.mean(self.train_loss)
        self.train_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        self.precision_per_epochs.append(precision)
        self.recall_per_epochs.append(recall)
        print(f'train_loss: {avg_loss}')
        print(f'train_precision: {precision}')
        print(f'train_recall: {recall}')

        wandb.log({'loss': avg_loss},step=self.step)
        wandb.log({'Normal precision': precision[0].item()},step=self.step)
        wandb.log({'Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'Other precision': precision[3].item()},step=self.step)


        wandb.log({'Normal recall': recall[0].item()},step=self.step)
        wandb.log({'Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'Other recall': recall[3].item()},step=self.step)
        
        
        self.metric_precision.reset()
        self.metric_recall.reset()


    

    def evaluate(self, testloader):
        self.eval()
        with torch.no_grad():
            for batch_idx, (inputs, labels) in enumerate(testloader):
                inputs, labels = inputs.to('cuda'), labels.to('cuda')
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)
                _, labels = torch.max(labels, 1)
                self.metric_precision(preds, labels)
                self.metric_recall(preds, labels)
                self.valid_loss.append(loss.item())
    
        avg_loss = np.mean(self.valid_loss)
        self.scheduler.step(avg_loss)
        self.valid_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        print(f'val_loss: {avg_loss}')
        print(f'val_precision: {precision}')
        print(f'val_recall: {recall}')
        self.metric_precision.reset()
        self.metric_recall.reset()

        wandb.log({'val_loss': avg_loss}, step=self.step)
        
        wandb.log({'val_Normal precision': precision[0].item()},step=self.step)
        wandb.log({'val_Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'val_Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'val_Other precision': precision[3].item()},step=self.step)


        wandb.log({'val_Normal recall': recall[0].item()},step=self.step)
        wandb.log({'val_Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'val_Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'val_Other recall': recall[3].item()},step=self.step)


        for param_group in self.optimizer.param_groups:
            print(f"Learning rate: {param_group['lr']}")
        return avg_loss

torch.cuda.empty_cache()
batch_size = 16

trainset = ImageDataset(data_path='train_data', transform=transform)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=3)

testset = ImageDataset(data_path='validation_data', transform=transform_test)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)


learning_rate = 0.0001
weight_decay = 0.00001

model = EfficientNetB0()
model = model.to('cuda')


my_model = MyModel(model=model, learning_rate=learning_rate, weight_decay=weight_decay)
my_model = my_model.to('cuda')

num_epochs = 100
early_stop_patience = 10
best_val_loss = float('inf')
best_model_state_dict = None

for epoch in range(num_epochs):
    print('========================================')
    print(f'EPOCH: {epoch}') 
    time_start = time.perf_counter()
    my_model.train_one_epoch(trainloader)
    val_loss = my_model.evaluate(testloader)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_state_dict = my_model.state_dict()
        torch.save(best_model_state_dict, f'{run_path}.pth')
        
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch} with best validation loss {best_val_loss}")
        break
    time_epoch = time.perf_counter() - time_start
    print(f'epoch {epoch} time:  {time_epoch}')
    print('--------------------------------')

# Load the best model state dict
print(f'{run_path}.pth')
my_model.load_state_dict(torch.load(f'{run_path}.pth'))
# Out:
# Finishing last run (ID:361lm70f) before initializing another...
#  View run <strong style="color:#cdcd00">efficient_norm_b0_16batch2024-04-25 01:05:09.159323</strong> at: <a href='https://wandb.ai/adamsoja/cells/runs/361lm70f' target="_blank">https://wandb.ai/adamsoja/cells/runs/361lm70f</a><br/> View project at: <a href='https://wandb.ai/adamsoja/cells' target="_blank">https://wandb.ai/adamsoja/cells</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240425_010510-361lm70f/logs</code>
# Successfully finished last run (ID:361lm70f). Initializing new run:<br/>
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/adam/Desktop/cells_master_thesis/wandb/run-20240425_010546-bczpp86u</code>
# Syncing run <strong><a href='https://wandb.ai/adamsoja/cells/runs/bczpp86u' target="_blank">efficient_norm_b0_16batch2024-04-25 01:05:46.729052</a></strong> to <a href='https://wandb.ai/adamsoja/cells' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adamsoja/cells' target="_blank">https://wandb.ai/adamsoja/cells</a>
#  View run at <a href='https://wandb.ai/adamsoja/cells/runs/bczpp86u' target="_blank">https://wandb.ai/adamsoja/cells/runs/bczpp86u</a>
# ========================================
# EPOCH: 0
# train_loss: 1.062044206202372
# train_precision: tensor([0.4703, 0.5562, 0.5276, 0.0128], device='cuda:0')
# train_recall: tensor([4.3287e-01, 6.6639e-01, 5.1730e-01, 1.4430e-04], device='cuda:0')
# val_loss: 0.955842741720579
# val_precision: tensor([0.5573, 0.7286, 0.5832, 0.0833], device='cuda:0')
# val_recall: tensor([5.3239e-01, 6.2882e-01, 7.4727e-01, 3.3670e-04], device='cuda:0')
# Learning rate: 0.0001
# epoch 0 time:  150.8051055779997
# --------------------------------
# ========================================
# EPOCH: 1
# train_loss: 0.9557654351215756
# train_precision: tensor([0.5432, 0.6281, 0.6152, 0.3709], device='cuda:0')
# train_recall: tensor([0.5188, 0.7248, 0.6084, 0.0081], device='cuda:0')
# val_loss: 0.9537601751984979
# val_precision: tensor([0.5269, 0.6637, 0.6397, 0.1494], device='cuda:0')
# val_recall: tensor([0.5074, 0.6335, 0.7131, 0.1010], device='cuda:0')
# Learning rate: 0.0001
# epoch 1 time:  152.91098758800035
# --------------------------------
# ========================================
# EPOCH: 2
# train_loss: 0.9261896461681216
# train_precision: tensor([0.5582, 0.6378, 0.6334, 0.5214], device='cuda:0')
# train_recall: tensor([0.5308, 0.7398, 0.6230, 0.0299], device='cuda:0')
# val_loss: 0.8759457595031434
# val_precision: tensor([0.6249, 0.6884, 0.6593, 0.2538], device='cuda:0')
# val_recall: tensor([0.5385, 0.7730, 0.6896, 0.1761], device='cuda:0')
# Learning rate: 0.0001
# epoch 2 time:  153.5854190170012
# --------------------------------
# ========================================
# EPOCH: 3
# train_loss: 0.9238757731603424
# train_precision: tensor([0.5565, 0.6442, 0.6323, 0.5269], device='cuda:0')
# train_recall: tensor([0.5292, 0.7440, 0.6246, 0.0325], device='cuda:0')
# val_loss: 1.0118433950208354
# val_precision: tensor([0.4937, 0.7734, 0.5711, 0.0574], device='cuda:0')
# val_recall: tensor([0.5983, 0.6759, 0.5631, 0.0162], device='cuda:0')
# Learning rate: 0.0001
# epoch 3 time:  153.4209784350005
# --------------------------------
# ========================================
# EPOCH: 4
# train_loss: 0.9126169153111081
# train_precision: tensor([0.5583, 0.6545, 0.6351, 0.5287], device='cuda:0')
# train_recall: tensor([0.5356, 0.7465, 0.6327, 0.0199], device='cuda:0')
# val_loss: 0.8634113142326746
# val_precision: tensor([0.5851, 0.7523, 0.6619, 0.1914], device='cuda:0')
# val_recall: tensor([0.6042, 0.7248, 0.6879, 0.1232], device='cuda:0')
# Learning rate: 0.0001
# epoch 4 time:  154.00124120800137
# --------------------------------
# ========================================
# EPOCH: 5
# train_loss: 0.8911519170499943
# train_precision: tensor([0.5700, 0.6651, 0.6437, 0.5865], device='cuda:0')
# train_recall: tensor([0.5466, 0.7536, 0.6430, 0.0528], device='cuda:0')
# val_loss: 0.8607434207879389
# val_precision: tensor([0.6018, 0.7107, 0.6992, 0.2620], device='cuda:0')
# val_recall: tensor([0.5939, 0.7916, 0.6473, 0.1926], device='cuda:0')
# Learning rate: 0.0001
# epoch 5 time:  155.83882273400013
# --------------------------------
# ========================================
# EPOCH: 6
# train_loss: 0.889471219913189
# train_precision: tensor([0.5756, 0.6620, 0.6467, 0.5878], device='cuda:0')
# train_recall: tensor([0.5521, 0.7500, 0.6449, 0.0623], device='cuda:0')
# val_loss: 0.8314967215579039
# val_precision: tensor([0.6243, 0.7244, 0.6621, 0.3640], device='cuda:0')
# val_recall: tensor([0.5851, 0.7646, 0.6966, 0.2010], device='cuda:0')
# Learning rate: 0.0001
# epoch 6 time:  154.87561465600083
# --------------------------------
# ========================================
# EPOCH: 7
# train_loss: 0.8876951379032707
# train_precision: tensor([0.5795, 0.6562, 0.6513, 0.6214], device='cuda:0')
# train_recall: tensor([0.5448, 0.7584, 0.6472, 0.0654], device='cuda:0')
# val_loss: 0.8352293093136142
# val_precision: tensor([0.6306, 0.7299, 0.6474, 0.3586], device='cuda:0')
# val_recall: tensor([0.5709, 0.7507, 0.7254, 0.1640], device='cuda:0')
# Learning rate: 0.0001
# epoch 7 time:  143.40882529600094
# --------------------------------
# ========================================
# EPOCH: 8
# train_loss: 0.8733792027234232
# train_precision: tensor([0.5876, 0.6642, 0.6541, 0.6161], device='cuda:0')
# train_recall: tensor([0.5492, 0.7628, 0.6561, 0.0861], device='cuda:0')
# val_loss: 0.819226594948955
# val_precision: tensor([0.6206, 0.7163, 0.7154, 0.4991], device='cuda:0')
# val_recall: tensor([0.6198, 0.8042, 0.6720, 0.1956], device='cuda:0')
# Learning rate: 0.0001
# epoch 8 time:  143.93903228400086
# --------------------------------
# ========================================
# EPOCH: 9
# train_loss: 0.867326023751416
# train_precision: tensor([0.5869, 0.6688, 0.6589, 0.6152], device='cuda:0')
# train_recall: tensor([0.5586, 0.7624, 0.6543, 0.0937], device='cuda:0')
# val_loss: 0.8221595026481473
# val_precision: tensor([0.6195, 0.7717, 0.6683, 0.4411], device='cuda:0')
# val_recall: tensor([0.6083, 0.7402, 0.7382, 0.2394], device='cuda:0')
# Learning rate: 0.0001
# epoch 9 time:  143.73223883599894
# --------------------------------
# ========================================
# EPOCH: 10
# train_loss: 0.8556748723636622
# train_precision: tensor([0.5888, 0.6759, 0.6618, 0.6184], device='cuda:0')
# train_recall: tensor([0.5616, 0.7628, 0.6622, 0.1055], device='cuda:0')
# val_loss: 0.8446438046562268
# val_precision: tensor([0.6111, 0.7481, 0.6781, 0.4233], device='cuda:0')
# val_recall: tensor([0.6032, 0.7685, 0.7015, 0.2165], device='cuda:0')
# Learning rate: 0.0001
# epoch 10 time:  143.47183535299882
# --------------------------------
# ========================================
# EPOCH: 11
# train_loss: 0.8499819730255408
# train_precision: tensor([0.5882, 0.6825, 0.6643, 0.5922], device='cuda:0')
# train_recall: tensor([0.5648, 0.7642, 0.6656, 0.1075], device='cuda:0')
# val_loss: 0.8049601406299167
# val_precision: tensor([0.6505, 0.7625, 0.6435, 0.4772], device='cuda:0')
# val_recall: tensor([0.5525, 0.7499, 0.7728, 0.3165], device='cuda:0')
# Learning rate: 0.0001
# epoch 11 time:  143.52426299999934
# --------------------------------
# ========================================
# EPOCH: 12
# train_loss: 0.8463462879872246
# train_precision: tensor([0.5930, 0.6809, 0.6668, 0.5868], device='cuda:0')
# train_recall: tensor([0.5684, 0.7674, 0.6626, 0.1209], device='cuda:0')
# val_loss: 0.799021992390307
# val_precision: tensor([0.6301, 0.7849, 0.6456, 0.4688], device='cuda:0')
# val_recall: tensor([0.5617, 0.7216, 0.7902, 0.3061], device='cuda:0')
# Learning rate: 0.0001
# epoch 12 time:  143.35853239300013
# --------------------------------
# ========================================
# EPOCH: 13
# train_loss: 0.8425201444457344
# train_precision: tensor([0.5945, 0.6815, 0.6685, 0.6146], device='cuda:0')
# train_recall: tensor([0.5737, 0.7664, 0.6613, 0.1300], device='cuda:0')
# val_loss: 0.7810690747562644
# val_precision: tensor([0.6466, 0.7806, 0.6389, 0.5537], device='cuda:0')
# val_recall: tensor([0.5560, 0.7304, 0.7987, 0.3003], device='cuda:0')
# Learning rate: 0.0001
# epoch 13 time:  143.7123357879991
# --------------------------------
# ========================================
# EPOCH: 14
# train_loss: 0.8453035531936633
# train_precision: tensor([0.5953, 0.6774, 0.6650, 0.5879], device='cuda:0')
# train_recall: tensor([0.5649, 0.7639, 0.6635, 0.1505], device='cuda:0')
# val_loss: 0.7709278144906854
# val_precision: tensor([0.6279, 0.7841, 0.6635, 0.5496], device='cuda:0')
# val_recall: tensor([0.6105, 0.7291, 0.7634, 0.2593], device='cuda:0')
# Learning rate: 0.0001
# epoch 14 time:  143.4257711750015
# --------------------------------
# ========================================
# EPOCH: 15
# train_loss: 0.8320513799206147
# train_precision: tensor([0.6012, 0.6841, 0.6746, 0.5788], device='cuda:0')
# train_recall: tensor([0.5699, 0.7746, 0.6699, 0.1543], device='cuda:0')
# val_loss: 0.7732451992072198
# val_precision: tensor([0.6424, 0.7359, 0.6890, 0.5737], device='cuda:0')
# val_recall: tensor([0.5787, 0.7965, 0.7336, 0.3000], device='cuda:0')
# Learning rate: 0.0001
# epoch 15 time:  143.32339670799956
# --------------------------------
# ========================================
# EPOCH: 16
# train_loss: 0.8248413836773131
# train_precision: tensor([0.6077, 0.6875, 0.6751, 0.5946], device='cuda:0')
# train_recall: tensor([0.5709, 0.7779, 0.6756, 0.1674], device='cuda:0')
# val_loss: 0.7694288067772117
# val_precision: tensor([0.6373, 0.7848, 0.6813, 0.7451], device='cuda:0')
# val_recall: tensor([0.6297, 0.7381, 0.7708, 0.2973], device='cuda:0')
# Learning rate: 0.0001
# epoch 16 time:  143.87474821400065
# --------------------------------
# ========================================
# EPOCH: 17
# train_loss: 0.8210087408834446
# train_precision: tensor([0.6122, 0.6875, 0.6759, 0.5939], device='cuda:0')
# train_recall: tensor([0.5709, 0.7796, 0.6783, 0.1775], device='cuda:0')
# val_loss: 0.8212980781142137
# val_precision: tensor([0.6246, 0.7719, 0.6655, 0.7591], device='cuda:0')
# val_recall: tensor([0.5971, 0.7114, 0.7882, 0.2886], device='cuda:0')
# Learning rate: 0.0001
# epoch 17 time:  142.90502283100068
# --------------------------------
# ========================================
# EPOCH: 18
# train_loss: 0.814968519407204
# train_precision: tensor([0.6137, 0.6928, 0.6764, 0.6226], device='cuda:0')
# train_recall: tensor([0.5776, 0.7804, 0.6775, 0.1924], device='cuda:0')
# val_loss: 0.753116157715679
# val_precision: tensor([0.6651, 0.7867, 0.6600, 0.7562], device='cuda:0')
# val_recall: tensor([0.5838, 0.7613, 0.8020, 0.2997], device='cuda:0')
# Learning rate: 0.0001
# epoch 18 time:  143.77814506800132
# --------------------------------
# ========================================
# EPOCH: 19
# train_loss: 0.8199700329059055
# train_precision: tensor([0.6089, 0.6879, 0.6773, 0.5730], device='cuda:0')
# train_recall: tensor([0.5759, 0.7764, 0.6728, 0.1853], device='cuda:0')
# val_loss: 0.8127231504221153
# val_precision: tensor([0.6168, 0.7656, 0.7179, 0.6051], device='cuda:0')
# val_recall: tensor([0.6645, 0.7483, 0.7119, 0.3246], device='cuda:0')
# Learning rate: 0.0001
# epoch 19 time:  143.11121715599802
# --------------------------------
# ========================================
# EPOCH: 20
# train_loss: 0.8136350697018397
# train_precision: tensor([0.6151, 0.6936, 0.6755, 0.6019], device='cuda:0')
# train_recall: tensor([0.5763, 0.7801, 0.6783, 0.2055], device='cuda:0')
# val_loss: 0.9828686217501513
# val_precision: tensor([0.6048, 0.7453, 0.6832, 0.6602], device='cuda:0')
# val_recall: tensor([0.5991, 0.6987, 0.7660, 0.3343], device='cuda:0')
# Learning rate: 0.0001
# epoch 20 time:  143.28430934900098
# --------------------------------
# ========================================
# EPOCH: 21
# train_loss: 0.8155537663518588
# train_precision: tensor([0.6152, 0.6883, 0.6777, 0.5809], device='cuda:0')
# train_recall: tensor([0.5768, 0.7802, 0.6738, 0.2014], device='cuda:0')
# val_loss: 0.7953111620699189
# val_precision: tensor([0.6467, 0.7369, 0.6579, 0.8996], device='cuda:0')
# val_recall: tensor([0.5704, 0.7368, 0.7864, 0.2051], device='cuda:0')
# Learning rate: 0.0001
# epoch 21 time:  143.16640570099844
# --------------------------------
# ========================================
# EPOCH: 22
# train_loss: 0.8119737597337348
# train_precision: tensor([0.6146, 0.6945, 0.6782, 0.5900], device='cuda:0')
# train_recall: tensor([0.5806, 0.7779, 0.6793, 0.1973], device='cuda:0')
# val_loss: 0.759210909578098
# val_precision: tensor([0.6541, 0.7825, 0.6713, 0.6183], device='cuda:0')
# val_recall: tensor([0.6081, 0.7435, 0.7810, 0.3512], device='cuda:0')
# Learning rate: 0.0001
# epoch 22 time:  143.351660368
# --------------------------------
# ========================================
# EPOCH: 23
# train_loss: 0.8055359876043986
# train_precision: tensor([0.6168, 0.6963, 0.6808, 0.6003], device='cuda:0')
# train_recall: tensor([0.5792, 0.7800, 0.6844, 0.2124], device='cuda:0')
# val_loss: 0.792157826197862
# val_precision: tensor([0.6847, 0.7259, 0.6589, 0.6875], device='cuda:0')
# val_recall: tensor([0.5644, 0.7620, 0.7748, 0.3438], device='cuda:0')
# Learning rate: 5e-06
# epoch 23 time:  143.52220305800074
# --------------------------------
# ========================================
# EPOCH: 24
# train_loss: 0.7914677959432408
# train_precision: tensor([0.6260, 0.7016, 0.6846, 0.6029], device='cuda:0')
# train_recall: tensor([0.5808, 0.7863, 0.6929, 0.2362], device='cuda:0')
# val_loss: 0.733409213965401
# val_precision: tensor([0.6595, 0.7823, 0.6782, 0.7283], device='cuda:0')
# val_recall: tensor([0.6103, 0.7559, 0.7881, 0.3357], device='cuda:0')
# Learning rate: 5e-06
# epoch 24 time:  143.94938754800023
# --------------------------------
# ========================================
# EPOCH: 25
# train_loss: 0.7866147497573559
# train_precision: tensor([0.6277, 0.7037, 0.6875, 0.6070], device='cuda:0')
# train_recall: tensor([0.5876, 0.7853, 0.6938, 0.2367], device='cuda:0')
# val_loss: 0.7784170162097772
# val_precision: tensor([0.6476, 0.7854, 0.6538, 0.6499], device='cuda:0')
# val_recall: tensor([0.6043, 0.6995, 0.7993, 0.3488], device='cuda:0')
# Learning rate: 5e-06
# epoch 25 time:  143.32981755799847
# --------------------------------
# ========================================
# EPOCH: 26
# train_loss: 0.7834103848526304
# train_precision: tensor([0.6266, 0.7075, 0.6885, 0.6250], device='cuda:0')
# train_recall: tensor([0.5873, 0.7883, 0.6945, 0.2485], device='cuda:0')
# val_loss: 0.7512845588600398
# val_precision: tensor([0.6540, 0.7882, 0.6713, 0.7134], device='cuda:0')
# val_recall: tensor([0.6274, 0.7319, 0.7816, 0.3394], device='cuda:0')
# Learning rate: 5e-06
# epoch 26 time:  143.1991681039981
# --------------------------------
# ========================================
# EPOCH: 27
# train_loss: 0.7796561213809096
# train_precision: tensor([0.6293, 0.7094, 0.6902, 0.6215], device='cuda:0')
# train_recall: tensor([0.5922, 0.7897, 0.6937, 0.2532], device='cuda:0')
# val_loss: 0.944156559480987
# val_precision: tensor([0.6231, 0.7524, 0.6290, 0.6573], device='cuda:0')
# val_recall: tensor([0.5979, 0.6123, 0.8004, 0.3559], device='cuda:0')
# Learning rate: 5e-06
# epoch 27 time:  143.69558586600033
# --------------------------------
# ========================================
# EPOCH: 28
# train_loss: 0.7785597687024339
# train_precision: tensor([0.6307, 0.7067, 0.6915, 0.6150], device='cuda:0')
# train_recall: tensor([0.5939, 0.7897, 0.6918, 0.2485], device='cuda:0')
# val_loss: 0.8225789438994628
# val_precision: tensor([0.6215, 0.7769, 0.6625, 0.6549], device='cuda:0')
# val_recall: tensor([0.6239, 0.6596, 0.7896, 0.3616], device='cuda:0')
# Learning rate: 5e-06
# epoch 28 time:  143.37433929100007
# --------------------------------
# ========================================
# EPOCH: 29
# train_loss: 0.7796756100355402
# train_precision: tensor([0.6305, 0.7087, 0.6907, 0.6155], device='cuda:0')
# train_recall: tensor([0.5934, 0.7881, 0.6952, 0.2481], device='cuda:0')
# val_loss: 0.7332102108012066
# val_precision: tensor([0.6535, 0.7940, 0.6803, 0.7190], device='cuda:0')
# val_recall: tensor([0.6322, 0.7445, 0.7812, 0.3360], device='cuda:0')
# Learning rate: 5e-06
# epoch 29 time:  144.03509402400232
# --------------------------------
# ========================================
# EPOCH: 30
# train_loss: 0.7773038170254576
# train_precision: tensor([0.6303, 0.7097, 0.6908, 0.6156], device='cuda:0')
# train_recall: tensor([0.5941, 0.7901, 0.6943, 0.2410], device='cuda:0')
# val_loss: 0.8187097901292307
# val_precision: tensor([0.6491, 0.7878, 0.6283, 0.6429], device='cuda:0')
# val_recall: tensor([0.5826, 0.6566, 0.8249, 0.3606], device='cuda:0')
# Learning rate: 5e-06
# epoch 30 time:  142.87118424299842
# --------------------------------
# ========================================
# EPOCH: 31
# train_loss: 0.7763696890949999
# train_precision: tensor([0.6320, 0.7098, 0.6905, 0.6247], device='cuda:0')
# train_recall: tensor([0.5939, 0.7899, 0.6953, 0.2537], device='cuda:0')
# val_loss: 0.7522891527616283
# val_precision: tensor([0.6403, 0.7886, 0.6821, 0.7058], device='cuda:0')
# val_recall: tensor([0.6515, 0.7192, 0.7647, 0.3481], device='cuda:0')
# Learning rate: 5e-06
# epoch 31 time:  143.17927019800118
# --------------------------------
# ========================================
# EPOCH: 32
# train_loss: 0.7750202019447064
# train_precision: tensor([0.6325, 0.7097, 0.6919, 0.6242], device='cuda:0')
# train_recall: tensor([0.5941, 0.7894, 0.6966, 0.2610], device='cuda:0')
# val_loss: 0.7882346693170682
# val_precision: tensor([0.6213, 0.7937, 0.6713, 0.8081], device='cuda:0')
# val_recall: tensor([0.6495, 0.6729, 0.7851, 0.3007], device='cuda:0')
# Learning rate: 5e-06
# epoch 32 time:  143.6761531230004
# --------------------------------
# ========================================
# EPOCH: 33
# train_loss: 0.7742612450513657
# train_precision: tensor([0.6311, 0.7105, 0.6919, 0.6278], device='cuda:0')
# train_recall: tensor([0.5942, 0.7891, 0.6964, 0.2595], device='cuda:0')
# val_loss: 0.741416264237993
# val_precision: tensor([0.6467, 0.8045, 0.6719, 0.7233], device='cuda:0')
# val_recall: tensor([0.6296, 0.7196, 0.7969, 0.3327], device='cuda:0')
# Learning rate: 5e-06
# epoch 33 time:  143.53382667499682
# --------------------------------
# ========================================
# EPOCH: 34
# train_loss: 0.7742665033911508
# train_precision: tensor([0.6291, 0.7106, 0.6889, 0.6263], device='cuda:0')
# train_recall: tensor([0.5915, 0.7870, 0.6959, 0.2636], device='cuda:0')
# val_loss: 0.8687053235171672
# val_precision: tensor([0.6195, 0.7735, 0.6571, 0.7278], device='cuda:0')
# val_recall: tensor([0.6672, 0.6348, 0.7599, 0.3340], device='cuda:0')
# Learning rate: 5e-06
# epoch 34 time:  143.38928803700037
# --------------------------------
# ========================================
# EPOCH: 35
# train_loss: 0.7742907513392747
# train_precision: tensor([0.6324, 0.7121, 0.6898, 0.6224], device='cuda:0')
# train_recall: tensor([0.5954, 0.7871, 0.6975, 0.2616], device='cuda:0')
# val_loss: 0.7537658728018313
# val_precision: tensor([0.6211, 0.7914, 0.6973, 0.7016], device='cuda:0')
# val_recall: tensor([0.6639, 0.7042, 0.7601, 0.3586], device='cuda:0')
# Learning rate: 5e-06
# epoch 35 time:  143.48437904399907
# --------------------------------
# ========================================
# EPOCH: 36
# train_loss: 0.7729893313641611
# train_precision: tensor([0.6342, 0.7114, 0.6897, 0.6332], device='cuda:0')
# train_recall: tensor([0.5919, 0.7900, 0.6996, 0.2655], device='cuda:0')
# val_loss: 0.8976684541675343
# val_precision: tensor([0.6046, 0.7626, 0.6606, 0.6832], device='cuda:0')
# val_recall: tensor([0.6528, 0.6194, 0.7653, 0.3377], device='cuda:0')
# Learning rate: 5e-06
# epoch 36 time:  143.15184265599964
# --------------------------------
# ========================================
# EPOCH: 37
# train_loss: 0.7702134599491767
# train_precision: tensor([0.6335, 0.7125, 0.6919, 0.6305], device='cuda:0')
# train_recall: tensor([0.5956, 0.7894, 0.6982, 0.2706], device='cuda:0')
# val_loss: 0.7964253993318146
# val_precision: tensor([0.6271, 0.7833, 0.6666, 0.7048], device='cuda:0')
# val_recall: tensor([0.6364, 0.6732, 0.7831, 0.3586], device='cuda:0')
# Learning rate: 5e-06
# epoch 37 time:  142.97340730499855
# --------------------------------
# ========================================
# EPOCH: 38
# train_loss: 0.7715056238782959
# train_precision: tensor([0.6307, 0.7133, 0.6918, 0.6141], device='cuda:0')
# train_recall: tensor([0.5950, 0.7883, 0.6981, 0.2595], device='cuda:0')
# val_loss: 0.7273578423971099
# val_precision: tensor([0.6715, 0.8037, 0.6653, 0.7462], device='cuda:0')
# val_recall: tensor([0.6079, 0.7481, 0.8114, 0.3306], device='cuda:0')
# Learning rate: 5e-06
# epoch 38 time:  143.663840727997
# --------------------------------
# ========================================
# EPOCH: 39
# train_loss: 0.7699523229800359
# train_precision: tensor([0.6313, 0.7140, 0.6907, 0.6376], device='cuda:0')
# train_recall: tensor([0.5934, 0.7889, 0.6991, 0.2742], device='cuda:0')
# val_loss: 0.7214121278527506
# val_precision: tensor([0.6554, 0.8024, 0.6869, 0.7481], device='cuda:0')
# val_recall: tensor([0.6375, 0.7480, 0.7902, 0.3350], device='cuda:0')
# Learning rate: 5e-06
# epoch 39 time:  143.7293581189988
# --------------------------------
# ========================================
# EPOCH: 40
# train_loss: 0.7711461043512332
# train_precision: tensor([0.6315, 0.7153, 0.6914, 0.6264], device='cuda:0')
# train_recall: tensor([0.5988, 0.7893, 0.6949, 0.2700], device='cuda:0')
# val_loss: 0.8040997888501265
# val_precision: tensor([0.6432, 0.7883, 0.6509, 0.7532], device='cuda:0')
# val_recall: tensor([0.6339, 0.6703, 0.7955, 0.3165], device='cuda:0')
# Learning rate: 5e-06
# epoch 40 time:  143.4190298629983
# --------------------------------
# ========================================
# EPOCH: 41
# train_loss: 0.7697869049732138
# train_precision: tensor([0.6330, 0.7139, 0.6932, 0.6299], device='cuda:0')
# train_recall: tensor([0.5985, 0.7872, 0.6994, 0.2711], device='cuda:0')
# val_loss: 0.7246085606198224
# val_precision: tensor([0.6665, 0.7919, 0.6772, 0.7282], device='cuda:0')
# val_recall: tensor([0.6182, 0.7555, 0.7932, 0.3428], device='cuda:0')
# Learning rate: 5e-06
# epoch 41 time:  143.54212381899924
# --------------------------------
# ========================================
# EPOCH: 42
# train_loss: 0.7686479342079681
# train_precision: tensor([0.6337, 0.7133, 0.6944, 0.6221], device='cuda:0')
# train_recall: tensor([0.5974, 0.7911, 0.6981, 0.2668], device='cuda:0')
# val_loss: 0.7684268535426344
# val_precision: tensor([0.6439, 0.7790, 0.6778, 0.7217], device='cuda:0')
# val_recall: tensor([0.6425, 0.7163, 0.7714, 0.3222], device='cuda:0')
# Learning rate: 5e-06
# epoch 42 time:  143.4887474240022
# --------------------------------
# ========================================
# EPOCH: 43
# train_loss: 0.769735065146303
# train_precision: tensor([0.6330, 0.7144, 0.6929, 0.6225], device='cuda:0')
# train_recall: tensor([0.5976, 0.7898, 0.6981, 0.2672], device='cuda:0')
# val_loss: 0.7357414989343009
# val_precision: tensor([0.6584, 0.7895, 0.6826, 0.7406], device='cuda:0')
# val_recall: tensor([0.6393, 0.7450, 0.7773, 0.3441], device='cuda:0')
# Learning rate: 5e-06
# epoch 43 time:  143.05125690600107
# --------------------------------
# ========================================
# EPOCH: 44
# train_loss: 0.767267489886971
# train_precision: tensor([0.6339, 0.7147, 0.6960, 0.6303], device='cuda:0')
# train_recall: tensor([0.6009, 0.7912, 0.6975, 0.2704], device='cuda:0')
# val_loss: 0.7203932951058024
# val_precision: tensor([0.6670, 0.7924, 0.6860, 0.7364], device='cuda:0')
# val_recall: tensor([0.6257, 0.7633, 0.7912, 0.3330], device='cuda:0')
# Learning rate: 5e-06
# epoch 44 time:  144.3597071969998
# --------------------------------
# ========================================
# EPOCH: 45
# train_loss: 0.7673697776278425
# train_precision: tensor([0.6324, 0.7152, 0.6932, 0.6209], device='cuda:0')
# train_recall: tensor([0.5968, 0.7914, 0.6975, 0.2709], device='cuda:0')
# val_loss: 0.7268650131884292
# val_precision: tensor([0.6727, 0.8019, 0.6694, 0.7228], device='cuda:0')
# val_recall: tensor([0.6075, 0.7544, 0.8104, 0.3283], device='cuda:0')
# Learning rate: 5e-06
# epoch 45 time:  143.47092327000064
# --------------------------------
# ========================================
# EPOCH: 46
# train_loss: 0.7663313202743618
# train_precision: tensor([0.6352, 0.7146, 0.6935, 0.6417], device='cuda:0')
# train_recall: tensor([0.5970, 0.7922, 0.6990, 0.2814], device='cuda:0')
# val_loss: 0.7236824575866646
# val_precision: tensor([0.6573, 0.7903, 0.6943, 0.7032], device='cuda:0')
# val_recall: tensor([0.6381, 0.7635, 0.7719, 0.3606], device='cuda:0')
# Learning rate: 5e-06
# epoch 46 time:  143.6819466809975
# --------------------------------
# ========================================
# EPOCH: 47
# train_loss: 0.7664399452070794
# train_precision: tensor([0.6346, 0.7160, 0.6940, 0.6204], device='cuda:0')
# train_recall: tensor([0.5989, 0.7914, 0.6993, 0.2684], device='cuda:0')
# val_loss: 0.737404347620872
# val_precision: tensor([0.6446, 0.8104, 0.6795, 0.7776], device='cuda:0')
# val_recall: tensor([0.6486, 0.7234, 0.7876, 0.3273], device='cuda:0')
# Learning rate: 5e-06
# epoch 47 time:  143.2986537020006
# --------------------------------
# ========================================
# EPOCH: 48
# train_loss: 0.7670653788200164
# train_precision: tensor([0.6338, 0.7151, 0.6920, 0.6331], device='cuda:0')
# train_recall: tensor([0.5977, 0.7909, 0.6975, 0.2722], device='cuda:0')
# val_loss: 0.801514142083666
# val_precision: tensor([0.6243, 0.7840, 0.6792, 0.7281], device='cuda:0')
# val_recall: tensor([0.6494, 0.6797, 0.7770, 0.3552], device='cuda:0')
# Learning rate: 5e-06
# epoch 48 time:  143.67981247599892
# --------------------------------
# ========================================
# EPOCH: 49
# train_loss: 0.7667401497758419
# train_precision: tensor([0.6334, 0.7149, 0.6928, 0.6322], device='cuda:0')
# train_recall: tensor([0.5968, 0.7911, 0.6981, 0.2753], device='cuda:0')
# val_loss: 0.7417024146205544
# val_precision: tensor([0.6525, 0.7927, 0.6844, 0.7441], device='cuda:0')
# val_recall: tensor([0.6490, 0.7356, 0.7755, 0.3300], device='cuda:0')
# Learning rate: 5e-06
# epoch 49 time:  143.581920654
# --------------------------------
# ========================================
# EPOCH: 50
# train_loss: 0.7653750552178992
# train_precision: tensor([0.6343, 0.7144, 0.6943, 0.6350], device='cuda:0')
# train_recall: tensor([0.6000, 0.7906, 0.6975, 0.2722], device='cuda:0')
# val_loss: 0.7516309853122092
# val_precision: tensor([0.6531, 0.7906, 0.6726, 0.7578], device='cuda:0')
# val_recall: tensor([0.6334, 0.7216, 0.7885, 0.3424], device='cuda:0')
# Learning rate: 5e-06
# epoch 50 time:  143.47958275800192
# --------------------------------
# ========================================
# EPOCH: 51
# train_loss: 0.7666347403754301
# train_precision: tensor([0.6333, 0.7141, 0.6926, 0.6123], device='cuda:0')
# train_recall: tensor([0.5970, 0.7891, 0.6983, 0.2703], device='cuda:0')
# val_loss: 0.7309597794228694
# val_precision: tensor([0.6494, 0.7926, 0.6894, 0.7370], device='cuda:0')
# val_recall: tensor([0.6418, 0.7392, 0.7812, 0.3377], device='cuda:0')
# Learning rate: 5e-06
# epoch 51 time:  143.24842734599952
# --------------------------------
# ========================================
# EPOCH: 52
# train_loss: 0.765428269272134
# train_precision: tensor([0.6348, 0.7139, 0.6937, 0.6342], device='cuda:0')
# train_recall: tensor([0.5991, 0.7918, 0.6964, 0.2742], device='cuda:0')
# val_loss: 0.8109748280845861
# val_precision: tensor([0.6389, 0.8052, 0.6513, 0.7591], device='cuda:0')
# val_recall: tensor([0.6428, 0.6606, 0.8011, 0.3300], device='cuda:0')
# Learning rate: 5e-06
# epoch 52 time:  143.16131558599955
# --------------------------------
# ========================================
# EPOCH: 53
# train_loss: 0.7637445043605713
# train_precision: tensor([0.6358, 0.7161, 0.6938, 0.6285], device='cuda:0')
# train_recall: tensor([0.5988, 0.7920, 0.6999, 0.2732], device='cuda:0')
# val_loss: 0.7196625749019827
# val_precision: tensor([0.6650, 0.8050, 0.6720, 0.7748], device='cuda:0')
# val_recall: tensor([0.6187, 0.7466, 0.8064, 0.3266], device='cuda:0')
# Learning rate: 5e-06
# epoch 53 time:  144.0683389449987
# --------------------------------
# ========================================
# EPOCH: 54
# train_loss: 0.7639701710526299
# train_precision: tensor([0.6367, 0.7174, 0.6928, 0.6187], device='cuda:0')
# train_recall: tensor([0.5993, 0.7913, 0.7010, 0.2711], device='cuda:0')
# val_loss: 0.7205487065166105
# val_precision: tensor([0.6696, 0.7921, 0.6850, 0.7634], device='cuda:0')
# val_recall: tensor([0.6273, 0.7641, 0.7921, 0.3215], device='cuda:0')
# Learning rate: 5e-06
# epoch 54 time:  144.00315960900116
# --------------------------------
# ========================================
# EPOCH: 55
# train_loss: 0.763890379099957
# train_precision: tensor([0.6353, 0.7163, 0.6951, 0.6235], device='cuda:0')
# train_recall: tensor([0.6013, 0.7906, 0.6993, 0.2732], device='cuda:0')
# val_loss: 0.7337206587855657
# val_precision: tensor([0.6471, 0.8095, 0.6781, 0.7851], device='cuda:0')
# val_recall: tensor([0.6398, 0.7219, 0.7991, 0.3222], device='cuda:0')
# Learning rate: 5e-06
# epoch 55 time:  143.83802126999944
# --------------------------------
# ========================================
# EPOCH: 56
# train_loss: 0.7627938682452169
# train_precision: tensor([0.6361, 0.7178, 0.6937, 0.6285], device='cuda:0')
# train_recall: tensor([0.6007, 0.7906, 0.7004, 0.2795], device='cuda:0')
# val_loss: 0.7324301352819912
# val_precision: tensor([0.6473, 0.7952, 0.6928, 0.7593], device='cuda:0')
# val_recall: tensor([0.6376, 0.7426, 0.7875, 0.3377], device='cuda:0')
# Learning rate: 5e-06
# epoch 56 time:  143.6133626640003
# --------------------------------
# ========================================
# EPOCH: 57
# train_loss: 0.7629576379197027
# train_precision: tensor([0.6355, 0.7172, 0.6945, 0.6308], device='cuda:0')
# train_recall: tensor([0.6001, 0.7934, 0.6984, 0.2786], device='cuda:0')
# val_loss: 0.8161996435487301
# val_precision: tensor([0.6232, 0.7978, 0.6563, 0.7741], device='cuda:0')
# val_recall: tensor([0.6365, 0.6456, 0.8061, 0.3195], device='cuda:0')
# Learning rate: 5e-06
# epoch 57 time:  143.6470233680011
# --------------------------------
# ========================================
# EPOCH: 58
# train_loss: 0.7642839381240578
# train_precision: tensor([0.6366, 0.7180, 0.6917, 0.6260], device='cuda:0')
# train_recall: tensor([0.5986, 0.7929, 0.7004, 0.2664], device='cuda:0')
# val_loss: 0.7722305824247057
# val_precision: tensor([0.6434, 0.7822, 0.6785, 0.6959], device='cuda:0')
# val_recall: tensor([0.6418, 0.7068, 0.7788, 0.3552], device='cuda:0')
# Learning rate: 5e-06
# epoch 58 time:  143.50674410099964
# --------------------------------
# ========================================
# EPOCH: 59
# train_loss: 0.7620912521262974
# train_precision: tensor([0.6351, 0.7177, 0.6947, 0.6346], device='cuda:0')
# train_recall: tensor([0.6019, 0.7891, 0.7002, 0.2847], device='cuda:0')
# val_loss: 0.786202414314401
# val_precision: tensor([0.6482, 0.7965, 0.6555, 0.7496], device='cuda:0')
# val_recall: tensor([0.6118, 0.6922, 0.8143, 0.3367], device='cuda:0')
# Learning rate: 5e-06
# epoch 59 time:  143.64962058299716
# --------------------------------
# ========================================
# EPOCH: 60
# train_loss: 0.7639804644067759
# train_precision: tensor([0.6339, 0.7169, 0.6949, 0.6237], device='cuda:0')
# train_recall: tensor([0.6009, 0.7907, 0.6980, 0.2786], device='cuda:0')
# val_loss: 0.8190427642506584
# val_precision: tensor([0.6433, 0.7982, 0.6419, 0.7631], device='cuda:0')
# val_recall: tensor([0.6394, 0.6466, 0.8044, 0.3276], device='cuda:0')
# Learning rate: 5e-06
# epoch 60 time:  143.33741539100083
# --------------------------------
# ========================================
# EPOCH: 61
# train_loss: 0.7614186258466794
# train_precision: tensor([0.6382, 0.7175, 0.6963, 0.6273], device='cuda:0')
# train_recall: tensor([0.6032, 0.7911, 0.7007, 0.2883], device='cuda:0')
# val_loss: 0.7322056413991466
# val_precision: tensor([0.6654, 0.8060, 0.6686, 0.7405], device='cuda:0')
# val_recall: tensor([0.6290, 0.7326, 0.8011, 0.3525], device='cuda:0')
# Learning rate: 5e-06
# epoch 61 time:  143.10135446900313
# --------------------------------
# ========================================
# EPOCH: 62
# train_loss: 0.7627792453019202
# train_precision: tensor([0.6369, 0.7175, 0.6958, 0.6310], device='cuda:0')
# train_recall: tensor([0.6021, 0.7916, 0.7006, 0.2805], device='cuda:0')
# val_loss: 0.892777380551803
# val_precision: tensor([0.6525, 0.7931, 0.6219, 0.7543], device='cuda:0')
# val_recall: tensor([0.6284, 0.6208, 0.8156, 0.3226], device='cuda:0')
# Learning rate: 5e-06
# epoch 62 time:  143.25424465899778
# --------------------------------
# ========================================
# EPOCH: 63
# train_loss: 0.7609006894691761
# train_precision: tensor([0.6369, 0.7178, 0.6953, 0.6264], device='cuda:0')
# train_recall: tensor([0.6003, 0.7931, 0.7006, 0.2810], device='cuda:0')
# val_loss: 0.7170524159791053
# val_precision: tensor([0.6463, 0.8078, 0.7003, 0.7860], device='cuda:0')
# val_recall: tensor([0.6665, 0.7420, 0.7759, 0.3327], device='cuda:0')
# Learning rate: 5e-06
# epoch 63 time:  144.37980060300106
# --------------------------------
# ========================================
# EPOCH: 64
# train_loss: 0.7617061357114803
# train_precision: tensor([0.6345, 0.7172, 0.6938, 0.6216], device='cuda:0')
# train_recall: tensor([0.5993, 0.7897, 0.7000, 0.2828], device='cuda:0')
# val_loss: 0.8505980029249067
# val_precision: tensor([0.6160, 0.7785, 0.6746, 0.7651], device='cuda:0')
# val_recall: tensor([0.6755, 0.6478, 0.7620, 0.3202], device='cuda:0')
# Learning rate: 5e-06
# epoch 64 time:  143.9044313819977
# --------------------------------
# ========================================
# EPOCH: 65
# train_loss: 0.7604815261672239
# train_precision: tensor([0.6363, 0.7169, 0.6958, 0.6238], device='cuda:0')
# train_recall: tensor([0.6014, 0.7908, 0.7010, 0.2763], device='cuda:0')
# val_loss: 0.7228822756756087
# val_precision: tensor([0.6713, 0.8059, 0.6733, 0.8163], device='cuda:0')
# val_recall: tensor([0.6243, 0.7490, 0.8096, 0.3111], device='cuda:0')
# Learning rate: 5e-06
# epoch 65 time:  143.69789939199836
# --------------------------------
# ========================================
# EPOCH: 66
# train_loss: 0.7627421284637279
# train_precision: tensor([0.6362, 0.7180, 0.6933, 0.6244], device='cuda:0')
# train_recall: tensor([0.5981, 0.7917, 0.7018, 0.2818], device='cuda:0')
# val_loss: 0.7779105333583858
# val_precision: tensor([0.6569, 0.8072, 0.6459, 0.7560], device='cuda:0')
# val_recall: tensor([0.6127, 0.6852, 0.8236, 0.3276], device='cuda:0')
# Learning rate: 5e-06
# epoch 66 time:  143.6725566690002
# --------------------------------
# ========================================
# EPOCH: 67
# train_loss: 0.7599618679148767
# train_precision: tensor([0.6377, 0.7185, 0.6962, 0.6351], device='cuda:0')
# train_recall: tensor([0.6016, 0.7926, 0.7022, 0.2843], device='cuda:0')
# val_loss: 0.7752708031911626
# val_precision: tensor([0.6574, 0.8143, 0.6491, 0.6975], device='cuda:0')
# val_recall: tensor([0.6340, 0.6860, 0.8083, 0.3330], device='cuda:0')
# Learning rate: 5e-06
# epoch 67 time:  143.69628582299993
# --------------------------------
# ========================================
# EPOCH: 68
# train_loss: 0.7594057280475104
# train_precision: tensor([0.6382, 0.7192, 0.6937, 0.6326], device='cuda:0')
# train_recall: tensor([0.6004, 0.7938, 0.7017, 0.2781], device='cuda:0')
# val_loss: 0.716136543441088
# val_precision: tensor([0.6512, 0.8170, 0.6858, 0.7552], device='cuda:0')
# val_recall: tensor([0.6566, 0.7303, 0.7906, 0.3407], device='cuda:0')
# Learning rate: 5e-06
# epoch 68 time:  143.93525570900238
# --------------------------------
# ========================================
# EPOCH: 69
# train_loss: 0.7581489801366907
# train_precision: tensor([0.6391, 0.7186, 0.6968, 0.6417], device='cuda:0')
# train_recall: tensor([0.6016, 0.7944, 0.7033, 0.2817], device='cuda:0')
# val_loss: 0.7076200561975003
# val_precision: tensor([0.6835, 0.7873, 0.6874, 0.7700], device='cuda:0')
# val_recall: tensor([0.6125, 0.7863, 0.7992, 0.3269], device='cuda:0')
# Learning rate: 5e-06
# epoch 69 time:  144.0261192500002
# --------------------------------
# ========================================
# EPOCH: 70
# train_loss: 0.7575198498860345
# train_precision: tensor([0.6397, 0.7191, 0.6971, 0.6405], device='cuda:0')
# train_recall: tensor([0.6030, 0.7944, 0.7018, 0.2934], device='cuda:0')
# val_loss: 0.7462619832347104
# val_precision: tensor([0.6469, 0.8026, 0.6834, 0.7966], device='cuda:0')
# val_recall: tensor([0.6594, 0.7178, 0.7826, 0.3283], device='cuda:0')
# Learning rate: 5e-06
# epoch 70 time:  143.96830280599897
# --------------------------------
# ========================================
# EPOCH: 71
# train_loss: 0.7584822227894137
# train_precision: tensor([0.6369, 0.7187, 0.6960, 0.6368], device='cuda:0')
# train_recall: tensor([0.6025, 0.7924, 0.7012, 0.2808], device='cuda:0')
# val_loss: 0.7396415207978438
# val_precision: tensor([0.6681, 0.8042, 0.6639, 0.7661], device='cuda:0')
# val_recall: tensor([0.6236, 0.7284, 0.8079, 0.3374], device='cuda:0')
# Learning rate: 5e-06
# epoch 71 time:  143.25030456199966
# --------------------------------
# ========================================
# EPOCH: 72
# train_loss: 0.7595938932978229
# train_precision: tensor([0.6361, 0.7191, 0.6963, 0.6345], device='cuda:0')
# train_recall: tensor([0.5999, 0.7941, 0.7016, 0.2848], device='cuda:0')
# val_loss: 0.734049153206247
# val_precision: tensor([0.6730, 0.7975, 0.6647, 0.7890], device='cuda:0')
# val_recall: tensor([0.6093, 0.7377, 0.8171, 0.3199], device='cuda:0')
# Learning rate: 5e-06
# epoch 72 time:  143.51285133999772
# --------------------------------
# ========================================
# EPOCH: 73
# train_loss: 0.7585667666710079
# train_precision: tensor([0.6395, 0.7190, 0.6958, 0.6381], device='cuda:0')
# train_recall: tensor([0.6017, 0.7938, 0.7027, 0.2877], device='cuda:0')
# val_loss: 0.7327214583638023
# val_precision: tensor([0.6589, 0.8032, 0.6799, 0.7875], device='cuda:0')
# val_recall: tensor([0.6349, 0.7377, 0.7999, 0.3269], device='cuda:0')
# Learning rate: 5e-06
# epoch 73 time:  143.27298464200067
# --------------------------------
# ========================================
# EPOCH: 74
# train_loss: 0.755951967237693
# train_precision: tensor([0.6395, 0.7188, 0.6960, 0.6371], device='cuda:0')
# train_recall: tensor([0.5998, 0.7941, 0.7039, 0.2924], device='cuda:0')
# val_loss: 0.750975496130959
# val_precision: tensor([0.6561, 0.8100, 0.6636, 0.7631], device='cuda:0')
# val_recall: tensor([0.6436, 0.7036, 0.8011, 0.3296], device='cuda:0')
# Learning rate: 5e-06
# epoch 74 time:  143.58056922200194
# --------------------------------
# ========================================
# EPOCH: 75
# train_loss: 0.757589549461018
# train_precision: tensor([0.6401, 0.7189, 0.6968, 0.6312], device='cuda:0')
# train_recall: tensor([0.6018, 0.7930, 0.7041, 0.2929], device='cuda:0')
# val_loss: 0.7778784777758745
# val_precision: tensor([0.6548, 0.7995, 0.6533, 0.7761], device='cuda:0')
# val_recall: tensor([0.6253, 0.6889, 0.8118, 0.3175], device='cuda:0')
# Learning rate: 5e-06
# epoch 75 time:  143.40223796300052
# --------------------------------
# ========================================
# EPOCH: 76
# train_loss: 0.7570164282838471
# train_precision: tensor([0.6383, 0.7204, 0.6950, 0.6288], device='cuda:0')
# train_recall: tensor([0.6009, 0.7917, 0.7049, 0.2850], device='cuda:0')
# val_loss: 0.7394000741785034
# val_precision: tensor([0.6771, 0.7994, 0.6629, 0.7633], device='cuda:0')
# val_recall: tensor([0.6104, 0.7378, 0.8161, 0.3387], device='cuda:0')
# Learning rate: 5e-06
# epoch 76 time:  143.6785681600013
# --------------------------------
# ========================================
# EPOCH: 77
# train_loss: 0.7565020445054238
# train_precision: tensor([0.6389, 0.7198, 0.6960, 0.6353], device='cuda:0')
# train_recall: tensor([0.6029, 0.7940, 0.7013, 0.2906], device='cuda:0')
# val_loss: 0.7517350904637062
# val_precision: tensor([0.6653, 0.8162, 0.6505, 0.7843], device='cuda:0')
# val_recall: tensor([0.6206, 0.7011, 0.8239, 0.3256], device='cuda:0')
# Learning rate: 5e-06
# epoch 77 time:  143.43209632599974
# --------------------------------
# ========================================
# EPOCH: 78
# train_loss: 0.7551233604436053
# train_precision: tensor([0.6388, 0.7207, 0.6959, 0.6276], device='cuda:0')
# train_recall: tensor([0.5999, 0.7949, 0.7039, 0.2911], device='cuda:0')
# val_loss: 0.7271009602461764
# val_precision: tensor([0.6615, 0.8107, 0.6721, 0.7978], device='cuda:0')
# val_recall: tensor([0.6311, 0.7339, 0.8074, 0.3135], device='cuda:0')
# Learning rate: 5e-06
# epoch 78 time:  143.3157164860022
# --------------------------------
# ========================================
# EPOCH: 79
# train_loss: 0.7550424505786743
# train_precision: tensor([0.6391, 0.7212, 0.6960, 0.6359], device='cuda:0')
# train_recall: tensor([0.6017, 0.7938, 0.7043, 0.2924], device='cuda:0')
# val_loss: 0.7327666150316997
# val_precision: tensor([0.6631, 0.8172, 0.6601, 0.7731], device='cuda:0')
# val_recall: tensor([0.6221, 0.7153, 0.8207, 0.3350], device='cuda:0')
# Learning rate: 5e-06
# Early stopping at epoch 79 with best validation loss 0.7076200561975003
# training_checkpoints/efficient_norm_b0_16batch2024-04-25 01:05:46.729052.pth
# <All keys matched successfully>

# %%
from sklearn.metrics import confusion_matrix, classification_report
from torch.utils.data import DataLoader
import numpy as np
import torch 
from torchvision.models import resnet18
import torch.nn as nn


def test_report(model, dataloader):
    """Prints confusion matrix for testing dataset
    dataloader should be of batch_size=1."""

    y_pred = []
    y_test = []
    model.eval()
    with torch.no_grad():
        for data, label in dataloader:
            output = model(data)
            label = label.numpy()
            output = output.numpy()
            y_pred.append(np.argmax(output))
            y_test.append(np.argmax(label))
        print(confusion_matrix(y_test, y_pred))
        print(classification_report(y_test, y_pred))

testset =ImageDataset(data_path='test_data', transform=transform_test)
dataloader = DataLoader(testset, batch_size=1, shuffle=True)

test_report(my_model.to('cpu'), dataloader)
# Out:
# [[621 111 267   1]
#  [114 803  81   2]
#  [123  45 827   5]
#  [ 28  15  21  36]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.62      0.66      1000
#            1       0.82      0.80      0.81      1000
#            2       0.69      0.83      0.75      1000
#            3       0.82      0.36      0.50       100
#
#     accuracy                           0.74      3100
#    macro avg       0.76      0.65      0.68      3100
# weighted avg       0.74      0.74      0.73      3100
