# %%
import time
import sys
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from dataset import ImageDataset
import torch.nn.functional as F
from torchmetrics import Precision, Recall
from torchvision.models import resnet18
import warnings
from collections import defaultdict
import wandb
import datetime
import os
import torchvision.models as models
import torch.nn as nn
#intecubic interpol

class EfficientNetB0(nn.Module):
    def __init__(self, num_classes=4):
        super(EfficientNetB0, self).__init__()
        self.base_model = models.efficientnet_b0(pretrained=False)
        num_ftrs = self.base_model.classifier[1].in_features
        self.base_model.classifier[1] = nn.Linear(num_ftrs, num_classes)

    def forward(self, x):
        return self.base_model(x)


warnings.filterwarnings('ignore')
torch.set_float32_matmul_precision('high')


run_name = f'efficient_net_b0{datetime.datetime.now()}'
run_path = f'training_checkpoints/{run_name}'

wandb.init(project="cells", 
           entity="adamsoja",
          name=run_name)

import random
random.seed(2233)
torch.manual_seed(2233)

from albumentations import (
    Compose,
    Resize,
    OneOf,
    RandomBrightness,
    RandomContrast,
    MotionBlur,
    MedianBlur,
    GaussianBlur,
    VerticalFlip,
    HorizontalFlip,
    ShiftScaleRotate,
    Normalize,
)

transform = Compose(
    [
        OneOf([RandomBrightness(limit=0.4, p=1), RandomContrast(limit=0.4, p=1)]),
        OneOf([MotionBlur(blur_limit=3), MedianBlur(blur_limit=3), GaussianBlur(blur_limit=3),], p=0.7,),
        VerticalFlip(p=0.5),
        HorizontalFlip(p=0.5),
    ]
)

class MyModel(nn.Module):
    def __init__(self, model, learning_rate, weight_decay):
        super(MyModel, self).__init__()
        self.model = model
        self.learning_rate = learning_rate
        self.weight_decay = weight_decay
        self.criterion = nn.CrossEntropyLoss()
        self.metric_precision = Precision(task="multiclass", num_classes=4, average=None).to('cuda')
        self.metric_recall = Recall(task="multiclass", num_classes=4, average=None).to('cuda')
        self.train_loss = []
        self.valid_loss = []
        self.precision_per_epochs = []
        self.recall_per_epochs = []

        self.optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, mode="min", factor=0.1, patience=2, min_lr=5e-6, verbose=True)
        self.step = 0

    
    def forward(self, x):
        return self.model(x)

    def train_one_epoch(self, trainloader):
        self.step += 1
        self.train()
        for batch_idx, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()
            _, preds = torch.max(outputs, 1)
            _, labels = torch.max(labels, 1)
            self.metric_precision(preds, labels)
            self.metric_recall(preds, labels)
            self.train_loss.append(loss.item())


        

        
        avg_loss = np.mean(self.train_loss)
        self.train_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        self.precision_per_epochs.append(precision)
        self.recall_per_epochs.append(recall)
        print(f'train_loss: {avg_loss}')
        print(f'train_precision: {precision}')
        print(f'train_recall: {recall}')

        wandb.log({'loss': avg_loss},step=self.step)
        wandb.log({'Normal precision': precision[0].item()},step=self.step)
        wandb.log({'Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'Other precision': precision[3].item()},step=self.step)


        wandb.log({'Normal recall': recall[0].item()},step=self.step)
        wandb.log({'Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'Other recall': recall[3].item()},step=self.step)
        
        
        self.metric_precision.reset()
        self.metric_recall.reset()


    

    def evaluate(self, testloader):
        self.eval()
        with torch.no_grad():
            for batch_idx, (inputs, labels) in enumerate(testloader):
                inputs, labels = inputs.to('cuda'), labels.to('cuda')
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)
                _, labels = torch.max(labels, 1)
                self.metric_precision(preds, labels)
                self.metric_recall(preds, labels)
                self.valid_loss.append(loss.item())
    
        avg_loss = np.mean(self.valid_loss)
        self.scheduler.step(avg_loss)
        self.valid_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        print(f'val_loss: {avg_loss}')
        print(f'val_precision: {precision}')
        print(f'val_recall: {recall}')
        self.metric_precision.reset()
        self.metric_recall.reset()

        wandb.log({'val_loss': avg_loss}, step=self.step)
        
        wandb.log({'val_Normal precision': precision[0].item()},step=self.step)
        wandb.log({'val_Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'val_Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'val_Other precision': precision[3].item()},step=self.step)


        wandb.log({'val_Normal recall': recall[0].item()},step=self.step)
        wandb.log({'val_Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'val_Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'val_Other recall': recall[3].item()},step=self.step)


        for param_group in self.optimizer.param_groups:
            print(f"Learning rate: {param_group['lr']}")
        return avg_loss

torch.cuda.empty_cache()
batch_size = 256
trainset = ImageDataset(data_path='train_data', transform=transform)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=5)

testset = ImageDataset(data_path='validation_data')
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=3)

learning_rate = 0.001
weight_decay = 0.00001

model = EfficientNetB0()
model = model.to('cuda')


my_model = MyModel(model=model, learning_rate=learning_rate, weight_decay=weight_decay)
my_model = my_model.to('cuda')

num_epochs = 100
early_stop_patience = 10
best_val_loss = float('inf')
best_model_state_dict = None

for epoch in range(num_epochs):
    print('========================================')
    print(f'EPOCH: {epoch}') 
    time_start = time.perf_counter()
    my_model.train_one_epoch(trainloader)
    val_loss = my_model.evaluate(testloader)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_state_dict = my_model.state_dict()
        torch.save(best_model_state_dict, f'{run_path}.pth')
        
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch} with best validation loss {best_val_loss}")
        break
    time_epoch = time.perf_counter() - time_start
    print(f'epoch {epoch} time:  {time_epoch/60}')
    print('--------------------------------')

# Load the best model state dict
print(f'{run_path}.pth')
my_model.load_state_dict(torch.load(f'{run_path}.pth'))
# Out:
# wandb: Currently logged in as: adamsoja. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/adam/Desktop/cells_master_thesis/wandb/run-20240421_154502-lm5h5q6r</code>
# Syncing run <strong><a href='https://wandb.ai/adamsoja/cells/runs/lm5h5q6r' target="_blank">efficient_net_b02024-04-21 15:45:01.873940</a></strong> to <a href='https://wandb.ai/adamsoja/cells' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adamsoja/cells' target="_blank">https://wandb.ai/adamsoja/cells</a>
#  View run at <a href='https://wandb.ai/adamsoja/cells/runs/lm5h5q6r' target="_blank">https://wandb.ai/adamsoja/cells/runs/lm5h5q6r</a>
# ========================================
# EPOCH: 0
# train_loss: 0.9476205743494488
# train_precision: tensor([0.5161, 0.6597, 0.6032, 0.1893], device='cuda:0')
# train_recall: tensor([0.4990, 0.7521, 0.5957, 0.0102], device='cuda:0')
# val_loss: 0.8283028226759699
# val_precision: tensor([0.5430, 0.7536, 0.6779, 0.8514], device='cuda:0')
# val_recall: tensor([0.6441, 0.7345, 0.6350, 0.0212], device='cuda:0')
# Learning rate: 0.001
# epoch 0 time:  0.34213542921666734
# --------------------------------
# ========================================
# EPOCH: 1
# train_loss: 0.8591464808299428
# train_precision: tensor([0.5611, 0.6994, 0.6531, 0.5362], device='cuda:0')
# train_recall: tensor([0.5480, 0.7748, 0.6549, 0.0694], device='cuda:0')
# val_loss: 0.7950782975388898
# val_precision: tensor([0.5733, 0.7356, 0.7009, 0.8210], device='cuda:0')
# val_recall: tensor([0.6256, 0.7686, 0.6648, 0.1266], device='cuda:0')
# Learning rate: 0.001
# epoch 1 time:  0.3352980877166677
# --------------------------------
# ========================================
# EPOCH: 2
# train_loss: 0.820674476595152
# train_precision: tensor([0.5809, 0.7138, 0.6710, 0.5708], device='cuda:0')
# train_recall: tensor([0.5703, 0.7805, 0.6718, 0.1338], device='cuda:0')
# val_loss: 0.7762706243329578
# val_precision: tensor([0.6309, 0.7265, 0.6590, 0.7136], device='cuda:0')
# val_recall: tensor([0.5309, 0.8105, 0.7398, 0.1451], device='cuda:0')
# Learning rate: 0.001
# epoch 2 time:  0.33162379724999863
# --------------------------------
# ========================================
# EPOCH: 3
# train_loss: 0.7895204473819052
# train_precision: tensor([0.5972, 0.7249, 0.6844, 0.5692], device='cuda:0')
# train_recall: tensor([0.5822, 0.7874, 0.6879, 0.1924], device='cuda:0')
# val_loss: 0.7879373826086521
# val_precision: tensor([0.6837, 0.7312, 0.6162, 0.7852], device='cuda:0')
# val_recall: tensor([0.4378, 0.7972, 0.8262, 0.2253], device='cuda:0')
# Learning rate: 0.001
# epoch 3 time:  0.3297181108166645
# --------------------------------
# ========================================
# EPOCH: 4
# train_loss: 0.7707230430983362
# train_precision: tensor([0.6063, 0.7341, 0.6925, 0.5861], device='cuda:0')
# train_recall: tensor([0.5915, 0.7904, 0.6959, 0.2504], device='cuda:0')
# val_loss: 0.7457949747641881
# val_precision: tensor([0.6371, 0.7690, 0.6643, 0.7136], device='cuda:0')
# val_recall: tensor([0.5708, 0.7726, 0.7745, 0.2391], device='cuda:0')
# Learning rate: 0.001
# epoch 4 time:  0.3287436465166669
# --------------------------------
# ========================================
# EPOCH: 5
# train_loss: 0.7501554496941112
# train_precision: tensor([0.6191, 0.7449, 0.7000, 0.6123], device='cuda:0')
# train_recall: tensor([0.6049, 0.7949, 0.7049, 0.2986], device='cuda:0')
# val_loss: 0.717663956185182
# val_precision: tensor([0.6216, 0.7727, 0.7150, 0.6536], device='cuda:0')
# val_recall: tensor([0.6274, 0.7994, 0.7158, 0.3603], device='cuda:0')
# Learning rate: 0.001
# epoch 5 time:  0.3274084106500027
# --------------------------------
# ========================================
# EPOCH: 6
# train_loss: 0.7304557217728525
# train_precision: tensor([0.6327, 0.7506, 0.7106, 0.6321], device='cuda:0')
# train_recall: tensor([0.6185, 0.8003, 0.7133, 0.3300], device='cuda:0')
# val_loss: 0.7041172761056158
# val_precision: tensor([0.6490, 0.7916, 0.6898, 0.7812], device='cuda:0')
# val_recall: tensor([0.6242, 0.7714, 0.7752, 0.3114], device='cuda:0')
# Learning rate: 0.001
# epoch 6 time:  0.32926073485000035
# --------------------------------
# ========================================
# EPOCH: 7
# train_loss: 0.7309816939490182
# train_precision: tensor([0.6273, 0.7519, 0.7087, 0.6214], device='cuda:0')
# train_recall: tensor([0.6140, 0.7980, 0.7132, 0.3335], device='cuda:0')
# val_loss: 0.7023648098938995
# val_precision: tensor([0.6788, 0.7357, 0.7047, 0.7887], device='cuda:0')
# val_recall: tensor([0.5808, 0.8394, 0.7479, 0.3330], device='cuda:0')
# Learning rate: 0.001
# epoch 7 time:  0.3292487048333328
# --------------------------------
# ========================================
# EPOCH: 8
# train_loss: 0.7213570968735785
# train_precision: tensor([0.6326, 0.7547, 0.7127, 0.6289], device='cuda:0')
# train_recall: tensor([0.6201, 0.8012, 0.7138, 0.3563], device='cuda:0')
# val_loss: 0.6781237723098861
# val_precision: tensor([0.6479, 0.7863, 0.7318, 0.7838], device='cuda:0')
# val_recall: tensor([0.6673, 0.7967, 0.7396, 0.3613], device='cuda:0')
# Learning rate: 0.001
# epoch 8 time:  0.3320876822666681
# --------------------------------
# ========================================
# EPOCH: 9
# train_loss: 0.701915563430105
# train_precision: tensor([0.6476, 0.7601, 0.7205, 0.6528], device='cuda:0')
# train_recall: tensor([0.6317, 0.8062, 0.7227, 0.3974], device='cuda:0')
# val_loss: 0.6751299309233825
# val_precision: tensor([0.6591, 0.8096, 0.7002, 0.7078], device='cuda:0')
# val_recall: tensor([0.6218, 0.7790, 0.7892, 0.4771], device='cuda:0')
# Learning rate: 0.001
# epoch 9 time:  0.3306141633833325
# --------------------------------
# ========================================
# EPOCH: 10
# train_loss: 0.6957332956649008
# train_precision: tensor([0.6510, 0.7641, 0.7221, 0.6498], device='cuda:0')
# train_recall: tensor([0.6335, 0.8090, 0.7257, 0.4094], device='cuda:0')
# val_loss: 0.6649947178860506
# val_precision: tensor([0.6620, 0.7738, 0.7398, 0.7790], device='cuda:0')
# val_recall: tensor([0.6559, 0.8198, 0.7420, 0.3643], device='cuda:0')
# Learning rate: 0.001
# epoch 10 time:  0.3293731971833343
# --------------------------------
# ========================================
# EPOCH: 11
# train_loss: 0.6795756696945146
# train_precision: tensor([0.6596, 0.7686, 0.7298, 0.6687], device='cuda:0')
# train_recall: tensor([0.6431, 0.8122, 0.7325, 0.4326], device='cuda:0')
# val_loss: 0.6613969578511185
# val_precision: tensor([0.6679, 0.7624, 0.7471, 0.7788], device='cuda:0')
# val_recall: tensor([0.6505, 0.8324, 0.7316, 0.4279], device='cuda:0')
# Learning rate: 0.001
# epoch 11 time:  0.3312258085666675
# --------------------------------
# ========================================
# EPOCH: 12
# train_loss: 0.6695169922141802
# train_precision: tensor([0.6634, 0.7712, 0.7344, 0.6683], device='cuda:0')
# train_recall: tensor([0.6475, 0.8143, 0.7345, 0.4547], device='cuda:0')
# val_loss: 0.6616546418103907
# val_precision: tensor([0.6692, 0.8158, 0.6998, 0.7647], device='cuda:0')
# val_recall: tensor([0.6204, 0.7824, 0.8066, 0.4694], device='cuda:0')
# Learning rate: 0.001
# epoch 12 time:  0.32436512766666586
# --------------------------------
# ========================================
# EPOCH: 13
# train_loss: 0.6615644178929783
# train_precision: tensor([0.6672, 0.7756, 0.7396, 0.6654], device='cuda:0')
# train_recall: tensor([0.6543, 0.8180, 0.7368, 0.4545], device='cuda:0')
# val_loss: 0.650275376273526
# val_precision: tensor([0.6845, 0.7797, 0.7301, 0.8320], device='cuda:0')
# val_recall: tensor([0.6273, 0.8403, 0.7715, 0.4084], device='cuda:0')
# Learning rate: 0.001
# epoch 13 time:  0.3298818155166676
# --------------------------------
# ========================================
# EPOCH: 14
# train_loss: 0.6571496861321585
# train_precision: tensor([0.6711, 0.7772, 0.7384, 0.6688], device='cuda:0')
# train_recall: tensor([0.6551, 0.8192, 0.7390, 0.4622], device='cuda:0')
# val_loss: 0.638412792649534
# val_precision: tensor([0.6981, 0.7968, 0.7136, 0.7832], device='cuda:0')
# val_recall: tensor([0.6267, 0.8177, 0.7986, 0.4451], device='cuda:0')
# Learning rate: 0.001
# epoch 14 time:  0.32807376095000035
# --------------------------------
# ========================================
# EPOCH: 15
# train_loss: 0.650471133880672
# train_precision: tensor([0.6731, 0.7806, 0.7432, 0.6801], device='cuda:0')
# train_recall: tensor([0.6596, 0.8216, 0.7404, 0.4853], device='cuda:0')
# val_loss: 0.6351939818097485
# val_precision: tensor([0.6909, 0.7779, 0.7441, 0.7410], device='cuda:0')
# val_recall: tensor([0.6370, 0.8410, 0.7661, 0.4980], device='cuda:0')
# Learning rate: 0.001
# epoch 15 time:  0.3275174629500005
# --------------------------------
# ========================================
# EPOCH: 16
# train_loss: 0.6450750651813689
# train_precision: tensor([0.6771, 0.7818, 0.7440, 0.6870], device='cuda:0')
# train_recall: tensor([0.6605, 0.8215, 0.7458, 0.4902], device='cuda:0')
# val_loss: 0.6465328843229347
# val_precision: tensor([0.6952, 0.8062, 0.7046, 0.7728], device='cuda:0')
# val_recall: tensor([0.6235, 0.8007, 0.8099, 0.4660], device='cuda:0')
# Learning rate: 0.001
# epoch 16 time:  0.32341569841666645
# --------------------------------
# ========================================
# EPOCH: 17
# train_loss: 0.6401593282109215
# train_precision: tensor([0.6788, 0.7841, 0.7465, 0.6899], device='cuda:0')
# train_recall: tensor([0.6641, 0.8240, 0.7458, 0.4944], device='cuda:0')
# val_loss: 0.62464910555217
# val_precision: tensor([0.7014, 0.8098, 0.7219, 0.8062], device='cuda:0')
# val_recall: tensor([0.6390, 0.8176, 0.8131, 0.4273], device='cuda:0')
# Learning rate: 0.001
# epoch 17 time:  0.3288481109000031
# --------------------------------
# ========================================
# EPOCH: 18
# train_loss: 0.6370467834529423
# train_precision: tensor([0.6815, 0.7847, 0.7493, 0.6899], device='cuda:0')
# train_recall: tensor([0.6666, 0.8251, 0.7482, 0.4962], device='cuda:0')
# val_loss: 0.6208336138890849
# val_precision: tensor([0.7148, 0.7943, 0.7216, 0.7717], device='cuda:0')
# val_recall: tensor([0.6221, 0.8345, 0.8058, 0.4815], device='cuda:0')
# Learning rate: 0.001
# epoch 18 time:  0.32945941525000155
# --------------------------------
# ========================================
# EPOCH: 19
# train_loss: 0.6295005559566476
# train_precision: tensor([0.6850, 0.7866, 0.7505, 0.6933], device='cuda:0')
# train_recall: tensor([0.6681, 0.8250, 0.7523, 0.5092], device='cuda:0')
# val_loss: 0.6102635862926642
# val_precision: tensor([0.6896, 0.7923, 0.7703, 0.7021], device='cuda:0')
# val_recall: tensor([0.6907, 0.8359, 0.7423, 0.5586], device='cuda:0')
# Learning rate: 0.001
# epoch 19 time:  0.3338054027166663
# --------------------------------
# ========================================
# EPOCH: 20
# train_loss: 0.6280915902129242
# train_precision: tensor([0.6854, 0.7897, 0.7504, 0.6923], device='cuda:0')
# train_recall: tensor([0.6704, 0.8261, 0.7516, 0.5137], device='cuda:0')
# val_loss: 0.630068247185813
# val_precision: tensor([0.6887, 0.7535, 0.7794, 0.7192], device='cuda:0')
# val_recall: tensor([0.6588, 0.8710, 0.7099, 0.5512], device='cuda:0')
# Learning rate: 0.001
# epoch 20 time:  0.333721803133335
# --------------------------------
# ========================================
# EPOCH: 21
# train_loss: 0.6355983247359593
# train_precision: tensor([0.6820, 0.7872, 0.7460, 0.6863], device='cuda:0')
# train_recall: tensor([0.6657, 0.8251, 0.7468, 0.5114], device='cuda:0')
# val_loss: 0.6026070570780171
# val_precision: tensor([0.6988, 0.8169, 0.7460, 0.7817], device='cuda:0')
# val_recall: tensor([0.6843, 0.8170, 0.7869, 0.5148], device='cuda:0')
# Learning rate: 0.001
# epoch 21 time:  0.34019111019999854
# --------------------------------
# ========================================
# EPOCH: 22
# train_loss: 0.6240907006675289
# train_precision: tensor([0.6866, 0.7914, 0.7514, 0.7011], device='cuda:0')
# train_recall: tensor([0.6725, 0.8277, 0.7512, 0.5250], device='cuda:0')
# val_loss: 0.6038152612745762
# val_precision: tensor([0.6723, 0.8178, 0.7716, 0.7913], device='cuda:0')
# val_recall: tensor([0.7262, 0.8159, 0.7388, 0.5118], device='cuda:0')
# Learning rate: 0.001
# epoch 22 time:  0.33217445643333576
# --------------------------------
# ========================================
# EPOCH: 23
# train_loss: 0.6256162533093066
# train_precision: tensor([0.6862, 0.7892, 0.7506, 0.6895], device='cuda:0')
# train_recall: tensor([0.6698, 0.8278, 0.7495, 0.5268], device='cuda:0')
# val_loss: 0.6971892491810852
# val_precision: tensor([0.6677, 0.8109, 0.6741, 0.6260], device='cuda:0')
# val_recall: tensor([0.5977, 0.7803, 0.7874, 0.4667], device='cuda:0')
# Learning rate: 0.001
# epoch 23 time:  0.33446117423333516
# --------------------------------
# ========================================
# EPOCH: 24
# train_loss: 0.624277618882202
# train_precision: tensor([0.6859, 0.7921, 0.7536, 0.6944], device='cuda:0')
# train_recall: tensor([0.6745, 0.8270, 0.7504, 0.5341], device='cuda:0')
# val_loss: 0.6131697862512535
# val_precision: tensor([0.7022, 0.8108, 0.7352, 0.7008], device='cuda:0')
# val_recall: tensor([0.6527, 0.8166, 0.7926, 0.5987], device='cuda:0')
# Learning rate: 0.0001
# epoch 24 time:  0.33346658001666657
# --------------------------------
# ========================================
# EPOCH: 25
# train_loss: 0.5982799790799618
# train_precision: tensor([0.6979, 0.7972, 0.7644, 0.7203], device='cuda:0')
# train_recall: tensor([0.6829, 0.8378, 0.7579, 0.5697], device='cuda:0')
# val_loss: 0.5817593704495165
# val_precision: tensor([0.7086, 0.8196, 0.7541, 0.7946], device='cuda:0')
# val_recall: tensor([0.6881, 0.8247, 0.7961, 0.5313], device='cuda:0')
# Learning rate: 0.0001
# epoch 25 time:  0.3418707148499986
# --------------------------------
# ========================================
# EPOCH: 26
# train_loss: 0.5869780115783214
# train_precision: tensor([0.7041, 0.8049, 0.7686, 0.7211], device='cuda:0')
# train_recall: tensor([0.6943, 0.8372, 0.7641, 0.5742], device='cuda:0')
# val_loss: 0.5770943723618984
# val_precision: tensor([0.7171, 0.8165, 0.7531, 0.7800], device='cuda:0')
# val_recall: tensor([0.6777, 0.8306, 0.8011, 0.5764], device='cuda:0')
# Learning rate: 0.0001
# epoch 26 time:  0.3403680034333358
# --------------------------------
# ========================================
# EPOCH: 27
# train_loss: 0.5829863640169303
# train_precision: tensor([0.7043, 0.8046, 0.7711, 0.7247], device='cuda:0')
# train_recall: tensor([0.6941, 0.8375, 0.7652, 0.5889], device='cuda:0')
# val_loss: 0.5736439033514924
# val_precision: tensor([0.7223, 0.8143, 0.7582, 0.7675], device='cuda:0')
# val_recall: tensor([0.6786, 0.8370, 0.8014, 0.5811], device='cuda:0')
# Learning rate: 0.0001
# epoch 27 time:  0.3406843881499981
# --------------------------------
# ========================================
# EPOCH: 28
# train_loss: 0.5800076723453544
# train_precision: tensor([0.7067, 0.8060, 0.7728, 0.7192], device='cuda:0')
# train_recall: tensor([0.6963, 0.8395, 0.7662, 0.5873], device='cuda:0')
# val_loss: 0.5705007256733047
# val_precision: tensor([0.7251, 0.8133, 0.7595, 0.7925], device='cuda:0')
# val_recall: tensor([0.6813, 0.8415, 0.8018, 0.5556], device='cuda:0')
# Learning rate: 0.0001
# epoch 28 time:  0.3411129677166703
# --------------------------------
# ========================================
# EPOCH: 29
# train_loss: 0.5760713812850771
# train_precision: tensor([0.7099, 0.8062, 0.7737, 0.7309], device='cuda:0')
# train_recall: tensor([0.6979, 0.8401, 0.7683, 0.5980], device='cuda:0')
# val_loss: 0.5706650996373759
# val_precision: tensor([0.7103, 0.8218, 0.7660, 0.7923], device='cuda:0')
# val_recall: tensor([0.7023, 0.8252, 0.7931, 0.5690], device='cuda:0')
# Learning rate: 0.0001
# epoch 29 time:  0.3379411592833321
# --------------------------------
# ========================================
# EPOCH: 30
# train_loss: 0.5761560317661081
# train_precision: tensor([0.7098, 0.8078, 0.7726, 0.7250], device='cuda:0')
# train_recall: tensor([0.6969, 0.8408, 0.7682, 0.6022], device='cuda:0')
# val_loss: 0.5759692915611797
# val_precision: tensor([0.7386, 0.8170, 0.7347, 0.7828], device='cuda:0')
# val_recall: tensor([0.6468, 0.8360, 0.8292, 0.5667], device='cuda:0')
# Learning rate: 0.0001
# epoch 30 time:  0.3335242592000024
# --------------------------------
# ========================================
# EPOCH: 31
# train_loss: 0.5733646294190771
# train_precision: tensor([0.7129, 0.8079, 0.7748, 0.7325], device='cuda:0')
# train_recall: tensor([0.6985, 0.8424, 0.7706, 0.6071], device='cuda:0')
# val_loss: 0.5700113902489344
# val_precision: tensor([0.7178, 0.8229, 0.7547, 0.8072], device='cuda:0')
# val_recall: tensor([0.6873, 0.8259, 0.8081, 0.5485], device='cuda:0')
# Learning rate: 0.0001
# epoch 31 time:  0.3416385867333323
# --------------------------------
# ========================================
# EPOCH: 32
# train_loss: 0.5718445990766797
# train_precision: tensor([0.7120, 0.8080, 0.7773, 0.7362], device='cuda:0')
# train_recall: tensor([0.7006, 0.8422, 0.7704, 0.6068], device='cuda:0')
# val_loss: 0.5659955246580972
# val_precision: tensor([0.7229, 0.8134, 0.7635, 0.8066], device='cuda:0')
# val_recall: tensor([0.6864, 0.8417, 0.7987, 0.5616], device='cuda:0')
# Learning rate: 0.0001
# epoch 32 time:  0.34128056530000017
# --------------------------------
# ========================================
# EPOCH: 33
# train_loss: 0.570432686025188
# train_precision: tensor([0.7129, 0.8077, 0.7768, 0.7333], device='cuda:0')
# train_recall: tensor([0.7009, 0.8407, 0.7716, 0.6052], device='cuda:0')
# val_loss: 0.5688229998780622
# val_precision: tensor([0.7175, 0.8250, 0.7569, 0.8018], device='cuda:0')
# val_recall: tensor([0.6907, 0.8258, 0.8074, 0.5586], device='cuda:0')
# Learning rate: 0.0001
# epoch 33 time:  0.33530406943333446
# --------------------------------
# ========================================
# EPOCH: 34
# train_loss: 0.5690252617001533
# train_precision: tensor([0.7119, 0.8093, 0.7785, 0.7314], device='cuda:0')
# train_recall: tensor([0.7012, 0.8426, 0.7709, 0.6121], device='cuda:0')
# val_loss: 0.5652644050618013
# val_precision: tensor([0.7120, 0.8163, 0.7750, 0.7944], device='cuda:0')
# val_recall: tensor([0.7075, 0.8358, 0.7833, 0.5687], device='cuda:0')
# Learning rate: 0.0001
# epoch 34 time:  0.340971722116664
# --------------------------------
# ========================================
# EPOCH: 35
# train_loss: 0.5692465833964802
# train_precision: tensor([0.7115, 0.8095, 0.7769, 0.7318], device='cuda:0')
# train_recall: tensor([0.7007, 0.8417, 0.7707, 0.6102], device='cuda:0')
# val_loss: 0.5635227801899115
# val_precision: tensor([0.7159, 0.8154, 0.7751, 0.7808], device='cuda:0')
# val_recall: tensor([0.7057, 0.8379, 0.7842, 0.5852], device='cuda:0')
# Learning rate: 0.0001
# epoch 35 time:  0.3386814305166695
# --------------------------------
# ========================================
# EPOCH: 36
# train_loss: 0.5673471225159509
# train_precision: tensor([0.7145, 0.8102, 0.7793, 0.7309], device='cuda:0')
# train_recall: tensor([0.7026, 0.8444, 0.7723, 0.6104], device='cuda:0')
# val_loss: 0.5645142191814052
# val_precision: tensor([0.7187, 0.8152, 0.7707, 0.7976], device='cuda:0')
# val_recall: tensor([0.6980, 0.8396, 0.7921, 0.5667], device='cuda:0')
# Learning rate: 0.0001
# epoch 36 time:  0.33457591851666846
# --------------------------------
# ========================================
# EPOCH: 37
# train_loss: 0.5660241656360172
# train_precision: tensor([0.7143, 0.8099, 0.7786, 0.7269], device='cuda:0')
# train_recall: tensor([0.7027, 0.8434, 0.7715, 0.6105], device='cuda:0')
# val_loss: 0.5635331535504924
# val_precision: tensor([0.7222, 0.8208, 0.7614, 0.7848], device='cuda:0')
# val_recall: tensor([0.6902, 0.8333, 0.8036, 0.5785], device='cuda:0')
# Learning rate: 0.0001
# epoch 37 time:  0.3336673330333345
# --------------------------------
# ========================================
# EPOCH: 38
# train_loss: 0.5645200645994572
# train_precision: tensor([0.7131, 0.8099, 0.7782, 0.7381], device='cuda:0')
# train_recall: tensor([0.7032, 0.8405, 0.7717, 0.6225], device='cuda:0')
# val_loss: 0.5642729548944367
# val_precision: tensor([0.7234, 0.8199, 0.7609, 0.7934], device='cuda:0')
# val_recall: tensor([0.6907, 0.8332, 0.8037, 0.5781], device='cuda:0')
# Learning rate: 1e-05
# epoch 38 time:  0.33366918733333173
# --------------------------------
# ========================================
# EPOCH: 39
# train_loss: 0.5621929896019754
# train_precision: tensor([0.7154, 0.8105, 0.7796, 0.7462], device='cuda:0')
# train_recall: tensor([0.7030, 0.8446, 0.7725, 0.6299], device='cuda:0')
# val_loss: 0.5663984787960847
# val_precision: tensor([0.7137, 0.8334, 0.7571, 0.7977], device='cuda:0')
# val_recall: tensor([0.7014, 0.8153, 0.8079, 0.5734], device='cuda:0')
# Learning rate: 1e-05
# epoch 39 time:  0.33436961928333253
# --------------------------------
# ========================================
# EPOCH: 40
# train_loss: 0.5621964974417573
# train_precision: tensor([0.7158, 0.8105, 0.7807, 0.7332], device='cuda:0')
# train_recall: tensor([0.7050, 0.8428, 0.7729, 0.6257], device='cuda:0')
# val_loss: 0.5629593523012267
# val_precision: tensor([0.7258, 0.8127, 0.7655, 0.8068], device='cuda:0')
# val_recall: tensor([0.6894, 0.8436, 0.7984, 0.5596], device='cuda:0')
# Learning rate: 1e-05
# epoch 40 time:  0.33981192581666925
# --------------------------------
# ========================================
# EPOCH: 41
# train_loss: 0.5612907694563979
# train_precision: tensor([0.7158, 0.8117, 0.7808, 0.7322], device='cuda:0')
# train_recall: tensor([0.7068, 0.8436, 0.7715, 0.6235], device='cuda:0')
# val_loss: 0.5649449278910955
# val_precision: tensor([0.7178, 0.8288, 0.7564, 0.7982], device='cuda:0')
# val_recall: tensor([0.6957, 0.8219, 0.8075, 0.5714], device='cuda:0')
# Learning rate: 1e-05
# epoch 41 time:  0.3337039913166677
# --------------------------------
# ========================================
# EPOCH: 42
# train_loss: 0.5605317320497263
# train_precision: tensor([0.7158, 0.8122, 0.7795, 0.7351], device='cuda:0')
# train_recall: tensor([0.7051, 0.8441, 0.7732, 0.6160], device='cuda:0')
# val_loss: 0.5619810560511218
# val_precision: tensor([0.7245, 0.8182, 0.7649, 0.7896], device='cuda:0')
# val_recall: tensor([0.6916, 0.8368, 0.8018, 0.5862], device='cuda:0')
# Learning rate: 1e-05
# epoch 42 time:  0.34076799853333645
# --------------------------------
# ========================================
# EPOCH: 43
# train_loss: 0.5601897731423378
# train_precision: tensor([0.7177, 0.8117, 0.7814, 0.7467], device='cuda:0')
# train_recall: tensor([0.7062, 0.8452, 0.7741, 0.6278], device='cuda:0')
# val_loss: 0.5653220703204472
# val_precision: tensor([0.7335, 0.8146, 0.7533, 0.7885], device='cuda:0')
# val_recall: tensor([0.6701, 0.8421, 0.8128, 0.5811], device='cuda:0')
# Learning rate: 1e-05
# epoch 43 time:  0.33743812278333585
# --------------------------------
# ========================================
# EPOCH: 44
# train_loss: 0.5608182123374371
# train_precision: tensor([0.7158, 0.8112, 0.7810, 0.7362], device='cuda:0')
# train_recall: tensor([0.7059, 0.8422, 0.7738, 0.6250], device='cuda:0')
# val_loss: 0.5618887638052305
# val_precision: tensor([0.7152, 0.8256, 0.7686, 0.7967], device='cuda:0')
# val_recall: tensor([0.7080, 0.8278, 0.7956, 0.5768], device='cuda:0')
# Learning rate: 1e-05
# epoch 44 time:  0.3381181540333349
# --------------------------------
# ========================================
# EPOCH: 45
# train_loss: 0.5591964491776058
# train_precision: tensor([0.7168, 0.8128, 0.7807, 0.7364], device='cuda:0')
# train_recall: tensor([0.7076, 0.8423, 0.7745, 0.6228], device='cuda:0')
# val_loss: 0.5639717289143138
# val_precision: tensor([0.7198, 0.8307, 0.7564, 0.7894], device='cuda:0')
# val_recall: tensor([0.6956, 0.8213, 0.8103, 0.5832], device='cuda:0')
# Learning rate: 1e-05
# epoch 45 time:  0.33201442668332676
# --------------------------------
# ========================================
# EPOCH: 46
# train_loss: 0.5604579677539212
# train_precision: tensor([0.7167, 0.8103, 0.7818, 0.7476], device='cuda:0')
# train_recall: tensor([0.7059, 0.8445, 0.7738, 0.6215], device='cuda:0')
# val_loss: 0.560950519475672
# val_precision: tensor([0.7232, 0.8174, 0.7703, 0.7722], device='cuda:0')
# val_recall: tensor([0.6964, 0.8397, 0.7954, 0.5980], device='cuda:0')
# Learning rate: 1e-05
# epoch 46 time:  0.33934197193333
# --------------------------------
# ========================================
# EPOCH: 47
# train_loss: 0.5601366231838862
# train_precision: tensor([0.7163, 0.8135, 0.7813, 0.7390], device='cuda:0')
# train_recall: tensor([0.7070, 0.8435, 0.7739, 0.6325], device='cuda:0')
# val_loss: 0.5618390999734402
# val_precision: tensor([0.7171, 0.8257, 0.7663, 0.8010], device='cuda:0')
# val_recall: tensor([0.7044, 0.8284, 0.7994, 0.5707], device='cuda:0')
# Learning rate: 1e-05
# epoch 47 time:  0.3356585954999976
# --------------------------------
# ========================================
# EPOCH: 48
# train_loss: 0.5592956878599666
# train_precision: tensor([0.7175, 0.8119, 0.7816, 0.7444], device='cuda:0')
# train_recall: tensor([0.7066, 0.8445, 0.7750, 0.6203], device='cuda:0')
# val_loss: 0.5595151592459944
# val_precision: tensor([0.7256, 0.8164, 0.7670, 0.7858], device='cuda:0')
# val_recall: tensor([0.6908, 0.8413, 0.7995, 0.5906], device='cuda:0')
# Learning rate: 1e-05
# epoch 48 time:  0.34081078550000254
# --------------------------------
# ========================================
# EPOCH: 49
# train_loss: 0.5591897619267304
# train_precision: tensor([0.7171, 0.8130, 0.7801, 0.7376], device='cuda:0')
# train_recall: tensor([0.7064, 0.8431, 0.7747, 0.6263], device='cuda:0')
# val_loss: 0.5613330746690433
# val_precision: tensor([0.7236, 0.8172, 0.7666, 0.7916], device='cuda:0')
# val_recall: tensor([0.6942, 0.8386, 0.7981, 0.5805], device='cuda:0')
# Learning rate: 1e-05
# epoch 49 time:  0.33137897115000214
# --------------------------------
# ========================================
# EPOCH: 50
# train_loss: 0.5578858440475805
# train_precision: tensor([0.7160, 0.8135, 0.7824, 0.7425], device='cuda:0')
# train_recall: tensor([0.7081, 0.8427, 0.7744, 0.6351], device='cuda:0')
# val_loss: 0.5637880965239472
# val_precision: tensor([0.7254, 0.8224, 0.7553, 0.8109], device='cuda:0')
# val_recall: tensor([0.6853, 0.8320, 0.8118, 0.5586], device='cuda:0')
# Learning rate: 1e-05
# epoch 50 time:  0.33004530181666875
# --------------------------------
# ========================================
# EPOCH: 51
# train_loss: 0.5587060278370267
# train_precision: tensor([0.7171, 0.8125, 0.7820, 0.7411], device='cuda:0')
# train_recall: tensor([0.7062, 0.8435, 0.7762, 0.6257], device='cuda:0')
# val_loss: 0.5622003426154455
# val_precision: tensor([0.7285, 0.8209, 0.7572, 0.7879], device='cuda:0')
# val_recall: tensor([0.6829, 0.8342, 0.8119, 0.5842], device='cuda:0')
# Learning rate: 5e-06
# epoch 51 time:  0.32566435841667196
# --------------------------------
# ========================================
# EPOCH: 52
# train_loss: 0.5576018847879909
# train_precision: tensor([0.7176, 0.8119, 0.7820, 0.7440], device='cuda:0')
# train_recall: tensor([0.7071, 0.8440, 0.7747, 0.6286], device='cuda:0')
# val_loss: 0.5620435695681307
# val_precision: tensor([0.7223, 0.8217, 0.7615, 0.7876], device='cuda:0')
# val_recall: tensor([0.6912, 0.8325, 0.8045, 0.5795], device='cuda:0')
# Learning rate: 5e-06
# epoch 52 time:  0.32234140071667144
# --------------------------------
# ========================================
# EPOCH: 53
# train_loss: 0.5587957164361363
# train_precision: tensor([0.7170, 0.8137, 0.7809, 0.7419], device='cuda:0')
# train_recall: tensor([0.7050, 0.8451, 0.7762, 0.6247], device='cuda:0')
# val_loss: 0.5626542931629552
# val_precision: tensor([0.7251, 0.8220, 0.7595, 0.7813], device='cuda:0')
# val_recall: tensor([0.6874, 0.8322, 0.8075, 0.5966], device='cuda:0')
# Learning rate: 5e-06
# epoch 53 time:  0.3234068455166683
# --------------------------------
# ========================================
# EPOCH: 54
# train_loss: 0.5580653821428617
# train_precision: tensor([0.7173, 0.8136, 0.7793, 0.7368], device='cuda:0')
# train_recall: tensor([0.7044, 0.8445, 0.7751, 0.6294], device='cuda:0')
# val_loss: 0.5609833777778679
# val_precision: tensor([0.7244, 0.8178, 0.7657, 0.7948], device='cuda:0')
# val_recall: tensor([0.6928, 0.8373, 0.8018, 0.5778], device='cuda:0')
# Learning rate: 5e-06
# epoch 54 time:  0.3227016004166671
# --------------------------------
# ========================================
# EPOCH: 55
# train_loss: 0.5579064586687655
# train_precision: tensor([0.7160, 0.8129, 0.7825, 0.7378], device='cuda:0')
# train_recall: tensor([0.7075, 0.8437, 0.7735, 0.6302], device='cuda:0')
# val_loss: 0.5633613937430911
# val_precision: tensor([0.7228, 0.8262, 0.7570, 0.7897], device='cuda:0')
# val_recall: tensor([0.6897, 0.8271, 0.8107, 0.5828], device='cuda:0')
# Learning rate: 5e-06
# epoch 55 time:  0.32495005724999826
# --------------------------------
# ========================================
# EPOCH: 56
# train_loss: 0.5581031869209948
# train_precision: tensor([0.7163, 0.8128, 0.7823, 0.7294], device='cuda:0')
# train_recall: tensor([0.7070, 0.8445, 0.7730, 0.6260], device='cuda:0')
# val_loss: 0.5617913665870825
# val_precision: tensor([0.7233, 0.8191, 0.7621, 0.8085], device='cuda:0')
# val_recall: tensor([0.6906, 0.8356, 0.8043, 0.5630], device='cuda:0')
# Learning rate: 5e-06
# epoch 56 time:  0.3228149356333309
# --------------------------------
# ========================================
# EPOCH: 57
# train_loss: 0.5581375717407181
# train_precision: tensor([0.7179, 0.8128, 0.7821, 0.7418], device='cuda:0')
# train_recall: tensor([0.7077, 0.8455, 0.7738, 0.6263], device='cuda:0')
# val_loss: 0.5634740495019489
# val_precision: tensor([0.7106, 0.8329, 0.7651, 0.7875], device='cuda:0')
# val_recall: tensor([0.7095, 0.8174, 0.8004, 0.5828], device='cuda:0')
# Learning rate: 5e-06
# epoch 57 time:  0.32184825406667034
# --------------------------------
# ========================================
# EPOCH: 58
# train_loss: 0.5582338956849916
# train_precision: tensor([0.7176, 0.8136, 0.7805, 0.7399], device='cuda:0')
# train_recall: tensor([0.7071, 0.8434, 0.7750, 0.6289], device='cuda:0')
# val_loss: 0.5603315745790799
# val_precision: tensor([0.7270, 0.8203, 0.7610, 0.7755], device='cuda:0')
# val_recall: tensor([0.6871, 0.8350, 0.8067, 0.5966], device='cuda:0')
# Learning rate: 5e-06
# Early stopping at epoch 58 with best validation loss 0.5595151592459944
# training_checkpoints/efficient_net_b02024-04-21 15:45:01.873940.pth
# <All keys matched successfully>

# %%
from sklearn.metrics import confusion_matrix, classification_report
from torch.utils.data import DataLoader
import numpy as np
import torch 
from torchvision.models import resnet18
import torch.nn as nn


def test_report(model, dataloader):
    """Prints confusion matrix for testing dataset
    dataloader should be of batch_size=1."""

    y_pred = []
    y_test = []
    model.eval()
    with torch.no_grad():
        for data, label in dataloader:
            output = model(data)
            label = label.numpy()
            output = output.numpy()
            y_pred.append(np.argmax(output))
            y_test.append(np.argmax(label))
        print(confusion_matrix(y_test, y_pred))
        print(classification_report(y_test, y_pred))

testset =ImageDataset(data_path='test_data')
dataloader = DataLoader(testset, batch_size=1, shuffle=True)

test_report(my_model.to('cpu'), dataloader)
# Out:
# [[693  93 209   5]
#  [ 98 845  50   7]
#  [131  50 813   6]
#  [ 22  11  12  55]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.69      0.71      1000
#            1       0.85      0.84      0.85      1000
#            2       0.75      0.81      0.78      1000
#            3       0.75      0.55      0.64       100
#
#     accuracy                           0.78      3100
#    macro avg       0.77      0.73      0.74      3100
# weighted avg       0.78      0.78      0.77      3100
# wandb: Network error (ReadTimeout), entering retry loop.
