# %%
import time
import sys
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from dataset import ImageDataset
import torch.nn.functional as F
from torchmetrics import Precision, Recall
from torchvision.models import resnet18
import warnings
from collections import defaultdict
import wandb
import datetime
import os
import torchvision.models as models
import torch.nn as nn


class EfficientNetB0(nn.Module):
    def __init__(self, num_classes=4):
        super(EfficientNetB0, self).__init__()
        self.base_model = models.efficientnet_b5(pretrained=False)
        num_ftrs = self.base_model.classifier[1].in_features
        self.base_model.classifier[1] = nn.Linear(num_ftrs, num_classes)

    def forward(self, x):
        return self.base_model(x)


warnings.filterwarnings('ignore')
torch.set_float32_matmul_precision('high')


run_name = f'efficient_net_b5_{datetime.datetime.now()}'
run_path = f'training_checkpoints/{run_name}'

wandb.init(project="cells", 
           entity="adamsoja",
          name=run_name)

import random
random.seed(2233)
torch.manual_seed(2233)

from albumentations import (
    Compose,
    Resize,
    OneOf,
    RandomBrightness,
    RandomContrast,
    MotionBlur,
    MedianBlur,
    GaussianBlur,
    VerticalFlip,
    HorizontalFlip,
    ShiftScaleRotate,
    Normalize,
)

transform = Compose(
    [
        OneOf([RandomBrightness(limit=0.4, p=1), RandomContrast(limit=0.4, p=1)]),
        OneOf([MotionBlur(blur_limit=3), MedianBlur(blur_limit=3), GaussianBlur(blur_limit=3),], p=0.7,),
        VerticalFlip(p=0.5),
        HorizontalFlip(p=0.5),]
)

class MyModel(nn.Module):
    def __init__(self, model, learning_rate, weight_decay):
        super(MyModel, self).__init__()
        self.model = model
        self.learning_rate = learning_rate
        self.weight_decay = weight_decay
        self.criterion = nn.CrossEntropyLoss()
        self.metric_precision = Precision(task="multiclass", num_classes=4, average=None).to('cuda')
        self.metric_recall = Recall(task="multiclass", num_classes=4, average=None).to('cuda')
        self.train_loss = []
        self.valid_loss = []
        self.precision_per_epochs = []
        self.recall_per_epochs = []

        self.optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, mode="min", factor=0.1, patience=2, min_lr=5e-6, verbose=True)
        self.step = 0

    
    def forward(self, x):
        return self.model(x)

    def train_one_epoch(self, trainloader):
        self.step += 1
        self.train()
        for batch_idx, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()
            _, preds = torch.max(outputs, 1)
            _, labels = torch.max(labels, 1)
            self.metric_precision(preds, labels)
            self.metric_recall(preds, labels)
            self.train_loss.append(loss.item())


        

        
        avg_loss = np.mean(self.train_loss)
        self.train_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        self.precision_per_epochs.append(precision)
        self.recall_per_epochs.append(recall)
        print(f'train_loss: {avg_loss}')
        print(f'train_precision: {precision}')
        print(f'train_recall: {recall}')

        wandb.log({'loss': avg_loss},step=self.step)
        wandb.log({'Normal precision': precision[0].item()},step=self.step)
        wandb.log({'Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'Other precision': precision[3].item()},step=self.step)


        wandb.log({'Normal recall': recall[0].item()},step=self.step)
        wandb.log({'Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'Other recall': recall[3].item()},step=self.step)
        
        
        self.metric_precision.reset()
        self.metric_recall.reset()


    

    def evaluate(self, testloader):
        self.eval()
        with torch.no_grad():
            for batch_idx, (inputs, labels) in enumerate(testloader):
                inputs, labels = inputs.to('cuda'), labels.to('cuda')
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)
                _, labels = torch.max(labels, 1)
                self.metric_precision(preds, labels)
                self.metric_recall(preds, labels)
                self.valid_loss.append(loss.item())
    
        avg_loss = np.mean(self.valid_loss)
        self.scheduler.step(avg_loss)
        self.valid_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        print(f'val_loss: {avg_loss}')
        print(f'val_precision: {precision}')
        print(f'val_recall: {recall}')
        self.metric_precision.reset()
        self.metric_recall.reset()

        wandb.log({'val_loss': avg_loss}, step=self.step)
        
        wandb.log({'val_Normal precision': precision[0].item()},step=self.step)
        wandb.log({'val_Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'val_Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'val_Other precision': precision[3].item()},step=self.step)


        wandb.log({'val_Normal recall': recall[0].item()},step=self.step)
        wandb.log({'val_Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'val_Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'val_Other recall': recall[3].item()},step=self.step)


        for param_group in self.optimizer.param_groups:
            print(f"Learning rate: {param_group['lr']}")
        return avg_loss

torch.cuda.empty_cache()
batch_size = 256
trainset = ImageDataset(data_path='train_data', transform=transform)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=5)

testset = ImageDataset(data_path='validation_data')
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=3)

learning_rate = 0.001
weight_decay = 0.00001

model = EfficientNetB0()
model = model.to('cuda')


my_model = MyModel(model=model, learning_rate=learning_rate, weight_decay=weight_decay)
my_model = my_model.to('cuda')

num_epochs = 100
early_stop_patience = 10
best_val_loss = float('inf')
best_model_state_dict = None

for epoch in range(num_epochs):
    print('========================================')
    print(f'EPOCH: {epoch}') 
    time_start = time.perf_counter()
    my_model.train_one_epoch(trainloader)
    
    with torch.no_grad():
        val_loss = my_model.evaluate(testloader)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_state_dict = my_model.state_dict()
        torch.save(best_model_state_dict, f'{run_path}.pth')
        
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch} with best validation loss {best_val_loss}")
        break
    time_epoch = time.perf_counter() - time_start
    print(f'epoch {epoch} time:  {time_epoch/60}')
    print('--------------------------------')

# Load the best model state dict
print(f'{run_path}.pth')
my_model.load_state_dict(torch.load(f'{run_path}.pth'))
# Out:
# wandb: Currently logged in as: adamsoja. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/adam/Desktop/cells_master_thesis/wandb/run-20240421_184602-sufhz7dp</code>
# Syncing run <strong><a href='https://wandb.ai/adamsoja/cells/runs/sufhz7dp' target="_blank">efficient_net_b5_2024-04-21 18:46:01.146855</a></strong> to <a href='https://wandb.ai/adamsoja/cells' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adamsoja/cells' target="_blank">https://wandb.ai/adamsoja/cells</a>
#  View run at <a href='https://wandb.ai/adamsoja/cells/runs/sufhz7dp' target="_blank">https://wandb.ai/adamsoja/cells/runs/sufhz7dp</a>
# ========================================
# EPOCH: 0
# train_loss: 1.2499522850626992
# train_precision: tensor([0.3246, 0.3381, 0.3246, 0.0293], device='cuda:0')
# train_recall: tensor([0.3773, 0.2483, 0.3895, 0.0010], device='cuda:0')
# val_loss: 4.67663554896911
# val_precision: tensor([0.2975, 0.2677, 0.3234, 0.0000], device='cuda:0')
# val_recall: tensor([0.2321, 0.4443, 0.2136, 0.0000], device='cuda:0')
# Learning rate: 0.001
# epoch 0 time:  1.1319465305166887
# --------------------------------
# ========================================
# EPOCH: 1
# train_loss: 1.2313500940090134
# train_precision: tensor([0.3370, 0.3823, 0.3518, 0.0196], device='cuda:0')
# train_recall: tensor([3.3055e-01, 4.2925e-01, 3.5030e-01, 1.4430e-04], device='cuda:0')
# val_loss: 1.3013328555557462
# val_precision: tensor([0.3519, 0.7555, 0.5391, 0.0000], device='cuda:0')
# val_recall: tensor([0.9443, 0.2807, 0.0243, 0.0000], device='cuda:0')
# Learning rate: 0.001
# epoch 1 time:  1.150729812833318
# --------------------------------
# ========================================
# EPOCH: 2
# train_loss: 1.0394752901224864
# train_precision: tensor([0.4346, 0.6288, 0.5663, 0.0000], device='cuda:0')
# train_recall: tensor([0.4170, 0.7581, 0.5292, 0.0000], device='cuda:0')
# val_loss: 0.9836934599611494
# val_precision: tensor([0.4212, 0.8423, 0.6467, 0.0000], device='cuda:0')
# val_recall: tensor([0.6742, 0.4609, 0.6156, 0.0000], device='cuda:0')
# Learning rate: 0.001
# epoch 2 time:  1.1434901374166657
# --------------------------------
# ========================================
# EPOCH: 3
# train_loss: 0.9949742127742086
# train_precision: tensor([0.4646, 0.6657, 0.6414, 0.0588], device='cuda:0')
# train_recall: tensor([5.3551e-01, 7.5317e-01, 5.2313e-01, 1.4430e-04], device='cuda:0')
# val_loss: 1.0225239253706402
# val_precision: tensor([0.4244, 0.7176, 0.5298, 0.0000], device='cuda:0')
# val_recall: tensor([0.4305, 0.6062, 0.6574, 0.0000], device='cuda:0')
# Learning rate: 0.001
# epoch 3 time:  1.0921941338833372
# --------------------------------
# ========================================
# EPOCH: 4
# train_loss: 1.0159696848619553
# train_precision: tensor([0.4726, 0.6449, 0.6169, 0.0000], device='cuda:0')
# train_recall: tensor([0.5095, 0.7476, 0.5321, 0.0000], device='cuda:0')
# val_loss: 1.2101411865817175
# val_precision: tensor([0.3340, 0.5609, 0.3488, 0.0000], device='cuda:0')
# val_recall: tensor([0.3702, 0.3535, 0.4748, 0.0000], device='cuda:0')
# Learning rate: 0.001
# epoch 4 time:  1.092712870216686
# --------------------------------
# ========================================
# EPOCH: 5
# train_loss: 1.0618450236462411
# train_precision: tensor([0.4370, 0.6126, 0.5266, 0.0357], device='cuda:0')
# train_recall: tensor([3.6140e-01, 7.2569e-01, 5.7299e-01, 1.4430e-04], device='cuda:0')
# val_loss: 0.9133085207806693
# val_precision: tensor([0.5091, 0.7282, 0.6635, 0.0000], device='cuda:0')
# val_recall: tensor([0.6427, 0.6930, 0.5877, 0.0000], device='cuda:0')
# Learning rate: 0.001
# epoch 5 time:  1.153073763483341
# --------------------------------
# ========================================
# EPOCH: 6
# train_loss: 0.9648194647970654
# train_precision: tensor([0.5276, 0.6607, 0.6322, 0.1176], device='cuda:0')
# train_recall: tensor([5.1727e-01, 7.5365e-01, 6.1870e-01, 2.8860e-04], device='cuda:0')
# val_loss: 0.9088183834320969
# val_precision: tensor([0.5571, 0.6423, 0.6555, 0.0000], device='cuda:0')
# val_recall: tensor([0.4947, 0.8369, 0.5959, 0.0000], device='cuda:0')
# Learning rate: 0.001
# epoch 6 time:  1.142709893283336
# --------------------------------
# ========================================
# EPOCH: 7
# train_loss: 1.0257513902726627
# train_precision: tensor([0.4723, 0.6366, 0.5682, 0.0588], device='cuda:0')
# train_recall: tensor([4.3861e-01, 7.4227e-01, 5.7100e-01, 2.8860e-04], device='cuda:0')
# val_loss: 1.4570919973982706
# val_precision: tensor([0.4458, 0.7068, 0.6972, 0.0000], device='cuda:0')
# val_recall: tensor([0.6743, 0.7333, 0.3835, 0.0000], device='cuda:0')
# Learning rate: 0.001
# epoch 7 time:  1.0956087555500138
# --------------------------------
# ========================================
# EPOCH: 8
# train_loss: 0.9667021046791758
# train_precision: tensor([0.5134, 0.6676, 0.6294, 0.0000], device='cuda:0')
# train_recall: tensor([0.5155, 0.7607, 0.6018, 0.0000], device='cuda:0')
# val_loss: 0.9079645484685898
# val_precision: tensor([0.5532, 0.6511, 0.6229, 0.0000], device='cuda:0')
# val_recall: tensor([0.4373, 0.8030, 0.6703, 0.0000], device='cuda:0')
# Learning rate: 0.001
# epoch 8 time:  1.1440851747833525
# --------------------------------
# ========================================
# EPOCH: 9
# train_loss: 0.9226851283794357
# train_precision: tensor([0.5347, 0.6762, 0.6320, 0.0000], device='cuda:0')
# train_recall: tensor([0.5261, 0.7634, 0.6233, 0.0000], device='cuda:0')
# val_loss: 0.8803021058440208
# val_precision: tensor([0.5947, 0.7052, 0.6143, 0.0000], device='cuda:0')
# val_recall: tensor([0.5074, 0.7511, 0.7259, 0.0000], device='cuda:0')
# Learning rate: 0.001
# epoch 9 time:  1.1451602668000003
# --------------------------------
# ========================================
# EPOCH: 10
# train_loss: 0.8875508163656507
# train_precision: tensor([0.5559, 0.6853, 0.6448, 0.0545], device='cuda:0')
# train_recall: tensor([5.4117e-01, 7.6486e-01, 6.5107e-01, 4.3290e-04], device='cuda:0')
# val_loss: 0.8763987912072075
# val_precision: tensor([0.5755, 0.7610, 0.5973, 0.0000], device='cuda:0')
# val_recall: tensor([0.5053, 0.6885, 0.7868, 0.0000], device='cuda:0')
# Learning rate: 0.001
# epoch 10 time:  1.146112308766654
# --------------------------------
# ========================================
# EPOCH: 11
# train_loss: 0.8578064504833448
# train_precision: tensor([0.5694, 0.6927, 0.6633, 0.4987], device='cuda:0')
# train_recall: tensor([0.5595, 0.7715, 0.6621, 0.0278], device='cuda:0')
# val_loss: 0.8360865770942635
# val_precision: tensor([0.6048, 0.7734, 0.6036, 0.8438], device='cuda:0')
# val_recall: tensor([0.5317, 0.6972, 0.7925, 0.0545], device='cuda:0')
# Learning rate: 0.001
# epoch 11 time:  1.1436842770166853
# --------------------------------
# ========================================
# EPOCH: 12
# train_loss: 0.83763428209793
# train_precision: tensor([0.5802, 0.7016, 0.6765, 0.6310], device='cuda:0')
# train_recall: tensor([0.5732, 0.7773, 0.6718, 0.0698], device='cuda:0')
# val_loss: 0.8227592570914163
# val_precision: tensor([0.5566, 0.7643, 0.6977, 0.8106], device='cuda:0')
# val_recall: tensor([0.6698, 0.7167, 0.6584, 0.1239], device='cuda:0')
# Learning rate: 0.001
# epoch 12 time:  1.1452573505833545
# --------------------------------
# ========================================
# EPOCH: 13
# train_loss: 0.8254054142605691
# train_precision: tensor([0.5860, 0.7086, 0.6821, 0.6808], device='cuda:0')
# train_recall: tensor([0.5794, 0.7804, 0.6792, 0.0973], device='cuda:0')
# val_loss: 0.8043685480952263
# val_precision: tensor([0.6107, 0.7266, 0.6647, 0.9274], device='cuda:0')
# val_recall: tensor([0.5606, 0.7655, 0.7422, 0.1118], device='cuda:0')
# Learning rate: 0.001
# epoch 13 time:  1.1423313275166644
# --------------------------------
# ========================================
# EPOCH: 14
# train_loss: 0.8080937217388834
# train_precision: tensor([0.5975, 0.7169, 0.6896, 0.7291], device='cuda:0')
# train_recall: tensor([0.5883, 0.7847, 0.6927, 0.1196], device='cuda:0')
# val_loss: 0.8004978321492672
# val_precision: tensor([0.6376, 0.7807, 0.6180, 0.9393], device='cuda:0')
# val_recall: tensor([0.5285, 0.7235, 0.8237, 0.1094], device='cuda:0')
# Learning rate: 0.001
# epoch 14 time:  1.1403737425833544
# --------------------------------
# ========================================
# EPOCH: 15
# train_loss: 0.8142111307808331
# train_precision: tensor([0.5958, 0.7156, 0.6865, 0.7128], device='cuda:0')
# train_recall: tensor([0.5827, 0.7845, 0.6937, 0.1092], device='cuda:0')
# val_loss: 0.8478821146819326
# val_precision: tensor([0.5704, 0.7146, 0.7079, 0.8007], device='cuda:0')
# val_recall: tensor([0.6266, 0.7808, 0.6364, 0.0798], device='cuda:0')
# Learning rate: 0.001
# epoch 15 time:  1.0909295779166617
# --------------------------------
# ========================================
# EPOCH: 16
# train_loss: 0.860179469982783
# train_precision: tensor([0.5708, 0.6936, 0.6632, 0.6241], device='cuda:0')
# train_recall: tensor([0.5561, 0.7718, 0.6666, 0.0494], device='cuda:0')
# val_loss: 0.9460945699777868
# val_precision: tensor([0.5984, 0.8313, 0.5059, 0.8342], device='cuda:0')
# val_recall: tensor([0.4260, 0.5416, 0.8753, 0.0542], device='cuda:0')
# Learning rate: 0.001
# epoch 16 time:  1.089221342066685
# --------------------------------
# ========================================
# EPOCH: 17
# train_loss: 0.830850067167055
# train_precision: tensor([0.5961, 0.6987, 0.6805, 0.7017], device='cuda:0')
# train_recall: tensor([0.5653, 0.7877, 0.6869, 0.1049], device='cuda:0')
# val_loss: 0.8087099037236638
# val_precision: tensor([0.6311, 0.7668, 0.6357, 0.5540], device='cuda:0')
# val_recall: tensor([0.5322, 0.7456, 0.7951, 0.1865], device='cuda:0')
# Learning rate: 0.0001
# epoch 17 time:  1.0906608115166818
# --------------------------------
# ========================================
# EPOCH: 18
# train_loss: 0.7904793788989385
# train_precision: tensor([0.6129, 0.7175, 0.6981, 0.7500], device='cuda:0')
# train_recall: tensor([0.5848, 0.7990, 0.7066, 0.1515], device='cuda:0')
# val_loss: 0.7609400037262175
# val_precision: tensor([0.6446, 0.7414, 0.6853, 0.8018], device='cuda:0')
# val_recall: tensor([0.5716, 0.8036, 0.7582, 0.1838], device='cuda:0')
# Learning rate: 0.0001
# epoch 18 time:  1.1408808667833303
# --------------------------------
# ========================================
# EPOCH: 19
# train_loss: 0.7821251859977132
# train_precision: tensor([0.6170, 0.7212, 0.6991, 0.7733], device='cuda:0')
# train_recall: tensor([0.5877, 0.7993, 0.7119, 0.1615], device='cuda:0')
# val_loss: 0.7525215975112385
# val_precision: tensor([0.6436, 0.7445, 0.6948, 0.7219], device='cuda:0')
# val_recall: tensor([0.5898, 0.8059, 0.7461, 0.1966], device='cuda:0')
# Learning rate: 0.0001
# epoch 19 time:  1.141861060916684
# --------------------------------
# ========================================
# EPOCH: 20
# train_loss: 0.77612168717952
# train_precision: tensor([0.6187, 0.7239, 0.7032, 0.7885], device='cuda:0')
# train_recall: tensor([0.5943, 0.7988, 0.7135, 0.1678], device='cuda:0')
# val_loss: 0.7485720266070631
# val_precision: tensor([0.6410, 0.7513, 0.6912, 0.8359], device='cuda:0')
# val_recall: tensor([0.5955, 0.7971, 0.7520, 0.1852], device='cuda:0')
# Learning rate: 0.0001
# epoch 20 time:  1.1421025483500065
# --------------------------------
# ========================================
# EPOCH: 21
# train_loss: 0.7710672965361959
# train_precision: tensor([0.6187, 0.7256, 0.7038, 0.7821], device='cuda:0')
# train_recall: tensor([0.5943, 0.7986, 0.7160, 0.1678], device='cuda:0')
# val_loss: 0.7416177150275972
# val_precision: tensor([0.6392, 0.7684, 0.6941, 0.8042], device='cuda:0')
# val_recall: tensor([0.6235, 0.7836, 0.7501, 0.1949], device='cuda:0')
# Learning rate: 0.0001
# epoch 21 time:  1.1430222097166733
# --------------------------------
# ========================================
# EPOCH: 22
# train_loss: 0.7620835842830794
# train_precision: tensor([0.6232, 0.7301, 0.7040, 0.7654], device='cuda:0')
# train_recall: tensor([0.5983, 0.8006, 0.7180, 0.1808], device='cuda:0')
# val_loss: 0.7330811688469516
# val_precision: tensor([0.6431, 0.7620, 0.6891, 0.8718], device='cuda:0')
# val_recall: tensor([0.5982, 0.7920, 0.7638, 0.1923], device='cuda:0')
# Learning rate: 0.0001
# epoch 22 time:  1.1441058479833373
# --------------------------------
# ========================================
# EPOCH: 23
# train_loss: 0.7559295109340123
# train_precision: tensor([0.6272, 0.7318, 0.7045, 0.7175], device='cuda:0')
# train_recall: tensor([0.5998, 0.8006, 0.7200, 0.1990], device='cuda:0')
# val_loss: 0.7340476431780392
# val_precision: tensor([0.6717, 0.7280, 0.6871, 0.7914], device='cuda:0')
# val_recall: tensor([0.5439, 0.8278, 0.7730, 0.2222], device='cuda:0')
# Learning rate: 0.0001
# epoch 23 time:  1.0898027674333206
# --------------------------------
# ========================================
# EPOCH: 24
# train_loss: 0.7497627403764497
# train_precision: tensor([0.6281, 0.7340, 0.7071, 0.6882], device='cuda:0')
# train_recall: tensor([0.6002, 0.8008, 0.7214, 0.2274], device='cuda:0')
# val_loss: 0.720053112341298
# val_precision: tensor([0.6500, 0.7711, 0.6898, 0.7786], device='cuda:0')
# val_recall: tensor([0.6070, 0.7844, 0.7706, 0.2451], device='cuda:0')
# Learning rate: 0.0001
# epoch 24 time:  1.141127053466668
# --------------------------------
# ========================================
# EPOCH: 25
# train_loss: 0.7425901754980996
# train_precision: tensor([0.6310, 0.7400, 0.7096, 0.6807], device='cuda:0')
# train_recall: tensor([0.6067, 0.8000, 0.7236, 0.2550], device='cuda:0')
# val_loss: 0.7113925325373809
# val_precision: tensor([0.6592, 0.7660, 0.6943, 0.7816], device='cuda:0')
# val_recall: tensor([0.5990, 0.7998, 0.7724, 0.2710], device='cuda:0')
# Learning rate: 0.0001
# epoch 25 time:  1.1422764196833366
# --------------------------------
# ========================================
# EPOCH: 26
# train_loss: 0.7371300276546251
# train_precision: tensor([0.6343, 0.7411, 0.7089, 0.6617], device='cuda:0')
# train_recall: tensor([0.6061, 0.8011, 0.7245, 0.2749], device='cuda:0')
# val_loss: 0.706694299644894
# val_precision: tensor([0.6550, 0.7678, 0.7012, 0.8276], device='cuda:0')
# val_recall: tensor([0.6107, 0.7979, 0.7687, 0.2667], device='cuda:0')
# Learning rate: 0.0001
# epoch 26 time:  1.1442305501499808
# --------------------------------
# ========================================
# EPOCH: 27
# train_loss: 0.7299072207439513
# train_precision: tensor([0.6390, 0.7449, 0.7117, 0.6573], device='cuda:0')
# train_recall: tensor([0.6103, 0.8023, 0.7286, 0.2895], device='cuda:0')
# val_loss: 0.6996735536389881
# val_precision: tensor([0.6639, 0.7646, 0.7039, 0.7624], device='cuda:0')
# val_recall: tensor([0.6037, 0.8063, 0.7706, 0.3155], device='cuda:0')
# Learning rate: 0.0001
# epoch 27 time:  1.1434136156500245
# --------------------------------
# ========================================
# EPOCH: 28
# train_loss: 0.7250777302753357
# train_precision: tensor([0.6409, 0.7460, 0.7135, 0.6474], device='cuda:0')
# train_recall: tensor([0.6135, 0.8044, 0.7260, 0.3033], device='cuda:0')
# val_loss: 0.6995509060720603
# val_precision: tensor([0.6523, 0.7772, 0.7072, 0.7964], device='cuda:0')
# val_recall: tensor([0.6341, 0.7925, 0.7576, 0.2949], device='cuda:0')
# Learning rate: 0.0001
# epoch 28 time:  1.1431281397333501
# --------------------------------
# ========================================
# EPOCH: 29
# train_loss: 0.722280203586533
# train_precision: tensor([0.6421, 0.7474, 0.7134, 0.6636], device='cuda:0')
# train_recall: tensor([0.6139, 0.8048, 0.7271, 0.3196], device='cuda:0')
# val_loss: 0.6990727571149667
# val_precision: tensor([0.6436, 0.7908, 0.7040, 0.8131], device='cuda:0')
# val_recall: tensor([0.6423, 0.7728, 0.7659, 0.3017], device='cuda:0')
# Learning rate: 0.0001
# epoch 29 time:  1.141434940266663
# --------------------------------
# ========================================
# EPOCH: 30
# train_loss: 0.7177652412936801
# train_precision: tensor([0.6410, 0.7499, 0.7152, 0.6648], device='cuda:0')
# train_recall: tensor([0.6153, 0.8041, 0.7280, 0.3315], device='cuda:0')
# val_loss: 0.6916799911194378
# val_precision: tensor([0.6692, 0.7754, 0.6952, 0.7433], device='cuda:0')
# val_recall: tensor([0.5983, 0.8014, 0.7820, 0.3529], device='cuda:0')
# Learning rate: 0.0001
# epoch 30 time:  1.1424317100666788
# --------------------------------
# ========================================
# EPOCH: 31
# train_loss: 0.7126647142427308
# train_precision: tensor([0.6445, 0.7513, 0.7153, 0.6553], device='cuda:0')
# train_recall: tensor([0.6156, 0.8050, 0.7309, 0.3374], device='cuda:0')
# val_loss: 0.6881869159638881
# val_precision: tensor([0.6592, 0.7812, 0.7068, 0.8011], device='cuda:0')
# val_recall: tensor([0.6289, 0.7914, 0.7716, 0.3296], device='cuda:0')
# Learning rate: 0.0001
# epoch 31 time:  1.1409295315166674
# --------------------------------
# ========================================
# EPOCH: 32
# train_loss: 0.7100650495006925
# train_precision: tensor([0.6456, 0.7512, 0.7185, 0.6603], device='cuda:0')
# train_recall: tensor([0.6193, 0.8078, 0.7281, 0.3430], device='cuda:0')
# val_loss: 0.689039410981867
# val_precision: tensor([0.6831, 0.7769, 0.6864, 0.7661], device='cuda:0')
# val_recall: tensor([0.5858, 0.7966, 0.8030, 0.3606], device='cuda:0')
# Learning rate: 0.0001
# epoch 32 time:  1.0899990229499963
# --------------------------------
# ========================================
# EPOCH: 33
# train_loss: 0.707268875837326
# train_precision: tensor([0.6487, 0.7534, 0.7199, 0.6651], device='cuda:0')
# train_recall: tensor([0.6218, 0.8076, 0.7304, 0.3657], device='cuda:0')
# val_loss: 0.6799048446946674
# val_precision: tensor([0.6495, 0.7858, 0.7292, 0.7415], device='cuda:0')
# val_recall: tensor([0.6607, 0.7913, 0.7468, 0.3815], device='cuda:0')
# Learning rate: 0.0001
# epoch 33 time:  1.139238078616654
# --------------------------------
# ========================================
# EPOCH: 34
# train_loss: 0.7047581285947845
# train_precision: tensor([0.6496, 0.7525, 0.7224, 0.6638], device='cuda:0')
# train_recall: tensor([0.6257, 0.8075, 0.7288, 0.3638], device='cuda:0')
# val_loss: 0.6824710669616858
# val_precision: tensor([0.6729, 0.7939, 0.6871, 0.7805], device='cuda:0')
# val_recall: tensor([0.6022, 0.7837, 0.8054, 0.3593], device='cuda:0')
# Learning rate: 0.0001
# epoch 34 time:  1.0911735666000217
# --------------------------------
# ========================================
# EPOCH: 35
# train_loss: 0.7017644822597504
# train_precision: tensor([0.6507, 0.7561, 0.7228, 0.6631], device='cuda:0')
# train_recall: tensor([0.6283, 0.8068, 0.7304, 0.3766], device='cuda:0')
# val_loss: 0.6795952194266849
# val_precision: tensor([0.6825, 0.7791, 0.6960, 0.8041], device='cuda:0')
# val_recall: tensor([0.5984, 0.8047, 0.7990, 0.3414], device='cuda:0')
# Learning rate: 0.0001
# epoch 35 time:  1.1414448767166807
# --------------------------------
# ========================================
# EPOCH: 36
# train_loss: 0.6986065404755729
# train_precision: tensor([0.6516, 0.7559, 0.7243, 0.6515], device='cuda:0')
# train_recall: tensor([0.6290, 0.8076, 0.7303, 0.3782], device='cuda:0')
# val_loss: 0.6702963527705934
# val_precision: tensor([0.6772, 0.7891, 0.7009, 0.7464], device='cuda:0')
# val_recall: tensor([0.6172, 0.7938, 0.7918, 0.3963], device='cuda:0')
# Learning rate: 0.0001
# epoch 36 time:  1.1411194573833503
# --------------------------------
# ========================================
# EPOCH: 37
# train_loss: 0.695254891756035
# train_precision: tensor([0.6534, 0.7583, 0.7241, 0.6641], device='cuda:0')
# train_recall: tensor([0.6291, 0.8098, 0.7322, 0.3866], device='cuda:0')
# val_loss: 0.6680817374752628
# val_precision: tensor([0.6922, 0.7705, 0.7107, 0.7482], device='cuda:0')
# val_recall: tensor([0.5989, 0.8231, 0.7900, 0.4111], device='cuda:0')
# Learning rate: 0.0001
# epoch 37 time:  1.1425297964833285
# --------------------------------
# ========================================
# EPOCH: 38
# train_loss: 0.6920511588454247
# train_precision: tensor([0.6555, 0.7600, 0.7268, 0.6706], device='cuda:0')
# train_recall: tensor([0.6335, 0.8112, 0.7317, 0.3978], device='cuda:0')
# val_loss: 0.667881721092595
# val_precision: tensor([0.6810, 0.7886, 0.7025, 0.7667], device='cuda:0')
# val_recall: tensor([0.6149, 0.7951, 0.7994, 0.3896], device='cuda:0')
# Learning rate: 0.0001
# epoch 38 time:  1.1800450804333196
# --------------------------------
# ========================================
# EPOCH: 39
# train_loss: 0.6895550585218838
# train_precision: tensor([0.6545, 0.7604, 0.7271, 0.6633], device='cuda:0')
# train_recall: tensor([0.6340, 0.8095, 0.7320, 0.3986], device='cuda:0')
# val_loss: 0.6629309763511022
# val_precision: tensor([0.6889, 0.7880, 0.7044, 0.7600], device='cuda:0')
# val_recall: tensor([0.6103, 0.8057, 0.8005, 0.4202], device='cuda:0')
# Learning rate: 0.0001
# epoch 39 time:  1.2074103086666583
# --------------------------------
# ========================================
# EPOCH: 40
# train_loss: 0.6852228412670749
# train_precision: tensor([0.6564, 0.7625, 0.7293, 0.6788], device='cuda:0')
# train_recall: tensor([0.6389, 0.8088, 0.7336, 0.4065], device='cuda:0')
# val_loss: 0.6659070725242296
# val_precision: tensor([0.6886, 0.7907, 0.6953, 0.8010], device='cuda:0')
# val_recall: tensor([0.6058, 0.8001, 0.8084, 0.3660], device='cuda:0')
# Learning rate: 0.0001
# epoch 40 time:  1.1274719364833496
# --------------------------------
# ========================================
# EPOCH: 41
# train_loss: 0.6821131910596575
# train_precision: tensor([0.6592, 0.7628, 0.7317, 0.6810], device='cuda:0')
# train_recall: tensor([0.6381, 0.8117, 0.7375, 0.4078], device='cuda:0')
# val_loss: 0.6967302500373788
# val_precision: tensor([0.6699, 0.8354, 0.6538, 0.7717], device='cuda:0')
# val_recall: tensor([0.6031, 0.7195, 0.8434, 0.3744], device='cuda:0')
# Learning rate: 0.0001
# epoch 41 time:  1.175354816600005
# --------------------------------
# ========================================
# EPOCH: 42
# train_loss: 0.6822216644173577
# train_precision: tensor([0.6621, 0.7645, 0.7305, 0.6681], device='cuda:0')
# train_recall: tensor([0.6394, 0.8123, 0.7380, 0.4117], device='cuda:0')
# val_loss: 0.6625928092334006
# val_precision: tensor([0.6853, 0.8017, 0.6948, 0.7719], device='cuda:0')
# val_recall: tensor([0.6122, 0.7914, 0.8108, 0.4057], device='cuda:0')
# Learning rate: 0.0001
# epoch 42 time:  1.2286434439333485
# --------------------------------
# ========================================
# EPOCH: 43
# train_loss: 0.6782107340438025
# train_precision: tensor([0.6610, 0.7663, 0.7323, 0.6738], device='cuda:0')
# train_recall: tensor([0.6423, 0.8130, 0.7353, 0.4260], device='cuda:0')
# val_loss: 0.6524732602967156
# val_precision: tensor([0.6705, 0.7930, 0.7317, 0.7924], device='cuda:0')
# val_recall: tensor([0.6639, 0.8020, 0.7674, 0.3946], device='cuda:0')
# Learning rate: 0.0001
# epoch 43 time:  1.226798696266663
# --------------------------------
# ========================================
# EPOCH: 44
# train_loss: 0.674471596238159
# train_precision: tensor([0.6639, 0.7655, 0.7343, 0.6737], device='cuda:0')
# train_recall: tensor([0.6422, 0.8147, 0.7377, 0.4290], device='cuda:0')
# val_loss: 0.6513592413730092
# val_precision: tensor([0.6809, 0.8014, 0.7157, 0.7851], device='cuda:0')
# val_recall: tensor([0.6433, 0.7970, 0.7944, 0.3973], device='cuda:0')
# Learning rate: 0.0001
# epoch 44 time:  1.2299673889999818
# --------------------------------
# ========================================
# EPOCH: 45
# train_loss: 0.6734558602883702
# train_precision: tensor([0.6638, 0.7679, 0.7353, 0.6722], device='cuda:0')
# train_recall: tensor([0.6456, 0.8134, 0.7387, 0.4281], device='cuda:0')
# val_loss: 0.6482748759289583
# val_precision: tensor([0.6707, 0.7902, 0.7420, 0.8057], device='cuda:0')
# val_recall: tensor([0.6761, 0.8077, 0.7578, 0.3923], device='cuda:0')
# Learning rate: 0.0001
# epoch 45 time:  1.1943414168000042
# --------------------------------
# ========================================
# EPOCH: 46
# train_loss: 0.6692389580465499
# train_precision: tensor([0.6659, 0.7691, 0.7348, 0.6750], device='cuda:0')
# train_recall: tensor([0.6454, 0.8155, 0.7389, 0.4385], device='cuda:0')
# val_loss: 0.6440050607754124
# val_precision: tensor([0.6803, 0.7965, 0.7276, 0.7796], device='cuda:0')
# val_recall: tensor([0.6493, 0.8071, 0.7850, 0.4168], device='cuda:0')
# Learning rate: 0.0001
# epoch 46 time:  1.2073601291500078
# --------------------------------
# ========================================
# EPOCH: 47
# train_loss: 0.6674384031267393
# train_precision: tensor([0.6666, 0.7695, 0.7376, 0.6773], device='cuda:0')
# train_recall: tensor([0.6495, 0.8139, 0.7398, 0.4395], device='cuda:0')
# val_loss: 0.6475344847473833
# val_precision: tensor([0.6775, 0.7928, 0.7336, 0.7238], device='cuda:0')
# val_recall: tensor([0.6606, 0.8054, 0.7669, 0.4606], device='cuda:0')
# Learning rate: 0.0001
# epoch 47 time:  1.1265946666333244
# --------------------------------
# ========================================
# EPOCH: 48
# train_loss: 0.666194661742165
# train_precision: tensor([0.6681, 0.7708, 0.7370, 0.6783], device='cuda:0')
# train_recall: tensor([0.6502, 0.8164, 0.7392, 0.4385], device='cuda:0')
# val_loss: 0.641871657801999
# val_precision: tensor([0.6835, 0.8043, 0.7205, 0.7827], device='cuda:0')
# val_recall: tensor([0.6546, 0.7943, 0.7922, 0.4316], device='cuda:0')
# Learning rate: 0.0001
# epoch 48 time:  1.1727152112166854
# --------------------------------
# ========================================
# EPOCH: 49
# train_loss: 0.6609448762167067
# train_precision: tensor([0.6692, 0.7725, 0.7388, 0.6899], device='cuda:0')
# train_recall: tensor([0.6518, 0.8155, 0.7426, 0.4505], device='cuda:0')
# val_loss: 0.638077666113774
# val_precision: tensor([0.6845, 0.7994, 0.7279, 0.7622], device='cuda:0')
# val_recall: tensor([0.6539, 0.8081, 0.7821, 0.4522], device='cuda:0')
# Learning rate: 0.0001
# epoch 49 time:  1.199025732016677
# --------------------------------
# ========================================
# EPOCH: 50
# train_loss: 0.660185159884748
# train_precision: tensor([0.6708, 0.7722, 0.7401, 0.6850], device='cuda:0')
# train_recall: tensor([0.6524, 0.8181, 0.7418, 0.4488], device='cuda:0')
# val_loss: 0.6421709967156252
# val_precision: tensor([0.6918, 0.7957, 0.7189, 0.8358], device='cuda:0')
# val_recall: tensor([0.6385, 0.8124, 0.7979, 0.3838], device='cuda:0')
# Learning rate: 0.0001
# epoch 50 time:  1.147222685450015
# --------------------------------
# ========================================
# EPOCH: 51
# train_loss: 0.6571989395788738
# train_precision: tensor([0.6718, 0.7747, 0.7417, 0.6877], device='cuda:0')
# train_recall: tensor([0.6562, 0.8188, 0.7418, 0.4547], device='cuda:0')
# val_loss: 0.6386108298268584
# val_precision: tensor([0.6943, 0.8032, 0.7169, 0.8076], device='cuda:0')
# val_recall: tensor([0.6422, 0.8054, 0.8037, 0.4141], device='cuda:0')
# Learning rate: 0.0001
# epoch 51 time:  1.1615851266666748
# --------------------------------
# ========================================
# EPOCH: 52
# train_loss: 0.6562557568152746
# train_precision: tensor([0.6751, 0.7741, 0.7417, 0.6765], device='cuda:0')
# train_recall: tensor([0.6556, 0.8201, 0.7430, 0.4583], device='cuda:0')
# val_loss: 0.6435894961158435
# val_precision: tensor([0.6852, 0.8007, 0.7175, 0.8358], device='cuda:0')
# val_recall: tensor([0.6437, 0.8045, 0.7978, 0.3684], device='cuda:0')
# Learning rate: 1e-05
# epoch 52 time:  1.1723465615166484
# --------------------------------
# ========================================
# EPOCH: 53
# train_loss: 0.650905886789163
# train_precision: tensor([0.6775, 0.7760, 0.7441, 0.6936], device='cuda:0')
# train_recall: tensor([0.6566, 0.8211, 0.7477, 0.4700], device='cuda:0')
# val_loss: 0.6305175969170199
# val_precision: tensor([0.6939, 0.8052, 0.7250, 0.7776], device='cuda:0')
# val_recall: tensor([0.6528, 0.8065, 0.7971, 0.4532], device='cuda:0')
# Learning rate: 1e-05
# epoch 53 time:  1.2268677684833165
# --------------------------------
# ========================================
# EPOCH: 54
# train_loss: 0.6481737163095247
# train_precision: tensor([0.6779, 0.7760, 0.7435, 0.6973], device='cuda:0')
# train_recall: tensor([0.6566, 0.8213, 0.7469, 0.4773], device='cuda:0')
# val_loss: 0.6294238648480839
# val_precision: tensor([0.6937, 0.8032, 0.7284, 0.7793], device='cuda:0')
# val_recall: tensor([0.6552, 0.8081, 0.7951, 0.4505], device='cuda:0')
# Learning rate: 1e-05
# epoch 54 time:  1.2217360369166879
# --------------------------------
# ========================================
# EPOCH: 55
# train_loss: 0.6492208430454844
# train_precision: tensor([0.6765, 0.7758, 0.7443, 0.6988], device='cuda:0')
# train_recall: tensor([0.6560, 0.8214, 0.7469, 0.4765], device='cuda:0')
# val_loss: 0.6287147394484944
# val_precision: tensor([0.6932, 0.8047, 0.7277, 0.7757], device='cuda:0')
# val_recall: tensor([0.6547, 0.8074, 0.7957, 0.4552], device='cuda:0')
# Learning rate: 1e-05
# epoch 55 time:  1.220578141416657
# --------------------------------
# ========================================
# EPOCH: 56
# train_loss: 0.6475413630051272
# train_precision: tensor([0.6762, 0.7776, 0.7464, 0.6986], device='cuda:0')
# train_recall: tensor([0.6630, 0.8198, 0.7438, 0.4807], device='cuda:0')
# val_loss: 0.6283411193225119
# val_precision: tensor([0.6934, 0.8047, 0.7278, 0.7672], device='cuda:0')
# val_recall: tensor([0.6540, 0.8070, 0.7960, 0.4616], device='cuda:0')
# Learning rate: 1e-05
# epoch 56 time:  1.2245238920500015
# --------------------------------
# ========================================
# EPOCH: 57
# train_loss: 0.647032172481219
# train_precision: tensor([0.6780, 0.7780, 0.7447, 0.6991], device='cuda:0')
# train_recall: tensor([0.6593, 0.8218, 0.7466, 0.4801], device='cuda:0')
# val_loss: 0.6286681483189265
# val_precision: tensor([0.6930, 0.8069, 0.7277, 0.7844], device='cuda:0')
# val_recall: tensor([0.6581, 0.8048, 0.7975, 0.4471], device='cuda:0')
# Learning rate: 1e-05
# epoch 57 time:  1.175561013100014
# --------------------------------
# ========================================
# EPOCH: 58
# train_loss: 0.6477567504559244
# train_precision: tensor([0.6773, 0.7772, 0.7464, 0.6935], device='cuda:0')
# train_recall: tensor([0.6600, 0.8203, 0.7476, 0.4745], device='cuda:0')
# val_loss: 0.6277115349968274
# val_precision: tensor([0.6929, 0.8029, 0.7317, 0.7721], device='cuda:0')
# val_recall: tensor([0.6580, 0.8100, 0.7918, 0.4586], device='cuda:0')
# Learning rate: 1e-05
# epoch 58 time:  1.2250941753000006
# --------------------------------
# ========================================
# EPOCH: 59
# train_loss: 0.6465259894373871
# train_precision: tensor([0.6770, 0.7780, 0.7466, 0.6943], device='cuda:0')
# train_recall: tensor([0.6598, 0.8237, 0.7452, 0.4752], device='cuda:0')
# val_loss: 0.6279799477093749
# val_precision: tensor([0.6971, 0.8068, 0.7237, 0.7671], device='cuda:0')
# val_recall: tensor([0.6484, 0.8062, 0.8034, 0.4636], device='cuda:0')
# Learning rate: 1e-05
# epoch 59 time:  1.1703720538500118
# --------------------------------
# ========================================
# EPOCH: 60
# train_loss: 0.6464063597576959
# train_precision: tensor([0.6783, 0.7780, 0.7467, 0.7076], device='cuda:0')
# train_recall: tensor([0.6591, 0.8215, 0.7495, 0.4853], device='cuda:0')
# val_loss: 0.6271481566958957
# val_precision: tensor([0.6987, 0.8039, 0.7254, 0.7781], device='cuda:0')
# val_recall: tensor([0.6500, 0.8099, 0.8007, 0.4545], device='cuda:0')
# Learning rate: 1e-05
# epoch 60 time:  1.2234814006000003
# --------------------------------
# ========================================
# EPOCH: 61
# train_loss: 0.6457693217056139
# train_precision: tensor([0.6783, 0.7774, 0.7459, 0.6990], device='cuda:0')
# train_recall: tensor([0.6590, 0.8221, 0.7467, 0.4872], device='cuda:0')
# val_loss: 0.6276708478728931
# val_precision: tensor([0.6980, 0.8044, 0.7249, 0.7737], device='cuda:0')
# val_recall: tensor([0.6494, 0.8086, 0.8013, 0.4559], device='cuda:0')
# Learning rate: 1e-05
# epoch 61 time:  1.1740304773833485
# --------------------------------
# ========================================
# EPOCH: 62
# train_loss: 0.6454520002717063
# train_precision: tensor([0.6770, 0.7790, 0.7460, 0.6991], device='cuda:0')
# train_recall: tensor([0.6598, 0.8220, 0.7461, 0.4898], device='cuda:0')
# val_loss: 0.625790311396122
# val_precision: tensor([0.6914, 0.8037, 0.7322, 0.7785], device='cuda:0')
# val_recall: tensor([0.6604, 0.8092, 0.7902, 0.4579], device='cuda:0')
# Learning rate: 1e-05
# epoch 62 time:  1.1864286829166606
# --------------------------------
# ========================================
# EPOCH: 63
# train_loss: 0.6464423171821094
# train_precision: tensor([0.6778, 0.7779, 0.7465, 0.6949], device='cuda:0')
# train_recall: tensor([0.6608, 0.8214, 0.7469, 0.4775], device='cuda:0')
# val_loss: 0.625459991974963
# val_precision: tensor([0.6921, 0.8057, 0.7325, 0.7798], device='cuda:0')
# val_recall: tensor([0.6628, 0.8088, 0.7912, 0.4542], device='cuda:0')
# Learning rate: 1e-05
# epoch 63 time:  1.2320991338333747
# --------------------------------
# ========================================
# EPOCH: 64
# train_loss: 0.6456469523410002
# train_precision: tensor([0.6775, 0.7785, 0.7481, 0.7062], device='cuda:0')
# train_recall: tensor([0.6630, 0.8221, 0.7453, 0.4885], device='cuda:0')
# val_loss: 0.626725742717584
# val_precision: tensor([0.6943, 0.8081, 0.7266, 0.7826], device='cuda:0')
# val_recall: tensor([0.6555, 0.8070, 0.7988, 0.4532], device='cuda:0')
# Learning rate: 1e-05
# epoch 64 time:  1.1771041403333584
# --------------------------------
# ========================================
# EPOCH: 65
# train_loss: 0.6442925548979215
# train_precision: tensor([0.6792, 0.7780, 0.7462, 0.6972], device='cuda:0')
# train_recall: tensor([0.6604, 0.8219, 0.7481, 0.4784], device='cuda:0')
# val_loss: 0.624520640157991
# val_precision: tensor([0.6936, 0.8038, 0.7337, 0.7697], device='cuda:0')
# val_recall: tensor([0.6619, 0.8115, 0.7889, 0.4680], device='cuda:0')
# Learning rate: 1e-05
# epoch 65 time:  1.22524625824996
# --------------------------------
# ========================================
# EPOCH: 66
# train_loss: 0.644303505619367
# train_precision: tensor([0.6783, 0.7792, 0.7470, 0.6904], device='cuda:0')
# train_recall: tensor([0.6626, 0.8229, 0.7453, 0.4782], device='cuda:0')
# val_loss: 0.625415831224786
# val_precision: tensor([0.6941, 0.8052, 0.7308, 0.7724], device='cuda:0')
# val_recall: tensor([0.6587, 0.8088, 0.7940, 0.4650], device='cuda:0')
# Learning rate: 1e-05
# epoch 66 time:  1.177041964216672
# --------------------------------
# ========================================
# EPOCH: 67
# train_loss: 0.643977356169905
# train_precision: tensor([0.6802, 0.7778, 0.7477, 0.6970], device='cuda:0')
# train_recall: tensor([0.6621, 0.8232, 0.7465, 0.4867], device='cuda:0')
# val_loss: 0.6246038648817275
# val_precision: tensor([0.6971, 0.8008, 0.7300, 0.7787], device='cuda:0')
# val_recall: tensor([0.6528, 0.8151, 0.7939, 0.4515], device='cuda:0')
# Learning rate: 1e-05
# epoch 67 time:  1.1679937714166349
# --------------------------------
# ========================================
# EPOCH: 68
# train_loss: 0.6438123741320201
# train_precision: tensor([0.6793, 0.7782, 0.7474, 0.7002], device='cuda:0')
# train_recall: tensor([0.6606, 0.8229, 0.7477, 0.4874], device='cuda:0')
# val_loss: 0.6255144269929992
# val_precision: tensor([0.6963, 0.8066, 0.7278, 0.7826], device='cuda:0')
# val_recall: tensor([0.6568, 0.8085, 0.7975, 0.4593], device='cuda:0')
# Learning rate: 5e-06
# epoch 68 time:  1.1547472359499806
# --------------------------------
# ========================================
# EPOCH: 69
# train_loss: 0.6435980072333699
# train_precision: tensor([0.6801, 0.7799, 0.7472, 0.6946], device='cuda:0')
# train_recall: tensor([0.6621, 0.8235, 0.7473, 0.4885], device='cuda:0')
# val_loss: 0.6244546606308884
# val_precision: tensor([0.6964, 0.8031, 0.7295, 0.7808], device='cuda:0')
# val_recall: tensor([0.6537, 0.8122, 0.7961, 0.4593], device='cuda:0')
# Learning rate: 5e-06
# epoch 69 time:  1.2309502734333364
# --------------------------------
# ========================================
# EPOCH: 70
# train_loss: 0.6423442350966589
# train_precision: tensor([0.6803, 0.7801, 0.7490, 0.6956], device='cuda:0')
# train_recall: tensor([0.6646, 0.8239, 0.7469, 0.4838], device='cuda:0')
# val_loss: 0.6245028558704588
# val_precision: tensor([0.6956, 0.8047, 0.7293, 0.7818], device='cuda:0')
# val_recall: tensor([0.6551, 0.8109, 0.7962, 0.4596], device='cuda:0')
# Learning rate: 5e-06
# epoch 70 time:  1.13711259703335
# --------------------------------
# ========================================
# EPOCH: 71
# train_loss: 0.6420102527453786
# train_precision: tensor([0.6792, 0.7782, 0.7483, 0.6940], device='cuda:0')
# train_recall: tensor([0.6612, 0.8240, 0.7462, 0.4880], device='cuda:0')
# val_loss: 0.6235670305788517
# val_precision: tensor([0.6946, 0.8041, 0.7319, 0.7817], device='cuda:0')
# val_recall: tensor([0.6589, 0.8118, 0.7928, 0.4582], device='cuda:0')
# Learning rate: 5e-06
# epoch 71 time:  1.177863750533288
# --------------------------------
# ========================================
# EPOCH: 72
# train_loss: 0.6420944753147307
# train_precision: tensor([0.6793, 0.7792, 0.7475, 0.6996], device='cuda:0')
# train_recall: tensor([0.6610, 0.8233, 0.7481, 0.4873], device='cuda:0')
# val_loss: 0.6253565556473202
# val_precision: tensor([0.6950, 0.8065, 0.7283, 0.7863], device='cuda:0')
# val_recall: tensor([0.6561, 0.8093, 0.7972, 0.4559], device='cuda:0')
# Learning rate: 5e-06
# epoch 72 time:  1.0989150861500092
# --------------------------------
# ========================================
# EPOCH: 73
# train_loss: 0.6423283870731081
# train_precision: tensor([0.6801, 0.7791, 0.7465, 0.6982], device='cuda:0')
# train_recall: tensor([0.6612, 0.8225, 0.7484, 0.4863], device='cuda:0')
# val_loss: 0.6244512346883615
# val_precision: tensor([0.6964, 0.8065, 0.7284, 0.7812], device='cuda:0')
# val_recall: tensor([0.6553, 0.8103, 0.7981, 0.4579], device='cuda:0')
# Learning rate: 5e-06
# epoch 73 time:  1.103351817099974
# --------------------------------
# ========================================
# EPOCH: 74
# train_loss: 0.6429001828744298
# train_precision: tensor([0.6785, 0.7790, 0.7475, 0.6901], device='cuda:0')
# train_recall: tensor([0.6622, 0.8228, 0.7460, 0.4823], device='cuda:0')
# val_loss: 0.6247148142092758
# val_precision: tensor([0.6976, 0.8062, 0.7272, 0.7877], device='cuda:0')
# val_recall: tensor([0.6543, 0.8091, 0.8006, 0.4535], device='cuda:0')
# Learning rate: 5e-06
# epoch 74 time:  1.125480467133275
# --------------------------------
# ========================================
# EPOCH: 75
# train_loss: 0.6416751955236707
# train_precision: tensor([0.6801, 0.7804, 0.7473, 0.6968], device='cuda:0')
# train_recall: tensor([0.6628, 0.8225, 0.7484, 0.4872], device='cuda:0')
# val_loss: 0.6249437557326423
# val_precision: tensor([0.6973, 0.8061, 0.7272, 0.7837], device='cuda:0')
# val_recall: tensor([0.6534, 0.8107, 0.7992, 0.4562], device='cuda:0')
# Learning rate: 5e-06
# epoch 75 time:  1.1271770275833357
# --------------------------------
# ========================================
# EPOCH: 76
# train_loss: 0.6417850596564156
# train_precision: tensor([0.6796, 0.7800, 0.7469, 0.6929], device='cuda:0')
# train_recall: tensor([0.6623, 0.8226, 0.7476, 0.4834], device='cuda:0')
# val_loss: 0.6241598534915183
# val_precision: tensor([0.6963, 0.8060, 0.7286, 0.7887], device='cuda:0')
# val_recall: tensor([0.6563, 0.8105, 0.7968, 0.4586], device='cuda:0')
# Learning rate: 5e-06
# epoch 76 time:  1.1333787634500065
# --------------------------------
# ========================================
# EPOCH: 77
# train_loss: 0.6406505840874853
# train_precision: tensor([0.6820, 0.7801, 0.7483, 0.6992], device='cuda:0')
# train_recall: tensor([0.6635, 0.8234, 0.7494, 0.4900], device='cuda:0')
# val_loss: 0.6235966667532921
# val_precision: tensor([0.6986, 0.8046, 0.7290, 0.7799], device='cuda:0')
# val_recall: tensor([0.6543, 0.8122, 0.7978, 0.4640], device='cuda:0')
# Learning rate: 5e-06
# epoch 77 time:  1.1170047765832958
# --------------------------------
# ========================================
# EPOCH: 78
# train_loss: 0.640271425531024
# train_precision: tensor([0.6786, 0.7800, 0.7487, 0.6946], device='cuda:0')
# train_recall: tensor([0.6633, 0.8221, 0.7471, 0.4906], device='cuda:0')
# val_loss: 0.6237703249686294
# val_precision: tensor([0.6951, 0.8073, 0.7294, 0.7855], device='cuda:0')
# val_recall: tensor([0.6582, 0.8089, 0.7968, 0.4623], device='cuda:0')
# Learning rate: 5e-06
# epoch 78 time:  1.1054688621999957
# --------------------------------
# ========================================
# EPOCH: 79
# train_loss: 0.6419454158062027
# train_precision: tensor([0.6801, 0.7803, 0.7475, 0.7022], device='cuda:0')
# train_recall: tensor([0.6633, 0.8239, 0.7467, 0.4916], device='cuda:0')
# val_loss: 0.6233359351754189
# val_precision: tensor([0.6961, 0.8074, 0.7294, 0.7853], device='cuda:0')
# val_recall: tensor([0.6588, 0.8088, 0.7971, 0.4630], device='cuda:0')
# Learning rate: 5e-06
# epoch 79 time:  1.1569287353333493
# --------------------------------
# ========================================
# EPOCH: 80
# train_loss: 0.6419490314665295
# train_precision: tensor([0.6794, 0.7785, 0.7483, 0.6973], device='cuda:0')
# train_recall: tensor([0.6609, 0.8222, 0.7482, 0.4960], device='cuda:0')
# val_loss: 0.6228762564559778
# val_precision: tensor([0.6959, 0.8063, 0.7304, 0.7797], device='cuda:0')
# val_recall: tensor([0.6585, 0.8102, 0.7956, 0.4646], device='cuda:0')
# Learning rate: 5e-06
# epoch 80 time:  1.1511147954999614
# --------------------------------
# ========================================
# EPOCH: 81
# train_loss: 0.6410803039159093
# train_precision: tensor([0.6798, 0.7798, 0.7475, 0.7009], device='cuda:0')
# train_recall: tensor([0.6621, 0.8238, 0.7474, 0.4893], device='cuda:0')
# val_loss: 0.623125987003247
# val_precision: tensor([0.6964, 0.8055, 0.7290, 0.7889], device='cuda:0')
# val_recall: tensor([0.6558, 0.8121, 0.7966, 0.4542], device='cuda:0')
# Learning rate: 5e-06
# epoch 81 time:  1.0974744049333216
# --------------------------------
# ========================================
# EPOCH: 82
# train_loss: 0.6419326329515094
# train_precision: tensor([0.6802, 0.7798, 0.7477, 0.6993], device='cuda:0')
# train_recall: tensor([0.6632, 0.8228, 0.7478, 0.4870], device='cuda:0')
# val_loss: 0.6232124267352952
# val_precision: tensor([0.6945, 0.8044, 0.7313, 0.7884], device='cuda:0')
# val_recall: tensor([0.6579, 0.8115, 0.7940, 0.4579], device='cuda:0')
# Learning rate: 5e-06
# epoch 82 time:  1.13824836403334
# --------------------------------
# ========================================
# EPOCH: 83
# train_loss: 0.6405686074069568
# train_precision: tensor([0.6809, 0.7802, 0.7501, 0.6898], device='cuda:0')
# train_recall: tensor([0.6647, 0.8246, 0.7476, 0.4840], device='cuda:0')
# val_loss: 0.6234107001788086
# val_precision: tensor([0.6965, 0.8072, 0.7288, 0.7929], device='cuda:0')
# val_recall: tensor([0.6563, 0.8106, 0.7992, 0.4512], device='cuda:0')
# Learning rate: 5e-06
# epoch 83 time:  1.1336164374500488
# --------------------------------
# ========================================
# EPOCH: 84
# train_loss: 0.639964006628309
# train_precision: tensor([0.6807, 0.7821, 0.7492, 0.6959], device='cuda:0')
# train_recall: tensor([0.6650, 0.8226, 0.7501, 0.4883], device='cuda:0')
# val_loss: 0.6223222244944837
# val_precision: tensor([0.6973, 0.8055, 0.7294, 0.7868], device='cuda:0')
# val_recall: tensor([0.6549, 0.8122, 0.7979, 0.4609], device='cuda:0')
# Learning rate: 5e-06
# epoch 84 time:  1.1940812179667166
# --------------------------------
# ========================================
# EPOCH: 85
# train_loss: 0.6405633175656908
# train_precision: tensor([0.6808, 0.7800, 0.7487, 0.7004], device='cuda:0')
# train_recall: tensor([0.6627, 0.8243, 0.7483, 0.4908], device='cuda:0')
# val_loss: 0.6226608874897163
# val_precision: tensor([0.6970, 0.8057, 0.7299, 0.7845], device='cuda:0')
# val_recall: tensor([0.6570, 0.8112, 0.7967, 0.4646], device='cuda:0')
# Learning rate: 5e-06
# epoch 85 time:  1.1360048318166567
# --------------------------------
# ========================================
# EPOCH: 86
# train_loss: 0.6399920897114845
# train_precision: tensor([0.6815, 0.7809, 0.7480, 0.6981], device='cuda:0')
# train_recall: tensor([0.6637, 0.8225, 0.7497, 0.4932], device='cuda:0')
# val_loss: 0.6235963784158229
# val_precision: tensor([0.6992, 0.8074, 0.7260, 0.7836], device='cuda:0')
# val_recall: tensor([0.6530, 0.8092, 0.8020, 0.4646], device='cuda:0')
# Learning rate: 5e-06
# epoch 86 time:  1.107896786366655
# --------------------------------
# ========================================
# EPOCH: 87
# train_loss: 0.6400986623905954
# train_precision: tensor([0.6806, 0.7799, 0.7490, 0.7031], device='cuda:0')
# train_recall: tensor([0.6623, 0.8256, 0.7476, 0.4944], device='cuda:0')
# val_loss: 0.6223016230596436
# val_precision: tensor([0.7026, 0.8047, 0.7271, 0.7790], device='cuda:0')
# val_recall: tensor([0.6499, 0.8141, 0.8021, 0.4687], device='cuda:0')
# Learning rate: 5e-06
# epoch 87 time:  1.1871236455500063
# --------------------------------
# ========================================
# EPOCH: 88
# train_loss: 0.6398146675456138
# train_precision: tensor([0.6810, 0.7811, 0.7477, 0.6955], device='cuda:0')
# train_recall: tensor([0.6621, 0.8239, 0.7495, 0.4905], device='cuda:0')
# val_loss: 0.6222713238663143
# val_precision: tensor([0.6981, 0.8048, 0.7300, 0.7809], device='cuda:0')
# val_recall: tensor([0.6556, 0.8125, 0.7971, 0.4643], device='cuda:0')
# Learning rate: 5e-06
# epoch 88 time:  1.1902218326999596
# --------------------------------
# ========================================
# EPOCH: 89
# train_loss: 0.6393742013545264
# train_precision: tensor([0.6808, 0.7819, 0.7488, 0.6963], device='cuda:0')
# train_recall: tensor([0.6655, 0.8232, 0.7473, 0.5001], device='cuda:0')
# val_loss: 0.6225318817628754
# val_precision: tensor([0.6980, 0.8034, 0.7303, 0.7908], device='cuda:0')
# val_recall: tensor([0.6551, 0.8139, 0.7964, 0.4569], device='cuda:0')
# Learning rate: 5e-06
# epoch 89 time:  1.1494614774833585
# --------------------------------
# ========================================
# EPOCH: 90
# train_loss: 0.6395011622281301
# train_precision: tensor([0.6816, 0.7791, 0.7476, 0.6992], device='cuda:0')
# train_recall: tensor([0.6611, 0.8248, 0.7484, 0.4924], device='cuda:0')
# val_loss: 0.6226891679068406
# val_precision: tensor([0.6957, 0.8089, 0.7292, 0.7878], device='cuda:0')
# val_recall: tensor([0.6603, 0.8081, 0.7975, 0.4576], device='cuda:0')
# Learning rate: 5e-06
# epoch 90 time:  1.136665297349949
# --------------------------------
# ========================================
# EPOCH: 91
# train_loss: 0.6398159981483504
# train_precision: tensor([0.6801, 0.7813, 0.7468, 0.6970], device='cuda:0')
# train_recall: tensor([0.6623, 0.8226, 0.7491, 0.4889], device='cuda:0')
# val_loss: 0.6220530933803983
# val_precision: tensor([0.6974, 0.8066, 0.7311, 0.7858], device='cuda:0')
# val_recall: tensor([0.6579, 0.8116, 0.7976, 0.4680], device='cuda:0')
# Learning rate: 5e-06
# epoch 91 time:  1.187963492750047
# --------------------------------
# ========================================
# EPOCH: 92
# train_loss: 0.6397144189902715
# train_precision: tensor([0.6827, 0.7790, 0.7482, 0.6977], device='cuda:0')
# train_recall: tensor([0.6616, 0.8253, 0.7490, 0.4919], device='cuda:0')
# val_loss: 0.6220766667690542
# val_precision: tensor([0.6954, 0.8077, 0.7316, 0.7798], device='cuda:0')
# val_recall: tensor([0.6605, 0.8100, 0.7957, 0.4650], device='cuda:0')
# Learning rate: 5e-06
# epoch 92 time:  1.1315513304999816
# --------------------------------
# ========================================
# EPOCH: 93
# train_loss: 0.6402532857088815
# train_precision: tensor([0.6808, 0.7806, 0.7509, 0.6929], device='cuda:0')
# train_recall: tensor([0.6651, 0.8235, 0.7488, 0.4906], device='cuda:0')
# val_loss: 0.6226890180673864
# val_precision: tensor([0.6966, 0.8062, 0.7309, 0.7892], device='cuda:0')
# val_recall: tensor([0.6593, 0.8115, 0.7960, 0.4589], device='cuda:0')
# Learning rate: 5e-06
# epoch 93 time:  1.1455755199500346
# --------------------------------
# ========================================
# EPOCH: 94
# train_loss: 0.639270595567567
# train_precision: tensor([0.6802, 0.7811, 0.7480, 0.7008], device='cuda:0')
# train_recall: tensor([0.6643, 0.8231, 0.7473, 0.4945], device='cuda:0')
# val_loss: 0.6215840410855081
# val_precision: tensor([0.6980, 0.8044, 0.7320, 0.7847], device='cuda:0')
# val_recall: tensor([0.6581, 0.8138, 0.7951, 0.4640], device='cuda:0')
# Learning rate: 5e-06
# epoch 94 time:  1.1939180094999755
# --------------------------------
# ========================================
# EPOCH: 95
# train_loss: 0.6388223861654599
# train_precision: tensor([0.6809, 0.7822, 0.7498, 0.7053], device='cuda:0')
# train_recall: tensor([0.6658, 0.8242, 0.7487, 0.4945], device='cuda:0')
# val_loss: 0.6219488866627216
# val_precision: tensor([0.6970, 0.8071, 0.7300, 0.7859], device='cuda:0')
# val_recall: tensor([0.6580, 0.8106, 0.7978, 0.4623], device='cuda:0')
# Learning rate: 5e-06
# epoch 95 time:  1.158596427299987
# --------------------------------
# ========================================
# EPOCH: 96
# train_loss: 0.639248984058698
# train_precision: tensor([0.6810, 0.7801, 0.7484, 0.7002], device='cuda:0')
# train_recall: tensor([0.6621, 0.8246, 0.7485, 0.4948], device='cuda:0')
# val_loss: 0.6223526396685176
# val_precision: tensor([0.6968, 0.8074, 0.7297, 0.7845], device='cuda:0')
# val_recall: tensor([0.6579, 0.8097, 0.7985, 0.4609], device='cuda:0')
# Learning rate: 5e-06
# epoch 96 time:  1.1476436315333558
# --------------------------------
# ========================================
# EPOCH: 97
# train_loss: 0.639622187508004
# train_precision: tensor([0.6812, 0.7797, 0.7488, 0.6971], device='cuda:0')
# train_recall: tensor([0.6625, 0.8237, 0.7491, 0.4929], device='cuda:0')
# val_loss: 0.6226063486602571
# val_precision: tensor([0.6996, 0.8061, 0.7273, 0.7870], device='cuda:0')
# val_recall: tensor([0.6533, 0.8115, 0.8013, 0.4542], device='cuda:0')
# Learning rate: 5e-06
# epoch 97 time:  1.1551668877166472
# --------------------------------
# ========================================
# EPOCH: 98
# train_loss: 0.6382837032987958
# train_precision: tensor([0.6814, 0.7824, 0.7510, 0.7039], device='cuda:0')
# train_recall: tensor([0.6688, 0.8235, 0.7475, 0.4960], device='cuda:0')
# val_loss: 0.6218650081919299
# val_precision: tensor([0.6991, 0.8071, 0.7287, 0.7809], device='cuda:0')
# val_recall: tensor([0.6555, 0.8104, 0.8007, 0.4643], device='cuda:0')
# Learning rate: 5e-06
# epoch 98 time:  1.1501998188499782
# --------------------------------
# ========================================
# EPOCH: 99
# train_loss: 0.638285231590271
# train_precision: tensor([0.6829, 0.7795, 0.7497, 0.7036], device='cuda:0')
# train_recall: tensor([0.6638, 0.8248, 0.7498, 0.4908], device='cuda:0')
# val_loss: 0.6216513905260298
# val_precision: tensor([0.6991, 0.8072, 0.7293, 0.7801], device='cuda:0')
# val_recall: tensor([0.6558, 0.8109, 0.8005, 0.4670], device='cuda:0')
# Learning rate: 5e-06
# epoch 99 time:  1.1508630307999435
# --------------------------------
# training_checkpoints/efficient_net_b5_2024-04-21 18:46:01.146855.pth
# <All keys matched successfully>

# %%
from sklearn.metrics import confusion_matrix, classification_report
from torch.utils.data import DataLoader
import numpy as np
import torch 
from torchvision.models import resnet18
import torch.nn as nn


def test_report(model, dataloader):
    """Prints confusion matrix for testing dataset
    dataloader should be of batch_size=1."""

    y_pred = []
    y_test = []
    model.eval()
    with torch.no_grad():
        for data, label in dataloader:
            output = model(data)
            label = label.numpy()
            output = output.numpy()
            y_pred.append(np.argmax(output))
            y_test.append(np.argmax(label))
        print(confusion_matrix(y_test, y_pred))
        print(classification_report(y_test, y_pred))

testset =ImageDataset(data_path='test_data')
dataloader = DataLoader(testset, batch_size=1, shuffle=True)

test_report(my_model.to('cpu'), dataloader)
# Out:
# [[673 105 221   1]
#  [109 821  67   3]
#  [138  48 811   3]
#  [ 23  16  13  48]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.67      0.69      1000
#            1       0.83      0.82      0.83      1000
#            2       0.73      0.81      0.77      1000
#            3       0.87      0.48      0.62       100
#
#     accuracy                           0.76      3100
#    macro avg       0.79      0.70      0.73      3100
# weighted avg       0.76      0.76      0.76      3100
