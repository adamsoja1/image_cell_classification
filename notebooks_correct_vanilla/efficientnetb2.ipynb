# %%
import time
import sys
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from dataset import ImageDataset
import torch.nn.functional as F
from torchmetrics import Precision, Recall
from torchvision.models import resnet18
import warnings
from collections import defaultdict
import wandb
import datetime
import os
import torchvision.models as models
import torch.nn as nn
#intecubic interpol

class EfficientNetB0(nn.Module):
    def __init__(self, num_classes=4):
        super(EfficientNetB0, self).__init__()
        self.base_model = models.efficientnet_b2(pretrained=False)
        num_ftrs = self.base_model.classifier[1].in_features
        self.base_model.classifier[1] = nn.Linear(num_ftrs, num_classes)

    def forward(self, x):
        return self.base_model(x)


warnings.filterwarnings('ignore')
torch.set_float32_matmul_precision('high')


run_name = f'efficient_net_b2_{datetime.datetime.now()}'
run_path = f'training_checkpoints/{run_name}'

wandb.init(project="cells", 
           entity="adamsoja",
          name=run_name)

import random
random.seed(2233)
torch.manual_seed(2233)

from albumentations import (
    Compose,
    Resize,
    OneOf,
    RandomBrightness,
    RandomContrast,
    MotionBlur,
    MedianBlur,
    GaussianBlur,
    VerticalFlip,
    HorizontalFlip,
    ShiftScaleRotate,
    Normalize,
)

transform = Compose(
    [
        OneOf([RandomBrightness(limit=0.4, p=1), RandomContrast(limit=0.4, p=1)]),
        OneOf([MotionBlur(blur_limit=3), MedianBlur(blur_limit=3), GaussianBlur(blur_limit=3),], p=0.7,),
        VerticalFlip(p=0.5),
        HorizontalFlip(p=0.5),]
)

class MyModel(nn.Module):
    def __init__(self, model, learning_rate, weight_decay):
        super(MyModel, self).__init__()
        self.model = model
        self.learning_rate = learning_rate
        self.weight_decay = weight_decay
        self.criterion = nn.CrossEntropyLoss()
        self.metric_precision = Precision(task="multiclass", num_classes=4, average=None).to('cuda')
        self.metric_recall = Recall(task="multiclass", num_classes=4, average=None).to('cuda')
        self.train_loss = []
        self.valid_loss = []
        self.precision_per_epochs = []
        self.recall_per_epochs = []

        self.optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, mode="min", factor=0.1, patience=2, min_lr=5e-6, verbose=True)
        self.step = 0

    
    def forward(self, x):
        return self.model(x)

    def train_one_epoch(self, trainloader):
        self.step += 1
        self.train()
        for batch_idx, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()
            _, preds = torch.max(outputs, 1)
            _, labels = torch.max(labels, 1)
            self.metric_precision(preds, labels)
            self.metric_recall(preds, labels)
            self.train_loss.append(loss.item())


        

        
        avg_loss = np.mean(self.train_loss)
        self.train_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        self.precision_per_epochs.append(precision)
        self.recall_per_epochs.append(recall)
        print(f'train_loss: {avg_loss}')
        print(f'train_precision: {precision}')
        print(f'train_recall: {recall}')

        wandb.log({'loss': avg_loss},step=self.step)
        wandb.log({'Normal precision': precision[0].item()},step=self.step)
        wandb.log({'Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'Other precision': precision[3].item()},step=self.step)


        wandb.log({'Normal recall': recall[0].item()},step=self.step)
        wandb.log({'Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'Other recall': recall[3].item()},step=self.step)
        
        
        self.metric_precision.reset()
        self.metric_recall.reset()


    

    def evaluate(self, testloader):
        self.eval()
        with torch.no_grad():
            for batch_idx, (inputs, labels) in enumerate(testloader):
                inputs, labels = inputs.to('cuda'), labels.to('cuda')
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)
                _, labels = torch.max(labels, 1)
                self.metric_precision(preds, labels)
                self.metric_recall(preds, labels)
                self.valid_loss.append(loss.item())
    
        avg_loss = np.mean(self.valid_loss)
        self.scheduler.step(avg_loss)
        self.valid_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        print(f'val_loss: {avg_loss}')
        print(f'val_precision: {precision}')
        print(f'val_recall: {recall}')
        self.metric_precision.reset()
        self.metric_recall.reset()

        wandb.log({'val_loss': avg_loss}, step=self.step)
        
        wandb.log({'val_Normal precision': precision[0].item()},step=self.step)
        wandb.log({'val_Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'val_Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'val_Other precision': precision[3].item()},step=self.step)


        wandb.log({'val_Normal recall': recall[0].item()},step=self.step)
        wandb.log({'val_Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'val_Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'val_Other recall': recall[3].item()},step=self.step)


        for param_group in self.optimizer.param_groups:
            print(f"Learning rate: {param_group['lr']}")
        return avg_loss

torch.cuda.empty_cache()
batch_size = 256
trainset = ImageDataset(data_path='train_data', transform=transform)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=5)

testset = ImageDataset(data_path='validation_data')
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=3)

learning_rate = 0.001
weight_decay = 0.00001

model = EfficientNetB0()
model = model.to('cuda')


my_model = MyModel(model=model, learning_rate=learning_rate, weight_decay=weight_decay)
my_model = my_model.to('cuda')

num_epochs = 100
early_stop_patience = 10
best_val_loss = float('inf')
best_model_state_dict = None

for epoch in range(num_epochs):
    print('========================================')
    print(f'EPOCH: {epoch}') 
    time_start = time.perf_counter()
    my_model.train_one_epoch(trainloader)
    val_loss = my_model.evaluate(testloader)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_state_dict = my_model.state_dict()
        torch.save(best_model_state_dict, f'{run_path}.pth')
        
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch} with best validation loss {best_val_loss}")
        break
    time_epoch = time.perf_counter() - time_start
    print(f'epoch {epoch} time:  {time_epoch/60}')
    print('--------------------------------')

# Load the best model state dict
print(f'{run_path}.pth')
my_model.load_state_dict(torch.load(f'{run_path}.pth'))
# Out:
# wandb: Currently logged in as: adamsoja. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/adam/Desktop/cells_master_thesis/wandb/run-20240421_175550-dw7dudxq</code>
# Syncing run <strong><a href='https://wandb.ai/adamsoja/cells/runs/dw7dudxq' target="_blank">efficient_net_b2_2024-04-21 17:55:48.047123</a></strong> to <a href='https://wandb.ai/adamsoja/cells' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adamsoja/cells' target="_blank">https://wandb.ai/adamsoja/cells</a>
#  View run at <a href='https://wandb.ai/adamsoja/cells/runs/dw7dudxq' target="_blank">https://wandb.ai/adamsoja/cells/runs/dw7dudxq</a>
# ========================================
# EPOCH: 0
# train_loss: 0.9993292943352745
# train_precision: tensor([0.4911, 0.6388, 0.5714, 0.0448], device='cuda:0')
# train_recall: tensor([0.4704, 0.7273, 0.5706, 0.0022], device='cuda:0')
# val_loss: 0.9512479846676191
# val_precision: tensor([0.5443, 0.6628, 0.6403, 0.0000], device='cuda:0')
# val_recall: tensor([0.5184, 0.7998, 0.6025, 0.0000], device='cuda:0')
# Learning rate: 0.001
# epoch 0 time:  0.4720695516833075
# --------------------------------
# ========================================
# EPOCH: 1
# train_loss: 0.9282545030826614
# train_precision: tensor([0.5314, 0.6773, 0.6320, 0.2044], device='cuda:0')
# train_recall: tensor([0.5347, 0.7566, 0.6162, 0.0040], device='cuda:0')
# val_loss: 0.8615054905414581
# val_precision: tensor([0.5853, 0.6877, 0.6549, 0.7860], device='cuda:0')
# val_recall: tensor([0.5095, 0.7933, 0.6984, 0.0754], device='cuda:0')
# Learning rate: 0.001
# epoch 1 time:  0.47239363146666924
# --------------------------------
# ========================================
# EPOCH: 2
# train_loss: 0.8762476786261513
# train_precision: tensor([0.5576, 0.6936, 0.6548, 0.5477], device='cuda:0')
# train_recall: tensor([0.5516, 0.7696, 0.6497, 0.0489], device='cuda:0')
# val_loss: 0.8140990203453435
# val_precision: tensor([0.6121, 0.6936, 0.6706, 0.6452], device='cuda:0')
# val_recall: tensor([0.5222, 0.8111, 0.7043, 0.1758], device='cuda:0')
# Learning rate: 0.001
# epoch 2 time:  0.4726640060833233
# --------------------------------
# ========================================
# EPOCH: 3
# train_loss: 0.8259165214640753
# train_precision: tensor([0.5806, 0.7043, 0.6705, 0.6022], device='cuda:0')
# train_recall: tensor([0.5672, 0.7794, 0.6689, 0.1127], device='cuda:0')
# val_loss: 0.8316190499398444
# val_precision: tensor([0.6338, 0.7668, 0.5873, 0.7537], device='cuda:0')
# val_recall: tensor([0.4656, 0.7233, 0.8244, 0.1380], device='cuda:0')
# Learning rate: 0.001
# epoch 3 time:  0.4624873834166768
# --------------------------------
# ========================================
# EPOCH: 4
# train_loss: 0.8060333916828746
# train_precision: tensor([0.5912, 0.7129, 0.6750, 0.6234], device='cuda:0')
# train_recall: tensor([0.5705, 0.7835, 0.6798, 0.1801], device='cuda:0')
# val_loss: 0.7702994671960671
# val_precision: tensor([0.6406, 0.7169, 0.6769, 0.8717], device='cuda:0')
# val_recall: tensor([0.5494, 0.8135, 0.7369, 0.1646], device='cuda:0')
# Learning rate: 0.001
# epoch 4 time:  0.47321886366668575
# --------------------------------
# ========================================
# EPOCH: 5
# train_loss: 0.7969060198891731
# train_precision: tensor([0.5983, 0.7160, 0.6808, 0.6211], device='cuda:0')
# train_recall: tensor([0.5742, 0.7883, 0.6849, 0.2058], device='cuda:0')
# val_loss: 0.7893053723706139
# val_precision: tensor([0.6373, 0.7353, 0.6300, 0.4707], device='cuda:0')
# val_recall: tensor([0.4535, 0.7997, 0.7963, 0.1734], device='cuda:0')
# Learning rate: 0.001
# epoch 5 time:  0.4599615737499941
# --------------------------------
# ========================================
# EPOCH: 6
# train_loss: 0.7793495404578391
# train_precision: tensor([0.6085, 0.7233, 0.6892, 0.6097], device='cuda:0')
# train_recall: tensor([0.5831, 0.7915, 0.6949, 0.2385], device='cuda:0')
# val_loss: 0.7860089860028691
# val_precision: tensor([0.6187, 0.6921, 0.7213, 0.6063], device='cuda:0')
# val_recall: tensor([0.5794, 0.8387, 0.6595, 0.2276], device='cuda:0')
# Learning rate: 0.001
# epoch 6 time:  0.46022912568332686
# --------------------------------
# ========================================
# EPOCH: 7
# train_loss: 0.7570400884463674
# train_precision: tensor([0.6210, 0.7344, 0.6961, 0.6376], device='cuda:0')
# train_recall: tensor([0.5948, 0.7963, 0.7065, 0.2732], device='cuda:0')
# val_loss: 0.7494624594847361
# val_precision: tensor([0.6440, 0.8192, 0.6217, 0.8097], device='cuda:0')
# val_recall: tensor([0.5395, 0.7205, 0.8389, 0.2694], device='cuda:0')
# Learning rate: 0.001
# epoch 7 time:  0.4742502544166503
# --------------------------------
# ========================================
# EPOCH: 8
# train_loss: 0.7723828227037475
# train_precision: tensor([0.6132, 0.7254, 0.6894, 0.6230], device='cuda:0')
# train_recall: tensor([0.5845, 0.7912, 0.6980, 0.2711], device='cuda:0')
# val_loss: 0.7414965573284361
# val_precision: tensor([0.6178, 0.7785, 0.6896, 0.7943], device='cuda:0')
# val_recall: tensor([0.6497, 0.7507, 0.7237, 0.2744], device='cuda:0')
# Learning rate: 0.001
# epoch 8 time:  0.47308385711667145
# --------------------------------
# ========================================
# EPOCH: 9
# train_loss: 0.7422792243106024
# train_precision: tensor([0.6291, 0.7401, 0.7024, 0.6198], device='cuda:0')
# train_recall: tensor([0.6055, 0.7983, 0.7078, 0.3176], device='cuda:0')
# val_loss: 0.6984331004321576
# val_precision: tensor([0.6403, 0.7675, 0.7421, 0.5996], device='cuda:0')
# val_recall: tensor([0.6675, 0.8112, 0.6862, 0.4542], device='cuda:0')
# Learning rate: 0.001
# epoch 9 time:  0.4763251920666638
# --------------------------------
# ========================================
# EPOCH: 10
# train_loss: 0.7216183954051563
# train_precision: tensor([0.6384, 0.7481, 0.7103, 0.6378], device='cuda:0')
# train_recall: tensor([0.6137, 0.8018, 0.7176, 0.3609], device='cuda:0')
# val_loss: 0.6852824404835701
# val_precision: tensor([0.6387, 0.8153, 0.7115, 0.7563], device='cuda:0')
# val_recall: tensor([0.6874, 0.7540, 0.7458, 0.3845], device='cuda:0')
# Learning rate: 0.001
# epoch 10 time:  0.4759540358166608
# --------------------------------
# ========================================
# EPOCH: 11
# train_loss: 0.7085948873843465
# train_precision: tensor([0.6450, 0.7542, 0.7163, 0.6527], device='cuda:0')
# train_recall: tensor([0.6236, 0.8047, 0.7224, 0.3766], device='cuda:0')
# val_loss: 0.6935166479812728
# val_precision: tensor([0.6979, 0.7696, 0.6848, 0.7371], device='cuda:0')
# val_recall: tensor([0.5678, 0.8116, 0.8047, 0.4192], device='cuda:0')
# Learning rate: 0.001
# epoch 11 time:  0.46387852558333786
# --------------------------------
# ========================================
# EPOCH: 12
# train_loss: 0.7067179995633307
# train_precision: tensor([0.6471, 0.7534, 0.7191, 0.6491], device='cuda:0')
# train_recall: tensor([0.6262, 0.8065, 0.7212, 0.3823], device='cuda:0')
# val_loss: 0.6827768739726808
# val_precision: tensor([0.6545, 0.7839, 0.7162, 0.8284], device='cuda:0')
# val_recall: tensor([0.6424, 0.7994, 0.7584, 0.3300], device='cuda:0')
# Learning rate: 0.001
# epoch 12 time:  0.4754791139500109
# --------------------------------
# ========================================
# EPOCH: 13
# train_loss: 0.7033931028984842
# train_precision: tensor([0.6529, 0.7562, 0.7232, 0.6520], device='cuda:0')
# train_recall: tensor([0.6336, 0.8071, 0.7245, 0.3949], device='cuda:0')
# val_loss: 0.760200914243857
# val_precision: tensor([0.6097, 0.8101, 0.6640, 0.7005], device='cuda:0')
# val_recall: tensor([0.6215, 0.7088, 0.7703, 0.3182], device='cuda:0')
# Learning rate: 0.001
# epoch 13 time:  0.46222777605001586
# --------------------------------
# ========================================
# EPOCH: 14
# train_loss: 0.7072057857399895
# train_precision: tensor([0.6491, 0.7502, 0.7193, 0.6576], device='cuda:0')
# train_recall: tensor([0.6254, 0.8054, 0.7226, 0.3838], device='cuda:0')
# val_loss: 0.6760349224838945
# val_precision: tensor([0.6751, 0.7903, 0.6911, 0.8409], device='cuda:0')
# val_recall: tensor([0.6075, 0.7955, 0.7997, 0.3061], device='cuda:0')
# Learning rate: 0.001
# epoch 14 time:  0.47548827421666523
# --------------------------------
# ========================================
# EPOCH: 15
# train_loss: 0.6846861312077159
# train_precision: tensor([0.6595, 0.7629, 0.7304, 0.6675], device='cuda:0')
# train_recall: tensor([0.6405, 0.8104, 0.7319, 0.4293], device='cuda:0')
# val_loss: 0.6800685459540949
# val_precision: tensor([0.6420, 0.7766, 0.7386, 0.7818], device='cuda:0')
# val_recall: tensor([0.6712, 0.7857, 0.7328, 0.3956], device='cuda:0')
# Learning rate: 0.001
# epoch 15 time:  0.4627677572666774
# --------------------------------
# ========================================
# EPOCH: 16
# train_loss: 0.7932016279016222
# train_precision: tensor([0.5988, 0.7208, 0.6789, 0.5974], device='cuda:0')
# train_recall: tensor([0.5778, 0.7853, 0.6862, 0.2075], device='cuda:0')
# val_loss: 0.801464326845275
# val_precision: tensor([0.6603, 0.6970, 0.6310, 0.5170], device='cuda:0')
# val_recall: tensor([0.4357, 0.8057, 0.7767, 0.2768], device='cuda:0')
# Learning rate: 0.001
# epoch 16 time:  0.461438934000004
# --------------------------------
# ========================================
# EPOCH: 17
# train_loss: 0.719940291699909
# train_precision: tensor([0.6387, 0.7540, 0.7091, 0.6283], device='cuda:0')
# train_recall: tensor([0.6197, 0.8012, 0.7183, 0.3410], device='cuda:0')
# val_loss: 0.7958136726584699
# val_precision: tensor([0.6080, 0.8147, 0.6109, 0.8470], device='cuda:0')
# val_recall: tensor([0.5810, 0.6605, 0.7995, 0.2125], device='cuda:0')
# Learning rate: 0.0001
# epoch 17 time:  0.462189886933326
# --------------------------------
# ========================================
# EPOCH: 18
# train_loss: 0.6869249790906906
# train_precision: tensor([0.6572, 0.7633, 0.7222, 0.6699], device='cuda:0')
# train_recall: tensor([0.6355, 0.8098, 0.7312, 0.4003], device='cuda:0')
# val_loss: 0.6551155132551988
# val_precision: tensor([0.6664, 0.7973, 0.7283, 0.8283], device='cuda:0')
# val_recall: tensor([0.6711, 0.8041, 0.7566, 0.3768], device='cuda:0')
# Learning rate: 0.0001
# epoch 18 time:  0.4773324407333045
# --------------------------------
# ========================================
# EPOCH: 19
# train_loss: 0.6693318345007442
# train_precision: tensor([0.6666, 0.7693, 0.7329, 0.6860], device='cuda:0')
# train_recall: tensor([0.6464, 0.8177, 0.7357, 0.4356], device='cuda:0')
# val_loss: 0.648175747692585
# val_precision: tensor([0.6816, 0.8010, 0.7149, 0.8217], device='cuda:0')
# val_recall: tensor([0.6468, 0.8048, 0.7845, 0.4020], device='cuda:0')
# Learning rate: 0.0001
# epoch 19 time:  0.47464220851664624
# --------------------------------
# ========================================
# EPOCH: 20
# train_loss: 0.6653513952380135
# train_precision: tensor([0.6693, 0.7734, 0.7343, 0.6959], device='cuda:0')
# train_recall: tensor([0.6513, 0.8174, 0.7383, 0.4483], device='cuda:0')
# val_loss: 0.6406656448211935
# val_precision: tensor([0.6846, 0.8047, 0.7182, 0.7962], device='cuda:0')
# val_recall: tensor([0.6507, 0.8023, 0.7884, 0.4354], device='cuda:0')
# Learning rate: 0.0001
# epoch 20 time:  0.4739304035333286
# --------------------------------
# ========================================
# EPOCH: 21
# train_loss: 0.6614167985462007
# train_precision: tensor([0.6696, 0.7753, 0.7363, 0.6881], device='cuda:0')
# train_recall: tensor([0.6511, 0.8202, 0.7395, 0.4488], device='cuda:0')
# val_loss: 0.6358190471927325
# val_precision: tensor([0.6849, 0.8022, 0.7262, 0.8015], device='cuda:0')
# val_recall: tensor([0.6577, 0.8132, 0.7781, 0.4377], device='cuda:0')
# Learning rate: 0.0001
# epoch 21 time:  0.47625310644998536
# --------------------------------
# ========================================
# EPOCH: 22
# train_loss: 0.6574826630453269
# train_precision: tensor([0.6726, 0.7755, 0.7363, 0.6969], device='cuda:0')
# train_recall: tensor([0.6520, 0.8204, 0.7411, 0.4619], device='cuda:0')
# val_loss: 0.6372588559985161
# val_precision: tensor([0.6808, 0.8142, 0.7228, 0.7982], device='cuda:0')
# val_recall: tensor([0.6655, 0.7968, 0.7859, 0.4529], device='cuda:0')
# Learning rate: 0.0001
# epoch 22 time:  0.46187051195001916
# --------------------------------
# ========================================
# EPOCH: 23
# train_loss: 0.6553102648683957
# train_precision: tensor([0.6726, 0.7776, 0.7390, 0.6931], device='cuda:0')
# train_recall: tensor([0.6551, 0.8199, 0.7420, 0.4690], device='cuda:0')
# val_loss: 0.6360536538892322
# val_precision: tensor([0.6830, 0.8100, 0.7188, 0.8244], device='cuda:0')
# val_recall: tensor([0.6598, 0.8003, 0.7879, 0.4111], device='cuda:0')
# Learning rate: 0.0001
# epoch 23 time:  0.46193345383332296
# --------------------------------
# ========================================
# EPOCH: 24
# train_loss: 0.6537973005147207
# train_precision: tensor([0.6741, 0.7773, 0.7384, 0.6953], device='cuda:0')
# train_recall: tensor([0.6545, 0.8211, 0.7425, 0.4662], device='cuda:0')
# val_loss: 0.6330476424760288
# val_precision: tensor([0.6808, 0.8073, 0.7316, 0.7927], device='cuda:0')
# val_recall: tensor([0.6678, 0.8053, 0.7799, 0.4404], device='cuda:0')
# Learning rate: 0.0001
# epoch 24 time:  0.476904584883323
# --------------------------------
# ========================================
# EPOCH: 25
# train_loss: 0.6516666883514041
# train_precision: tensor([0.6760, 0.7783, 0.7380, 0.6918], device='cuda:0')
# train_recall: tensor([0.6557, 0.8213, 0.7436, 0.4661], device='cuda:0')
# val_loss: 0.628018052296506
# val_precision: tensor([0.6821, 0.8017, 0.7393, 0.7915], device='cuda:0')
# val_recall: tensor([0.6708, 0.8152, 0.7700, 0.4613], device='cuda:0')
# Learning rate: 0.0001
# epoch 25 time:  0.47689892586665034
# --------------------------------
# ========================================
# EPOCH: 26
# train_loss: 0.6476667033774512
# train_precision: tensor([0.6781, 0.7795, 0.7435, 0.6950], device='cuda:0')
# train_recall: tensor([0.6602, 0.8226, 0.7448, 0.4833], device='cuda:0')
# val_loss: 0.6269337491028839
# val_precision: tensor([0.6831, 0.8166, 0.7254, 0.7996], device='cuda:0')
# val_recall: tensor([0.6692, 0.7991, 0.7879, 0.4448], device='cuda:0')
# Learning rate: 0.0001
# epoch 26 time:  0.4736837886499719
# --------------------------------
# ========================================
# EPOCH: 27
# train_loss: 0.6487105111990656
# train_precision: tensor([0.6762, 0.7784, 0.7407, 0.6926], device='cuda:0')
# train_recall: tensor([0.6558, 0.8210, 0.7456, 0.4771], device='cuda:0')
# val_loss: 0.6286315914657381
# val_precision: tensor([0.6813, 0.8080, 0.7365, 0.8232], device='cuda:0')
# val_recall: tensor([0.6791, 0.8101, 0.7722, 0.4310], device='cuda:0')
# Learning rate: 0.0001
# epoch 27 time:  0.46201679680001084
# --------------------------------
# ========================================
# EPOCH: 28
# train_loss: 0.6487430498358749
# train_precision: tensor([0.6771, 0.7771, 0.7409, 0.6951], device='cuda:0')
# train_recall: tensor([0.6557, 0.8225, 0.7441, 0.4779], device='cuda:0')
# val_loss: 0.6300966786841552
# val_precision: tensor([0.6840, 0.8097, 0.7290, 0.7782], device='cuda:0')
# val_recall: tensor([0.6686, 0.8018, 0.7816, 0.4690], device='cuda:0')
# Learning rate: 0.0001
# epoch 28 time:  0.46322144571665075
# --------------------------------
# ========================================
# EPOCH: 29
# train_loss: 0.6448851268206324
# train_precision: tensor([0.6787, 0.7789, 0.7437, 0.7029], device='cuda:0')
# train_recall: tensor([0.6594, 0.8231, 0.7455, 0.4876], device='cuda:0')
# val_loss: 0.6306568455364969
# val_precision: tensor([0.6917, 0.8119, 0.7215, 0.8088], device='cuda:0')
# val_recall: tensor([0.6582, 0.8048, 0.7957, 0.4401], device='cuda:0')
# Learning rate: 1e-05
# epoch 29 time:  0.4647487328999887
# --------------------------------
# ========================================
# EPOCH: 30
# train_loss: 0.6420011445879936
# train_precision: tensor([0.6814, 0.7814, 0.7431, 0.6987], device='cuda:0')
# train_recall: tensor([0.6596, 0.8226, 0.7492, 0.4962], device='cuda:0')
# val_loss: 0.6270397065414323
# val_precision: tensor([0.6855, 0.8177, 0.7239, 0.7990], device='cuda:0')
# val_recall: tensor([0.6697, 0.7951, 0.7921, 0.4525], device='cuda:0')
# Learning rate: 1e-05
# epoch 30 time:  0.4639569214333278
# --------------------------------
# ========================================
# EPOCH: 31
# train_loss: 0.6390979142416091
# train_precision: tensor([0.6822, 0.7808, 0.7432, 0.7013], device='cuda:0')
# train_recall: tensor([0.6594, 0.8252, 0.7482, 0.4903], device='cuda:0')
# val_loss: 0.622986016008589
# val_precision: tensor([0.6989, 0.8002, 0.7282, 0.7798], device='cuda:0')
# val_recall: tensor([0.6508, 0.8212, 0.7885, 0.4663], device='cuda:0')
# Learning rate: 1e-05
# epoch 31 time:  0.47430729263332977
# --------------------------------
# ========================================
# EPOCH: 32
# train_loss: 0.6397287277238709
# train_precision: tensor([0.6809, 0.7812, 0.7451, 0.7059], device='cuda:0')
# train_recall: tensor([0.6617, 0.8254, 0.7477, 0.4825], device='cuda:0')
# val_loss: 0.623707181132502
# val_precision: tensor([0.6897, 0.8096, 0.7293, 0.7884], device='cuda:0')
# val_recall: tensor([0.6651, 0.8085, 0.7867, 0.4593], device='cuda:0')
# Learning rate: 1e-05
# epoch 32 time:  0.46364278835001943
# --------------------------------
# ========================================
# EPOCH: 33
# train_loss: 0.6396273341916856
# train_precision: tensor([0.6809, 0.7823, 0.7448, 0.6986], device='cuda:0')
# train_recall: tensor([0.6601, 0.8247, 0.7490, 0.4941], device='cuda:0')
# val_loss: 0.6208592038187716
# val_precision: tensor([0.6945, 0.8029, 0.7350, 0.7801], device='cuda:0')
# val_recall: tensor([0.6653, 0.8190, 0.7805, 0.4694], device='cuda:0')
# Learning rate: 1e-05
# epoch 33 time:  0.47304401801666246
# --------------------------------
# ========================================
# EPOCH: 34
# train_loss: 0.6388455328842004
# train_precision: tensor([0.6809, 0.7809, 0.7455, 0.7075], device='cuda:0')
# train_recall: tensor([0.6617, 0.8255, 0.7470, 0.4883], device='cuda:0')
# val_loss: 0.625263915459315
# val_precision: tensor([0.6952, 0.8046, 0.7285, 0.8213], device='cuda:0')
# val_recall: tensor([0.6606, 0.8159, 0.7888, 0.4364], device='cuda:0')
# Learning rate: 1e-05
# epoch 34 time:  0.46351290651667415
# --------------------------------
# ========================================
# EPOCH: 35
# train_loss: 0.6382115005382469
# train_precision: tensor([0.6834, 0.7823, 0.7464, 0.7032], device='cuda:0')
# train_recall: tensor([0.6641, 0.8248, 0.7493, 0.4929], device='cuda:0')
# val_loss: 0.6241557151079178
# val_precision: tensor([0.6916, 0.8164, 0.7210, 0.7957], device='cuda:0')
# val_recall: tensor([0.6604, 0.8007, 0.7977, 0.4616], device='cuda:0')
# Learning rate: 1e-05
# epoch 35 time:  0.4655212568666684
# --------------------------------
# ========================================
# EPOCH: 36
# train_loss: 0.6384303134112131
# train_precision: tensor([0.6825, 0.7819, 0.7456, 0.7001], device='cuda:0')
# train_recall: tensor([0.6631, 0.8237, 0.7490, 0.4931], device='cuda:0')
# val_loss: 0.6261155818899472
# val_precision: tensor([0.6853, 0.8178, 0.7253, 0.8057], device='cuda:0')
# val_recall: tensor([0.6719, 0.7945, 0.7922, 0.4495], device='cuda:0')
# Learning rate: 5e-06
# epoch 36 time:  0.4750496752166631
# --------------------------------
# ========================================
# EPOCH: 37
# train_loss: 0.6379583684816247
# train_precision: tensor([0.6812, 0.7820, 0.7452, 0.7042], device='cuda:0')
# train_recall: tensor([0.6635, 0.8237, 0.7477, 0.4885], device='cuda:0')
# val_loss: 0.6307674958474107
# val_precision: tensor([0.6823, 0.8174, 0.7263, 0.8379], device='cuda:0')
# val_recall: tensor([0.6739, 0.7969, 0.7893, 0.4246], device='cuda:0')
# Learning rate: 5e-06
# epoch 37 time:  0.46356810638332413
# --------------------------------
# ========================================
# EPOCH: 38
# train_loss: 0.6371147025908742
# train_precision: tensor([0.6830, 0.7822, 0.7449, 0.7028], device='cuda:0')
# train_recall: tensor([0.6620, 0.8242, 0.7503, 0.4916], device='cuda:0')
# val_loss: 0.6245977544950114
# val_precision: tensor([0.6892, 0.8134, 0.7258, 0.8111], device='cuda:0')
# val_recall: tensor([0.6664, 0.8034, 0.7920, 0.4394], device='cuda:0')
# Learning rate: 5e-06
# epoch 38 time:  0.4618530247333486
# --------------------------------
# ========================================
# EPOCH: 39
# train_loss: 0.637393024918579
# train_precision: tensor([0.6829, 0.7799, 0.7460, 0.7131], device='cuda:0')
# train_recall: tensor([0.6625, 0.8259, 0.7478, 0.4902], device='cuda:0')
# val_loss: 0.6224494972162776
# val_precision: tensor([0.6875, 0.8127, 0.7321, 0.8153], device='cuda:0')
# val_recall: tensor([0.6731, 0.8068, 0.7862, 0.4428], device='cuda:0')
# Learning rate: 5e-06
# epoch 39 time:  0.46292494104997484
# --------------------------------
# ========================================
# EPOCH: 40
# train_loss: 0.6369100057653019
# train_precision: tensor([0.6828, 0.7836, 0.7463, 0.7040], device='cuda:0')
# train_recall: tensor([0.6648, 0.8255, 0.7479, 0.4975], device='cuda:0')
# val_loss: 0.6223865801261531
# val_precision: tensor([0.6907, 0.8101, 0.7323, 0.8055], device='cuda:0')
# val_recall: tensor([0.6700, 0.8108, 0.7858, 0.4519], device='cuda:0')
# Learning rate: 5e-06
# epoch 40 time:  0.46393724310000833
# --------------------------------
# ========================================
# EPOCH: 41
# train_loss: 0.6373133110148567
# train_precision: tensor([0.6833, 0.7823, 0.7453, 0.6966], device='cuda:0')
# train_recall: tensor([0.6617, 0.8244, 0.7501, 0.4960], device='cuda:0')
# val_loss: 0.6246585106684102
# val_precision: tensor([0.6941, 0.8107, 0.7238, 0.8151], device='cuda:0')
# val_recall: tensor([0.6582, 0.8082, 0.7966, 0.4424], device='cuda:0')
# Learning rate: 5e-06
# epoch 41 time:  0.46264567640000676
# --------------------------------
# ========================================
# EPOCH: 42
# train_loss: 0.6354420322747457
# train_precision: tensor([0.6823, 0.7838, 0.7456, 0.7103], device='cuda:0')
# train_recall: tensor([0.6630, 0.8245, 0.7507, 0.4944], device='cuda:0')
# val_loss: 0.6187681828108099
# val_precision: tensor([0.6911, 0.8076, 0.7366, 0.7927], device='cuda:0')
# val_recall: tensor([0.6736, 0.8132, 0.7805, 0.4660], device='cuda:0')
# Learning rate: 5e-06
# epoch 42 time:  0.4744781793833378
# --------------------------------
# ========================================
# EPOCH: 43
# train_loss: 0.636723866987796
# train_precision: tensor([0.6842, 0.7811, 0.7460, 0.6979], device='cuda:0')
# train_recall: tensor([0.6634, 0.8250, 0.7492, 0.4895], device='cuda:0')
# val_loss: 0.6239817414018843
# val_precision: tensor([0.6879, 0.8123, 0.7321, 0.8203], device='cuda:0')
# val_recall: tensor([0.6741, 0.8069, 0.7858, 0.4380], device='cuda:0')
# Learning rate: 5e-06
# epoch 43 time:  0.4610690637000213
# --------------------------------
# ========================================
# EPOCH: 44
# train_loss: 0.6356266405256021
# train_precision: tensor([0.6842, 0.7838, 0.7467, 0.7095], device='cuda:0')
# train_recall: tensor([0.6643, 0.8255, 0.7512, 0.4968], device='cuda:0')
# val_loss: 0.6203488680223624
# val_precision: tensor([0.7048, 0.8021, 0.7235, 0.7974], device='cuda:0')
# val_recall: tensor([0.6435, 0.8218, 0.7986, 0.4677], device='cuda:0')
# Learning rate: 5e-06
# epoch 44 time:  0.4620604951666792
# --------------------------------
# ========================================
# EPOCH: 45
# train_loss: 0.6360568875003428
# train_precision: tensor([0.6821, 0.7813, 0.7466, 0.7050], device='cuda:0')
# train_recall: tensor([0.6640, 0.8235, 0.7483, 0.4951], device='cuda:0')
# val_loss: 0.6248350639310148
# val_precision: tensor([0.6905, 0.8187, 0.7201, 0.8007], device='cuda:0')
# val_recall: tensor([0.6605, 0.7974, 0.8010, 0.4572], device='cuda:0')
# Learning rate: 5e-06
# epoch 45 time:  0.463872871033315
# --------------------------------
# ========================================
# EPOCH: 46
# train_loss: 0.634792480298451
# train_precision: tensor([0.6841, 0.7829, 0.7468, 0.7017], device='cuda:0')
# train_recall: tensor([0.6639, 0.8267, 0.7494, 0.4922], device='cuda:0')
# val_loss: 0.6225149725874265
# val_precision: tensor([0.6822, 0.8152, 0.7362, 0.8122], device='cuda:0')
# val_recall: tensor([0.6831, 0.8016, 0.7805, 0.4471], device='cuda:0')
# Learning rate: 5e-06
# epoch 46 time:  0.4622507984333121
# --------------------------------
# ========================================
# EPOCH: 47
# train_loss: 0.6356610046965735
# train_precision: tensor([0.6855, 0.7837, 0.7458, 0.6967], device='cuda:0')
# train_recall: tensor([0.6640, 0.8252, 0.7510, 0.4980], device='cuda:0')
# val_loss: 0.6195661104387707
# val_precision: tensor([0.6901, 0.8033, 0.7393, 0.8216], device='cuda:0')
# val_recall: tensor([0.6726, 0.8195, 0.7774, 0.4404], device='cuda:0')
# Learning rate: 5e-06
# epoch 47 time:  0.46207913786668847
# --------------------------------
# ========================================
# EPOCH: 48
# train_loss: 0.6347688649736699
# train_precision: tensor([0.6831, 0.7832, 0.7471, 0.7014], device='cuda:0')
# train_recall: tensor([0.6643, 0.8254, 0.7494, 0.4949], device='cuda:0')
# val_loss: 0.6223447518216239
# val_precision: tensor([0.6870, 0.8137, 0.7307, 0.8228], device='cuda:0')
# val_recall: tensor([0.6739, 0.8049, 0.7862, 0.4441], device='cuda:0')
# Learning rate: 5e-06
# epoch 48 time:  0.46115578478332586
# --------------------------------
# ========================================
# EPOCH: 49
# train_loss: 0.6340260050836064
# train_precision: tensor([0.6849, 0.7841, 0.7468, 0.7040], device='cuda:0')
# train_recall: tensor([0.6650, 0.8262, 0.7502, 0.4986], device='cuda:0')
# val_loss: 0.6203372991747327
# val_precision: tensor([0.6844, 0.8162, 0.7339, 0.7979], device='cuda:0')
# val_recall: tensor([0.6791, 0.8016, 0.7833, 0.4653], device='cuda:0')
# Learning rate: 5e-06
# epoch 49 time:  0.463563010083332
# --------------------------------
# ========================================
# EPOCH: 50
# train_loss: 0.6345906672023591
# train_precision: tensor([0.6849, 0.7827, 0.7471, 0.7034], device='cuda:0')
# train_recall: tensor([0.6643, 0.8260, 0.7505, 0.4931], device='cuda:0')
# val_loss: 0.6202751885685656
# val_precision: tensor([0.6910, 0.8077, 0.7345, 0.8102], device='cuda:0')
# val_recall: tensor([0.6692, 0.8143, 0.7843, 0.4498], device='cuda:0')
# Learning rate: 5e-06
# epoch 50 time:  0.46348947053332573
# --------------------------------
# ========================================
# EPOCH: 51
# train_loss: 0.6349123622335139
# train_precision: tensor([0.6833, 0.7835, 0.7478, 0.7067], device='cuda:0')
# train_recall: tensor([0.6653, 0.8255, 0.7494, 0.4990], device='cuda:0')
# val_loss: 0.6233211081061099
# val_precision: tensor([0.6876, 0.8138, 0.7302, 0.8213], device='cuda:0')
# val_recall: tensor([0.6734, 0.8036, 0.7882, 0.4411], device='cuda:0')
# Learning rate: 5e-06
# epoch 51 time:  0.46604756758330645
# --------------------------------
# ========================================
# EPOCH: 52
# train_loss: 0.6348226538016682
# train_precision: tensor([0.6841, 0.7827, 0.7462, 0.7009], device='cuda:0')
# train_recall: tensor([0.6620, 0.8273, 0.7495, 0.4964], device='cuda:0')
# val_loss: 0.6259518736766444
# val_precision: tensor([0.6925, 0.8124, 0.7274, 0.8263], device='cuda:0')
# val_recall: tensor([0.6666, 0.8075, 0.7932, 0.4387], device='cuda:0')
# Learning rate: 5e-06
# Early stopping at epoch 52 with best validation loss 0.6187681828108099
# training_checkpoints/efficient_net_b2_2024-04-21 17:55:48.047123.pth
# <All keys matched successfully>

# %%
from sklearn.metrics import confusion_matrix, classification_report
from torch.utils.data import DataLoader
import numpy as np
import torch 
from torchvision.models import resnet18
import torch.nn as nn


def test_report(model, dataloader):
    """Prints confusion matrix for testing dataset
    dataloader should be of batch_size=1."""

    y_pred = []
    y_test = []
    model.eval()
    with torch.no_grad():
        for data, label in dataloader:
            output = model(data)
            label = label.numpy()
            output = output.numpy()
            y_pred.append(np.argmax(output))
            y_test.append(np.argmax(label))
        print(confusion_matrix(y_test, y_pred))
        print(classification_report(y_test, y_pred))

testset =ImageDataset(data_path='test_data')
dataloader = DataLoader(testset, batch_size=1, shuffle=True)

test_report(my_model.to('cpu'), dataloader)
# Out:
# [[675 102 221   2]
#  [110 824  62   4]
#  [157  48 790   5]
#  [ 24  16  13  47]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.68      0.69      1000
#            1       0.83      0.82      0.83      1000
#            2       0.73      0.79      0.76      1000
#            3       0.81      0.47      0.59       100
#
#     accuracy                           0.75      3100
#    macro avg       0.77      0.69      0.72      3100
# weighted avg       0.75      0.75      0.75      3100
