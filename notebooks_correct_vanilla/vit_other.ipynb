# %%
import time
import sys
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from dataset import ImageDataset
import torch.nn.functional as F
from torchmetrics import Precision, Recall
from torchvision.models import resnet50
import warnings
from collections import defaultdict
import wandb
import datetime
import os
from vit.vit import VisionTransformer

warnings.filterwarnings('ignore')
torch.set_float32_matmul_precision('high')
#intecubic interpol

run_name = f'vit_other_{datetime.datetime.now()}'
run_path = f'training_checkpoints/{run_name}'

wandb.init(project="cells", 
           entity="adamsoja",
          name=run_name)

import random
random.seed(2233)
torch.manual_seed(2233)

#After /255 so in loading dataset there are no division by 255 just this normalization
mean = [0.5006, 0.3526, 0.5495]
std = [0.1493, 0.1341, 0.1124]


from albumentations import (
    Compose,
    Resize,
    OneOf,
    RandomBrightness,
    RandomContrast,
    MotionBlur,
    MedianBlur,
    GaussianBlur,
    VerticalFlip,
    HorizontalFlip,
    ShiftScaleRotate,
    Normalize,
)

transform = Compose(
    [
        Normalize(mean=mean, std=std),
        OneOf([RandomBrightness(limit=0.1, p=1), RandomContrast(limit=0.1, p=0.8)]),
        OneOf([MotionBlur(blur_limit=3), MedianBlur(blur_limit=3), GaussianBlur(blur_limit=3),], p=0.7,),
        VerticalFlip(p=0.5),
        HorizontalFlip(p=0.5),
    ]
)

transform_test = Compose(
    [Normalize(mean=mean, std=std)]
)


class MyModel(nn.Module):
    def __init__(self, model, learning_rate, weight_decay):
        super(MyModel, self).__init__()
        self.model = model
        self.learning_rate = learning_rate
        self.weight_decay = weight_decay
        self.criterion = nn.CrossEntropyLoss()
        self.metric_precision = Precision(task="multiclass", num_classes=4, average=None).to('cuda')
        self.metric_recall = Recall(task="multiclass", num_classes=4, average=None).to('cuda')
        self.train_loss = []
        self.valid_loss = []
        self.precision_per_epochs = []
        self.recall_per_epochs = []

        self.optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, mode="min", factor=0.1, patience=6, min_lr=5e-6, verbose=True)
        self.step = 0

    
    def forward(self, x):
        return self.model(x)

    def train_one_epoch(self, trainloader):
        self.step += 1
        self.train()
        for batch_idx, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()
            _, preds = torch.max(outputs, 1)
            _, labels = torch.max(labels, 1)
            self.metric_precision(preds, labels)
            self.metric_recall(preds, labels)
            self.train_loss.append(loss.item())


        

        
        avg_loss = np.mean(self.train_loss)
        self.train_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        self.precision_per_epochs.append(precision)
        self.recall_per_epochs.append(recall)
        print(f'train_loss: {avg_loss}')
        print(f'train_precision: {precision}')
        print(f'train_recall: {recall}')

        wandb.log({'loss': avg_loss}, step=self.step)
        
        # Logowanie precision dla każdej klasy
        wandb.log({'Normal precision': precision[0].item()}, step=self.step)
        wandb.log({'Inflamatory precision': precision[1].item()}, step=self.step)
        wandb.log({'Tumor precision': precision[2].item()}, step=self.step)
        wandb.log({'Other precision': precision[3].item()}, step=self.step)
        
        # Logowanie recall dla każdej klasy
        wandb.log({'Normal recall': recall[0].item()}, step=self.step)
        wandb.log({'Inflamatory recall': recall[1].item()}, step=self.step)
        wandb.log({'Tumor recall': recall[2].item()}, step=self.step)
        wandb.log({'Other recall': recall[3].item()}, step=self.step)
        
        # Obliczanie głównych metryk
        main_metrics_precision = (precision[0].item() + precision[1].item() + precision[2].item() + precision[3].item()) / 4
        main_metrics_recall = (recall[0].item() + recall[1].item() + recall[2].item() + recall[3].item()) / 4
        
        # Logowanie głównych metryk
        wandb.log({'main_metrics_precision': main_metrics_precision}, step=self.step)
        wandb.log({'main_metrics_recall': main_metrics_recall}, step=self.step)

        wandb.log({'f1_score': (main_metrics_recall + main_metrics_precision )/ 2}, step=self.step)

        
        
        self.metric_precision.reset()
        self.metric_recall.reset()


    

    def evaluate(self, testloader):
        self.eval()
        with torch.no_grad():
            for batch_idx, (inputs, labels) in enumerate(testloader):
                inputs, labels = inputs.to('cuda'), labels.to('cuda')
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)
                _, labels = torch.max(labels, 1)
                self.metric_precision(preds, labels)
                self.metric_recall(preds, labels)
                self.valid_loss.append(loss.item())
    
        avg_loss = np.mean(self.valid_loss)
        self.scheduler.step(avg_loss)
        self.valid_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        print(f'val_loss: {avg_loss}')
        print(f'val_precision: {precision}')
        print(f'val_recall: {recall}')
        self.metric_precision.reset()
        self.metric_recall.reset()
    
        main_metrics_precision = (precision[0].item() + precision[1].item() + precision[2].item() + precision[3].item()) / 4
        
        main_metrics_recall = (recall[0].item() + recall[1].item() + recall[2].item() + recall[3].item()) / 4
        
        wandb.log({'val_loss': avg_loss}, step=self.step)
        
        wandb.log({'val_Normal precision': precision[0].item()}, step=self.step)
        wandb.log({'val_Inflamatory precision': precision[1].item()}, step=self.step)
        wandb.log({'val_Tumor precision': precision[2].item()}, step=self.step)
        wandb.log({'val_Other precision': precision[3].item()}, step=self.step)
        
        wandb.log({'val_Normal recall': recall[0].item()}, step=self.step)
        wandb.log({'val_Inflamatory recall': recall[1].item()}, step=self.step)
        wandb.log({'val_Tumor recall': recall[2].item()}, step=self.step)
        wandb.log({'val_Other recall': recall[3].item()}, step=self.step)
        
        wandb.log({'val_main_metrics_precision': main_metrics_precision}, step=self.step)
        wandb.log({'val_main_metrics_recall': main_metrics_recall}, step=self.step)
        wandb.log({'f1_score_val': (main_metrics_recall + main_metrics_precision )/ 2}, step=self.step)
        

        for param_group in self.optimizer.param_groups:
            print(f"Learning rate: {param_group['lr']}")
        return avg_loss

torch.cuda.empty_cache()
batch_size = 128

trainset = ImageDataset(data_path='train_data', transform=transform)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=5)

testset = ImageDataset(data_path='validation_data', transform=transform_test)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=3)


learning_rate = 0.001
weight_decay = 0.00001

model = VisionTransformer(image_size=32, 
                          in_channels=3, 
                          num_classes=4, 
                          dropout_rate=0.2,
                          embedding_dim=32,
                          patch_size=8,
                          num_layers=3,
                          num_heads=2,
                          use_linear_patch=False,
                          use_conv_stem=True,
                          hidden_dims = [32, 32],
                          use_conv_patch=False)
model = model.to('cuda')


my_model = MyModel(model=model, learning_rate=learning_rate, weight_decay=weight_decay)
my_model = my_model.to('cuda')

num_epochs = 100
early_stop_patience = 15
best_val_loss = float('inf')
best_model_state_dict = None

for epoch in range(num_epochs):
    print('========================================')
    print(f'EPOCH: {epoch}') 
    time_start = time.perf_counter()
    my_model.train_one_epoch(trainloader)
    val_loss = my_model.evaluate(testloader)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_state_dict = my_model.state_dict()
        torch.save(best_model_state_dict, f'{run_path}.pth')
        
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch} with best validation loss {best_val_loss}")
        break
    time_epoch = time.perf_counter() - time_start
    print(f'epoch {epoch} time:  {time_epoch}')
    print('--------------------------------')

# Load the best model state dict
print(f'{run_path}.pth')
my_model.load_state_dict(torch.load(f'{run_path}.pth'))
# Out:
# wandb: Currently logged in as: adamsoja. Use `wandb login --relogin` to force relogin
# wandb version 0.17.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/adam/Desktop/cells_master_thesis/wandb/run-20240526_143030-pvzwnrle</code>
# Syncing run <strong><a href='https://wandb.ai/adamsoja/cells/runs/pvzwnrle' target="_blank">vit_other_2024-05-26 14:30:29.615910</a></strong> to <a href='https://wandb.ai/adamsoja/cells' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adamsoja/cells' target="_blank">https://wandb.ai/adamsoja/cells</a>
#  View run at <a href='https://wandb.ai/adamsoja/cells/runs/pvzwnrle' target="_blank">https://wandb.ai/adamsoja/cells/runs/pvzwnrle</a>
# ========================================
# EPOCH: 0
# train_loss: 0.9338926752455678
# train_precision: tensor([0.5280, 0.6312, 0.6208, 0.5954], device='cuda:0')
# train_recall: tensor([0.4894, 0.7600, 0.6004, 0.0113], device='cuda:0')
# val_loss: 0.8188573350095086
# val_precision: tensor([0.5874, 0.7059, 0.6884, 0.9800], device='cuda:0')
# val_recall: tensor([0.5978, 0.7868, 0.6639, 0.0330], device='cuda:0')
# Learning rate: 0.001
# epoch 0 time:  33.14456826300011
# --------------------------------
# ========================================
# EPOCH: 1
# train_loss: 0.8531247860906804
# train_precision: tensor([0.5708, 0.6820, 0.6672, 0.5492], device='cuda:0')
# train_recall: tensor([0.5634, 0.7670, 0.6507, 0.0724], device='cuda:0')
# val_loss: 0.790262337649862
# val_precision: tensor([0.6435, 0.7604, 0.6282, 0.5151], device='cuda:0')
# val_recall: tensor([0.5105, 0.7457, 0.8014, 0.2586], device='cuda:0')
# Learning rate: 0.001
# epoch 1 time:  32.89221389700106
# --------------------------------
# ========================================
# EPOCH: 2
# train_loss: 0.8287471610211843
# train_precision: tensor([0.5868, 0.6939, 0.6754, 0.5478], device='cuda:0')
# train_recall: tensor([0.5724, 0.7726, 0.6664, 0.1341], device='cuda:0')
# val_loss: 0.772204164084461
# val_precision: tensor([0.6099, 0.7892, 0.6668, 0.6603], device='cuda:0')
# val_recall: tensor([0.6254, 0.7180, 0.7498, 0.2663], device='cuda:0')
# Learning rate: 0.001
# epoch 2 time:  32.89146411399997
# --------------------------------
# ========================================
# EPOCH: 3
# train_loss: 0.8134708415191042
# train_precision: tensor([0.5993, 0.6969, 0.6813, 0.5457], device='cuda:0')
# train_recall: tensor([0.5773, 0.7787, 0.6721, 0.1792], device='cuda:0')
# val_loss: 0.7340589406175746
# val_precision: tensor([0.6138, 0.7543, 0.7287, 0.6933], device='cuda:0')
# val_recall: tensor([0.6539, 0.7812, 0.6966, 0.2983], device='cuda:0')
# Learning rate: 0.001
# epoch 3 time:  33.06314279999788
# --------------------------------
# ========================================
# EPOCH: 4
# train_loss: 0.8014865760436862
# train_precision: tensor([0.6046, 0.7039, 0.6841, 0.5482], device='cuda:0')
# train_recall: tensor([0.5831, 0.7801, 0.6763, 0.2124], device='cuda:0')
# val_loss: 0.7430391892376873
# val_precision: tensor([0.6419, 0.7851, 0.6634, 0.6592], device='cuda:0')
# val_recall: tensor([0.5875, 0.7472, 0.7821, 0.3576], device='cuda:0')
# Learning rate: 0.001
# epoch 4 time:  32.95782958500058
# --------------------------------
# ========================================
# EPOCH: 5
# train_loss: 0.7929826475382561
# train_precision: tensor([0.6089, 0.7062, 0.6860, 0.5528], device='cuda:0')
# train_recall: tensor([0.5849, 0.7826, 0.6797, 0.2228], device='cuda:0')
# val_loss: 0.732345508908232
# val_precision: tensor([0.6684, 0.7793, 0.6534, 0.6001], device='cuda:0')
# val_recall: tensor([0.5376, 0.7744, 0.8079, 0.3926], device='cuda:0')
# Learning rate: 0.001
# epoch 5 time:  33.01014858599956
# --------------------------------
# ========================================
# EPOCH: 6
# train_loss: 0.7819987859592472
# train_precision: tensor([0.6145, 0.7127, 0.6905, 0.5738], device='cuda:0')
# train_recall: tensor([0.5887, 0.7872, 0.6870, 0.2440], device='cuda:0')
# val_loss: 0.7215799068825113
# val_precision: tensor([0.6374, 0.7279, 0.7649, 0.5825], device='cuda:0')
# val_recall: tensor([0.6518, 0.8389, 0.6554, 0.3970], device='cuda:0')
# Learning rate: 0.001
# epoch 6 time:  33.06678459300019
# --------------------------------
# ========================================
# EPOCH: 7
# train_loss: 0.7746934367120798
# train_precision: tensor([0.6208, 0.7146, 0.6919, 0.5671], device='cuda:0')
# train_recall: tensor([0.5933, 0.7848, 0.6923, 0.2579], device='cuda:0')
# val_loss: 0.7339520052075386
# val_precision: tensor([0.6792, 0.7904, 0.6410, 0.8026], device='cuda:0')
# val_recall: tensor([0.5525, 0.7588, 0.8322, 0.2259], device='cuda:0')
# Learning rate: 0.001
# epoch 7 time:  33.01432008700067
# --------------------------------
# ========================================
# EPOCH: 8
# train_loss: 0.7680496341987619
# train_precision: tensor([0.6246, 0.7173, 0.6920, 0.5848], device='cuda:0')
# train_recall: tensor([0.5951, 0.7884, 0.6933, 0.2701], device='cuda:0')
# val_loss: 0.6905235667195585
# val_precision: tensor([0.6582, 0.7718, 0.7181, 0.7351], device='cuda:0')
# val_recall: tensor([0.6247, 0.8040, 0.7612, 0.3606], device='cuda:0')
# Learning rate: 0.001
# epoch 8 time:  32.997944069997175
# --------------------------------
# ========================================
# EPOCH: 9
# train_loss: 0.7611261943112249
# train_precision: tensor([0.6294, 0.7210, 0.6953, 0.5896], device='cuda:0')
# train_recall: tensor([0.5983, 0.7901, 0.6989, 0.2843], device='cuda:0')
# val_loss: 0.6990749009367493
# val_precision: tensor([0.6470, 0.8121, 0.6922, 0.7773], device='cuda:0')
# val_recall: tensor([0.6612, 0.7442, 0.7719, 0.3620], device='cuda:0')
# Learning rate: 0.001
# epoch 9 time:  32.931155812002544
# --------------------------------
# ========================================
# EPOCH: 10
# train_loss: 0.7553088443488006
# train_precision: tensor([0.6337, 0.7223, 0.6984, 0.5910], device='cuda:0')
# train_recall: tensor([0.6033, 0.7910, 0.7015, 0.2872], device='cuda:0')
# val_loss: 0.6857763201412227
# val_precision: tensor([0.6558, 0.8122, 0.6985, 0.6246], device='cuda:0')
# val_recall: tensor([0.6265, 0.7603, 0.7962, 0.4296], device='cuda:0')
# Learning rate: 0.001
# epoch 10 time:  33.136179863002326
# --------------------------------
# ========================================
# EPOCH: 11
# train_loss: 0.75006387590865
# train_precision: tensor([0.6356, 0.7241, 0.6994, 0.5981], device='cuda:0')
# train_recall: tensor([0.6036, 0.7938, 0.7019, 0.3014], device='cuda:0')
# val_loss: 0.694117400671045
# val_precision: tensor([0.6615, 0.8240, 0.6806, 0.6823], device='cuda:0')
# val_recall: tensor([0.6470, 0.7330, 0.7957, 0.4303], device='cuda:0')
# Learning rate: 0.001
# epoch 11 time:  33.150519590999465
# --------------------------------
# ========================================
# EPOCH: 12
# train_loss: 0.7457755349660786
# train_precision: tensor([0.6374, 0.7266, 0.7000, 0.5999], device='cuda:0')
# train_recall: tensor([0.6071, 0.7925, 0.7041, 0.3053], device='cuda:0')
# val_loss: 0.6755311336368323
# val_precision: tensor([0.6433, 0.7853, 0.7530, 0.6701], device='cuda:0')
# val_recall: tensor([0.6953, 0.7938, 0.7171, 0.3761], device='cuda:0')
# Learning rate: 0.001
# epoch 12 time:  33.14421293899795
# --------------------------------
# ========================================
# EPOCH: 13
# train_loss: 0.7412862473119222
# train_precision: tensor([0.6394, 0.7307, 0.7034, 0.6099], device='cuda:0')
# train_recall: tensor([0.6115, 0.7966, 0.7046, 0.3154], device='cuda:0')
# val_loss: 0.6849594762755765
# val_precision: tensor([0.7013, 0.7909, 0.6766, 0.7110], device='cuda:0')
# val_recall: tensor([0.5639, 0.8016, 0.8301, 0.3943], device='cuda:0')
# Learning rate: 0.001
# epoch 13 time:  33.117951107997214
# --------------------------------
# ========================================
# EPOCH: 14
# train_loss: 0.7395681409412654
# train_precision: tensor([0.6402, 0.7281, 0.7044, 0.6139], device='cuda:0')
# train_recall: tensor([0.6113, 0.7943, 0.7061, 0.3182], device='cuda:0')
# val_loss: 0.6831543648408519
# val_precision: tensor([0.6796, 0.8157, 0.6831, 0.7780], device='cuda:0')
# val_recall: tensor([0.6267, 0.7660, 0.8166, 0.3364], device='cuda:0')
# Learning rate: 0.001
# epoch 14 time:  33.15730244400038
# --------------------------------
# ========================================
# EPOCH: 15
# train_loss: 0.7345631432149863
# train_precision: tensor([0.6423, 0.7317, 0.7064, 0.6154], device='cuda:0')
# train_recall: tensor([0.6135, 0.7976, 0.7074, 0.3289], device='cuda:0')
# val_loss: 0.6525100907517805
# val_precision: tensor([0.6927, 0.7777, 0.7440, 0.5650], device='cuda:0')
# val_recall: tensor([0.6321, 0.8257, 0.7650, 0.5505], device='cuda:0')
# Learning rate: 0.001
# epoch 15 time:  33.06885645399598
# --------------------------------
# ========================================
# EPOCH: 16
# train_loss: 0.7307500964193702
# train_precision: tensor([0.6452, 0.7329, 0.7065, 0.6287], device='cuda:0')
# train_recall: tensor([0.6161, 0.7978, 0.7081, 0.3408], device='cuda:0')
# val_loss: 0.6581771615892649
# val_precision: tensor([0.6808, 0.7925, 0.7191, 0.7615], device='cuda:0')
# val_recall: tensor([0.6314, 0.8043, 0.7929, 0.4192], device='cuda:0')
# Learning rate: 0.001
# epoch 16 time:  33.06700799400278
# --------------------------------
# ========================================
# EPOCH: 17
# train_loss: 0.7279018190661096
# train_precision: tensor([0.6471, 0.7339, 0.7088, 0.6245], device='cuda:0')
# train_recall: tensor([0.6171, 0.7988, 0.7114, 0.3387], device='cuda:0')
# val_loss: 0.6679017332692941
# val_precision: tensor([0.6885, 0.8160, 0.6915, 0.7293], device='cuda:0')
# val_recall: tensor([0.6156, 0.7718, 0.8303, 0.4337], device='cuda:0')
# Learning rate: 0.001
# epoch 17 time:  33.06067956100014
# --------------------------------
# ========================================
# EPOCH: 18
# train_loss: 0.72342131175478
# train_precision: tensor([0.6504, 0.7352, 0.7096, 0.6234], device='cuda:0')
# train_recall: tensor([0.6176, 0.7999, 0.7137, 0.3531], device='cuda:0')
# val_loss: 0.6518199999713236
# val_precision: tensor([0.6851, 0.8029, 0.7173, 0.7103], device='cuda:0')
# val_recall: tensor([0.6497, 0.7932, 0.7890, 0.4532], device='cuda:0')
# Learning rate: 0.001
# epoch 18 time:  33.07075142599933
# --------------------------------
# ========================================
# EPOCH: 19
# train_loss: 0.7187196195587081
# train_precision: tensor([0.6508, 0.7376, 0.7131, 0.6290], device='cuda:0')
# train_recall: tensor([0.6216, 0.8021, 0.7142, 0.3508], device='cuda:0')
# val_loss: 0.6550685454573896
# val_precision: tensor([0.6810, 0.8138, 0.7113, 0.7674], device='cuda:0')
# val_recall: tensor([0.6495, 0.7815, 0.8060, 0.4054], device='cuda:0')
# Learning rate: 0.001
# epoch 19 time:  33.001356115004455
# --------------------------------
# ========================================
# EPOCH: 20
# train_loss: 0.7164454139223263
# train_precision: tensor([0.6540, 0.7378, 0.7147, 0.6324], device='cuda:0')
# train_recall: tensor([0.6247, 0.8029, 0.7145, 0.3590], device='cuda:0')
# val_loss: 0.6534381520003081
# val_precision: tensor([0.7194, 0.7877, 0.6930, 0.7924], device='cuda:0')
# val_recall: tensor([0.5922, 0.8163, 0.8236, 0.4138], device='cuda:0')
# Learning rate: 0.001
# epoch 20 time:  33.050433978998626
# --------------------------------
# ========================================
# EPOCH: 21
# train_loss: 0.7128126355350692
# train_precision: tensor([0.6566, 0.7388, 0.7168, 0.6437], device='cuda:0')
# train_recall: tensor([0.6261, 0.8027, 0.7191, 0.3661], device='cuda:0')
# val_loss: 0.6396745291435056
# val_precision: tensor([0.7007, 0.7713, 0.7360, 0.7749], device='cuda:0')
# val_recall: tensor([0.6288, 0.8449, 0.7735, 0.4347], device='cuda:0')
# Learning rate: 0.001
# epoch 21 time:  33.09483997999632
# --------------------------------
# ========================================
# EPOCH: 22
# train_loss: 0.7113684314819515
# train_precision: tensor([0.6568, 0.7392, 0.7173, 0.6411], device='cuda:0')
# train_recall: tensor([0.6260, 0.8037, 0.7193, 0.3645], device='cuda:0')
# val_loss: 0.6440196305513382
# val_precision: tensor([0.6853, 0.8221, 0.7145, 0.6839], device='cuda:0')
# val_recall: tensor([0.6670, 0.7686, 0.7981, 0.5108], device='cuda:0')
# Learning rate: 0.001
# epoch 22 time:  33.13523118699959
# --------------------------------
# ========================================
# EPOCH: 23
# train_loss: 0.7083555478436241
# train_precision: tensor([0.6594, 0.7408, 0.7174, 0.6351], device='cuda:0')
# train_recall: tensor([0.6290, 0.8050, 0.7174, 0.3775], device='cuda:0')
# val_loss: 0.6267472369803323
# val_precision: tensor([0.6828, 0.8038, 0.7429, 0.7037], device='cuda:0')
# val_recall: tensor([0.6669, 0.8107, 0.7754, 0.4997], device='cuda:0')
# Learning rate: 0.001
# epoch 23 time:  33.09288876899518
# --------------------------------
# ========================================
# EPOCH: 24
# train_loss: 0.7059624621454913
# train_precision: tensor([0.6599, 0.7417, 0.7190, 0.6301], device='cuda:0')
# train_recall: tensor([0.6299, 0.8054, 0.7194, 0.3717], device='cuda:0')
# val_loss: 0.6332224188993375
# val_precision: tensor([0.6923, 0.8097, 0.7272, 0.6747], device='cuda:0')
# val_recall: tensor([0.6507, 0.7946, 0.8033, 0.5000], device='cuda:0')
# Learning rate: 0.001
# epoch 24 time:  32.87441702700016
# --------------------------------
# ========================================
# EPOCH: 25
# train_loss: 0.7032498517087558
# train_precision: tensor([0.6608, 0.7436, 0.7192, 0.6397], device='cuda:0')
# train_recall: tensor([0.6306, 0.8056, 0.7220, 0.3730], device='cuda:0')
# val_loss: 0.6493282715065611
# val_precision: tensor([0.7021, 0.8255, 0.6961, 0.6981], device='cuda:0')
# val_recall: tensor([0.6290, 0.7759, 0.8325, 0.4764], device='cuda:0')
# Learning rate: 0.001
# epoch 25 time:  33.214400156997726
# --------------------------------
# ========================================
# EPOCH: 26
# train_loss: 0.702137648793045
# train_precision: tensor([0.6612, 0.7435, 0.7204, 0.6419], device='cuda:0')
# train_recall: tensor([0.6311, 0.8077, 0.7207, 0.3771], device='cuda:0')
# val_loss: 0.6434251972784598
# val_precision: tensor([0.6803, 0.8225, 0.7193, 0.7292], device='cuda:0')
# val_recall: tensor([0.6642, 0.7733, 0.8041, 0.4788], device='cuda:0')
# Learning rate: 0.001
# epoch 26 time:  33.28278495800623
# --------------------------------
# ========================================
# EPOCH: 27
# train_loss: 0.6996773961685185
# train_precision: tensor([0.6638, 0.7454, 0.7213, 0.6495], device='cuda:0')
# train_recall: tensor([0.6339, 0.8063, 0.7245, 0.3837], device='cuda:0')
# val_loss: 0.6248224155770408
# val_precision: tensor([0.6925, 0.8096, 0.7435, 0.6671], device='cuda:0')
# val_recall: tensor([0.6884, 0.8004, 0.7762, 0.4899], device='cuda:0')
# Learning rate: 0.001
# epoch 27 time:  33.04860785400524
# --------------------------------
# ========================================
# EPOCH: 28
# train_loss: 0.6962636294217249
# train_precision: tensor([0.6644, 0.7466, 0.7228, 0.6439], device='cuda:0')
# train_recall: tensor([0.6366, 0.8062, 0.7243, 0.3851], device='cuda:0')
# val_loss: 0.6135429457243946
# val_precision: tensor([0.7002, 0.8019, 0.7561, 0.6705], device='cuda:0')
# val_recall: tensor([0.6802, 0.8191, 0.7743, 0.5556], device='cuda:0')
# Learning rate: 0.001
# epoch 28 time:  33.117123049996735
# --------------------------------
# ========================================
# EPOCH: 29
# train_loss: 0.6954278936337829
# train_precision: tensor([0.6668, 0.7460, 0.7247, 0.6445], device='cuda:0')
# train_recall: tensor([0.6365, 0.8086, 0.7255, 0.3896], device='cuda:0')
# val_loss: 0.6429070357647207
# val_precision: tensor([0.6786, 0.8208, 0.7253, 0.7465], device='cuda:0')
# val_recall: tensor([0.6738, 0.7682, 0.8055, 0.4532], device='cuda:0')
# Learning rate: 0.001
# epoch 29 time:  33.08086835999711
# --------------------------------
# ========================================
# EPOCH: 30
# train_loss: 0.6926480710080438
# train_precision: tensor([0.6658, 0.7485, 0.7238, 0.6558], device='cuda:0')
# train_recall: tensor([0.6382, 0.8080, 0.7254, 0.3918], device='cuda:0')
# val_loss: 0.6107632247524128
# val_precision: tensor([0.6819, 0.8029, 0.7800, 0.6357], device='cuda:0')
# val_recall: tensor([0.7032, 0.8239, 0.7415, 0.5845], device='cuda:0')
# Learning rate: 0.001
# epoch 30 time:  33.053566665999824
# --------------------------------
# ========================================
# EPOCH: 31
# train_loss: 0.6910557458804008
# train_precision: tensor([0.6665, 0.7486, 0.7243, 0.6426], device='cuda:0')
# train_recall: tensor([0.6386, 0.8086, 0.7240, 0.3993], device='cuda:0')
# val_loss: 0.6221114335788621
# val_precision: tensor([0.7403, 0.8028, 0.7201, 0.5860], device='cuda:0')
# val_recall: tensor([0.6081, 0.8227, 0.8259, 0.6266], device='cuda:0')
# Learning rate: 0.001
# epoch 31 time:  33.05856140299875
# --------------------------------
# ========================================
# EPOCH: 32
# train_loss: 0.6895432744869666
# train_precision: tensor([0.6654, 0.7478, 0.7244, 0.6577], device='cuda:0')
# train_recall: tensor([0.6371, 0.8083, 0.7244, 0.4056], device='cuda:0')
# val_loss: 0.6142341142313348
# val_precision: tensor([0.6851, 0.7869, 0.7916, 0.6569], device='cuda:0')
# val_recall: tensor([0.7160, 0.8439, 0.7151, 0.5195], device='cuda:0')
# Learning rate: 0.001
# epoch 32 time:  33.083355189999565
# --------------------------------
# ========================================
# EPOCH: 33
# train_loss: 0.6889490903914862
# train_precision: tensor([0.6670, 0.7495, 0.7249, 0.6437], device='cuda:0')
# train_recall: tensor([0.6405, 0.8075, 0.7259, 0.3915], device='cuda:0')
# val_loss: 0.6200631405744288
# val_precision: tensor([0.7019, 0.8087, 0.7395, 0.7335], device='cuda:0')
# val_recall: tensor([0.6742, 0.8139, 0.7908, 0.4670], device='cuda:0')
# Learning rate: 0.001
# epoch 33 time:  33.12590788200032
# --------------------------------
# ========================================
# EPOCH: 34
# train_loss: 0.687014265171185
# train_precision: tensor([0.6691, 0.7509, 0.7261, 0.6460], device='cuda:0')
# train_recall: tensor([0.6406, 0.8092, 0.7278, 0.4039], device='cuda:0')
# val_loss: 0.6370450843539502
# val_precision: tensor([0.7154, 0.8307, 0.7105, 0.5793], device='cuda:0')
# val_recall: tensor([0.6363, 0.7810, 0.8306, 0.5869], device='cuda:0')
# Learning rate: 0.001
# epoch 34 time:  33.0276563610023
# --------------------------------
# ========================================
# EPOCH: 35
# train_loss: 0.6849842282226215
# train_precision: tensor([0.6713, 0.7521, 0.7276, 0.6508], device='cuda:0')
# train_recall: tensor([0.6431, 0.8113, 0.7283, 0.4066], device='cuda:0')
# val_loss: 0.618150275780095
# val_precision: tensor([0.7128, 0.8132, 0.7333, 0.6834], device='cuda:0')
# val_recall: tensor([0.6601, 0.8060, 0.8065, 0.5677], device='cuda:0')
# Learning rate: 0.0001
# epoch 35 time:  33.00621886499721
# --------------------------------
# ========================================
# EPOCH: 36
# train_loss: 0.660179557812363
# train_precision: tensor([0.6795, 0.7630, 0.7373, 0.6740], device='cuda:0')
# train_recall: tensor([0.6573, 0.8131, 0.7388, 0.4374], device='cuda:0')
# val_loss: 0.5957093585696486
# val_precision: tensor([0.7279, 0.8051, 0.7499, 0.6921], device='cuda:0')
# val_recall: tensor([0.6622, 0.8328, 0.8056, 0.5640], device='cuda:0')
# Learning rate: 0.0001
# epoch 36 time:  33.05226267900434
# --------------------------------
# ========================================
# EPOCH: 37
# train_loss: 0.6571683812134318
# train_precision: tensor([0.6834, 0.7638, 0.7378, 0.6752], device='cuda:0')
# train_recall: tensor([0.6559, 0.8165, 0.7415, 0.4470], device='cuda:0')
# val_loss: 0.594517052339183
# val_precision: tensor([0.7303, 0.8129, 0.7455, 0.6829], device='cuda:0')
# val_recall: tensor([0.6604, 0.8260, 0.8139, 0.6003], device='cuda:0')
# Learning rate: 0.0001
# epoch 37 time:  32.990853361996415
# --------------------------------
# ========================================
# EPOCH: 38
# train_loss: 0.6552868338480388
# train_precision: tensor([0.6850, 0.7642, 0.7396, 0.6674], device='cuda:0')
# train_recall: tensor([0.6580, 0.8169, 0.7418, 0.4508], device='cuda:0')
# val_loss: 0.5910507960865895
# val_precision: tensor([0.7216, 0.8160, 0.7582, 0.6899], device='cuda:0')
# val_recall: tensor([0.6849, 0.8232, 0.8009, 0.5926], device='cuda:0')
# Learning rate: 0.0001
# epoch 38 time:  33.47434135700314
# --------------------------------
# ========================================
# EPOCH: 39
# train_loss: 0.6538001960448526
# train_precision: tensor([0.6860, 0.7637, 0.7409, 0.6692], device='cuda:0')
# train_recall: tensor([0.6598, 0.8170, 0.7412, 0.4543], device='cuda:0')
# val_loss: 0.5936772795187102
# val_precision: tensor([0.7379, 0.8125, 0.7419, 0.6814], device='cuda:0')
# val_recall: tensor([0.6531, 0.8299, 0.8195, 0.6064], device='cuda:0')
# Learning rate: 0.0001
# epoch 39 time:  32.99769035600184
# --------------------------------
# ========================================
# EPOCH: 40
# train_loss: 0.654149574225967
# train_precision: tensor([0.6862, 0.7632, 0.7408, 0.6750], device='cuda:0')
# train_recall: tensor([0.6604, 0.8168, 0.7414, 0.4505], device='cuda:0')
# val_loss: 0.5940780414889256
# val_precision: tensor([0.7347, 0.8156, 0.7432, 0.6704], device='cuda:0')
# val_recall: tensor([0.6589, 0.8255, 0.8187, 0.5987], device='cuda:0')
# Learning rate: 0.0001
# epoch 40 time:  33.07391315199493
# --------------------------------
# ========================================
# EPOCH: 41
# train_loss: 0.6518413051030976
# train_precision: tensor([0.6869, 0.7656, 0.7400, 0.6823], device='cuda:0')
# train_recall: tensor([0.6602, 0.8164, 0.7435, 0.4632], device='cuda:0')
# val_loss: 0.5971268344256613
# val_precision: tensor([0.7314, 0.8145, 0.7443, 0.6703], device='cuda:0')
# val_recall: tensor([0.6609, 0.8235, 0.8158, 0.5983], device='cuda:0')
# Learning rate: 0.0001
# epoch 41 time:  33.0177615529974
# --------------------------------
# ========================================
# EPOCH: 42
# train_loss: 0.652086702040649
# train_precision: tensor([0.6875, 0.7643, 0.7415, 0.6784], device='cuda:0')
# train_recall: tensor([0.6612, 0.8173, 0.7421, 0.4629], device='cuda:0')
# val_loss: 0.5918670731286207
# val_precision: tensor([0.7411, 0.8060, 0.7462, 0.6934], device='cuda:0')
# val_recall: tensor([0.6530, 0.8389, 0.8153, 0.5933], device='cuda:0')
# Learning rate: 0.0001
# epoch 42 time:  33.048300049005775
# --------------------------------
# ========================================
# EPOCH: 43
# train_loss: 0.6502156096636503
# train_precision: tensor([0.6876, 0.7654, 0.7425, 0.6785], device='cuda:0')
# train_recall: tensor([0.6600, 0.8181, 0.7444, 0.4659], device='cuda:0')
# val_loss: 0.5954409759077761
# val_precision: tensor([0.7272, 0.8175, 0.7482, 0.7146], device='cuda:0')
# val_recall: tensor([0.6726, 0.8230, 0.8137, 0.5774], device='cuda:0')
# Learning rate: 1e-05
# epoch 43 time:  33.009692069994344
# --------------------------------
# ========================================
# EPOCH: 44
# train_loss: 0.6486192158356247
# train_precision: tensor([0.6915, 0.7654, 0.7454, 0.6776], device='cuda:0')
# train_recall: tensor([0.6661, 0.8181, 0.7448, 0.4652], device='cuda:0')
# val_loss: 0.5932410231894917
# val_precision: tensor([0.7349, 0.8163, 0.7441, 0.6771], device='cuda:0')
# val_recall: tensor([0.6628, 0.8262, 0.8170, 0.5966], device='cuda:0')
# Learning rate: 1e-05
# epoch 44 time:  33.02583951999986
# --------------------------------
# ========================================
# EPOCH: 45
# train_loss: 0.6476907945410562
# train_precision: tensor([0.6881, 0.7672, 0.7439, 0.6720], device='cuda:0')
# train_recall: tensor([0.6643, 0.8168, 0.7445, 0.4651], device='cuda:0')
# val_loss: 0.5929467983543872
# val_precision: tensor([0.7336, 0.8166, 0.7439, 0.6897], device='cuda:0')
# val_recall: tensor([0.6639, 0.8255, 0.8168, 0.5936], device='cuda:0')
# Learning rate: 1e-05
# epoch 45 time:  33.0466350429997
# --------------------------------
# ========================================
# EPOCH: 46
# train_loss: 0.6476013935201576
# train_precision: tensor([0.6894, 0.7666, 0.7443, 0.6796], device='cuda:0')
# train_recall: tensor([0.6646, 0.8181, 0.7449, 0.4625], device='cuda:0')
# val_loss: 0.5909815847459766
# val_precision: tensor([0.7349, 0.8147, 0.7472, 0.6736], device='cuda:0')
# val_recall: tensor([0.6640, 0.8284, 0.8149, 0.6003], device='cuda:0')
# Learning rate: 1e-05
# epoch 46 time:  33.06451174499671
# --------------------------------
# ========================================
# EPOCH: 47
# train_loss: 0.6476719150804493
# train_precision: tensor([0.6891, 0.7660, 0.7434, 0.6747], device='cuda:0')
# train_recall: tensor([0.6649, 0.8165, 0.7437, 0.4651], device='cuda:0')
# val_loss: 0.588872888394528
# val_precision: tensor([0.7341, 0.8115, 0.7533, 0.6703], device='cuda:0')
# val_recall: tensor([0.6689, 0.8319, 0.8089, 0.6024], device='cuda:0')
# Learning rate: 1e-05
# epoch 47 time:  33.08665511599975
# --------------------------------
# ========================================
# EPOCH: 48
# train_loss: 0.6466748445001367
# train_precision: tensor([0.6906, 0.7655, 0.7448, 0.6799], device='cuda:0')
# train_recall: tensor([0.6648, 0.8188, 0.7439, 0.4680], device='cuda:0')
# val_loss: 0.5928599195761813
# val_precision: tensor([0.7356, 0.8144, 0.7460, 0.6760], device='cuda:0')
# val_recall: tensor([0.6611, 0.8290, 0.8163, 0.6013], device='cuda:0')
# Learning rate: 1e-05
# epoch 48 time:  33.137601435999386
# --------------------------------
# ========================================
# EPOCH: 49
# train_loss: 0.6483751771668723
# train_precision: tensor([0.6885, 0.7656, 0.7415, 0.6701], device='cuda:0')
# train_recall: tensor([0.6612, 0.8182, 0.7435, 0.4576], device='cuda:0')
# val_loss: 0.5901541942109664
# val_precision: tensor([0.7311, 0.8149, 0.7521, 0.6772], device='cuda:0')
# val_recall: tensor([0.6717, 0.8287, 0.8099, 0.5926], device='cuda:0')
# Learning rate: 1e-05
# epoch 49 time:  32.480751908005914
# --------------------------------
# ========================================
# EPOCH: 50
# train_loss: 0.6472572031263939
# train_precision: tensor([0.6905, 0.7663, 0.7428, 0.6752], device='cuda:0')
# train_recall: tensor([0.6640, 0.8184, 0.7445, 0.4593], device='cuda:0')
# val_loss: 0.5924790922138427
# val_precision: tensor([0.7355, 0.8157, 0.7447, 0.6669], device='cuda:0')
# val_recall: tensor([0.6616, 0.8268, 0.8160, 0.6074], device='cuda:0')
# Learning rate: 1e-05
# epoch 50 time:  32.60404346099676
# --------------------------------
# ========================================
# EPOCH: 51
# train_loss: 0.6463884099599079
# train_precision: tensor([0.6888, 0.7670, 0.7452, 0.6787], device='cuda:0')
# train_recall: tensor([0.6654, 0.8175, 0.7446, 0.4683], device='cuda:0')
# val_loss: 0.5900149040751987
# val_precision: tensor([0.7309, 0.8162, 0.7524, 0.6670], device='cuda:0')
# val_recall: tensor([0.6739, 0.8277, 0.8081, 0.6003], device='cuda:0')
# Learning rate: 1e-05
# epoch 51 time:  32.63934856600099
# --------------------------------
# ========================================
# EPOCH: 52
# train_loss: 0.647140335972782
# train_precision: tensor([0.6901, 0.7667, 0.7437, 0.6813], device='cuda:0')
# train_recall: tensor([0.6624, 0.8189, 0.7452, 0.4775], device='cuda:0')
# val_loss: 0.591470662297474
# val_precision: tensor([0.7318, 0.8185, 0.7462, 0.6796], device='cuda:0')
# val_recall: tensor([0.6699, 0.8229, 0.8145, 0.5963], device='cuda:0')
# Learning rate: 5e-06
# epoch 52 time:  32.65802445400186
# --------------------------------
# ========================================
# EPOCH: 53
# train_loss: 0.6465107855731493
# train_precision: tensor([0.6883, 0.7670, 0.7446, 0.6817], device='cuda:0')
# train_recall: tensor([0.6639, 0.8182, 0.7452, 0.4629], device='cuda:0')
# val_loss: 0.5917267699622446
# val_precision: tensor([0.7323, 0.8191, 0.7473, 0.6688], device='cuda:0')
# val_recall: tensor([0.6695, 0.8234, 0.8150, 0.6024], device='cuda:0')
# Learning rate: 5e-06
# epoch 53 time:  33.15733648699825
# --------------------------------
# ========================================
# EPOCH: 54
# train_loss: 0.6467362022989204
# train_precision: tensor([0.6882, 0.7669, 0.7447, 0.6813], device='cuda:0')
# train_recall: tensor([0.6637, 0.8187, 0.7439, 0.4704], device='cuda:0')
# val_loss: 0.5900492153647873
# val_precision: tensor([0.7283, 0.8221, 0.7512, 0.6796], device='cuda:0')
# val_recall: tensor([0.6798, 0.8204, 0.8114, 0.6020], device='cuda:0')
# Learning rate: 5e-06
# epoch 54 time:  33.10531913900195
# --------------------------------
# ========================================
# EPOCH: 55
# train_loss: 0.6454638033271048
# train_precision: tensor([0.6897, 0.7660, 0.7443, 0.6812], device='cuda:0')
# train_recall: tensor([0.6628, 0.8183, 0.7455, 0.4703], device='cuda:0')
# val_loss: 0.5900470100343227
# val_precision: tensor([0.7347, 0.8123, 0.7504, 0.6746], device='cuda:0')
# val_recall: tensor([0.6667, 0.8319, 0.8103, 0.5976], device='cuda:0')
# Learning rate: 5e-06
# epoch 55 time:  32.323560116004955
# --------------------------------
# ========================================
# EPOCH: 56
# train_loss: 0.6468849399744435
# train_precision: tensor([0.6895, 0.7676, 0.7457, 0.6730], device='cuda:0')
# train_recall: tensor([0.6659, 0.8185, 0.7449, 0.4648], device='cuda:0')
# val_loss: 0.5914620323313607
# val_precision: tensor([0.7360, 0.8164, 0.7457, 0.6744], device='cuda:0')
# val_recall: tensor([0.6641, 0.8274, 0.8163, 0.6034], device='cuda:0')
# Learning rate: 5e-06
# epoch 56 time:  32.117495614998916
# --------------------------------
# ========================================
# EPOCH: 57
# train_loss: 0.6465804309913131
# train_precision: tensor([0.6875, 0.7653, 0.7456, 0.6740], device='cuda:0')
# train_recall: tensor([0.6625, 0.8181, 0.7445, 0.4633], device='cuda:0')
# val_loss: 0.5919408063507743
# val_precision: tensor([0.7325, 0.8187, 0.7466, 0.6722], device='cuda:0')
# val_recall: tensor([0.6682, 0.8232, 0.8156, 0.6027], device='cuda:0')
# Learning rate: 5e-06
# Early stopping at epoch 57 with best validation loss 0.588872888394528
# training_checkpoints/vit_other_2024-05-26 14:30:29.615910.pth
# <All keys matched successfully>
