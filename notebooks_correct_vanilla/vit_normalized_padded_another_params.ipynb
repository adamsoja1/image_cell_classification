# %%
import time
import sys
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from dataset import ImageDataset
import torch.nn.functional as F
from torchmetrics import Precision, Recall
from torchvision.models import resnet50
import warnings
from collections import defaultdict
import wandb
import datetime
import os
from vit.vit import VisionTransformer

warnings.filterwarnings('ignore')
torch.set_float32_matmul_precision('high')
#intecubic interpol

run_name = f'vit_normalized_padded_another_params_local{datetime.datetime.now()}'
run_path = f'training_checkpoints/{run_name}'

wandb.init(project="cells", 
           entity="adamsoja",
          name=run_name)

import random
random.seed(2233)
torch.manual_seed(2233)

#After /255 so in loading dataset there are no division by 255 just this normalization
mean = [0.5006, 0.3526, 0.5495]
std = [0.1493, 0.1341, 0.1124]


from albumentations import (
    Compose,
    Resize,
    OneOf,
    RandomBrightness,
    RandomContrast,
    MotionBlur,
    MedianBlur,
    GaussianBlur,
    VerticalFlip,
    HorizontalFlip,
    ShiftScaleRotate,
    Normalize,
)

transform = Compose(
    [
        Normalize(mean=mean, std=std),
        OneOf([RandomBrightness(limit=0.4, p=1), RandomContrast(limit=0.4, p=0.8)]),
        OneOf([MotionBlur(blur_limit=3), MedianBlur(blur_limit=3), GaussianBlur(blur_limit=3),], p=0.6,),
        VerticalFlip(p=0.5),
        HorizontalFlip(p=0.5),
    ]
)

transform_test = Compose(
    [Normalize(mean=mean, std=std)]
)

class MyModel(nn.Module):
    def __init__(self, model, learning_rate, weight_decay):
        super(MyModel, self).__init__()
        self.model = model
        self.learning_rate = learning_rate
        self.weight_decay = weight_decay
        self.criterion = nn.CrossEntropyLoss()
        self.metric_precision = Precision(task="multiclass", num_classes=4, average=None).to('cuda')
        self.metric_recall = Recall(task="multiclass", num_classes=4, average=None).to('cuda')
        self.train_loss = []
        self.valid_loss = []
        self.precision_per_epochs = []
        self.recall_per_epochs = []

        self.optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, mode="min", factor=0.1, patience=2, min_lr=5e-6, verbose=True)
        self.step = 0

    
    def forward(self, x):
        return self.model(x)

    def train_one_epoch(self, trainloader):
        self.step += 1
        self.train()
        for batch_idx, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()
            _, preds = torch.max(outputs, 1)
            _, labels = torch.max(labels, 1)
            self.metric_precision(preds, labels)
            self.metric_recall(preds, labels)
            self.train_loss.append(loss.item())


        

        
        avg_loss = np.mean(self.train_loss)
        self.train_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        self.precision_per_epochs.append(precision)
        self.recall_per_epochs.append(recall)
        print(f'train_loss: {avg_loss}')
        print(f'train_precision: {precision}')
        print(f'train_recall: {recall}')

        wandb.log({'loss': avg_loss},step=self.step)
        wandb.log({'Normal precision': precision[0].item()},step=self.step)
        wandb.log({'Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'Other precision': precision[3].item()},step=self.step)


        wandb.log({'Normal recall': recall[0].item()},step=self.step)
        wandb.log({'Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'Other recall': recall[3].item()},step=self.step)
        
        
        self.metric_precision.reset()
        self.metric_recall.reset()


    

    def evaluate(self, testloader):
        self.eval()
        with torch.no_grad():
            for batch_idx, (inputs, labels) in enumerate(testloader):
                inputs, labels = inputs.to('cuda'), labels.to('cuda')
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)
                _, labels = torch.max(labels, 1)
                self.metric_precision(preds, labels)
                self.metric_recall(preds, labels)
                self.valid_loss.append(loss.item())
    
        avg_loss = np.mean(self.valid_loss)
        self.scheduler.step(avg_loss)
        self.valid_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        print(f'val_loss: {avg_loss}')
        print(f'val_precision: {precision}')
        print(f'val_recall: {recall}')
        self.metric_precision.reset()
        self.metric_recall.reset()

        wandb.log({'val_loss': avg_loss}, step=self.step)
        
        wandb.log({'val_Normal precision': precision[0].item()},step=self.step)
        wandb.log({'val_Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'val_Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'val_Other precision': precision[3].item()},step=self.step)


        wandb.log({'val_Normal recall': recall[0].item()},step=self.step)
        wandb.log({'val_Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'val_Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'val_Other recall': recall[3].item()},step=self.step)


        for param_group in self.optimizer.param_groups:
            print(f"Learning rate: {param_group['lr']}")
        return avg_loss

torch.cuda.empty_cache()
batch_size = 512

trainset = ImageDataset(data_path='train_data', transform=transform)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=5)

testset = ImageDataset(data_path='validation_data', transform=transform_test)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=3)


learning_rate = 0.001
weight_decay = 0.00001


model = VisionTransformer(image_size=32, 
                          in_channels=3, 
                          num_classes=4, 
                          hidden_dims=[64, 8], 
                          dropout_rate=0.3,
                          embedding_dim=32,
                          patch_size=8,
                          num_layers=3,
                          num_heads=4)
model = model.to('cuda')


my_model = MyModel(model=model, learning_rate=learning_rate, weight_decay=weight_decay)
my_model = my_model.to('cuda')

num_epochs = 100
early_stop_patience = 10
best_val_loss = float('inf')
best_model_state_dict = None

for epoch in range(num_epochs):
    print('========================================')
    print(f'EPOCH: {epoch}') 
    time_start = time.perf_counter()
    my_model.train_one_epoch(trainloader)
    val_loss = my_model.evaluate(testloader)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_state_dict = my_model.state_dict()
        torch.save(best_model_state_dict, f'{run_path}.pth')
        
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch} with best validation loss {best_val_loss}")
        break
    time_epoch = time.perf_counter() - time_start
    print(f'epoch {epoch} time:  {time_epoch}')
    print('--------------------------------')

# Load the best model state dict
print(f'{run_path}.pth')
my_model.load_state_dict(torch.load(f'{run_path}.pth'))
# Out:
# wandb: Currently logged in as: adamsoja. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/adam/Desktop/cells_master_thesis/wandb/run-20240426_002729-0lid2vz9</code>
# Syncing run <strong><a href='https://wandb.ai/adamsoja/cells/runs/0lid2vz9' target="_blank">vit_normalized_padded_another_params_local2024-04-26 00:27:28.419547</a></strong> to <a href='https://wandb.ai/adamsoja/cells' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adamsoja/cells' target="_blank">https://wandb.ai/adamsoja/cells</a>
#  View run at <a href='https://wandb.ai/adamsoja/cells/runs/0lid2vz9' target="_blank">https://wandb.ai/adamsoja/cells/runs/0lid2vz9</a>
# ========================================
# EPOCH: 0
# train_loss: 1.0319260057948885
# train_precision: tensor([0.4675, 0.5746, 0.5349, 0.0000], device='cuda:0')
# train_recall: tensor([0.3906, 0.7735, 0.4911, 0.0000], device='cuda:0')
# val_loss: 0.9251428922017415
# val_precision: tensor([0.6031, 0.6143, 0.5852, 0.0000], device='cuda:0')
# val_recall: tensor([0.3333, 0.8252, 0.7045, 0.0000], device='cuda:0')
# Learning rate: 0.001
# epoch 0 time:  46.78055783800002
# --------------------------------
# ========================================
# EPOCH: 1
# train_loss: 0.9372470241217387
# train_precision: tensor([0.5287, 0.6342, 0.6234, 0.0000], device='cuda:0')
# train_recall: tensor([0.5202, 0.7534, 0.5786, 0.0000], device='cuda:0')
# val_loss: 0.8819427788257599
# val_precision: tensor([0.5424, 0.6805, 0.6508, 0.0000], device='cuda:0')
# val_recall: tensor([0.5411, 0.7652, 0.6363, 0.0000], device='cuda:0')
# Learning rate: 0.001
# epoch 1 time:  12.504588095000031
# --------------------------------
# ========================================
# EPOCH: 2
# train_loss: 0.909568159636997
# train_precision: tensor([0.5413, 0.6528, 0.6383, 0.0000], device='cuda:0')
# train_recall: tensor([0.5405, 0.7613, 0.5970, 0.0000], device='cuda:0')
# val_loss: 0.8679317540592617
# val_precision: tensor([0.5259, 0.7086, 0.7194, 0.4167], device='cuda:0')
# val_recall: tensor([0.6936, 0.7428, 0.5266, 0.0034], device='cuda:0')
# Learning rate: 0.001
# epoch 2 time:  12.505492147999973
# --------------------------------
# ========================================
# EPOCH: 3
# train_loss: 0.892040662254606
# train_precision: tensor([0.5497, 0.6628, 0.6406, 0.7273], device='cuda:0')
# train_recall: tensor([0.5498, 0.7603, 0.6102, 0.0012], device='cuda:0')
# val_loss: 0.8267204642295838
# val_precision: tensor([0.5874, 0.7362, 0.6396, 0.5067], device='cuda:0')
# val_recall: tensor([0.5648, 0.7482, 0.7129, 0.0384], device='cuda:0')
# Learning rate: 0.001
# epoch 3 time:  12.51569563999999
# --------------------------------
# ========================================
# EPOCH: 4
# train_loss: 0.8785622767039708
# train_precision: tensor([0.5580, 0.6681, 0.6451, 0.4918], device='cuda:0')
# train_recall: tensor([0.5584, 0.7627, 0.6162, 0.0130], device='cuda:0')
# val_loss: 0.814990387360255
# val_precision: tensor([0.6038, 0.7026, 0.6557, 0.4425], device='cuda:0')
# val_recall: tensor([0.5263, 0.8010, 0.7008, 0.0855], device='cuda:0')
# Learning rate: 0.001
# epoch 4 time:  12.462529684000003
# --------------------------------
# ========================================
# EPOCH: 5
# train_loss: 0.8710139065980911
# train_precision: tensor([0.5642, 0.6734, 0.6480, 0.4713], device='cuda:0')
# train_recall: tensor([0.5616, 0.7663, 0.6224, 0.0296], device='cuda:0')
# val_loss: 0.8138449009921815
# val_precision: tensor([0.5691, 0.7316, 0.7203, 0.3292], device='cuda:0')
# val_recall: tensor([0.6592, 0.7570, 0.6025, 0.2316], device='cuda:0')
# Learning rate: 0.001
# epoch 5 time:  12.420361684999989
# --------------------------------
# ========================================
# EPOCH: 6
# train_loss: 0.8621016475416365
# train_precision: tensor([0.5683, 0.6750, 0.6544, 0.4801], device='cuda:0')
# train_recall: tensor([0.5642, 0.7684, 0.6278, 0.0453], device='cuda:0')
# val_loss: 0.821590051220523
# val_precision: tensor([0.6127, 0.6441, 0.7312, 0.7521], device='cuda:0')
# val_recall: tensor([0.5481, 0.8757, 0.6096, 0.0919], device='cuda:0')
# Learning rate: 0.001
# epoch 6 time:  12.500181115999965
# --------------------------------
# ========================================
# EPOCH: 7
# train_loss: 0.8557598969766071
# train_precision: tensor([0.5740, 0.6784, 0.6561, 0.5271], device='cuda:0')
# train_recall: tensor([0.5675, 0.7716, 0.6304, 0.0687], device='cuda:0')
# val_loss: 0.8135862426625358
# val_precision: tensor([0.6233, 0.6891, 0.6499, 0.7438], device='cuda:0')
# val_recall: tensor([0.4913, 0.8115, 0.7291, 0.0909], device='cuda:0')
# Learning rate: 0.001
# epoch 7 time:  12.539550790000021
# --------------------------------
# ========================================
# EPOCH: 8
# train_loss: 0.8501997805777051
# train_precision: tensor([0.5788, 0.6817, 0.6584, 0.5146], device='cuda:0')
# train_recall: tensor([0.5703, 0.7731, 0.6353, 0.0815], device='cuda:0')
# val_loss: 0.7741948478751712
# val_precision: tensor([0.6257, 0.7287, 0.6889, 0.5194], device='cuda:0')
# val_recall: tensor([0.5942, 0.7927, 0.6978, 0.2572], device='cuda:0')
# Learning rate: 0.001
# epoch 8 time:  12.463600504999988
# --------------------------------
# ========================================
# EPOCH: 9
# train_loss: 0.8422915780828113
# train_precision: tensor([0.5847, 0.6842, 0.6609, 0.5486], device='cuda:0')
# train_recall: tensor([0.5726, 0.7755, 0.6399, 0.1035], device='cuda:0')
# val_loss: 0.788451956709226
# val_precision: tensor([0.5995, 0.7509, 0.6621, 0.5718], device='cuda:0')
# val_recall: tensor([0.5728, 0.7534, 0.7282, 0.2374], device='cuda:0')
# Learning rate: 0.001
# epoch 9 time:  12.472840249
# --------------------------------
# ========================================
# EPOCH: 10
# train_loss: 0.836394491933641
# train_precision: tensor([0.5883, 0.6872, 0.6617, 0.5719], device='cuda:0')
# train_recall: tensor([0.5766, 0.7777, 0.6399, 0.1199], device='cuda:0')
# val_loss: 0.7735675868060854
# val_precision: tensor([0.6258, 0.7728, 0.6547, 0.5129], device='cuda:0')
# val_recall: tensor([0.5860, 0.7444, 0.7475, 0.3010], device='cuda:0')
# Learning rate: 0.001
# epoch 10 time:  12.44349069499998
# --------------------------------
# ========================================
# EPOCH: 11
# train_loss: 0.8306188598984764
# train_precision: tensor([0.5919, 0.6905, 0.6635, 0.5378], device='cuda:0')
# train_recall: tensor([0.5799, 0.7780, 0.6433, 0.1274], device='cuda:0')
# val_loss: 0.7578732758760452
# val_precision: tensor([0.6291, 0.7482, 0.6728, 0.5756], device='cuda:0')
# val_recall: tensor([0.5809, 0.7770, 0.7334, 0.2768], device='cuda:0')
# Learning rate: 0.001
# epoch 11 time:  12.405611299999975
# --------------------------------
# ========================================
# EPOCH: 12
# train_loss: 0.8247688888084321
# train_precision: tensor([0.5968, 0.6934, 0.6658, 0.5574], device='cuda:0')
# train_recall: tensor([0.5815, 0.7787, 0.6492, 0.1528], device='cuda:0')
# val_loss: 0.7561386088530223
# val_precision: tensor([0.6379, 0.7247, 0.7000, 0.5302], device='cuda:0')
# val_recall: tensor([0.5854, 0.8157, 0.6932, 0.3519], device='cuda:0')
# Learning rate: 0.001
# epoch 12 time:  12.44420455300002
# --------------------------------
# ========================================
# EPOCH: 13
# train_loss: 0.8209542487348829
# train_precision: tensor([0.5983, 0.6939, 0.6673, 0.5484], device='cuda:0')
# train_recall: tensor([0.5838, 0.7798, 0.6498, 0.1470], device='cuda:0')
# val_loss: 0.7937281590369013
# val_precision: tensor([0.6840, 0.7655, 0.5966, 0.6011], device='cuda:0')
# val_recall: tensor([0.4591, 0.7612, 0.8293, 0.2663], device='cuda:0')
# Learning rate: 0.001
# epoch 13 time:  12.468155961999969
# --------------------------------
# ========================================
# EPOCH: 14
# train_loss: 0.8173340824388322
# train_precision: tensor([0.6037, 0.6950, 0.6695, 0.5782], device='cuda:0')
# train_recall: tensor([0.5872, 0.7814, 0.6533, 0.1574], device='cuda:0')
# val_loss: 0.7599022747741805
# val_precision: tensor([0.6445, 0.7721, 0.6527, 0.5748], device='cuda:0')
# val_recall: tensor([0.5640, 0.7660, 0.7686, 0.3182], device='cuda:0')
# Learning rate: 0.001
# epoch 14 time:  12.475271505999956
# --------------------------------
# ========================================
# EPOCH: 15
# train_loss: 0.8131613133918671
# train_precision: tensor([0.6055, 0.6970, 0.6704, 0.5801], device='cuda:0')
# train_recall: tensor([0.5894, 0.7807, 0.6556, 0.1651], device='cuda:0')
# val_loss: 0.7308072368303935
# val_precision: tensor([0.6596, 0.7203, 0.7127, 0.6457], device='cuda:0')
# val_recall: tensor([0.5988, 0.8338, 0.7028, 0.3141], device='cuda:0')
# Learning rate: 0.001
# epoch 15 time:  12.527265284999999
# --------------------------------
# ========================================
# EPOCH: 16
# train_loss: 0.8087405667418526
# train_precision: tensor([0.6100, 0.6976, 0.6703, 0.5920], device='cuda:0')
# train_recall: tensor([0.5869, 0.7833, 0.6606, 0.1742], device='cuda:0')
# val_loss: 0.7383191562361188
# val_precision: tensor([0.6699, 0.7424, 0.6760, 0.7308], device='cuda:0')
# val_recall: tensor([0.5707, 0.8079, 0.7591, 0.2697], device='cuda:0')
# Learning rate: 0.001
# epoch 16 time:  12.430424900000048
# --------------------------------
# ========================================
# EPOCH: 17
# train_loss: 0.8062930568343117
# train_precision: tensor([0.6125, 0.6993, 0.6724, 0.5836], device='cuda:0')
# train_recall: tensor([0.5910, 0.7840, 0.6619, 0.1713], device='cuda:0')
# val_loss: 0.774228128625287
# val_precision: tensor([0.6878, 0.7496, 0.6274, 0.5547], device='cuda:0')
# val_recall: tensor([0.5013, 0.7759, 0.8013, 0.3259], device='cuda:0')
# Learning rate: 0.001
# epoch 17 time:  12.478822627
# --------------------------------
# ========================================
# EPOCH: 18
# train_loss: 0.8037231265079408
# train_precision: tensor([0.6110, 0.7015, 0.6732, 0.5800], device='cuda:0')
# train_recall: tensor([0.5926, 0.7839, 0.6616, 0.1726], device='cuda:0')
# val_loss: 0.7425244884358512
# val_precision: tensor([0.6620, 0.7907, 0.6464, 0.6879], device='cuda:0')
# val_recall: tensor([0.5820, 0.7492, 0.7940, 0.3088], device='cuda:0')
# Learning rate: 0.0001
# epoch 18 time:  12.453602250000017
# --------------------------------
# ========================================
# EPOCH: 19
# train_loss: 0.784650098709833
# train_precision: tensor([0.6237, 0.7095, 0.6784, 0.6348], device='cuda:0')
# train_recall: tensor([0.5986, 0.7893, 0.6766, 0.1924], device='cuda:0')
# val_loss: 0.7164348847336239
# val_precision: tensor([0.6758, 0.7513, 0.6975, 0.5942], device='cuda:0')
# val_recall: tensor([0.5911, 0.8233, 0.7436, 0.3771], device='cuda:0')
# Learning rate: 0.0001
# epoch 19 time:  12.506015113000046
# --------------------------------
# ========================================
# EPOCH: 20
# train_loss: 0.7819053522178105
# train_precision: tensor([0.6253, 0.7114, 0.6819, 0.5958], device='cuda:0')
# train_recall: tensor([0.6004, 0.7913, 0.6770, 0.2063], device='cuda:0')
# val_loss: 0.7194616246554587
# val_precision: tensor([0.6736, 0.7566, 0.6851, 0.6365], device='cuda:0')
# val_recall: tensor([0.5830, 0.8137, 0.7563, 0.3508], device='cuda:0')
# Learning rate: 0.0001
# epoch 20 time:  12.432338894999987
# --------------------------------
# ========================================
# EPOCH: 21
# train_loss: 0.7798626004230409
# train_precision: tensor([0.6265, 0.7128, 0.6814, 0.6134], device='cuda:0')
# train_recall: tensor([0.6030, 0.7921, 0.6774, 0.1983], device='cuda:0')
# val_loss: 0.7196521730886565
# val_precision: tensor([0.6816, 0.7621, 0.6753, 0.6355], device='cuda:0')
# val_recall: tensor([0.5727, 0.8067, 0.7732, 0.3576], device='cuda:0')
# Learning rate: 0.0001
# epoch 21 time:  12.513627257000053
# --------------------------------
# ========================================
# EPOCH: 22
# train_loss: 0.779704522944632
# train_precision: tensor([0.6257, 0.7137, 0.6819, 0.6254], device='cuda:0')
# train_recall: tensor([0.6036, 0.7915, 0.6768, 0.2113], device='cuda:0')
# val_loss: 0.7149985273679097
# val_precision: tensor([0.6766, 0.7654, 0.6829, 0.6205], device='cuda:0')
# val_recall: tensor([0.5833, 0.8068, 0.7676, 0.3710], device='cuda:0')
# Learning rate: 0.0001
# epoch 22 time:  12.486299299000052
# --------------------------------
# ========================================
# EPOCH: 23
# train_loss: 0.7781762686513719
# train_precision: tensor([0.6276, 0.7133, 0.6825, 0.6067], device='cuda:0')
# train_recall: tensor([0.6044, 0.7897, 0.6789, 0.2130], device='cuda:0')
# val_loss: 0.718171422680219
# val_precision: tensor([0.6943, 0.7422, 0.6885, 0.6126], device='cuda:0')
# val_recall: tensor([0.5591, 0.8362, 0.7631, 0.3653], device='cuda:0')
# Learning rate: 0.0001
# epoch 23 time:  12.52953757299997
# --------------------------------
# ========================================
# EPOCH: 24
# train_loss: 0.777396310085342
# train_precision: tensor([0.6256, 0.7138, 0.6843, 0.6160], device='cuda:0')
# train_recall: tensor([0.6042, 0.7920, 0.6781, 0.2069], device='cuda:0')
# val_loss: 0.71408625062969
# val_precision: tensor([0.6785, 0.7613, 0.6866, 0.6245], device='cuda:0')
# val_recall: tensor([0.5911, 0.8047, 0.7646, 0.3623], device='cuda:0')
# Learning rate: 0.0001
# epoch 24 time:  12.486122236000028
# --------------------------------
# ========================================
# EPOCH: 25
# train_loss: 0.7758766469501314
# train_precision: tensor([0.6265, 0.7147, 0.6842, 0.6227], device='cuda:0')
# train_recall: tensor([0.6034, 0.7916, 0.6802, 0.2189], device='cuda:0')
# val_loss: 0.7130461709366904
# val_precision: tensor([0.6883, 0.7526, 0.6873, 0.6216], device='cuda:0')
# val_recall: tensor([0.5740, 0.8229, 0.7657, 0.3650], device='cuda:0')
# Learning rate: 0.0001
# epoch 25 time:  12.494424614999957
# --------------------------------
# ========================================
# EPOCH: 26
# train_loss: 0.7743297940208799
# train_precision: tensor([0.6309, 0.7166, 0.6836, 0.6102], device='cuda:0')
# train_recall: tensor([0.6056, 0.7935, 0.6821, 0.2126], device='cuda:0')
# val_loss: 0.7092866132656733
# val_precision: tensor([0.6674, 0.7475, 0.7184, 0.6081], device='cuda:0')
# val_recall: tensor([0.6222, 0.8324, 0.7132, 0.3741], device='cuda:0')
# Learning rate: 0.0001
# epoch 26 time:  12.470925734000048
# --------------------------------
# ========================================
# EPOCH: 27
# train_loss: 0.7756693050974891
# train_precision: tensor([0.6286, 0.7137, 0.6849, 0.6132], device='cuda:0')
# train_recall: tensor([0.6038, 0.7950, 0.6783, 0.2153], device='cuda:0')
# val_loss: 0.7096582551797231
# val_precision: tensor([0.6810, 0.7507, 0.6996, 0.6078], device='cuda:0')
# val_recall: tensor([0.5913, 0.8258, 0.7472, 0.3872], device='cuda:0')
# Learning rate: 0.0001
# epoch 27 time:  12.514548125000033
# --------------------------------
# ========================================
# EPOCH: 28
# train_loss: 0.7738144734076091
# train_precision: tensor([0.6285, 0.7165, 0.6842, 0.6215], device='cuda:0')
# train_recall: tensor([0.6048, 0.7933, 0.6810, 0.2185], device='cuda:0')
# val_loss: 0.7067664118276702
# val_precision: tensor([0.6788, 0.7610, 0.6952, 0.6404], device='cuda:0')
# val_recall: tensor([0.5961, 0.8146, 0.7607, 0.3663], device='cuda:0')
# Learning rate: 0.0001
# epoch 28 time:  12.460618510000018
# --------------------------------
# ========================================
# EPOCH: 29
# train_loss: 0.774711840067591
# train_precision: tensor([0.6279, 0.7140, 0.6852, 0.6133], device='cuda:0')
# train_recall: tensor([0.6043, 0.7937, 0.6793, 0.2133], device='cuda:0')
# val_loss: 0.711245991786321
# val_precision: tensor([0.6880, 0.7475, 0.6939, 0.6415], device='cuda:0')
# val_recall: tensor([0.5792, 0.8296, 0.7578, 0.3603], device='cuda:0')
# Learning rate: 0.0001
# epoch 29 time:  12.432847609999953
# --------------------------------
# ========================================
# EPOCH: 30
# train_loss: 0.773438366821834
# train_precision: tensor([0.6293, 0.7170, 0.6839, 0.6271], device='cuda:0')
# train_recall: tensor([0.6056, 0.7925, 0.6821, 0.2203], device='cuda:0')
# val_loss: 0.7074562172094981
# val_precision: tensor([0.6795, 0.7560, 0.7018, 0.6043], device='cuda:0')
# val_recall: tensor([0.5975, 0.8184, 0.7534, 0.3902], device='cuda:0')
# Learning rate: 0.0001
# epoch 30 time:  12.495760430000018
# --------------------------------
# ========================================
# EPOCH: 31
# train_loss: 0.7731692075729371
# train_precision: tensor([0.6313, 0.7155, 0.6856, 0.6004], device='cuda:0')
# train_recall: tensor([0.6048, 0.7926, 0.6850, 0.2110], device='cuda:0')
# val_loss: 0.7071443541182412
# val_precision: tensor([0.6884, 0.7590, 0.6893, 0.6316], device='cuda:0')
# val_recall: tensor([0.5794, 0.8181, 0.7719, 0.3838], device='cuda:0')
# Learning rate: 1e-05
# epoch 31 time:  12.55217875400001
# --------------------------------
# ========================================
# EPOCH: 32
# train_loss: 0.7707696494602022
# train_precision: tensor([0.6329, 0.7161, 0.6860, 0.6287], device='cuda:0')
# train_recall: tensor([0.6072, 0.7950, 0.6833, 0.2153], device='cuda:0')
# val_loss: 0.7064026557736927
# val_precision: tensor([0.6885, 0.7538, 0.6937, 0.6296], device='cuda:0')
# val_recall: tensor([0.5814, 0.8236, 0.7647, 0.3811], device='cuda:0')
# Learning rate: 1e-05
# epoch 32 time:  12.525057154000024
# --------------------------------
# ========================================
# EPOCH: 33
# train_loss: 0.7700000794160934
# train_precision: tensor([0.6311, 0.7175, 0.6851, 0.6221], device='cuda:0')
# train_recall: tensor([0.6067, 0.7941, 0.6831, 0.2183], device='cuda:0')
# val_loss: 0.7068443328142167
# val_precision: tensor([0.6875, 0.7584, 0.6922, 0.6131], device='cuda:0')
# val_recall: tensor([0.5829, 0.8191, 0.7672, 0.3906], device='cuda:0')
# Learning rate: 1e-05
# epoch 33 time:  12.600056492000022
# --------------------------------
# ========================================
# EPOCH: 34
# train_loss: 0.7702940441313244
# train_precision: tensor([0.6317, 0.7173, 0.6849, 0.6154], device='cuda:0')
# train_recall: tensor([0.6061, 0.7942, 0.6832, 0.2189], device='cuda:0')
# val_loss: 0.7056080316503842
# val_precision: tensor([0.6841, 0.7604, 0.6942, 0.6310], device='cuda:0')
# val_recall: tensor([0.5918, 0.8172, 0.7637, 0.3788], device='cuda:0')
# Learning rate: 1e-05
# epoch 34 time:  12.496068459999947
# --------------------------------
# ========================================
# EPOCH: 35
# train_loss: 0.7705525440829141
# train_precision: tensor([0.6318, 0.7178, 0.6859, 0.6209], device='cuda:0')
# train_recall: tensor([0.6065, 0.7947, 0.6848, 0.2153], device='cuda:0')
# val_loss: 0.7066218708952268
# val_precision: tensor([0.6856, 0.7627, 0.6890, 0.6346], device='cuda:0')
# val_recall: tensor([0.5864, 0.8156, 0.7692, 0.3737], device='cuda:0')
# Learning rate: 1e-05
# epoch 35 time:  12.501165281999988
# --------------------------------
# ========================================
# EPOCH: 36
# train_loss: 0.7703734246038255
# train_precision: tensor([0.6313, 0.7153, 0.6845, 0.6250], device='cuda:0')
# train_recall: tensor([0.6059, 0.7913, 0.6834, 0.2222], device='cuda:0')
# val_loss: 0.7052566048171786
# val_precision: tensor([0.6847, 0.7541, 0.6990, 0.6249], device='cuda:0')
# val_recall: tensor([0.5917, 0.8245, 0.7556, 0.3842], device='cuda:0')
# Learning rate: 1e-05
# epoch 36 time:  12.439654493000035
# --------------------------------
# ========================================
# EPOCH: 37
# train_loss: 0.7707611548049109
# train_precision: tensor([0.6301, 0.7160, 0.6854, 0.6168], device='cuda:0')
# train_recall: tensor([0.6038, 0.7937, 0.6839, 0.2188], device='cuda:0')
# val_loss: 0.7058721431427532
# val_precision: tensor([0.6846, 0.7580, 0.6957, 0.6198], device='cuda:0')
# val_recall: tensor([0.5890, 0.8220, 0.7601, 0.3886], device='cuda:0')
# Learning rate: 1e-05
# epoch 37 time:  12.431920297000033
# --------------------------------
# ========================================
# EPOCH: 38
# train_loss: 0.769803485983894
# train_precision: tensor([0.6312, 0.7176, 0.6870, 0.6196], device='cuda:0')
# train_recall: tensor([0.6077, 0.7935, 0.6847, 0.2153], device='cuda:0')
# val_loss: 0.7054117889867888
# val_precision: tensor([0.6871, 0.7545, 0.6962, 0.6295], device='cuda:0')
# val_recall: tensor([0.5865, 0.8251, 0.7605, 0.3805], device='cuda:0')
# Learning rate: 1e-05
# epoch 38 time:  12.473046801999999
# --------------------------------
# ========================================
# EPOCH: 39
# train_loss: 0.7693372323399499
# train_precision: tensor([0.6322, 0.7166, 0.6853, 0.6228], device='cuda:0')
# train_recall: tensor([0.6074, 0.7932, 0.6828, 0.2225], device='cuda:0')
# val_loss: 0.7053264300028483
# val_precision: tensor([0.6861, 0.7559, 0.6969, 0.6314], device='cuda:0')
# val_recall: tensor([0.5890, 0.8233, 0.7606, 0.3842], device='cuda:0')
# Learning rate: 5e-06
# epoch 39 time:  12.426240151000002
# --------------------------------
# ========================================
# EPOCH: 40
# train_loss: 0.7707982951686496
# train_precision: tensor([0.6317, 0.7162, 0.6849, 0.6182], device='cuda:0')
# train_recall: tensor([0.6071, 0.7933, 0.6821, 0.2185], device='cuda:0')
# val_loss: 0.7060754845539728
# val_precision: tensor([0.6849, 0.7599, 0.6931, 0.6268], device='cuda:0')
# val_recall: tensor([0.5883, 0.8174, 0.7649, 0.3869], device='cuda:0')
# Learning rate: 5e-06
# epoch 40 time:  12.42756822199999
# --------------------------------
# ========================================
# EPOCH: 41
# train_loss: 0.7698702406315576
# train_precision: tensor([0.6312, 0.7174, 0.6852, 0.6176], device='cuda:0')
# train_recall: tensor([0.6072, 0.7930, 0.6829, 0.2235], device='cuda:0')
# val_loss: 0.7075013231900004
# val_precision: tensor([0.6878, 0.7614, 0.6864, 0.6383], device='cuda:0')
# val_recall: tensor([0.5800, 0.8160, 0.7731, 0.3744], device='cuda:0')
# Learning rate: 5e-06
# epoch 41 time:  12.451253374999965
# --------------------------------
# ========================================
# EPOCH: 42
# train_loss: 0.7701161407289051
# train_precision: tensor([0.6315, 0.7170, 0.6866, 0.6234], device='cuda:0')
# train_recall: tensor([0.6062, 0.7944, 0.6836, 0.2271], device='cuda:0')
# val_loss: 0.7051170435216692
# val_precision: tensor([0.6849, 0.7572, 0.6981, 0.6214], device='cuda:0')
# val_recall: tensor([0.5918, 0.8220, 0.7593, 0.3896], device='cuda:0')
# Learning rate: 5e-06
# epoch 42 time:  12.505557123000017
# --------------------------------
# ========================================
# EPOCH: 43
# train_loss: 0.7686347913174402
# train_precision: tensor([0.6320, 0.7176, 0.6861, 0.6256], device='cuda:0')
# train_recall: tensor([0.6080, 0.7935, 0.6839, 0.2228], device='cuda:0')
# val_loss: 0.705769822994868
# val_precision: tensor([0.6850, 0.7591, 0.6956, 0.6156], device='cuda:0')
# val_recall: tensor([0.5901, 0.8195, 0.7620, 0.3909], device='cuda:0')
# Learning rate: 5e-06
# epoch 43 time:  12.467223315999945
# --------------------------------
# ========================================
# EPOCH: 44
# train_loss: 0.7703137417634328
# train_precision: tensor([0.6315, 0.7170, 0.6828, 0.6238], device='cuda:0')
# train_recall: tensor([0.6040, 0.7935, 0.6836, 0.2221], device='cuda:0')
# val_loss: 0.7056740548875596
# val_precision: tensor([0.6888, 0.7507, 0.7002, 0.6238], device='cuda:0')
# val_recall: tensor([0.5865, 0.8304, 0.7564, 0.3875], device='cuda:0')
# Learning rate: 5e-06
# epoch 44 time:  12.507101601000045
# --------------------------------
# ========================================
# EPOCH: 45
# train_loss: 0.7705539880763916
# train_precision: tensor([0.6300, 0.7156, 0.6870, 0.6173], device='cuda:0')
# train_recall: tensor([0.6077, 0.7931, 0.6812, 0.2199], device='cuda:0')
# val_loss: 0.7050788197252486
# val_precision: tensor([0.6855, 0.7587, 0.6963, 0.6114], device='cuda:0')
# val_recall: tensor([0.5901, 0.8204, 0.7618, 0.3899], device='cuda:0')
# Learning rate: 5e-06
# epoch 45 time:  12.492187898999987
# --------------------------------
# ========================================
# EPOCH: 46
# train_loss: 0.7693936968133563
# train_precision: tensor([0.6303, 0.7171, 0.6857, 0.6188], device='cuda:0')
# train_recall: tensor([0.6069, 0.7925, 0.6829, 0.2237], device='cuda:0')
# val_loss: 0.7059088163905674
# val_precision: tensor([0.6859, 0.7582, 0.6950, 0.6234], device='cuda:0')
# val_recall: tensor([0.5879, 0.8214, 0.7626, 0.3886], device='cuda:0')
# Learning rate: 5e-06
# epoch 46 time:  12.466215679000015
# --------------------------------
# ========================================
# EPOCH: 47
# train_loss: 0.7702708013000943
# train_precision: tensor([0.6316, 0.7175, 0.6854, 0.6204], device='cuda:0')
# train_recall: tensor([0.6076, 0.7938, 0.6825, 0.2227], device='cuda:0')
# val_loss: 0.7061907488438818
# val_precision: tensor([0.6871, 0.7581, 0.6930, 0.6281], device='cuda:0')
# val_recall: tensor([0.5849, 0.8213, 0.7651, 0.3838], device='cuda:0')
# Learning rate: 5e-06
# epoch 47 time:  12.489936699000054
# --------------------------------
# ========================================
# EPOCH: 48
# train_loss: 0.7690639925854547
# train_precision: tensor([0.6316, 0.7176, 0.6873, 0.6162], device='cuda:0')
# train_recall: tensor([0.6077, 0.7946, 0.6837, 0.2201], device='cuda:0')
# val_loss: 0.705808025929663
# val_precision: tensor([0.6857, 0.7600, 0.6927, 0.6308], device='cuda:0')
# val_recall: tensor([0.5883, 0.8192, 0.7644, 0.3808], device='cuda:0')
# Learning rate: 5e-06
# epoch 48 time:  12.489379124999914
# --------------------------------
# ========================================
# EPOCH: 49
# train_loss: 0.77052251072157
# train_precision: tensor([0.6314, 0.7176, 0.6850, 0.6208], device='cuda:0')
# train_recall: tensor([0.6070, 0.7928, 0.6835, 0.2228], device='cuda:0')
# val_loss: 0.7050092337860001
# val_precision: tensor([0.6850, 0.7570, 0.6973, 0.6215], device='cuda:0')
# val_recall: tensor([0.5905, 0.8229, 0.7592, 0.3865], device='cuda:0')
# Learning rate: 5e-06
# epoch 49 time:  12.467033897999954
# --------------------------------
# ========================================
# EPOCH: 50
# train_loss: 0.7689621303762708
# train_precision: tensor([0.6321, 0.7165, 0.6869, 0.6214], device='cuda:0')
# train_recall: tensor([0.6067, 0.7957, 0.6826, 0.2238], device='cuda:0')
# val_loss: 0.7049628597166803
# val_precision: tensor([0.6837, 0.7619, 0.6952, 0.6222], device='cuda:0')
# val_recall: tensor([0.5938, 0.8161, 0.7632, 0.3882], device='cuda:0')
# Learning rate: 5e-06
# epoch 50 time:  12.462406832000056
# --------------------------------
# ========================================
# EPOCH: 51
# train_loss: 0.7692311611913499
# train_precision: tensor([0.6316, 0.7176, 0.6851, 0.6144], device='cuda:0')
# train_recall: tensor([0.6066, 0.7932, 0.6840, 0.2198], device='cuda:0')
# val_loss: 0.7053562507033349
# val_precision: tensor([0.6834, 0.7638, 0.6922, 0.6262], device='cuda:0')
# val_recall: tensor([0.5919, 0.8143, 0.7658, 0.3842], device='cuda:0')
# Learning rate: 5e-06
# epoch 51 time:  12.559157359999972
# --------------------------------
# ========================================
# EPOCH: 52
# train_loss: 0.7687941443352472
# train_precision: tensor([0.6317, 0.7187, 0.6874, 0.6154], device='cuda:0')
# train_recall: tensor([0.6091, 0.7944, 0.6830, 0.2251], device='cuda:0')
# val_loss: 0.7051563993096351
# val_precision: tensor([0.6861, 0.7567, 0.6964, 0.6248], device='cuda:0')
# val_recall: tensor([0.5889, 0.8235, 0.7602, 0.3852], device='cuda:0')
# Learning rate: 5e-06
# epoch 52 time:  12.446726366000007
# --------------------------------
# ========================================
# EPOCH: 53
# train_loss: 0.7679821607612428
# train_precision: tensor([0.6309, 0.7183, 0.6862, 0.6382], device='cuda:0')
# train_recall: tensor([0.6047, 0.7941, 0.6862, 0.2293], device='cuda:0')
# val_loss: 0.7052550345659256
# val_precision: tensor([0.6827, 0.7617, 0.6961, 0.6195], device='cuda:0')
# val_recall: tensor([0.5947, 0.8173, 0.7608, 0.3902], device='cuda:0')
# Learning rate: 5e-06
# epoch 53 time:  12.467442615999971
# --------------------------------
# ========================================
# EPOCH: 54
# train_loss: 0.770352569364366
# train_precision: tensor([0.6329, 0.7178, 0.6858, 0.6204], device='cuda:0')
# train_recall: tensor([0.6103, 0.7921, 0.6832, 0.2231], device='cuda:0')
# val_loss: 0.705484212603834
# val_precision: tensor([0.6844, 0.7609, 0.6952, 0.6236], device='cuda:0')
# val_recall: tensor([0.5924, 0.8180, 0.7631, 0.3855], device='cuda:0')
# Learning rate: 5e-06
# epoch 54 time:  12.452951245999998
# --------------------------------
# ========================================
# EPOCH: 55
# train_loss: 0.7706217906304769
# train_precision: tensor([0.6315, 0.7174, 0.6842, 0.6245], device='cuda:0')
# train_recall: tensor([0.6067, 0.7933, 0.6826, 0.2240], device='cuda:0')
# val_loss: 0.7060014711485969
# val_precision: tensor([0.6875, 0.7595, 0.6926, 0.6248], device='cuda:0')
# val_recall: tensor([0.5854, 0.8201, 0.7668, 0.3852], device='cuda:0')
# Learning rate: 5e-06
# epoch 55 time:  12.426757381000016
# --------------------------------
# ========================================
# EPOCH: 56
# train_loss: 0.769366523197719
# train_precision: tensor([0.6308, 0.7173, 0.6861, 0.6214], device='cuda:0')
# train_recall: tensor([0.6069, 0.7952, 0.6815, 0.2238], device='cuda:0')
# val_loss: 0.7067856878042221
# val_precision: tensor([0.6858, 0.7666, 0.6884, 0.6149], device='cuda:0')
# val_recall: tensor([0.5864, 0.8107, 0.7738, 0.3902], device='cuda:0')
# Learning rate: 5e-06
# epoch 56 time:  12.45175752900002
# --------------------------------
# ========================================
# EPOCH: 57
# train_loss: 0.7692527521224249
# train_precision: tensor([0.6314, 0.7178, 0.6834, 0.6227], device='cuda:0')
# train_recall: tensor([0.6045, 0.7936, 0.6841, 0.2237], device='cuda:0')
# val_loss: 0.706427287724283
# val_precision: tensor([0.6844, 0.7681, 0.6881, 0.6217], device='cuda:0')
# val_recall: tensor([0.5889, 0.8094, 0.7733, 0.3862], device='cuda:0')
# Learning rate: 5e-06
# epoch 57 time:  12.451908588000038
# --------------------------------
# ========================================
# EPOCH: 58
# train_loss: 0.7687003545817874
# train_precision: tensor([0.6306, 0.7173, 0.6858, 0.6247], device='cuda:0')
# train_recall: tensor([0.6076, 0.7931, 0.6819, 0.2277], device='cuda:0')
# val_loss: 0.7050363601909744
# val_precision: tensor([0.6864, 0.7579, 0.6959, 0.6247], device='cuda:0')
# val_recall: tensor([0.5887, 0.8224, 0.7624, 0.3855], device='cuda:0')
# Learning rate: 5e-06
# epoch 58 time:  12.480438136999965
# --------------------------------
# ========================================
# EPOCH: 59
# train_loss: 0.7682789504528046
# train_precision: tensor([0.6334, 0.7178, 0.6857, 0.6121], device='cuda:0')
# train_recall: tensor([0.6063, 0.7954, 0.6852, 0.2170], device='cuda:0')
# val_loss: 0.7056564019785987
# val_precision: tensor([0.6855, 0.7614, 0.6929, 0.6237], device='cuda:0')
# val_recall: tensor([0.5897, 0.8174, 0.7652, 0.3862], device='cuda:0')
# Learning rate: 5e-06
# epoch 59 time:  12.459692615999984
# --------------------------------
# ========================================
# EPOCH: 60
# train_loss: 0.7695149379117149
# train_precision: tensor([0.6326, 0.7164, 0.6857, 0.6299], device='cuda:0')
# train_recall: tensor([0.6084, 0.7920, 0.6835, 0.2257], device='cuda:0')
# val_loss: 0.706065827773677
# val_precision: tensor([0.6849, 0.7645, 0.6898, 0.6245], device='cuda:0')
# val_recall: tensor([0.5876, 0.8142, 0.7692, 0.3869], device='cuda:0')
# Learning rate: 5e-06
# Early stopping at epoch 60 with best validation loss 0.7049628597166803
# training_checkpoints/vit_normalized_padded_another_params_local2024-04-26 00:27:28.419547.pth
# <All keys matched successfully>
