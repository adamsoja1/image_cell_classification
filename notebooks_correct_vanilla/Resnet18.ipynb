# %%
import time
import sys
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from dataset import ImageDataset
import torch.nn.functional as F
from torchmetrics import Precision, Recall
from torchvision.models import resnet18
import warnings
from collections import defaultdict
import wandb
import datetime
import os
warnings.filterwarnings('ignore')
torch.set_float32_matmul_precision('high')
#intecubic interpol

run_name = f'resnet18_{datetime.datetime.now()}'
run_path = f'training_checkpoints/{run_name}'

wandb.init(project="cells", 
           entity="adamsoja",
          name=run_name)

import random
random.seed(2233)
torch.manual_seed(2233)

from albumentations import (
    Compose,
    Resize,
    OneOf,
    RandomBrightness,
    RandomContrast,
    MotionBlur,
    MedianBlur,
    GaussianBlur,
    VerticalFlip,
    HorizontalFlip,
    ShiftScaleRotate,
    Normalize,
)

transform = Compose(
    [
        OneOf([RandomBrightness(limit=0.4, p=1), RandomContrast(limit=0.4, p=1)]),
        OneOf([MotionBlur(blur_limit=3), MedianBlur(blur_limit=3), GaussianBlur(blur_limit=3),], p=0.7,),
        VerticalFlip(p=0.5),
        HorizontalFlip(p=0.5),]
)

class MyModel(nn.Module):
    def __init__(self, model, learning_rate, weight_decay):
        super(MyModel, self).__init__()
        self.model = model
        self.learning_rate = learning_rate
        self.weight_decay = weight_decay
        self.criterion = nn.CrossEntropyLoss()
        self.metric_precision = Precision(task="multiclass", num_classes=4, average=None).to('cuda')
        self.metric_recall = Recall(task="multiclass", num_classes=4, average=None).to('cuda')
        self.train_loss = []
        self.valid_loss = []
        self.precision_per_epochs = []
        self.recall_per_epochs = []

        self.optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, mode="min", factor=0.1, patience=2, min_lr=5e-6, verbose=True)
        self.step = 0

    
    def forward(self, x):
        return self.model(x)

    def train_one_epoch(self, trainloader):
        self.step += 1
        self.train()
        for batch_idx, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()
            _, preds = torch.max(outputs, 1)
            _, labels = torch.max(labels, 1)
            self.metric_precision(preds, labels)
            self.metric_recall(preds, labels)
            self.train_loss.append(loss.item())


        

        
        avg_loss = np.mean(self.train_loss)
        self.train_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        self.precision_per_epochs.append(precision)
        self.recall_per_epochs.append(recall)
        print(f'train_loss: {avg_loss}')
        print(f'train_precision: {precision}')
        print(f'train_recall: {recall}')

        wandb.log({'loss': avg_loss},step=self.step)
        wandb.log({'Normal precision': precision[0].item()},step=self.step)
        wandb.log({'Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'Other precision': precision[3].item()},step=self.step)


        wandb.log({'Normal recall': recall[0].item()},step=self.step)
        wandb.log({'Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'Other recall': recall[3].item()},step=self.step)
        
        
        self.metric_precision.reset()
        self.metric_recall.reset()


    

    def evaluate(self, testloader):
        self.eval()
        with torch.no_grad():
            for batch_idx, (inputs, labels) in enumerate(testloader):
                inputs, labels = inputs.to('cuda'), labels.to('cuda')
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)
                _, labels = torch.max(labels, 1)
                self.metric_precision(preds, labels)
                self.metric_recall(preds, labels)
                self.valid_loss.append(loss.item())
    
        avg_loss = np.mean(self.valid_loss)
        self.scheduler.step(avg_loss)
        self.valid_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        print(f'val_loss: {avg_loss}')
        print(f'val_precision: {precision}')
        print(f'val_recall: {recall}')
        self.metric_precision.reset()
        self.metric_recall.reset()

        wandb.log({'val_loss': avg_loss}, step=self.step)
        
        wandb.log({'val_Normal precision': precision[0].item()},step=self.step)
        wandb.log({'val_Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'val_Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'val_Other precision': precision[3].item()},step=self.step)


        wandb.log({'val_Normal recall': recall[0].item()},step=self.step)
        wandb.log({'val_Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'val_Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'val_Other recall': recall[3].item()},step=self.step)


        for param_group in self.optimizer.param_groups:
            print(f"Learning rate: {param_group['lr']}")
        return avg_loss

torch.cuda.empty_cache()
batch_size = 256
trainset = ImageDataset(data_path='train_data', transform=transform)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=5)

testset = ImageDataset(data_path='validation_data')
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=3)

learning_rate = 0.001
weight_decay = 0.00001

model = resnet18()
model.conv1 = nn.Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
num_classes = 4
model.fc = nn.Sequential(
    nn.Dropout(0.2),
    nn.Linear(model.fc.in_features, num_classes))
model = model.to('cuda')


my_model = MyModel(model=model, learning_rate=learning_rate, weight_decay=weight_decay)
my_model = my_model.to('cuda')

num_epochs = 100
early_stop_patience = 10
best_val_loss = float('inf')
best_model_state_dict = None

for epoch in range(num_epochs):
    print('========================================')
    print(f'EPOCH: {epoch}') 
    time_start = time.perf_counter()
    my_model.train_one_epoch(trainloader)
    val_loss = my_model.evaluate(testloader)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_state_dict = my_model.state_dict()
        torch.save(best_model_state_dict, f'{run_path}.pth')
        
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch} with best validation loss {best_val_loss}")
        break
    time_epoch = time.perf_counter() - time_start
    print(f'epoch {epoch} time:  {time_epoch/60}')
    print('--------------------------------')

# Load the best model state dict
print(f'{run_path}.pth')
my_model.load_state_dict(torch.load(f'{run_path}.pth'))
# Out:
# wandb: Currently logged in as: adamsoja. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/adam/Desktop/cells_master_thesis/wandb/run-20240421_015932-t937w7hr</code>
# Syncing run <strong><a href='https://wandb.ai/adamsoja/cells/runs/t937w7hr' target="_blank">resnet18_2024-04-21 01:59:31.428721</a></strong> to <a href='https://wandb.ai/adamsoja/cells' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adamsoja/cells' target="_blank">https://wandb.ai/adamsoja/cells</a>
#  View run at <a href='https://wandb.ai/adamsoja/cells/runs/t937w7hr' target="_blank">https://wandb.ai/adamsoja/cells/runs/t937w7hr</a>
# ========================================
# EPOCH: 0
# train_loss: 0.8581801303795406
# train_precision: tensor([0.5603, 0.6925, 0.6536, 0.6050], device='cuda:0')
# train_recall: tensor([0.5540, 0.7646, 0.6484, 0.0915], device='cuda:0')
# val_loss: 0.7878658288054996
# val_precision: tensor([0.6051, 0.6767, 0.7474, 0.5132], device='cuda:0')
# val_recall: tensor([0.5967, 0.8412, 0.6033, 0.3266], device='cuda:0')
# Learning rate: 0.001
# epoch 0 time:  0.33299731730000226
# --------------------------------
# ========================================
# EPOCH: 1
# train_loss: 0.781412868698438
# train_precision: tensor([0.6049, 0.7254, 0.6873, 0.6156], device='cuda:0')
# train_recall: tensor([0.5916, 0.7853, 0.6883, 0.2343], device='cuda:0')
# val_loss: 0.7593650053772661
# val_precision: tensor([0.5999, 0.7082, 0.7607, 0.6820], device='cuda:0')
# val_recall: tensor([0.6550, 0.8320, 0.5973, 0.3286], device='cuda:0')
# Learning rate: 0.001
# epoch 1 time:  0.3510776240166706
# --------------------------------
# ========================================
# EPOCH: 2
# train_loss: 0.7427946904585475
# train_precision: tensor([0.6239, 0.7444, 0.7045, 0.6378], device='cuda:0')
# train_recall: tensor([0.6157, 0.7961, 0.7005, 0.3133], device='cuda:0')
# val_loss: 1.046711077209976
# val_precision: tensor([0.6594, 0.8623, 0.4386, 0.5595], device='cuda:0')
# val_recall: tensor([0.2238, 0.4754, 0.9514, 0.2249], device='cuda:0')
# Learning rate: 0.001
# epoch 2 time:  0.3289760016500016
# --------------------------------
# ========================================
# EPOCH: 3
# train_loss: 0.7143038092624574
# train_precision: tensor([0.6405, 0.7529, 0.7167, 0.6615], device='cuda:0')
# train_recall: tensor([0.6267, 0.8028, 0.7153, 0.3779], device='cuda:0')
# val_loss: 0.7707914830909834
# val_precision: tensor([0.6769, 0.6444, 0.7387, 0.8381], device='cuda:0')
# val_recall: tensor([0.5067, 0.8903, 0.6945, 0.2492], device='cuda:0')
# Learning rate: 0.001
# epoch 3 time:  0.3280234229500214
# --------------------------------
# ========================================
# EPOCH: 4
# train_loss: 0.6933023778455598
# train_precision: tensor([0.6521, 0.7613, 0.7241, 0.6564], device='cuda:0')
# train_recall: tensor([0.6371, 0.8090, 0.7219, 0.4166], device='cuda:0')
# val_loss: 0.6768557790252897
# val_precision: tensor([0.6607, 0.7359, 0.7796, 0.5948], device='cuda:0')
# val_recall: tensor([0.6437, 0.8671, 0.6665, 0.5502], device='cuda:0')
# Learning rate: 0.001
# epoch 4 time:  0.34284395343335444
# --------------------------------
# ========================================
# EPOCH: 5
# train_loss: 0.6768705738442284
# train_precision: tensor([0.6619, 0.7673, 0.7344, 0.6664], device='cuda:0')
# train_recall: tensor([0.6476, 0.8156, 0.7287, 0.4429], device='cuda:0')
# val_loss: 0.7265011221998268
# val_precision: tensor([0.5955, 0.7552, 0.7880, 0.6795], device='cuda:0')
# val_recall: tensor([0.7265, 0.8079, 0.5810, 0.4946], device='cuda:0')
# Learning rate: 0.001
# epoch 5 time:  0.3228380502333493
# --------------------------------
# ========================================
# EPOCH: 6
# train_loss: 0.6613617029218447
# train_precision: tensor([0.6707, 0.7729, 0.7396, 0.6824], device='cuda:0')
# train_recall: tensor([0.6541, 0.8199, 0.7359, 0.4710], device='cuda:0')
# val_loss: 0.7010091517948442
# val_precision: tensor([0.6664, 0.6884, 0.8166, 0.8290], device='cuda:0')
# val_recall: tensor([0.6553, 0.8976, 0.6300, 0.3428], device='cuda:0')
# Learning rate: 0.001
# epoch 6 time:  0.32432445183333886
# --------------------------------
# ========================================
# EPOCH: 7
# train_loss: 0.646127975838525
# train_precision: tensor([0.6784, 0.7792, 0.7454, 0.6973], device='cuda:0')
# train_recall: tensor([0.6612, 0.8239, 0.7430, 0.4964], device='cuda:0')
# val_loss: 0.6308423038158152
# val_precision: tensor([0.6907, 0.8000, 0.7313, 0.7619], device='cuda:0')
# val_recall: tensor([0.6561, 0.8203, 0.7739, 0.5064], device='cuda:0')
# Learning rate: 0.001
# epoch 7 time:  0.3427264466333327
# --------------------------------
# ========================================
# EPOCH: 8
# train_loss: 0.633441283411923
# train_precision: tensor([0.6821, 0.7836, 0.7508, 0.7011], device='cuda:0')
# train_recall: tensor([0.6700, 0.8254, 0.7439, 0.5156], device='cuda:0')
# val_loss: 0.6966508192320665
# val_precision: tensor([0.6977, 0.8389, 0.6325, 0.7493], device='cuda:0')
# val_recall: tensor([0.5323, 0.7541, 0.8689, 0.4822], device='cuda:0')
# Learning rate: 0.001
# epoch 8 time:  0.32323924016667055
# --------------------------------
# ========================================
# EPOCH: 9
# train_loss: 0.6193823373388676
# train_precision: tensor([0.6896, 0.7883, 0.7579, 0.7063], device='cuda:0')
# train_recall: tensor([0.6767, 0.8287, 0.7509, 0.5404], device='cuda:0')
# val_loss: 0.6819917332794931
# val_precision: tensor([0.7022, 0.8367, 0.6516, 0.6096], device='cuda:0')
# val_recall: tensor([0.5789, 0.7312, 0.8540, 0.5552], device='cuda:0')
# Learning rate: 0.001
# epoch 9 time:  0.3258829104499758
# --------------------------------
# ========================================
# EPOCH: 10
# train_loss: 0.608808022772982
# train_precision: tensor([0.6959, 0.7915, 0.7633, 0.7060], device='cuda:0')
# train_recall: tensor([0.6820, 0.8325, 0.7554, 0.5544], device='cuda:0')
# val_loss: 0.6912817991442151
# val_precision: tensor([0.7415, 0.8117, 0.6274, 0.6540], device='cuda:0')
# val_recall: tensor([0.4750, 0.8059, 0.8759, 0.4620], device='cuda:0')
# Learning rate: 0.0001
# epoch 10 time:  0.3307666126666845
# --------------------------------
# ========================================
# EPOCH: 11
# train_loss: 0.562250436523131
# train_precision: tensor([0.7195, 0.8082, 0.7823, 0.7485], device='cuda:0')
# train_recall: tensor([0.7029, 0.8460, 0.7774, 0.6176], device='cuda:0')
# val_loss: 0.5795990953842799
# val_precision: tensor([0.7076, 0.8428, 0.7482, 0.7381], device='cuda:0')
# val_recall: tensor([0.7004, 0.8014, 0.8060, 0.6074], device='cuda:0')
# Learning rate: 0.0001
# epoch 11 time:  0.351332721216689
# --------------------------------
# ========================================
# EPOCH: 12
# train_loss: 0.5469660877117088
# train_precision: tensor([0.7242, 0.8151, 0.7890, 0.7476], device='cuda:0')
# train_recall: tensor([0.7146, 0.8482, 0.7788, 0.6395], device='cuda:0')
# val_loss: 0.5635860487818718
# val_precision: tensor([0.7071, 0.8131, 0.7965, 0.7595], device='cuda:0')
# val_recall: tensor([0.7285, 0.8446, 0.7582, 0.5997], device='cuda:0')
# Learning rate: 0.0001
# epoch 12 time:  0.3559510669166533
# --------------------------------
# ========================================
# EPOCH: 13
# train_loss: 0.5388060371081035
# train_precision: tensor([0.7280, 0.8181, 0.7930, 0.7593], device='cuda:0')
# train_recall: tensor([0.7184, 0.8496, 0.7832, 0.6619], device='cuda:0')
# val_loss: 0.5623694715400537
# val_precision: tensor([0.7171, 0.8210, 0.7769, 0.7667], device='cuda:0')
# val_recall: tensor([0.7103, 0.8385, 0.7844, 0.6020], device='cuda:0')
# Learning rate: 0.0001
# epoch 13 time:  0.35355643156666094
# --------------------------------
# ========================================
# EPOCH: 14
# train_loss: 0.5324358163135392
# train_precision: tensor([0.7308, 0.8215, 0.7960, 0.7545], device='cuda:0')
# train_recall: tensor([0.7242, 0.8508, 0.7841, 0.6670], device='cuda:0')
# val_loss: 0.5657018785675366
# val_precision: tensor([0.7114, 0.7966, 0.8059, 0.7647], device='cuda:0')
# val_recall: tensor([0.7194, 0.8645, 0.7462, 0.5943], device='cuda:0')
# Learning rate: 0.0001
# epoch 14 time:  0.32213149343333497
# --------------------------------
# ========================================
# EPOCH: 15
# train_loss: 0.5270952634158589
# train_precision: tensor([0.7333, 0.8251, 0.7985, 0.7676], device='cuda:0')
# train_recall: tensor([0.7273, 0.8541, 0.7861, 0.6782], device='cuda:0')
# val_loss: 0.5590888063940737
# val_precision: tensor([0.7239, 0.8228, 0.7715, 0.7745], device='cuda:0')
# val_recall: tensor([0.7020, 0.8402, 0.7955, 0.6047], device='cuda:0')
# Learning rate: 0.0001
# epoch 15 time:  0.34181624783332154
# --------------------------------
# ========================================
# EPOCH: 16
# train_loss: 0.5228754349407696
# train_precision: tensor([0.7363, 0.8247, 0.8000, 0.7664], device='cuda:0')
# train_recall: tensor([0.7287, 0.8532, 0.7886, 0.6895], device='cuda:0')
# val_loss: 0.5589884983168708
# val_precision: tensor([0.7224, 0.8358, 0.7601, 0.7833], device='cuda:0')
# val_recall: tensor([0.7005, 0.8282, 0.8075, 0.6037], device='cuda:0')
# Learning rate: 0.0001
# epoch 16 time:  0.34842960166667275
# --------------------------------
# ========================================
# EPOCH: 17
# train_loss: 0.5178666465339207
# train_precision: tensor([0.7385, 0.8272, 0.8017, 0.7723], device='cuda:0')
# train_recall: tensor([0.7308, 0.8546, 0.7914, 0.6949], device='cuda:0')
# val_loss: 0.5639999309347735
# val_precision: tensor([0.7255, 0.8390, 0.7533, 0.7425], device='cuda:0')
# val_recall: tensor([0.6913, 0.8196, 0.8160, 0.6458], device='cuda:0')
# Learning rate: 0.0001
# epoch 17 time:  0.3278979200666678
# --------------------------------
# ========================================
# EPOCH: 18
# train_loss: 0.5113075714026178
# train_precision: tensor([0.7411, 0.8279, 0.8053, 0.7690], device='cuda:0')
# train_recall: tensor([0.7339, 0.8574, 0.7917, 0.7003], device='cuda:0')
# val_loss: 0.5547425041596095
# val_precision: tensor([0.7245, 0.8176, 0.7846, 0.7745], device='cuda:0')
# val_recall: tensor([0.7112, 0.8484, 0.7853, 0.6175], device='cuda:0')
# Learning rate: 0.0001
# epoch 18 time:  0.33998312878332704
# --------------------------------
# ========================================
# EPOCH: 19
# train_loss: 0.5075161654324759
# train_precision: tensor([0.7443, 0.8300, 0.8067, 0.7750], device='cuda:0')
# train_recall: tensor([0.7367, 0.8588, 0.7943, 0.7058], device='cuda:0')
# val_loss: 0.5571349841852983
# val_precision: tensor([0.7382, 0.8183, 0.7673, 0.7907], device='cuda:0')
# val_recall: tensor([0.6863, 0.8510, 0.8075, 0.6145], device='cuda:0')
# Learning rate: 0.0001
# epoch 19 time:  0.32190359880002384
# --------------------------------
# ========================================
# EPOCH: 20
# train_loss: 0.501171947057758
# train_precision: tensor([0.7465, 0.8324, 0.8088, 0.7784], device='cuda:0')
# train_recall: tensor([0.7393, 0.8602, 0.7961, 0.7159], device='cuda:0')
# val_loss: 0.5602657227052583
# val_precision: tensor([0.7375, 0.8174, 0.7670, 0.7714], device='cuda:0')
# val_recall: tensor([0.6857, 0.8525, 0.8031, 0.6192], device='cuda:0')
# Learning rate: 0.0001
# epoch 20 time:  0.32618300308331527
# --------------------------------
# ========================================
# EPOCH: 21
# train_loss: 0.4976392930107457
# train_precision: tensor([0.7475, 0.8334, 0.8120, 0.7786], device='cuda:0')
# train_recall: tensor([0.7420, 0.8618, 0.7958, 0.7255], device='cuda:0')
# val_loss: 0.5708729319274426
# val_precision: tensor([0.7206, 0.8473, 0.7495, 0.7281], device='cuda:0')
# val_recall: tensor([0.6922, 0.8115, 0.8189, 0.6481], device='cuda:0')
# Learning rate: 1e-05
# epoch 21 time:  0.3247982484833301
# --------------------------------
# ========================================
# EPOCH: 22
# train_loss: 0.4884185749150458
# train_precision: tensor([0.7529, 0.8344, 0.8169, 0.7853], device='cuda:0')
# train_recall: tensor([0.7461, 0.8640, 0.8000, 0.7392], device='cuda:0')
# val_loss: 0.5506612401869562
# val_precision: tensor([0.7273, 0.8269, 0.7837, 0.7701], device='cuda:0')
# val_recall: tensor([0.7164, 0.8468, 0.7895, 0.6428], device='cuda:0')
# Learning rate: 1e-05
# epoch 22 time:  0.341609018583343
# --------------------------------
# ========================================
# EPOCH: 23
# train_loss: 0.48516974921027817
# train_precision: tensor([0.7543, 0.8377, 0.8162, 0.7878], device='cuda:0')
# train_recall: tensor([0.7479, 0.8651, 0.8018, 0.7354], device='cuda:0')
# val_loss: 0.5508387147552437
# val_precision: tensor([0.7321, 0.8270, 0.7788, 0.7611], device='cuda:0')
# val_recall: tensor([0.7079, 0.8467, 0.7965, 0.6576], device='cuda:0')
# Learning rate: 1e-05
# epoch 23 time:  0.32434062923333234
# --------------------------------
# ========================================
# EPOCH: 24
# train_loss: 0.48572546002410705
# train_precision: tensor([0.7548, 0.8375, 0.8170, 0.7864], device='cuda:0')
# train_recall: tensor([0.7480, 0.8636, 0.8033, 0.7442], device='cuda:0')
# val_loss: 0.5520867127511236
# val_precision: tensor([0.7301, 0.8327, 0.7743, 0.7757], device='cuda:0')
# val_recall: tensor([0.7101, 0.8404, 0.8021, 0.6394], device='cuda:0')
# Learning rate: 1e-05
# epoch 24 time:  0.3235807734833543
# --------------------------------
# ========================================
# EPOCH: 25
# train_loss: 0.4855616877476374
# train_precision: tensor([0.7546, 0.8382, 0.8170, 0.7927], device='cuda:0')
# train_recall: tensor([0.7491, 0.8647, 0.8019, 0.7466], device='cuda:0')
# val_loss: 0.5529215517143409
# val_precision: tensor([0.7338, 0.8298, 0.7737, 0.7531], device='cuda:0')
# val_recall: tensor([0.7027, 0.8442, 0.8027, 0.6593], device='cuda:0')
# Learning rate: 5e-06
# epoch 25 time:  0.32368488983332405
# --------------------------------
# ========================================
# EPOCH: 26
# train_loss: 0.4821080936917237
# train_precision: tensor([0.7570, 0.8393, 0.8159, 0.7968], device='cuda:0')
# train_recall: tensor([0.7471, 0.8656, 0.8058, 0.7485], device='cuda:0')
# val_loss: 0.5542869594362047
# val_precision: tensor([0.7302, 0.8337, 0.7719, 0.7707], device='cuda:0')
# val_recall: tensor([0.7073, 0.8385, 0.8042, 0.6451], device='cuda:0')
# Learning rate: 5e-06
# epoch 26 time:  0.3240685090833419
# --------------------------------
# ========================================
# EPOCH: 27
# train_loss: 0.48328027899066606
# train_precision: tensor([0.7576, 0.8388, 0.8183, 0.7916], device='cuda:0')
# train_recall: tensor([0.7502, 0.8668, 0.8035, 0.7491], device='cuda:0')
# val_loss: 0.5515542343258858
# val_precision: tensor([0.7251, 0.8318, 0.7814, 0.7639], device='cuda:0')
# val_recall: tensor([0.7188, 0.8397, 0.7921, 0.6545], device='cuda:0')
# Learning rate: 5e-06
# epoch 27 time:  0.3235207783833175
# --------------------------------
# ========================================
# EPOCH: 28
# train_loss: 0.48216500892525627
# train_precision: tensor([0.7569, 0.8388, 0.8181, 0.7919], device='cuda:0')
# train_recall: tensor([0.7500, 0.8648, 0.8051, 0.7442], device='cuda:0')
# val_loss: 0.5538197719388538
# val_precision: tensor([0.7270, 0.8429, 0.7689, 0.7671], device='cuda:0')
# val_recall: tensor([0.7141, 0.8274, 0.8081, 0.6532], device='cuda:0')
# Learning rate: 5e-06
# epoch 28 time:  0.3247014858333083
# --------------------------------
# ========================================
# EPOCH: 29
# train_loss: 0.48232973707573756
# train_precision: tensor([0.7546, 0.8380, 0.8183, 0.7921], device='cuda:0')
# train_recall: tensor([0.7501, 0.8646, 0.8023, 0.7443], device='cuda:0')
# val_loss: 0.5531183889342679
# val_precision: tensor([0.7268, 0.8376, 0.7737, 0.7703], device='cuda:0')
# val_recall: tensor([0.7145, 0.8346, 0.8017, 0.6492], device='cuda:0')
# Learning rate: 5e-06
# epoch 29 time:  0.3239513795666729
# --------------------------------
# ========================================
# EPOCH: 30
# train_loss: 0.4821900363834131
# train_precision: tensor([0.7576, 0.8385, 0.8178, 0.7964], device='cuda:0')
# train_recall: tensor([0.7492, 0.8661, 0.8047, 0.7505], device='cuda:0')
# val_loss: 0.5497704996003046
# val_precision: tensor([0.7276, 0.8296, 0.7824, 0.7594], device='cuda:0')
# val_recall: tensor([0.7153, 0.8450, 0.7921, 0.6545], device='cuda:0')
# Learning rate: 5e-06
# epoch 30 time:  0.3420436932166619
# --------------------------------
# ========================================
# EPOCH: 31
# train_loss: 0.48110447831097103
# train_precision: tensor([0.7558, 0.8390, 0.8182, 0.7937], device='cuda:0')
# train_recall: tensor([0.7483, 0.8662, 0.8038, 0.7556], device='cuda:0')
# val_loss: 0.5522704051600562
# val_precision: tensor([0.7294, 0.8350, 0.7739, 0.7702], device='cuda:0')
# val_recall: tensor([0.7118, 0.8378, 0.8022, 0.6488], device='cuda:0')
# Learning rate: 5e-06
# epoch 31 time:  0.3242122349666715
# --------------------------------
# ========================================
# EPOCH: 32
# train_loss: 0.48126815259456635
# train_precision: tensor([0.7559, 0.8398, 0.8174, 0.7941], device='cuda:0')
# train_recall: tensor([0.7491, 0.8660, 0.8037, 0.7511], device='cuda:0')
# val_loss: 0.5531736757192347
# val_precision: tensor([0.7254, 0.8279, 0.7846, 0.7629], device='cuda:0')
# val_recall: tensor([0.7176, 0.8455, 0.7881, 0.6478], device='cuda:0')
# Learning rate: 5e-06
# epoch 32 time:  0.3236802018833259
# --------------------------------
# ========================================
# EPOCH: 33
# train_loss: 0.48120242768809907
# train_precision: tensor([0.7560, 0.8401, 0.8169, 0.7966], device='cuda:0')
# train_recall: tensor([0.7506, 0.8657, 0.8031, 0.7447], device='cuda:0')
# val_loss: 0.5523417433102925
# val_precision: tensor([0.7346, 0.8249, 0.7772, 0.7545], device='cuda:0')
# val_recall: tensor([0.7010, 0.8492, 0.7991, 0.6643], device='cuda:0')
# Learning rate: 5e-06
# epoch 33 time:  0.32427303363332005
# --------------------------------
# ========================================
# EPOCH: 34
# train_loss: 0.47982310585322835
# train_precision: tensor([0.7575, 0.8404, 0.8194, 0.7943], device='cuda:0')
# train_recall: tensor([0.7517, 0.8670, 0.8039, 0.7540], device='cuda:0')
# val_loss: 0.5529789406392309
# val_precision: tensor([0.7262, 0.8377, 0.7735, 0.7706], device='cuda:0')
# val_recall: tensor([0.7143, 0.8343, 0.8013, 0.6502], device='cuda:0')
# Learning rate: 5e-06
# epoch 34 time:  0.3241742453833467
# --------------------------------
# ========================================
# EPOCH: 35
# train_loss: 0.47940516603134925
# train_precision: tensor([0.7567, 0.8410, 0.8183, 0.7942], device='cuda:0')
# train_recall: tensor([0.7513, 0.8649, 0.8056, 0.7485], device='cuda:0')
# val_loss: 0.5493248314493232
# val_precision: tensor([0.7244, 0.8264, 0.7899, 0.7719], device='cuda:0')
# val_recall: tensor([0.7219, 0.8486, 0.7838, 0.6505], device='cuda:0')
# Learning rate: 5e-06
# epoch 35 time:  0.3446851914333517
# --------------------------------
# ========================================
# EPOCH: 36
# train_loss: 0.47886886209959073
# train_precision: tensor([0.7588, 0.8401, 0.8197, 0.7891], device='cuda:0')
# train_recall: tensor([0.7521, 0.8665, 0.8053, 0.7498], device='cuda:0')
# val_loss: 0.5528471089071698
# val_precision: tensor([0.7311, 0.8338, 0.7730, 0.7638], device='cuda:0')
# val_recall: tensor([0.7081, 0.8380, 0.8042, 0.6576], device='cuda:0')
# Learning rate: 5e-06
# epoch 36 time:  0.32972002420001445
# --------------------------------
# ========================================
# EPOCH: 37
# train_loss: 0.47913557961583136
# train_precision: tensor([0.7563, 0.8405, 0.8185, 0.7972], device='cuda:0')
# train_recall: tensor([0.7495, 0.8659, 0.8051, 0.7583], device='cuda:0')
# val_loss: 0.5536459708379374
# val_precision: tensor([0.7262, 0.8322, 0.7768, 0.7789], device='cuda:0')
# val_recall: tensor([0.7131, 0.8393, 0.7985, 0.6347], device='cuda:0')
# Learning rate: 5e-06
# epoch 37 time:  0.32753924854999544
# --------------------------------
# ========================================
# EPOCH: 38
# train_loss: 0.4784102481745538
# train_precision: tensor([0.7579, 0.8402, 0.8192, 0.7977], device='cuda:0')
# train_recall: tensor([0.7518, 0.8665, 0.8049, 0.7518], device='cuda:0')
# val_loss: 0.5535419751372602
# val_precision: tensor([0.7244, 0.8345, 0.7797, 0.7659], device='cuda:0')
# val_recall: tensor([0.7185, 0.8374, 0.7947, 0.6532], device='cuda:0')
# Learning rate: 5e-06
# epoch 38 time:  0.3257468965499963
# --------------------------------
# ========================================
# EPOCH: 39
# train_loss: 0.4790859484246799
# train_precision: tensor([0.7575, 0.8411, 0.8198, 0.7942], device='cuda:0')
# train_recall: tensor([0.7521, 0.8655, 0.8059, 0.7558], device='cuda:0')
# val_loss: 0.5534537283910645
# val_precision: tensor([0.7314, 0.8375, 0.7687, 0.7605], device='cuda:0')
# val_recall: tensor([0.7067, 0.8348, 0.8073, 0.6606], device='cuda:0')
# Learning rate: 5e-06
# epoch 39 time:  0.3234003890166908
# --------------------------------
# ========================================
# EPOCH: 40
# train_loss: 0.4771385486991633
# train_precision: tensor([0.7589, 0.8411, 0.8211, 0.7937], device='cuda:0')
# train_recall: tensor([0.7541, 0.8667, 0.8055, 0.7534], device='cuda:0')
# val_loss: 0.5525353199077977
# val_precision: tensor([0.7265, 0.8325, 0.7803, 0.7698], device='cuda:0')
# val_recall: tensor([0.7168, 0.8406, 0.7954, 0.6495], device='cuda:0')
# Learning rate: 5e-06
# epoch 40 time:  0.3220890371000072
# --------------------------------
# ========================================
# EPOCH: 41
# train_loss: 0.4776502061812651
# train_precision: tensor([0.7585, 0.8403, 0.8196, 0.7971], device='cuda:0')
# train_recall: tensor([0.7521, 0.8663, 0.8055, 0.7545], device='cuda:0')
# val_loss: 0.5543045427236292
# val_precision: tensor([0.7343, 0.8301, 0.7721, 0.7625], device='cuda:0')
# val_recall: tensor([0.7013, 0.8435, 0.8053, 0.6539], device='cuda:0')
# Learning rate: 5e-06
# epoch 41 time:  0.325995426916658
# --------------------------------
# ========================================
# EPOCH: 42
# train_loss: 0.4765329986101105
# train_precision: tensor([0.7580, 0.8422, 0.8208, 0.7984], device='cuda:0')
# train_recall: tensor([0.7533, 0.8670, 0.8060, 0.7564], device='cuda:0')
# val_loss: 0.5533648295534982
# val_precision: tensor([0.7255, 0.8346, 0.7790, 0.7721], device='cuda:0')
# val_recall: tensor([0.7180, 0.8379, 0.7962, 0.6512], device='cuda:0')
# Learning rate: 5e-06
# epoch 42 time:  0.3263323798833274
# --------------------------------
# ========================================
# EPOCH: 43
# train_loss: 0.4777369524751391
# train_precision: tensor([0.7588, 0.8412, 0.8195, 0.7946], device='cuda:0')
# train_recall: tensor([0.7516, 0.8676, 0.8059, 0.7515], device='cuda:0')
# val_loss: 0.5532789983683162
# val_precision: tensor([0.7292, 0.8342, 0.7740, 0.7657], device='cuda:0')
# val_recall: tensor([0.7091, 0.8394, 0.8017, 0.6559], device='cuda:0')
# Learning rate: 5e-06
# epoch 43 time:  0.3271199293333363
# --------------------------------
# ========================================
# EPOCH: 44
# train_loss: 0.4772637187370232
# train_precision: tensor([0.7585, 0.8409, 0.8195, 0.7944], device='cuda:0')
# train_recall: tensor([0.7521, 0.8672, 0.8047, 0.7566], device='cuda:0')
# val_loss: 0.5553013728724585
# val_precision: tensor([0.7313, 0.8327, 0.7744, 0.7605], device='cuda:0')
# val_recall: tensor([0.7081, 0.8413, 0.8016, 0.6566], device='cuda:0')
# Learning rate: 5e-06
# epoch 44 time:  0.32105862588332457
# --------------------------------
# ========================================
# EPOCH: 45
# train_loss: 0.47564273643351734
# train_precision: tensor([0.7593, 0.8408, 0.8207, 0.7940], device='cuda:0')
# train_recall: tensor([0.7534, 0.8671, 0.8057, 0.7509], device='cuda:0')
# val_loss: 0.555193807101912
# val_precision: tensor([0.7322, 0.8322, 0.7737, 0.7638], device='cuda:0')
# val_recall: tensor([0.7073, 0.8409, 0.8033, 0.6522], device='cuda:0')
# Learning rate: 5e-06
# Early stopping at epoch 45 with best validation loss 0.5493248314493232
# training_checkpoints/resnet18_2024-04-21 01:59:31.428721.pth
# <All keys matched successfully>

# %%
from sklearn.metrics import confusion_matrix, classification_report
from torch.utils.data import DataLoader
import numpy as np
import torch 
from torchvision.models import resnet18
import torch.nn as nn


def test_report(model, dataloader):
    """Prints confusion matrix for testing dataset
    dataloader should be of batch_size=1."""

    y_pred = []
    y_test = []
    model.eval()
    with torch.no_grad():
        for data, label in dataloader:
            output = model(data)
            label = label.numpy()
            output = output.numpy()
            y_pred.append(np.argmax(output))
            y_test.append(np.argmax(label))
        print(confusion_matrix(y_test, y_pred))
        print(classification_report(y_test, y_pred))

testset =ImageDataset(data_path='test_data')
dataloader = DataLoader(testset, batch_size=1, shuffle=True)

test_report(my_model.to('cpu'), dataloader)
# Out:
# [[733  97 164   6]
#  [ 97 853  44   6]
#  [155  45 794   6]
#  [ 18   8   6  68]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73      1000
#            1       0.85      0.85      0.85      1000
#            2       0.79      0.79      0.79      1000
#            3       0.79      0.68      0.73       100
#
#     accuracy                           0.79      3100
#    macro avg       0.79      0.77      0.78      3100
# weighted avg       0.79      0.79      0.79      3100

# %%
print(f'{run_path}.pth')
# Out:
# training_checkpoints/resnet18_2024-04-21 01:59:31.428721.pth

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Define the confusion matrix
confusion_matrix = np.array([
    [733,  97, 164,   6],
    [ 97, 853,  44,   6],
    [155,  45, 794,   6],
    [ 18,   8,   6,  68]
])

# Create a heatmap with annotations
labels = ['normal', 'inflammatory', 'tumor', 'other']

# Create a heatmap with larger text annotations and axis labels
plt.figure(figsize=(10, 7))
ax = sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='Blues',
                 cbar=True, square=True, linewidths=0.5, linecolor='black',
                 annot_kws={"size": 14},  # Increase text size here
                 xticklabels=labels,  # Set x-axis labels
                 yticklabels=labels)  # Set y-axis labels
# Set labels and title
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Resnet-18')

# Show the plot
plt.show()
