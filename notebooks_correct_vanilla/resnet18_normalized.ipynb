# %%
import time
import sys
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from dataset import ImageDataset
import torch.nn.functional as F
from torchmetrics import Precision, Recall
from torchvision.models import resnet18
import warnings
from collections import defaultdict
import wandb
import datetime
import os
warnings.filterwarnings('ignore')
torch.set_float32_matmul_precision('high')
#intecubic interpol

run_name = f'resnet18_normalize_batch_2048_test{datetime.datetime.now()}'
run_path = f'training_checkpoints/{run_name}'

wandb.init(project="cells", 
           entity="adamsoja",
          name=run_name)

import random
random.seed(2233)
torch.manual_seed(2233)

#After /255 so in loading dataset there are no division by 255 just this normalization
mean = [0.5006, 0.3526, 0.5495]
std = [0.1493, 0.1341, 0.1124]


from albumentations import (
    Compose,
    Resize,
    OneOf,
    RandomBrightness,
    RandomContrast,
    MotionBlur,
    MedianBlur,
    GaussianBlur,
    VerticalFlip,
    HorizontalFlip,
    ShiftScaleRotate,
    Normalize,
)

transform = Compose(
    [
        Normalize(mean=mean, std=std),
        OneOf([RandomBrightness(limit=0.4, p=1), RandomContrast(limit=0.4, p=0.8)]),
        OneOf([MotionBlur(blur_limit=3), MedianBlur(blur_limit=3), GaussianBlur(blur_limit=3),], p=0.7,),
        VerticalFlip(p=0.5),
        HorizontalFlip(p=0.5),
    ]
)

transform_test = Compose(
    [Normalize(mean=mean, std=std)]
)

class MyModel(nn.Module):
    def __init__(self, model, learning_rate, weight_decay):
        super(MyModel, self).__init__()
        self.model = model
        self.learning_rate = learning_rate
        self.weight_decay = weight_decay
        self.criterion = nn.CrossEntropyLoss()
        self.metric_precision = Precision(task="multiclass", num_classes=4, average=None).to('cuda')
        self.metric_recall = Recall(task="multiclass", num_classes=4, average=None).to('cuda')
        self.train_loss = []
        self.valid_loss = []
        self.precision_per_epochs = []
        self.recall_per_epochs = []

        self.optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, mode="min", factor=0.05, patience=2, min_lr=5e-6, verbose=True)
        self.step = 0

    
    def forward(self, x):
        return self.model(x)

    def train_one_epoch(self, trainloader):
        self.step += 1
        self.train()
        for batch_idx, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()
            _, preds = torch.max(outputs, 1)
            _, labels = torch.max(labels, 1)
            self.metric_precision(preds, labels)
            self.metric_recall(preds, labels)
            self.train_loss.append(loss.item())


        

        
        avg_loss = np.mean(self.train_loss)
        self.train_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        self.precision_per_epochs.append(precision)
        self.recall_per_epochs.append(recall)
        print(f'train_loss: {avg_loss}')
        print(f'train_precision: {precision}')
        print(f'train_recall: {recall}')

        wandb.log({'loss': avg_loss},step=self.step)
        wandb.log({'Normal precision': precision[0].item()},step=self.step)
        wandb.log({'Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'Other precision': precision[3].item()},step=self.step)


        wandb.log({'Normal recall': recall[0].item()},step=self.step)
        wandb.log({'Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'Other recall': recall[3].item()},step=self.step)
        
        
        self.metric_precision.reset()
        self.metric_recall.reset()


    

    def evaluate(self, testloader):
        self.eval()
        with torch.no_grad():
            for batch_idx, (inputs, labels) in enumerate(testloader):
                inputs, labels = inputs.to('cuda'), labels.to('cuda')
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)
                _, labels = torch.max(labels, 1)
                self.metric_precision(preds, labels)
                self.metric_recall(preds, labels)
                self.valid_loss.append(loss.item())
    
        avg_loss = np.mean(self.valid_loss)
        self.scheduler.step(avg_loss)
        self.valid_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        print(f'val_loss: {avg_loss}')
        print(f'val_precision: {precision}')
        print(f'val_recall: {recall}')
        self.metric_precision.reset()
        self.metric_recall.reset()

        wandb.log({'val_loss': avg_loss}, step=self.step)
        
        wandb.log({'val_Normal precision': precision[0].item()},step=self.step)
        wandb.log({'val_Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'val_Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'val_Other precision': precision[3].item()},step=self.step)


        wandb.log({'val_Normal recall': recall[0].item()},step=self.step)
        wandb.log({'val_Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'val_Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'val_Other recall': recall[3].item()},step=self.step)


        for param_group in self.optimizer.param_groups:
            print(f"Learning rate: {param_group['lr']}")
        return avg_loss

torch.cuda.empty_cache()
batch_size = 2048

trainset = ImageDataset(data_path='train_data', transform=transform)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=3)

testset = ImageDataset(data_path='validation_data', transform=transform_test)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)


learning_rate = 0.001
weight_decay = 0.00005

model = resnet18()
model.conv1 = nn.Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
num_classes = 4
model.fc = nn.Sequential(
    nn.Dropout(0.4),
    nn.Linear(model.fc.in_features, num_classes))
model = model.to('cuda')


my_model = MyModel(model=model, learning_rate=learning_rate, weight_decay=weight_decay)
my_model = my_model.to('cuda')

num_epochs = 100
early_stop_patience = 10
best_val_loss = float('inf')
best_model_state_dict = None

for epoch in range(num_epochs):
    print('========================================')
    print(f'EPOCH: {epoch}') 
    time_start = time.perf_counter()
    my_model.train_one_epoch(trainloader)
    val_loss = my_model.evaluate(testloader)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_state_dict = my_model.state_dict()
        torch.save(best_model_state_dict, f'{run_path}.pth')
        
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch} with best validation loss {best_val_loss}")
        break
    time_epoch = time.perf_counter() - time_start
    print(f'epoch {epoch} time:  {time_epoch/60}')
    print('--------------------------------')

# Load the best model state dict
print(f'{run_path}.pth')
my_model.load_state_dict(torch.load(f'{run_path}.pth'))
# Out:
# wandb: Currently logged in as: adamsoja. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/adam/Desktop/cells_master_thesis/wandb/run-20240424_232610-a33607uw</code>
# Syncing run <strong><a href='https://wandb.ai/adamsoja/cells/runs/a33607uw' target="_blank">resnet18_normalize_batch_2048_test2024-04-24 23:26:09.129372</a></strong> to <a href='https://wandb.ai/adamsoja/cells' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adamsoja/cells' target="_blank">https://wandb.ai/adamsoja/cells</a>
#  View run at <a href='https://wandb.ai/adamsoja/cells/runs/a33607uw' target="_blank">https://wandb.ai/adamsoja/cells/runs/a33607uw</a>
# ========================================
# EPOCH: 0
# train_loss: 0.9864978733516875
# train_precision: tensor([0.5243, 0.6282, 0.6074, 0.3214], device='cuda:0')
# train_recall: tensor([0.5160, 0.7227, 0.5831, 0.0182], device='cuda:0')
# val_loss: 0.805979131327735
# val_precision: tensor([0.5977, 0.7827, 0.6432, 0.6732], device='cuda:0')
# val_recall: tensor([0.6000, 0.7054, 0.7532, 0.1616], device='cuda:0')
# Learning rate: 0.001
# epoch 0 time:  0.36676220436665974
# --------------------------------
# ========================================
# EPOCH: 1
# train_loss: 0.8286207948412214
# train_precision: tensor([0.5933, 0.6932, 0.6688, 0.5440], device='cuda:0')
# train_recall: tensor([0.5800, 0.7727, 0.6597, 0.1167], device='cuda:0')
# val_loss: 0.8164587239424388
# val_precision: tensor([0.6979, 0.7850, 0.5678, 0.3735], device='cuda:0')
# val_recall: tensor([0.4086, 0.7066, 0.8679, 0.3202], device='cuda:0')
# Learning rate: 0.001
# epoch 1 time:  0.3598358648333336
# --------------------------------
# ========================================
# EPOCH: 2
# train_loss: 0.791736224151793
# train_precision: tensor([0.6166, 0.7093, 0.6803, 0.5546], device='cuda:0')
# train_recall: tensor([0.5924, 0.7835, 0.6772, 0.2176], device='cuda:0')
# val_loss: 0.7397298508220249
# val_precision: tensor([0.7090, 0.7369, 0.6681, 0.4962], device='cuda:0')
# val_recall: tensor([0.5056, 0.8286, 0.7874, 0.4165], device='cuda:0')
# Learning rate: 0.001
# epoch 2 time:  0.38284226014999756
# --------------------------------
# ========================================
# EPOCH: 3
# train_loss: 0.7685000709124974
# train_precision: tensor([0.6308, 0.7180, 0.6918, 0.5785], device='cuda:0')
# train_recall: tensor([0.6024, 0.7901, 0.6924, 0.2530], device='cuda:0')
# val_loss: 0.6999612861209445
# val_precision: tensor([0.6649, 0.7779, 0.6905, 0.8053], device='cuda:0')
# val_recall: tensor([0.6300, 0.7798, 0.7696, 0.2855], device='cuda:0')
# Learning rate: 0.001
# epoch 3 time:  0.3912245086666644
# --------------------------------
# ========================================
# EPOCH: 4
# train_loss: 0.7485857986268543
# train_precision: tensor([0.6404, 0.7251, 0.6984, 0.6020], device='cuda:0')
# train_recall: tensor([0.6105, 0.7946, 0.6995, 0.2955], device='cuda:0')
# val_loss: 0.77006536854638
# val_precision: tensor([0.7488, 0.7569, 0.6200, 0.4093], device='cuda:0')
# val_recall: tensor([0.4278, 0.7937, 0.8476, 0.4620], device='cuda:0')
# Learning rate: 0.001
# epoch 4 time:  0.36933763160000127
# --------------------------------
# ========================================
# EPOCH: 5
# train_loss: 0.7364897222745986
# train_precision: tensor([0.6460, 0.7276, 0.7035, 0.6106], device='cuda:0')
# train_recall: tensor([0.6143, 0.7990, 0.7041, 0.3056], device='cuda:0')
# val_loss: 0.6994622568289439
# val_precision: tensor([0.7221, 0.7040, 0.7151, 0.7597], device='cuda:0')
# val_recall: tensor([0.5524, 0.8734, 0.7464, 0.3842], device='cuda:0')
# Learning rate: 0.001
# epoch 5 time:  0.38548247506666183
# --------------------------------
# ========================================
# EPOCH: 6
# train_loss: 0.7244102614266532
# train_precision: tensor([0.6502, 0.7351, 0.7121, 0.6263], device='cuda:0')
# train_recall: tensor([0.6250, 0.8008, 0.7096, 0.3310], device='cuda:0')
# val_loss: 0.6500629001193576
# val_precision: tensor([0.6654, 0.8095, 0.7335, 0.7012], device='cuda:0')
# val_recall: tensor([0.6763, 0.7714, 0.7832, 0.4401], device='cuda:0')
# Learning rate: 0.001
# epoch 6 time:  0.3871452202166589
# --------------------------------
# ========================================
# EPOCH: 7
# train_loss: 0.7175603599775405
# train_precision: tensor([0.6559, 0.7371, 0.7145, 0.6279], device='cuda:0')
# train_recall: tensor([0.6257, 0.8040, 0.7147, 0.3446], device='cuda:0')
# val_loss: 0.662699857685301
# val_precision: tensor([0.7130, 0.7504, 0.7442, 0.5235], device='cuda:0')
# val_recall: tensor([0.6146, 0.8439, 0.7487, 0.5620], device='cuda:0')
# Learning rate: 0.001
# epoch 7 time:  0.3612603086999873
# --------------------------------
# ========================================
# EPOCH: 8
# train_loss: 0.7053632151512873
# train_precision: tensor([0.6618, 0.7416, 0.7202, 0.6428], device='cuda:0')
# train_recall: tensor([0.6335, 0.8075, 0.7184, 0.3625], device='cuda:0')
# val_loss: 0.6432658857769437
# val_precision: tensor([0.6988, 0.7808, 0.7332, 0.7745], device='cuda:0')
# val_recall: tensor([0.6430, 0.8312, 0.7796, 0.4024], device='cuda:0')
# Learning rate: 0.001
# epoch 8 time:  0.3833359431666698
# --------------------------------
# ========================================
# EPOCH: 9
# train_loss: 0.6958033181372143
# train_precision: tensor([0.6661, 0.7452, 0.7223, 0.6401], device='cuda:0')
# train_recall: tensor([0.6377, 0.8063, 0.7235, 0.3778], device='cuda:0')
# val_loss: 0.6345910787582397
# val_precision: tensor([0.7114, 0.7798, 0.7348, 0.6217], device='cuda:0')
# val_recall: tensor([0.6291, 0.8271, 0.7841, 0.5461], device='cuda:0')
# Learning rate: 0.001
# epoch 9 time:  0.3876038140999905
# --------------------------------
# ========================================
# EPOCH: 10
# train_loss: 0.6880039169674828
# train_precision: tensor([0.6713, 0.7486, 0.7288, 0.6467], device='cuda:0')
# train_recall: tensor([0.6443, 0.8112, 0.7257, 0.3938], device='cuda:0')
# val_loss: 0.6338431066936917
# val_precision: tensor([0.7162, 0.7976, 0.7224, 0.5703], device='cuda:0')
# val_recall: tensor([0.6141, 0.8197, 0.8020, 0.5966], device='cuda:0')
# Learning rate: 0.001
# epoch 10 time:  0.38171157704999437
# --------------------------------
# ========================================
# EPOCH: 11
# train_loss: 0.6823652494521368
# train_precision: tensor([0.6730, 0.7506, 0.7284, 0.6550], device='cuda:0')
# train_recall: tensor([0.6433, 0.8123, 0.7273, 0.4169], device='cuda:0')
# val_loss: 0.6513787766297658
# val_precision: tensor([0.7238, 0.8072, 0.6916, 0.6569], device='cuda:0')
# val_recall: tensor([0.6029, 0.7972, 0.8347, 0.4758], device='cuda:0')
# Learning rate: 0.001
# epoch 11 time:  0.3656834655500158
# --------------------------------
# ========================================
# EPOCH: 12
# train_loss: 0.6760801457223438
# train_precision: tensor([0.6762, 0.7549, 0.7322, 0.6508], device='cuda:0')
# train_recall: tensor([0.6506, 0.8130, 0.7303, 0.4131], device='cuda:0')
# val_loss: 0.6123628285196092
# val_precision: tensor([0.7102, 0.7535, 0.7885, 0.7592], device='cuda:0')
# val_recall: tensor([0.6727, 0.8727, 0.7325, 0.4990], device='cuda:0')
# Learning rate: 0.001
# epoch 12 time:  0.3806893549666711
# --------------------------------
# ========================================
# EPOCH: 13
# train_loss: 0.6671919215293157
# train_precision: tensor([0.6812, 0.7578, 0.7389, 0.6641], device='cuda:0')
# train_recall: tensor([0.6569, 0.8159, 0.7337, 0.4403], device='cuda:0')
# val_loss: 0.6160538501209682
# val_precision: tensor([0.7183, 0.7936, 0.7491, 0.6416], device='cuda:0')
# val_recall: tensor([0.6707, 0.8233, 0.7768, 0.5896], device='cuda:0')
# Learning rate: 0.001
# epoch 13 time:  0.3593373366999913
# --------------------------------
# ========================================
# EPOCH: 14
# train_loss: 0.6630329682713463
# train_precision: tensor([0.6801, 0.7603, 0.7371, 0.6629], device='cuda:0')
# train_recall: tensor([0.6597, 0.8147, 0.7320, 0.4328], device='cuda:0')
# val_loss: 0.60815576116244
# val_precision: tensor([0.7233, 0.7872, 0.7496, 0.7364], device='cuda:0')
# val_recall: tensor([0.6587, 0.8425, 0.7878, 0.5013], device='cuda:0')
# Learning rate: 0.001
# epoch 14 time:  0.38065999595000904
# --------------------------------
# ========================================
# EPOCH: 15
# train_loss: 0.6542788363638379
# train_precision: tensor([0.6877, 0.7638, 0.7403, 0.6706], device='cuda:0')
# train_recall: tensor([0.6623, 0.8174, 0.7396, 0.4547], device='cuda:0')
# val_loss: 0.6113787829875946
# val_precision: tensor([0.7090, 0.8318, 0.7286, 0.6984], device='cuda:0')
# val_recall: tensor([0.6802, 0.7867, 0.8148, 0.5333], device='cuda:0')
# Learning rate: 0.001
# epoch 15 time:  0.36059115891666804
# --------------------------------
# ========================================
# EPOCH: 16
# train_loss: 0.6495991065388634
# train_precision: tensor([0.6861, 0.7651, 0.7449, 0.6718], device='cuda:0')
# train_recall: tensor([0.6668, 0.8183, 0.7370, 0.4655], device='cuda:0')
# val_loss: 0.6039487328794267
# val_precision: tensor([0.7155, 0.8077, 0.7489, 0.7235], device='cuda:0')
# val_recall: tensor([0.6723, 0.8270, 0.7977, 0.5155], device='cuda:0')
# Learning rate: 0.001
# epoch 16 time:  0.383447570983329
# --------------------------------
# ========================================
# EPOCH: 17
# train_loss: 0.6434541242463249
# train_precision: tensor([0.6910, 0.7678, 0.7462, 0.6686], device='cuda:0')
# train_recall: tensor([0.6701, 0.8185, 0.7419, 0.4684], device='cuda:0')
# val_loss: 0.5932671937677595
# val_precision: tensor([0.7029, 0.7894, 0.7877, 0.8061], device='cuda:0')
# val_recall: tensor([0.7059, 0.8438, 0.7620, 0.4788], device='cuda:0')
# Learning rate: 0.001
# epoch 17 time:  0.37967984451664355
# --------------------------------
# ========================================
# EPOCH: 18
# train_loss: 0.639647935117994
# train_precision: tensor([0.6940, 0.7672, 0.7493, 0.6783], device='cuda:0')
# train_recall: tensor([0.6697, 0.8221, 0.7437, 0.4812], device='cuda:0')
# val_loss: 0.6404638879828983
# val_precision: tensor([0.6978, 0.8329, 0.7054, 0.7087], device='cuda:0')
# val_recall: tensor([0.6941, 0.7370, 0.8068, 0.5431], device='cuda:0')
# Learning rate: 0.001
# epoch 18 time:  0.3594714552333547
# --------------------------------
# ========================================
# EPOCH: 19
# train_loss: 0.6360994480905079
# train_precision: tensor([0.6948, 0.7687, 0.7501, 0.6870], device='cuda:0')
# train_recall: tensor([0.6735, 0.8236, 0.7408, 0.4932], device='cuda:0')
# val_loss: 0.6065693491035038
# val_precision: tensor([0.7523, 0.7547, 0.7640, 0.7698], device='cuda:0')
# val_recall: tensor([0.6311, 0.8864, 0.7809, 0.4966], device='cuda:0')
# Learning rate: 0.001
# epoch 19 time:  0.36179296344998874
# --------------------------------
# ========================================
# EPOCH: 20
# train_loss: 0.628671213558742
# train_precision: tensor([0.6975, 0.7737, 0.7536, 0.6878], device='cuda:0')
# train_recall: tensor([0.6771, 0.8244, 0.7473, 0.4970], device='cuda:0')
# val_loss: 0.5744306299421522
# val_precision: tensor([0.7389, 0.7910, 0.7735, 0.7213], device='cuda:0')
# val_recall: tensor([0.6714, 0.8621, 0.7882, 0.5943], device='cuda:0')
# Learning rate: 0.001
# epoch 20 time:  0.3835427650999918
# --------------------------------
# ========================================
# EPOCH: 21
# train_loss: 0.6218329571542286
# train_precision: tensor([0.7025, 0.7737, 0.7564, 0.6848], device='cuda:0')
# train_recall: tensor([0.6803, 0.8256, 0.7487, 0.5110], device='cuda:0')
# val_loss: 0.5984058015876346
# val_precision: tensor([0.7363, 0.7790, 0.7588, 0.7264], device='cuda:0')
# val_recall: tensor([0.6628, 0.8538, 0.7813, 0.5380], device='cuda:0')
# Learning rate: 0.001
# epoch 21 time:  0.369255238033323
# --------------------------------
# ========================================
# EPOCH: 22
# train_loss: 0.6182439571335202
# train_precision: tensor([0.7054, 0.7750, 0.7598, 0.6839], device='cuda:0')
# train_recall: tensor([0.6837, 0.8279, 0.7500, 0.5160], device='cuda:0')
# val_loss: 0.5886765294604831
# val_precision: tensor([0.7173, 0.7688, 0.8046, 0.6999], device='cuda:0')
# val_recall: tensor([0.7030, 0.8669, 0.7301, 0.5929], device='cuda:0')
# Learning rate: 0.001
# epoch 22 time:  0.37056818064999486
# --------------------------------
# ========================================
# EPOCH: 23
# train_loss: 0.6114947863987514
# train_precision: tensor([0.7067, 0.7778, 0.7623, 0.6919], device='cuda:0')
# train_recall: tensor([0.6867, 0.8284, 0.7526, 0.5266], device='cuda:0')
# val_loss: 0.583428172270457
# val_precision: tensor([0.6982, 0.8414, 0.7668, 0.6833], device='cuda:0')
# val_recall: tensor([0.7275, 0.7878, 0.7897, 0.6276], device='cuda:0')
# Learning rate: 5e-05
# epoch 23 time:  0.3708727147333472
# --------------------------------
# ========================================
# EPOCH: 24
# train_loss: 0.5797402472723098
# train_precision: tensor([0.7271, 0.7898, 0.7704, 0.7222], device='cuda:0')
# train_recall: tensor([0.6957, 0.8369, 0.7734, 0.5753], device='cuda:0')
# val_loss: 0.5427994476424323
# val_precision: tensor([0.7415, 0.8348, 0.7713, 0.7509], device='cuda:0')
# val_recall: tensor([0.7107, 0.8308, 0.8207, 0.6182], device='cuda:0')
# Learning rate: 5e-05
# epoch 24 time:  0.3876409421000062
# --------------------------------
# ========================================
# EPOCH: 25
# train_loss: 0.5659531667118981
# train_precision: tensor([0.7310, 0.7952, 0.7795, 0.7495], device='cuda:0')
# train_recall: tensor([0.7076, 0.8411, 0.7755, 0.5970], device='cuda:0')
# val_loss: 0.5389616423183017
# val_precision: tensor([0.7397, 0.8297, 0.7841, 0.7467], device='cuda:0')
# val_recall: tensor([0.7183, 0.8401, 0.8085, 0.6364], device='cuda:0')
# Learning rate: 5e-05
# epoch 25 time:  0.3807013319499977
# --------------------------------
# ========================================
# EPOCH: 26
# train_loss: 0.5573057027090164
# train_precision: tensor([0.7362, 0.7989, 0.7815, 0.7422], device='cuda:0')
# train_recall: tensor([0.7119, 0.8425, 0.7781, 0.6149], device='cuda:0')
# val_loss: 0.5413064989778731
# val_precision: tensor([0.7388, 0.8363, 0.7777, 0.7460], device='cuda:0')
# val_recall: tensor([0.7217, 0.8298, 0.8135, 0.6330], device='cuda:0')
# Learning rate: 5e-05
# epoch 26 time:  0.36706019361666525
# --------------------------------
# ========================================
# EPOCH: 27
# train_loss: 0.5549826724188668
# train_precision: tensor([0.7365, 0.7994, 0.7869, 0.7420], device='cuda:0')
# train_recall: tensor([0.7159, 0.8452, 0.7776, 0.6120], device='cuda:0')
# val_loss: 0.5378566794925266
# val_precision: tensor([0.7458, 0.8233, 0.7859, 0.7570], device='cuda:0')
# val_recall: tensor([0.7138, 0.8478, 0.8089, 0.6347], device='cuda:0')
# Learning rate: 5e-05
# epoch 27 time:  0.3833955711666628
# --------------------------------
# ========================================
# EPOCH: 28
# train_loss: 0.5518228757949103
# train_precision: tensor([0.7373, 0.7998, 0.7881, 0.7425], device='cuda:0')
# train_recall: tensor([0.7178, 0.8446, 0.7780, 0.6175], device='cuda:0')
# val_loss: 0.5390974594487085
# val_precision: tensor([0.7370, 0.8392, 0.7790, 0.7343], device='cuda:0')
# val_recall: tensor([0.7246, 0.8272, 0.8126, 0.6458], device='cuda:0')
# Learning rate: 5e-05
# epoch 28 time:  0.36427472341665634
# --------------------------------
# ========================================
# EPOCH: 29
# train_loss: 0.5471869284198397
# train_precision: tensor([0.7397, 0.8028, 0.7886, 0.7479], device='cuda:0')
# train_recall: tensor([0.7194, 0.8458, 0.7806, 0.6281], device='cuda:0')
# val_loss: 0.5415324906508128
# val_precision: tensor([0.7465, 0.8363, 0.7710, 0.7638], device='cuda:0')
# val_recall: tensor([0.7106, 0.8330, 0.8245, 0.6316], device='cuda:0')
# Learning rate: 5e-05
# epoch 29 time:  0.3631113186833318
# --------------------------------
# ========================================
# EPOCH: 30
# train_loss: 0.5445407793635414
# train_precision: tensor([0.7416, 0.8022, 0.7910, 0.7504], device='cuda:0')
# train_recall: tensor([0.7208, 0.8475, 0.7813, 0.6294], device='cuda:0')
# val_loss: 0.5366143948502011
# val_precision: tensor([0.7373, 0.8319, 0.7879, 0.7501], device='cuda:0')
# val_recall: tensor([0.7238, 0.8391, 0.8057, 0.6529], device='cuda:0')
# Learning rate: 5e-05
# epoch 30 time:  0.37832261606666484
# --------------------------------
# ========================================
# EPOCH: 31
# train_loss: 0.5427229461215791
# train_precision: tensor([0.7400, 0.8048, 0.7893, 0.7553], device='cuda:0')
# train_recall: tensor([0.7224, 0.8455, 0.7807, 0.6348], device='cuda:0')
# val_loss: 0.5362600021892123
# val_precision: tensor([0.7433, 0.8248, 0.7917, 0.7577], device='cuda:0')
# val_recall: tensor([0.7198, 0.8499, 0.8050, 0.6401], device='cuda:0')
# Learning rate: 5e-05
# epoch 31 time:  0.3804916015000041
# --------------------------------
# ========================================
# EPOCH: 32
# train_loss: 0.5394630029087975
# train_precision: tensor([0.7421, 0.8055, 0.7916, 0.7486], device='cuda:0')
# train_recall: tensor([0.7246, 0.8470, 0.7812, 0.6377], device='cuda:0')
# val_loss: 0.5395782523685031
# val_precision: tensor([0.7513, 0.8247, 0.7839, 0.7593], device='cuda:0')
# val_recall: tensor([0.7113, 0.8490, 0.8156, 0.6330], device='cuda:0')
# Learning rate: 5e-05
# epoch 32 time:  0.36597591795001183
# --------------------------------
# ========================================
# EPOCH: 33
# train_loss: 0.5384175726345607
# train_precision: tensor([0.7432, 0.8053, 0.7922, 0.7561], device='cuda:0')
# train_recall: tensor([0.7244, 0.8470, 0.7839, 0.6355], device='cuda:0')
# val_loss: 0.534441469113032
# val_precision: tensor([0.7395, 0.8249, 0.7960, 0.7543], device='cuda:0')
# val_recall: tensor([0.7274, 0.8464, 0.7992, 0.6502], device='cuda:0')
# Learning rate: 5e-05
# epoch 33 time:  0.38171966784999917
# --------------------------------
# ========================================
# EPOCH: 34
# train_loss: 0.5339509444577354
# train_precision: tensor([0.7454, 0.8067, 0.7945, 0.7582], device='cuda:0')
# train_recall: tensor([0.7266, 0.8488, 0.7842, 0.6519], device='cuda:0')
# val_loss: 0.5414266533321804
# val_precision: tensor([0.7390, 0.8394, 0.7760, 0.7643], device='cuda:0')
# val_recall: tensor([0.7216, 0.8280, 0.8194, 0.6202], device='cuda:0')
# Learning rate: 5e-05
# epoch 34 time:  0.36279470804999314
# --------------------------------
# ========================================
# EPOCH: 35
# train_loss: 0.5320959431784493
# train_precision: tensor([0.7472, 0.8079, 0.7937, 0.7620], device='cuda:0')
# train_recall: tensor([0.7289, 0.8477, 0.7852, 0.6537], device='cuda:0')
# val_loss: 0.5392097996340858
# val_precision: tensor([0.7406, 0.8302, 0.7882, 0.7525], device='cuda:0')
# val_recall: tensor([0.7257, 0.8391, 0.8067, 0.6471], device='cuda:0')
# Learning rate: 5e-05
# epoch 35 time:  0.3635266926666494
# --------------------------------
# ========================================
# EPOCH: 36
# train_loss: 0.5290509564535958
# train_precision: tensor([0.7474, 0.8090, 0.7969, 0.7613], device='cuda:0')
# train_recall: tensor([0.7307, 0.8499, 0.7846, 0.6633], device='cuda:0')
# val_loss: 0.5404219991630979
# val_precision: tensor([0.7485, 0.8247, 0.7845, 0.7566], device='cuda:0')
# val_recall: tensor([0.7132, 0.8467, 0.8125, 0.6414], device='cuda:0')
# Learning rate: 5e-06
# epoch 36 time:  0.3640956607833383
# --------------------------------
# ========================================
# EPOCH: 37
# train_loss: 0.5264187560195015
# train_precision: tensor([0.7489, 0.8097, 0.7975, 0.7662], device='cuda:0')
# train_recall: tensor([0.7317, 0.8506, 0.7869, 0.6567], device='cuda:0')
# val_loss: 0.5380845771895515
# val_precision: tensor([0.7426, 0.8305, 0.7887, 0.7573], device='cuda:0')
# val_recall: tensor([0.7250, 0.8412, 0.8095, 0.6387], device='cuda:0')
# Learning rate: 5e-06
# epoch 37 time:  0.3581409362333337
# --------------------------------
# ========================================
# EPOCH: 38
# train_loss: 0.5266387317861829
# train_precision: tensor([0.7490, 0.8088, 0.7963, 0.7604], device='cuda:0')
# train_recall: tensor([0.7310, 0.8502, 0.7852, 0.6597], device='cuda:0')
# val_loss: 0.53814630707105
# val_precision: tensor([0.7432, 0.8299, 0.7882, 0.7574], device='cuda:0')
# val_recall: tensor([0.7242, 0.8416, 0.8099, 0.6360], device='cuda:0')
# Learning rate: 5e-06
# epoch 38 time:  0.36397316174998195
# --------------------------------
# ========================================
# EPOCH: 39
# train_loss: 0.5243390778700511
# train_precision: tensor([0.7508, 0.8121, 0.7991, 0.7622], device='cuda:0')
# train_recall: tensor([0.7339, 0.8511, 0.7888, 0.6646], device='cuda:0')
# val_loss: 0.5385931246810489
# val_precision: tensor([0.7433, 0.8347, 0.7850, 0.7520], device='cuda:0')
# val_recall: tensor([0.7252, 0.8367, 0.8136, 0.6431], device='cuda:0')
# Learning rate: 5e-06
# epoch 39 time:  0.36530474585000167
# --------------------------------
# ========================================
# EPOCH: 40
# train_loss: 0.5245615436917259
# train_precision: tensor([0.7508, 0.8102, 0.7989, 0.7653], device='cuda:0')
# train_recall: tensor([0.7328, 0.8532, 0.7866, 0.6605], device='cuda:0')
# val_loss: 0.5384262939294179
# val_precision: tensor([0.7439, 0.8303, 0.7886, 0.7561], device='cuda:0')
# val_recall: tensor([0.7241, 0.8421, 0.8101, 0.6441], device='cuda:0')
# Learning rate: 5e-06
# epoch 40 time:  0.3671218172833505
# --------------------------------
# ========================================
# EPOCH: 41
# train_loss: 0.5226419457367488
# train_precision: tensor([0.7532, 0.8108, 0.7986, 0.7616], device='cuda:0')
# train_recall: tensor([0.7326, 0.8519, 0.7906, 0.6610], device='cuda:0')
# val_loss: 0.5383307092719608
# val_precision: tensor([0.7410, 0.8338, 0.7875, 0.7546], device='cuda:0')
# val_recall: tensor([0.7269, 0.8379, 0.8103, 0.6431], device='cuda:0')
# Learning rate: 5e-06
# epoch 41 time:  0.36089548863331705
# --------------------------------
# ========================================
# EPOCH: 42
# train_loss: 0.522691166684741
# train_precision: tensor([0.7526, 0.8114, 0.7983, 0.7641], device='cuda:0')
# train_recall: tensor([0.7332, 0.8518, 0.7902, 0.6584], device='cuda:0')
# val_loss: 0.5387460947036743
# val_precision: tensor([0.7451, 0.8307, 0.7872, 0.7592], device='cuda:0')
# val_recall: tensor([0.7223, 0.8422, 0.8120, 0.6475], device='cuda:0')
# Learning rate: 5e-06
# epoch 42 time:  0.36021596679999374
# --------------------------------
# ========================================
# EPOCH: 43
# train_loss: 0.520949611777351
# train_precision: tensor([0.7519, 0.8113, 0.7996, 0.7653], device='cuda:0')
# train_recall: tensor([0.7342, 0.8533, 0.7878, 0.6622], device='cuda:0')
# val_loss: 0.5384334491358863
# val_precision: tensor([0.7436, 0.8322, 0.7878, 0.7525], device='cuda:0')
# val_recall: tensor([0.7246, 0.8402, 0.8110, 0.6512], device='cuda:0')
# Learning rate: 5e-06
# Early stopping at epoch 43 with best validation loss 0.534441469113032
# training_checkpoints/resnet18_normalize_batch_2048_test2024-04-24 23:26:09.129372.pth
# <All keys matched successfully>

# %%
from sklearn.metrics import confusion_matrix, classification_report
from torch.utils.data import DataLoader
import numpy as np
import torch 
from torchvision.models import resnet18
import torch.nn as nn


def test_report(model, dataloader):
    """Prints confusion matrix for testing dataset
    dataloader should be of batch_size=1."""

    y_pred = []
    y_test = []
    model.eval()
    with torch.no_grad():
        for data, label in dataloader:
            output = model(data)
            label = label.numpy()
            output = output.numpy()
            y_pred.append(np.argmax(output))
            y_test.append(np.argmax(label))
        print(confusion_matrix(y_test, y_pred))
        print(classification_report(y_test, y_pred))

testset =ImageDataset(data_path='test_data', transform=transform_test)
dataloader = DataLoader(testset, batch_size=1, shuffle=True)

test_report(my_model.to('cpu'), dataloader)
# Out:
# [[717 109 170   4]
#  [100 853  44   3]
#  [142  38 815   5]
#  [ 15   7   9  69]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73      1000
#            1       0.85      0.85      0.85      1000
#            2       0.79      0.81      0.80      1000
#            3       0.85      0.69      0.76       100
#
#     accuracy                           0.79      3100
#    macro avg       0.81      0.77      0.78      3100
# weighted avg       0.79      0.79      0.79      3100
