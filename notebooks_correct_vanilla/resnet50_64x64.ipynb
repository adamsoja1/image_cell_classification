# %%
import time
import sys
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from dataset import ImageDataset
import torch.nn.functional as F
from torchmetrics import Precision, Recall
from torchvision.models import resnet50
import warnings
from collections import defaultdict
import wandb
import datetime
import os
warnings.filterwarnings('ignore')
torch.set_float32_matmul_precision('high')
#intecubic interpol

run_name = f'resnet50_64x64_padding_{datetime.datetime.now()}'
run_path = f'training_checkpoints/{run_name}'

wandb.init(project="cells", 
           entity="adamsoja",
          name=run_name)

import random
random.seed(2233)
torch.manual_seed(2233)

#After /255 so in loading dataset there are no division by 255 just this normalization
mean = [0.5006, 0.3526, 0.5495]
std = [0.1493, 0.1341, 0.1124]


from albumentations import (
    Compose,
    Resize,
    OneOf,
    RandomBrightness,
    RandomContrast,
    MotionBlur,
    MedianBlur,
    GaussianBlur,
    VerticalFlip,
    HorizontalFlip,
    ShiftScaleRotate,
    Normalize,
)

transform = Compose(
    [
        Normalize(mean=mean, std=std),
        OneOf([RandomBrightness(limit=0.4, p=1), RandomContrast(limit=0.4, p=0.8)]),
        OneOf([MotionBlur(blur_limit=3), MedianBlur(blur_limit=3), GaussianBlur(blur_limit=3),], p=0.7,),
        VerticalFlip(p=0.5),
        HorizontalFlip(p=0.5),
    ]
)

transform_test = Compose(
    [Normalize(mean=mean, std=std)]
)

class MyModel(nn.Module):
    def __init__(self, model, learning_rate, weight_decay):
        super(MyModel, self).__init__()
        self.model = model
        self.learning_rate = learning_rate
        self.weight_decay = weight_decay
        self.criterion = nn.CrossEntropyLoss()
        self.metric_precision = Precision(task="multiclass", num_classes=4, average=None).to('cuda')
        self.metric_recall = Recall(task="multiclass", num_classes=4, average=None).to('cuda')
        self.train_loss = []
        self.valid_loss = []
        self.precision_per_epochs = []
        self.recall_per_epochs = []

        self.optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, mode="min", factor=0.1, patience=3, min_lr=5e-6, verbose=True)
        self.step = 0

    
    def forward(self, x):
        return self.model(x)

    def train_one_epoch(self, trainloader):
        self.step += 1
        self.train()
        for batch_idx, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()
            _, preds = torch.max(outputs, 1)
            _, labels = torch.max(labels, 1)
            self.metric_precision(preds, labels)
            self.metric_recall(preds, labels)
            self.train_loss.append(loss.item())


        

        
        avg_loss = np.mean(self.train_loss)
        self.train_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        self.precision_per_epochs.append(precision)
        self.recall_per_epochs.append(recall)
        print(f'train_loss: {avg_loss}')
        print(f'train_precision: {precision}')
        print(f'train_recall: {recall}')

        wandb.log({'loss': avg_loss},step=self.step)
        wandb.log({'Normal precision': precision[0].item()},step=self.step)
        wandb.log({'Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'Other precision': precision[3].item()},step=self.step)


        wandb.log({'Normal recall': recall[0].item()},step=self.step)
        wandb.log({'Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'Other recall': recall[3].item()},step=self.step)
        
        
        self.metric_precision.reset()
        self.metric_recall.reset()


    

    def evaluate(self, testloader):
        self.eval()
        with torch.no_grad():
            for batch_idx, (inputs, labels) in enumerate(testloader):
                inputs, labels = inputs.to('cuda'), labels.to('cuda')
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)
                _, labels = torch.max(labels, 1)
                self.metric_precision(preds, labels)
                self.metric_recall(preds, labels)
                self.valid_loss.append(loss.item())
    
        avg_loss = np.mean(self.valid_loss)
        self.scheduler.step(avg_loss)
        self.valid_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        print(f'val_loss: {avg_loss}')
        print(f'val_precision: {precision}')
        print(f'val_recall: {recall}')
        self.metric_precision.reset()
        self.metric_recall.reset()

        wandb.log({'val_loss': avg_loss}, step=self.step)
        
        wandb.log({'val_Normal precision': precision[0].item()},step=self.step)
        wandb.log({'val_Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'val_Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'val_Other precision': precision[3].item()},step=self.step)


        wandb.log({'val_Normal recall': recall[0].item()},step=self.step)
        wandb.log({'val_Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'val_Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'val_Other recall': recall[3].item()},step=self.step)


        for param_group in self.optimizer.param_groups:
            print(f"Learning rate: {param_group['lr']}")
        return avg_loss

torch.cuda.empty_cache()
batch_size = 256

trainset = ImageDataset(data_path='train_data', transform=transform)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=3)

testset = ImageDataset(data_path='validation_data', transform=transform_test)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)


learning_rate = 0.001
weight_decay = 0.00005

model = resnet50()
model.conv1 = nn.Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
num_classes = 4
model.fc = nn.Sequential(
    nn.Dropout(0.4),
    nn.Linear(model.fc.in_features, num_classes))

model = model.to('cuda')


my_model = MyModel(model=model, learning_rate=learning_rate, weight_decay=weight_decay)
my_model = my_model.to('cuda')

num_epochs = 100
early_stop_patience = 5
best_val_loss = float('inf')
best_model_state_dict = None

for epoch in range(num_epochs):
    print('========================================')
    print(f'EPOCH: {epoch}') 
    time_start = time.perf_counter()
    my_model.train_one_epoch(trainloader)
    val_loss = my_model.evaluate(testloader)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_state_dict = my_model.state_dict()
        torch.save(best_model_state_dict, f'{run_path}.pth')
        
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch} with best validation loss {best_val_loss}")
        break
    time_epoch = time.perf_counter() - time_start
    print(f'epoch {epoch} time:  {time_epoch/60}')
    print('--------------------------------')

# Load the best model state dict
print(f'{run_path}.pth')
my_model.load_state_dict(torch.load(f'{run_path}.pth'))
# Out:
# wandb: Currently logged in as: adamsoja. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/adam/Desktop/cells_master_thesis/wandb/run-20240505_023720-gvzkzoq8</code>
# Syncing run <strong><a href='https://wandb.ai/adamsoja/cells/runs/gvzkzoq8' target="_blank">resnet50_64x64_padding_2024-05-05 02:37:19.086272</a></strong> to <a href='https://wandb.ai/adamsoja/cells' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adamsoja/cells' target="_blank">https://wandb.ai/adamsoja/cells</a>
#  View run at <a href='https://wandb.ai/adamsoja/cells/runs/gvzkzoq8' target="_blank">https://wandb.ai/adamsoja/cells/runs/gvzkzoq8</a>
# ========================================
# EPOCH: 0
# train_loss: 0.9436194534103076
# train_precision: tensor([0.5407, 0.6406, 0.6188, 0.4522], device='cuda:0')
# train_recall: tensor([0.5326, 0.7591, 0.5725, 0.0225], device='cuda:0')
# val_loss: 0.8922779309252898
# val_precision: tensor([0.5863, 0.7911, 0.5384, 0.8923], device='cuda:0')
# val_recall: tensor([0.4590, 0.6055, 0.8301, 0.0892], device='cuda:0')
# Learning rate: 0.001
# epoch 0 time:  4.675939034083332
# --------------------------------
# ========================================
# EPOCH: 1
# train_loss: 0.8408244665179934
# train_precision: tensor([0.5838, 0.6949, 0.6613, 0.5644], device='cuda:0')
# train_recall: tensor([0.5788, 0.7765, 0.6427, 0.1100], device='cuda:0')
# val_loss: 0.8192993043197526
# val_precision: tensor([0.5461, 0.8157, 0.6733, 0.5895], device='cuda:0')
# val_recall: tensor([0.7114, 0.6333, 0.6657, 0.1896], device='cuda:0')
# Learning rate: 0.001
# epoch 1 time:  3.9600592733333335
# --------------------------------
# ========================================
# EPOCH: 2
# train_loss: 0.8138915400419916
# train_precision: tensor([0.6000, 0.7065, 0.6731, 0.5665], device='cuda:0')
# train_recall: tensor([0.5909, 0.7851, 0.6579, 0.1505], device='cuda:0')
# val_loss: 0.7588634978565905
# val_precision: tensor([0.5954, 0.7527, 0.7216, 0.8091], device='cuda:0')
# val_recall: tensor([0.6744, 0.8021, 0.6449, 0.0657], device='cuda:0')
# Learning rate: 0.001
# epoch 2 time:  4.056197596983333
# --------------------------------
# ========================================
# EPOCH: 3
# train_loss: 0.7956315655083883
# train_precision: tensor([0.6073, 0.7131, 0.6779, 0.5783], device='cuda:0')
# train_recall: tensor([0.5958, 0.7881, 0.6664, 0.1775], device='cuda:0')
# val_loss: 0.764865575896369
# val_precision: tensor([0.5635, 0.7347, 0.7911, 0.7407], device='cuda:0')
# val_recall: tensor([0.7232, 0.8032, 0.5488, 0.2202], device='cuda:0')
# Learning rate: 0.001
# epoch 3 time:  3.8006423144333343
# --------------------------------
# ========================================
# EPOCH: 4
# train_loss: 0.7765024000690097
# train_precision: tensor([0.6196, 0.7194, 0.6903, 0.5823], device='cuda:0')
# train_recall: tensor([0.6053, 0.7965, 0.6780, 0.1960], device='cuda:0')
# val_loss: 0.7523839240272839
# val_precision: tensor([0.6311, 0.8081, 0.6805, 0.3724], device='cuda:0')
# val_recall: tensor([0.6081, 0.7468, 0.7374, 0.4795], device='cuda:0')
# Learning rate: 0.001
# epoch 4 time:  3.8265558917500018
# --------------------------------
# ========================================
# EPOCH: 5
# train_loss: 0.7651496210268566
# train_precision: tensor([0.6243, 0.7250, 0.6963, 0.5968], device='cuda:0')
# train_recall: tensor([0.6113, 0.7998, 0.6837, 0.2136], device='cuda:0')
# val_loss: 0.7463423598143789
# val_precision: tensor([0.6549, 0.8004, 0.6435, 0.7391], device='cuda:0')
# val_recall: tensor([0.6006, 0.7277, 0.7984, 0.2451], device='cuda:0')
# Learning rate: 0.001
# epoch 5 time:  3.816281875333334
# --------------------------------
# ========================================
# EPOCH: 6
# train_loss: 0.7535079377747718
# train_precision: tensor([0.6320, 0.7273, 0.6999, 0.6011], device='cuda:0')
# train_recall: tensor([0.6119, 0.8045, 0.6913, 0.2283], device='cuda:0')
# val_loss: 0.6961929308043586
# val_precision: tensor([0.6549, 0.7534, 0.7334, 0.6678], device='cuda:0')
# val_recall: tensor([0.6334, 0.8189, 0.7298, 0.3397], device='cuda:0')
# Learning rate: 0.001
# epoch 6 time:  3.8161816989666666
# --------------------------------
# ========================================
# EPOCH: 7
# train_loss: 0.7408341512084007
# train_precision: tensor([0.6386, 0.7326, 0.7053, 0.6129], device='cuda:0')
# train_recall: tensor([0.6187, 0.8056, 0.6983, 0.2543], device='cuda:0')
# val_loss: 0.6989866485198338
# val_precision: tensor([0.6771, 0.7101, 0.7391, 0.7205], device='cuda:0')
# val_recall: tensor([0.5834, 0.8714, 0.7119, 0.3471], device='cuda:0')
# Learning rate: 0.001
# epoch 7 time:  3.7735853038666693
# --------------------------------
# ========================================
# EPOCH: 8
# train_loss: 0.7325491898116612
# train_precision: tensor([0.6452, 0.7368, 0.7062, 0.6196], device='cuda:0')
# train_recall: tensor([0.6220, 0.8078, 0.7032, 0.2707], device='cuda:0')
# val_loss: 0.6945976311133968
# val_precision: tensor([0.6244, 0.7388, 0.8073, 0.7251], device='cuda:0')
# val_recall: tensor([0.7139, 0.8537, 0.6084, 0.3438], device='cuda:0')
# Learning rate: 0.001
# epoch 8 time:  3.8138657750833316
# --------------------------------
# ========================================
# EPOCH: 9
# train_loss: 0.7230457422279176
# train_precision: tensor([0.6448, 0.7408, 0.7112, 0.6283], device='cuda:0')
# train_recall: tensor([0.6243, 0.8094, 0.7056, 0.2939], device='cuda:0')
# val_loss: 0.6753687325451109
# val_precision: tensor([0.6651, 0.7999, 0.7152, 0.5808], device='cuda:0')
# val_recall: tensor([0.6680, 0.7868, 0.7441, 0.4165], device='cuda:0')
# Learning rate: 0.001
# epoch 9 time:  3.81343787821667
# --------------------------------
# ========================================
# EPOCH: 10
# train_loss: 0.7147798934862727
# train_precision: tensor([0.6525, 0.7444, 0.7158, 0.6328], device='cuda:0')
# train_recall: tensor([0.6308, 0.8125, 0.7110, 0.3074], device='cuda:0')
# val_loss: 0.6617593291733
# val_precision: tensor([0.6383, 0.8100, 0.7563, 0.7299], device='cuda:0')
# val_recall: tensor([0.7253, 0.7902, 0.7128, 0.3340], device='cuda:0')
# Learning rate: 0.001
# epoch 10 time:  3.810871884216666
# --------------------------------
# ========================================
# EPOCH: 11
# train_loss: 0.7104394781447593
# train_precision: tensor([0.6560, 0.7456, 0.7190, 0.6332], device='cuda:0')
# train_recall: tensor([0.6351, 0.8122, 0.7139, 0.3141], device='cuda:0')
# val_loss: 0.6649641458359029
# val_precision: tensor([0.6867, 0.7555, 0.7429, 0.6326], device='cuda:0')
# val_recall: tensor([0.6346, 0.8535, 0.7264, 0.4330], device='cuda:0')
# Learning rate: 0.001
# epoch 11 time:  3.7715908088500023
# --------------------------------
# ========================================
# EPOCH: 12
# train_loss: 0.7038410718951906
# train_precision: tensor([0.6606, 0.7482, 0.7202, 0.6421], device='cuda:0')
# train_recall: tensor([0.6365, 0.8132, 0.7180, 0.3381], device='cuda:0')
# val_loss: 0.6484936919477251
# val_precision: tensor([0.6690, 0.8070, 0.7347, 0.7027], device='cuda:0')
# val_recall: tensor([0.6822, 0.7918, 0.7610, 0.4448], device='cuda:0')
# Learning rate: 0.001
# epoch 12 time:  3.813087382766662
# --------------------------------
# ========================================
# EPOCH: 13
# train_loss: 0.6982876017689705
# train_precision: tensor([0.6613, 0.7504, 0.7227, 0.6480], device='cuda:0')
# train_recall: tensor([0.6418, 0.8129, 0.7182, 0.3405], device='cuda:0')
# val_loss: 0.6435573414795929
# val_precision: tensor([0.6562, 0.7846, 0.7862, 0.6860], device='cuda:0')
# val_recall: tensor([0.7235, 0.8327, 0.6880, 0.4172], device='cuda:0')
# Learning rate: 0.001
# epoch 13 time:  3.81284014493333
# --------------------------------
# ========================================
# EPOCH: 14
# train_loss: 0.6942201936528796
# train_precision: tensor([0.6660, 0.7517, 0.7247, 0.6516], device='cuda:0')
# train_recall: tensor([0.6432, 0.8142, 0.7230, 0.3485], device='cuda:0')
# val_loss: 0.6392225835058424
# val_precision: tensor([0.6706, 0.7753, 0.7858, 0.6799], device='cuda:0')
# val_recall: tensor([0.7067, 0.8413, 0.7007, 0.4721], device='cuda:0')
# Learning rate: 0.001
# epoch 14 time:  3.813108232799997
# --------------------------------
# ========================================
# EPOCH: 15
# train_loss: 0.6903324708342552
# train_precision: tensor([0.6670, 0.7551, 0.7244, 0.6574], device='cuda:0')
# train_recall: tensor([0.6433, 0.8170, 0.7229, 0.3652], device='cuda:0')
# val_loss: 0.6460481068326367
# val_precision: tensor([0.6635, 0.7970, 0.7538, 0.7544], device='cuda:0')
# val_recall: tensor([0.7068, 0.8063, 0.7321, 0.3919], device='cuda:0')
# Learning rate: 0.001
# epoch 15 time:  3.7723677211833317
# --------------------------------
# ========================================
# EPOCH: 16
# train_loss: 0.6863528346731549
# train_precision: tensor([0.6695, 0.7565, 0.7267, 0.6487], device='cuda:0')
# train_recall: tensor([0.6459, 0.8175, 0.7262, 0.3582], device='cuda:0')
# val_loss: 0.6285635085569488
# val_precision: tensor([0.6967, 0.7695, 0.7752, 0.6238], device='cuda:0')
# val_recall: tensor([0.6737, 0.8603, 0.7228, 0.5148], device='cuda:0')
# Learning rate: 0.001
# epoch 16 time:  3.813784850583329
# --------------------------------
# ========================================
# EPOCH: 17
# train_loss: 0.682024920625346
# train_precision: tensor([0.6716, 0.7571, 0.7290, 0.6609], device='cuda:0')
# train_recall: tensor([0.6496, 0.8175, 0.7260, 0.3773], device='cuda:0')
# val_loss: 0.6379711382091046
# val_precision: tensor([0.7026, 0.7723, 0.7428, 0.7786], device='cuda:0')
# val_recall: tensor([0.6500, 0.8429, 0.7681, 0.3848], device='cuda:0')
# Learning rate: 0.001
# epoch 17 time:  3.7712151555833318
# --------------------------------
# ========================================
# EPOCH: 18
# train_loss: 0.6797096434803236
# train_precision: tensor([0.6738, 0.7579, 0.7317, 0.6627], device='cuda:0')
# train_recall: tensor([0.6510, 0.8196, 0.7274, 0.3870], device='cuda:0')
# val_loss: 0.6219434491462178
# val_precision: tensor([0.6950, 0.8182, 0.7254, 0.7752], device='cuda:0')
# val_recall: tensor([0.6688, 0.8047, 0.7990, 0.4088], device='cuda:0')
# Learning rate: 0.001
# epoch 18 time:  3.8130625134000034
# --------------------------------
# ========================================
# EPOCH: 19
# train_loss: 0.6770952021791822
# train_precision: tensor([0.6759, 0.7590, 0.7298, 0.6621], device='cuda:0')
# train_recall: tensor([0.6510, 0.8203, 0.7277, 0.3887], device='cuda:0')
# val_loss: 0.6249401305284765
# val_precision: tensor([0.7044, 0.7622, 0.7683, 0.7941], device='cuda:0')
# val_recall: tensor([0.6792, 0.8564, 0.7407, 0.3832], device='cuda:0')
# Learning rate: 0.001
# epoch 19 time:  3.7714013442333303
# --------------------------------
# ========================================
# EPOCH: 20
# train_loss: 0.6744027566342127
# train_precision: tensor([0.6766, 0.7611, 0.7319, 0.6640], device='cuda:0')
# train_recall: tensor([0.6533, 0.8210, 0.7298, 0.3900], device='cuda:0')
# val_loss: 0.6209792926907539
# val_precision: tensor([0.7268, 0.7913, 0.7295, 0.7200], device='cuda:0')
# val_recall: tensor([0.6348, 0.8413, 0.8026, 0.4545], device='cuda:0')
# Learning rate: 0.001
# epoch 20 time:  3.811279672633327
# --------------------------------
# ========================================
# EPOCH: 21
# train_loss: 0.6720669409348852
# train_precision: tensor([0.6775, 0.7605, 0.7335, 0.6696], device='cuda:0')
# train_recall: tensor([0.6548, 0.8185, 0.7317, 0.3991], device='cuda:0')
# val_loss: 0.6219528086483479
# val_precision: tensor([0.7577, 0.7373, 0.7525, 0.6743], device='cuda:0')
# val_recall: tensor([0.5959, 0.8940, 0.7708, 0.5185], device='cuda:0')
# Learning rate: 0.001
# epoch 21 time:  3.7692947235333425
# --------------------------------
# ========================================
# EPOCH: 22
# train_loss: 0.6685470399402437
# train_precision: tensor([0.6793, 0.7626, 0.7352, 0.6602], device='cuda:0')
# train_recall: tensor([0.6562, 0.8214, 0.7329, 0.3954], device='cuda:0')
# val_loss: 0.6190705976552433
# val_precision: tensor([0.7223, 0.7878, 0.7379, 0.6844], device='cuda:0')
# val_recall: tensor([0.6374, 0.8425, 0.7920, 0.5125], device='cuda:0')
# Learning rate: 0.001
# epoch 22 time:  3.813189557183326
# --------------------------------
# ========================================
# EPOCH: 23
# train_loss: 0.6658634825831368
# train_precision: tensor([0.6802, 0.7629, 0.7374, 0.6633], device='cuda:0')
# train_recall: tensor([0.6601, 0.8204, 0.7321, 0.4062], device='cuda:0')
# val_loss: 0.6225702562265926
# val_precision: tensor([0.7324, 0.7983, 0.7127, 0.6926], device='cuda:0')
# val_recall: tensor([0.6072, 0.8396, 0.8251, 0.4256], device='cuda:0')
# Learning rate: 0.001
# epoch 23 time:  3.771067223266679
# --------------------------------
# ========================================
# EPOCH: 24
# train_loss: 0.6636206475042161
# train_precision: tensor([0.6799, 0.7646, 0.7365, 0.6692], device='cuda:0')
# train_recall: tensor([0.6570, 0.8235, 0.7330, 0.4113], device='cuda:0')
# val_loss: 0.6332998862697019
# val_precision: tensor([0.7194, 0.8079, 0.7107, 0.7523], device='cuda:0')
# val_recall: tensor([0.6278, 0.8101, 0.8296, 0.4316], device='cuda:0')
# Learning rate: 0.001
# epoch 24 time:  3.7714704063666584
# --------------------------------
# ========================================
# EPOCH: 25
# train_loss: 0.6624973188553538
# train_precision: tensor([0.6814, 0.7660, 0.7364, 0.6593], device='cuda:0')
# train_recall: tensor([0.6601, 0.8209, 0.7346, 0.4085], device='cuda:0')
# val_loss: 0.6130940743618541
# val_precision: tensor([0.7268, 0.7698, 0.7624, 0.7041], device='cuda:0')
# val_recall: tensor([0.6552, 0.8710, 0.7634, 0.4640], device='cuda:0')
# Learning rate: 0.001
# epoch 25 time:  3.81194284741667
# --------------------------------
# ========================================
# EPOCH: 26
# train_loss: 0.6588961284785043
# train_precision: tensor([0.6845, 0.7650, 0.7400, 0.6656], device='cuda:0')
# train_recall: tensor([0.6618, 0.8227, 0.7363, 0.4173], device='cuda:0')
# val_loss: 0.6021228179335594
# val_precision: tensor([0.7158, 0.8183, 0.7321, 0.7379], device='cuda:0')
# val_recall: tensor([0.6620, 0.8252, 0.8053, 0.4929], device='cuda:0')
# Learning rate: 0.001
# epoch 26 time:  3.811351810399992
# --------------------------------
# ========================================
# EPOCH: 27
# train_loss: 0.6578308502123469
# train_precision: tensor([0.6847, 0.7669, 0.7372, 0.6708], device='cuda:0')
# train_recall: tensor([0.6601, 0.8224, 0.7378, 0.4202], device='cuda:0')
# val_loss: 0.6249925010734134
# val_precision: tensor([0.7504, 0.7844, 0.7277, 0.5495], device='cuda:0')
# val_recall: tensor([0.6002, 0.8524, 0.7987, 0.6370], device='cuda:0')
# Learning rate: 0.001
# epoch 27 time:  3.7691064976166673
# --------------------------------
# ========================================
# EPOCH: 28
# train_loss: 0.6558633721300534
# train_precision: tensor([0.6857, 0.7668, 0.7403, 0.6714], device='cuda:0')
# train_recall: tensor([0.6625, 0.8236, 0.7376, 0.4261], device='cuda:0')
# val_loss: 0.6016913543972704
# val_precision: tensor([0.7129, 0.8263, 0.7351, 0.7390], device='cuda:0')
# val_recall: tensor([0.6832, 0.8104, 0.8039, 0.4987], device='cuda:0')
# Learning rate: 0.001
# epoch 28 time:  3.811168179699992
# --------------------------------
# ========================================
# EPOCH: 29
# train_loss: 0.6523997748891512
# train_precision: tensor([0.6875, 0.7692, 0.7423, 0.6739], device='cuda:0')
# train_recall: tensor([0.6661, 0.8257, 0.7384, 0.4244], device='cuda:0')
# val_loss: 0.5999261010024283
# val_precision: tensor([0.7230, 0.7727, 0.7790, 0.7398], device='cuda:0')
# val_recall: tensor([0.6774, 0.8723, 0.7551, 0.4805], device='cuda:0')
# Learning rate: 0.001
# epoch 29 time:  3.8099863517499974
# --------------------------------
# ========================================
# EPOCH: 30
# train_loss: 0.6522163926845506
# train_precision: tensor([0.6896, 0.7690, 0.7406, 0.6668], device='cuda:0')
# train_recall: tensor([0.6652, 0.8258, 0.7385, 0.4294], device='cuda:0')
# val_loss: 0.6096993998520904
# val_precision: tensor([0.7312, 0.7769, 0.7520, 0.7469], device='cuda:0')
# val_recall: tensor([0.6447, 0.8577, 0.7924, 0.4532], device='cuda:0')
# Learning rate: 0.001
# epoch 30 time:  3.7691327316166734
# --------------------------------
# ========================================
# EPOCH: 31
# train_loss: 0.6512989064767247
# train_precision: tensor([0.6875, 0.7686, 0.7427, 0.6795], device='cuda:0')
# train_recall: tensor([0.6662, 0.8243, 0.7390, 0.4310], device='cuda:0')
# val_loss: 0.6021879373325242
# val_precision: tensor([0.6882, 0.8052, 0.7912, 0.6077], device='cuda:0')
# val_recall: tensor([0.7306, 0.8261, 0.7327, 0.5253], device='cuda:0')
# Learning rate: 0.001
# epoch 31 time:  3.770737682066662
# --------------------------------
# ========================================
# EPOCH: 32
# train_loss: 0.6482702521341187
# train_precision: tensor([0.6895, 0.7704, 0.7424, 0.6623], device='cuda:0')
# train_recall: tensor([0.6655, 0.8252, 0.7415, 0.4302], device='cuda:0')
# val_loss: 0.5995938330060906
# val_precision: tensor([0.7019, 0.8161, 0.7620, 0.7060], device='cuda:0')
# val_recall: tensor([0.7139, 0.8174, 0.7724, 0.4771], device='cuda:0')
# Learning rate: 0.001
# epoch 32 time:  3.8130610250833343
# --------------------------------
# ========================================
# EPOCH: 33
# train_loss: 0.6483798781675952
# train_precision: tensor([0.6901, 0.7691, 0.7414, 0.6762], device='cuda:0')
# train_recall: tensor([0.6649, 0.8253, 0.7404, 0.4391], device='cuda:0')
# val_loss: 0.6015758983790874
# val_precision: tensor([0.7195, 0.8276, 0.7292, 0.7562], device='cuda:0')
# val_recall: tensor([0.6698, 0.8135, 0.8225, 0.4397], device='cuda:0')
# Learning rate: 0.001
# epoch 33 time:  3.7697378655000042
# --------------------------------
# ========================================
# EPOCH: 34
# train_loss: 0.6476793814982686
# train_precision: tensor([0.6881, 0.7698, 0.7436, 0.6772], device='cuda:0')
# train_recall: tensor([0.6675, 0.8243, 0.7392, 0.4404], device='cuda:0')
# val_loss: 0.597283414999644
# val_precision: tensor([0.7346, 0.7797, 0.7723, 0.6396], device='cuda:0')
# val_recall: tensor([0.6689, 0.8638, 0.7706, 0.5367], device='cuda:0')
# Learning rate: 0.001
# epoch 34 time:  3.8112384572833435
# --------------------------------
# ========================================
# EPOCH: 35
# train_loss: 0.6448419731287729
# train_precision: tensor([0.6912, 0.7728, 0.7451, 0.6737], device='cuda:0')
# train_recall: tensor([0.6702, 0.8253, 0.7426, 0.4430], device='cuda:0')
# val_loss: 0.6031034805708462
# val_precision: tensor([0.7539, 0.7905, 0.7368, 0.6514], device='cuda:0')
# val_recall: tensor([0.6254, 0.8581, 0.8080, 0.5751], device='cuda:0')
# Learning rate: 0.001
# epoch 35 time:  3.7696853713499876
# --------------------------------
# ========================================
# EPOCH: 36
# train_loss: 0.6440430884559949
# train_precision: tensor([0.6918, 0.7717, 0.7445, 0.6701], device='cuda:0')
# train_recall: tensor([0.6693, 0.8259, 0.7420, 0.4394], device='cuda:0')
# val_loss: 0.6057747954295741
# val_precision: tensor([0.7265, 0.8344, 0.7167, 0.6843], device='cuda:0')
# val_recall: tensor([0.6554, 0.7973, 0.8329, 0.5495], device='cuda:0')
# Learning rate: 0.001
# epoch 36 time:  3.769094256316657
# --------------------------------
# ========================================
# EPOCH: 37
# train_loss: 0.6422888140593256
# train_precision: tensor([0.6928, 0.7717, 0.7460, 0.6795], device='cuda:0')
# train_recall: tensor([0.6697, 0.8268, 0.7437, 0.4420], device='cuda:0')
# val_loss: 0.5939424417085117
# val_precision: tensor([0.7124, 0.8238, 0.7482, 0.6971], device='cuda:0')
# val_recall: tensor([0.6910, 0.8153, 0.7978, 0.5168], device='cuda:0')
# Learning rate: 0.001
# epoch 37 time:  3.8141484136833546
# --------------------------------
# ========================================
# EPOCH: 38
# train_loss: 0.6406549260020256
# train_precision: tensor([0.6937, 0.7708, 0.7473, 0.6841], device='cuda:0')
# train_recall: tensor([0.6693, 0.8273, 0.7448, 0.4462], device='cuda:0')
# val_loss: 0.5859329139192899
# val_precision: tensor([0.6999, 0.8085, 0.7811, 0.7614], device='cuda:0')
# val_recall: tensor([0.7174, 0.8328, 0.7656, 0.4933], device='cuda:0')
# Learning rate: 0.001
# epoch 38 time:  3.811409447483311
# --------------------------------
# ========================================
# EPOCH: 39
# train_loss: 0.6397583249424185
# train_precision: tensor([0.6940, 0.7716, 0.7475, 0.6827], device='cuda:0')
# train_recall: tensor([0.6719, 0.8257, 0.7448, 0.4456], device='cuda:0')
# val_loss: 0.5904501320587264
# val_precision: tensor([0.7184, 0.8288, 0.7432, 0.6808], device='cuda:0')
# val_recall: tensor([0.6912, 0.8126, 0.7963, 0.5859], device='cuda:0')
# Learning rate: 0.001
# epoch 39 time:  3.769603545483339
# --------------------------------
# ========================================
# EPOCH: 40
# train_loss: 0.6377624030978907
# train_precision: tensor([0.6930, 0.7740, 0.7472, 0.6854], device='cuda:0')
# train_recall: tensor([0.6734, 0.8261, 0.7425, 0.4606], device='cuda:0')
# val_loss: 0.6043478223184745
# val_precision: tensor([0.7009, 0.8197, 0.7354, 0.7638], device='cuda:0')
# val_recall: tensor([0.6717, 0.8136, 0.7986, 0.4811], device='cuda:0')
# Learning rate: 0.001
# epoch 40 time:  3.7705296049333508
# --------------------------------
# ========================================
# EPOCH: 41
# train_loss: 0.636227666125411
# train_precision: tensor([0.6964, 0.7737, 0.7480, 0.6833], device='cuda:0')
# train_recall: tensor([0.6721, 0.8287, 0.7453, 0.4620], device='cuda:0')
# val_loss: 0.5896252730654346
# val_precision: tensor([0.7010, 0.7997, 0.8007, 0.6530], device='cuda:0')
# val_recall: tensor([0.7268, 0.8463, 0.7316, 0.5970], device='cuda:0')
# Learning rate: 0.001
# epoch 41 time:  3.768763907850007
# --------------------------------
# ========================================
# EPOCH: 42
# train_loss: 0.635843096354178
# train_precision: tensor([0.6959, 0.7741, 0.7487, 0.6721], device='cuda:0')
# train_recall: tensor([0.6734, 0.8273, 0.7461, 0.4496], device='cuda:0')
# val_loss: 0.5828402981162071
# val_precision: tensor([0.7011, 0.8077, 0.7799, 0.7772], device='cuda:0')
# val_recall: tensor([0.7259, 0.8338, 0.7590, 0.4593], device='cuda:0')
# Learning rate: 0.001
# epoch 42 time:  3.811049370533328
# --------------------------------
# ========================================
# EPOCH: 43
# train_loss: 0.6357848041114353
# train_precision: tensor([0.6958, 0.7738, 0.7472, 0.6845], device='cuda:0')
# train_recall: tensor([0.6729, 0.8287, 0.7440, 0.4532], device='cuda:0')
# val_loss: 0.5889938655826781
# val_precision: tensor([0.7122, 0.8041, 0.7689, 0.7227], device='cuda:0')
# val_recall: tensor([0.6988, 0.8392, 0.7725, 0.5098], device='cuda:0')
# Learning rate: 0.001
# epoch 43 time:  3.7691798911666714
# --------------------------------
# ========================================
# EPOCH: 44
# train_loss: 0.6332643171861059
# train_precision: tensor([0.6956, 0.7757, 0.7480, 0.6790], device='cuda:0')
# train_recall: tensor([0.6761, 0.8267, 0.7433, 0.4661], device='cuda:0')
# val_loss: 0.5915132434003882
# val_precision: tensor([0.7240, 0.7649, 0.8054, 0.6326], device='cuda:0')
# val_recall: tensor([0.6830, 0.8820, 0.7349, 0.5774], device='cuda:0')
# Learning rate: 0.001
# epoch 44 time:  3.771092472616662
# --------------------------------
# ========================================
# EPOCH: 45
# train_loss: 0.6322407085271109
# train_precision: tensor([0.6981, 0.7766, 0.7510, 0.6820], device='cuda:0')
# train_recall: tensor([0.6777, 0.8291, 0.7466, 0.4612], device='cuda:0')
# val_loss: 0.5828757507105669
# val_precision: tensor([0.7440, 0.7919, 0.7604, 0.6709], device='cuda:0')
# val_recall: tensor([0.6582, 0.8589, 0.7952, 0.5697], device='cuda:0')
# Learning rate: 0.001
# epoch 45 time:  3.7692734241500148
# --------------------------------
# ========================================
# EPOCH: 46
# train_loss: 0.6318079143762588
# train_precision: tensor([0.6978, 0.7769, 0.7508, 0.6851], device='cuda:0')
# train_recall: tensor([0.6758, 0.8293, 0.7485, 0.4596], device='cuda:0')
# val_loss: 0.6007790923946433
# val_precision: tensor([0.6761, 0.8567, 0.7685, 0.6416], device='cuda:0')
# val_recall: tensor([0.7464, 0.7663, 0.7740, 0.6057], device='cuda:0')
# Learning rate: 0.0001
# epoch 46 time:  3.7691019872000044
# --------------------------------
# ========================================
# EPOCH: 47
# train_loss: 0.6016497416510469
# train_precision: tensor([0.7120, 0.7869, 0.7609, 0.7095], device='cuda:0')
# train_recall: tensor([0.6888, 0.8339, 0.7617, 0.5102], device='cuda:0')
# val_loss: 0.547280384434594
# val_precision: tensor([0.7427, 0.8243, 0.7775, 0.7185], device='cuda:0')
# val_recall: tensor([0.7073, 0.8466, 0.8062, 0.6017], device='cuda:0')
# Learning rate: 0.0001
# epoch 47 time:  3.812086768000002
# --------------------------------
# ========================================
# EPOCH: 48
# train_loss: 0.5906507827341556
# train_precision: tensor([0.7186, 0.7914, 0.7662, 0.7100], device='cuda:0')
# train_recall: tensor([0.6956, 0.8381, 0.7639, 0.5381], device='cuda:0')
# val_loss: 0.5414666057460837
# val_precision: tensor([0.7492, 0.8138, 0.7839, 0.7295], device='cuda:0')
# val_recall: tensor([0.7022, 0.8612, 0.8005, 0.6074], device='cuda:0')
# Learning rate: 0.0001
# epoch 48 time:  3.8099500468333343
# --------------------------------
# ========================================
# EPOCH: 49
# train_loss: 0.5867038560055551
# train_precision: tensor([0.7205, 0.7927, 0.7674, 0.7094], device='cuda:0')
# train_recall: tensor([0.6960, 0.8401, 0.7655, 0.5452], device='cuda:0')
# val_loss: 0.5399758006963465
# val_precision: tensor([0.7412, 0.8222, 0.7866, 0.7302], device='cuda:0')
# val_recall: tensor([0.7167, 0.8521, 0.7980, 0.5997], device='cuda:0')
# Learning rate: 0.0001
# epoch 49 time:  3.8113604987833543
# --------------------------------
# ========================================
# EPOCH: 50
# train_loss: 0.5844830988063698
# train_precision: tensor([0.7193, 0.7928, 0.7698, 0.7149], device='cuda:0')
# train_recall: tensor([0.6971, 0.8399, 0.7658, 0.5478], device='cuda:0')
# val_loss: 0.5386376812226242
# val_precision: tensor([0.7418, 0.8259, 0.7880, 0.7066], device='cuda:0')
# val_recall: tensor([0.7197, 0.8491, 0.7996, 0.6155], device='cuda:0')
# Learning rate: 0.0001
# epoch 50 time:  3.809761038500013
# --------------------------------
# ========================================
# EPOCH: 51
# train_loss: 0.5807071282750085
# train_precision: tensor([0.7249, 0.7956, 0.7707, 0.7160], device='cuda:0')
# train_recall: tensor([0.7015, 0.8406, 0.7695, 0.5532], device='cuda:0')
# val_loss: 0.5381915190981494
# val_precision: tensor([0.7491, 0.8232, 0.7817, 0.7045], device='cuda:0')
# val_recall: tensor([0.7064, 0.8525, 0.8060, 0.6367], device='cuda:0')
# Learning rate: 0.0001
# epoch 51 time:  3.8102006862499973
# --------------------------------
# ========================================
# EPOCH: 52
# train_loss: 0.5787133992073081
# train_precision: tensor([0.7243, 0.7957, 0.7720, 0.7152], device='cuda:0')
# train_recall: tensor([0.7020, 0.8399, 0.7697, 0.5587], device='cuda:0')
# val_loss: 0.5365396381252342
# val_precision: tensor([0.7474, 0.8158, 0.7917, 0.7065], device='cuda:0')
# val_recall: tensor([0.7098, 0.8614, 0.7963, 0.6256], device='cuda:0')
# Learning rate: 0.0001
# epoch 52 time:  3.8103412926666653
# --------------------------------
# ========================================
# EPOCH: 53
# train_loss: 0.5768067886786802
# train_precision: tensor([0.7249, 0.7961, 0.7726, 0.7196], device='cuda:0')
# train_recall: tensor([0.7027, 0.8402, 0.7708, 0.5584], device='cuda:0')
# val_loss: 0.5350091108017497
# val_precision: tensor([0.7361, 0.8251, 0.7989, 0.7081], device='cuda:0')
# val_recall: tensor([0.7298, 0.8512, 0.7893, 0.6296], device='cuda:0')
# Learning rate: 0.0001
# epoch 53 time:  3.8111565792833364
# --------------------------------
# ========================================
# EPOCH: 54
# train_loss: 0.5756126569140525
# train_precision: tensor([0.7248, 0.7974, 0.7731, 0.7169], device='cuda:0')
# train_recall: tensor([0.7046, 0.8418, 0.7677, 0.5661], device='cuda:0')
# val_loss: 0.5347273606393073
# val_precision: tensor([0.7399, 0.8355, 0.7832, 0.7206], device='cuda:0')
# val_recall: tensor([0.7249, 0.8415, 0.8047, 0.6165], device='cuda:0')
# Learning rate: 0.0001
# epoch 54 time:  3.811753869749979
# --------------------------------
# ========================================
# EPOCH: 55
# train_loss: 0.5748295755258628
# train_precision: tensor([0.7259, 0.7969, 0.7722, 0.7169], device='cuda:0')
# train_recall: tensor([0.7019, 0.8426, 0.7701, 0.5631], device='cuda:0')
# val_loss: 0.5359755807452732
# val_precision: tensor([0.7549, 0.8249, 0.7815, 0.6664], device='cuda:0')
# val_recall: tensor([0.7036, 0.8515, 0.8098, 0.6633], device='cuda:0')
# Learning rate: 0.0001
# epoch 55 time:  3.7692328969666655
# --------------------------------
# ========================================
# EPOCH: 56
# train_loss: 0.5738632687145755
# train_precision: tensor([0.7248, 0.7967, 0.7718, 0.7197], device='cuda:0')
# train_recall: tensor([0.7019, 0.8415, 0.7689, 0.5688], device='cuda:0')
# val_loss: 0.5331926366521252
# val_precision: tensor([0.7390, 0.8227, 0.7988, 0.7147], device='cuda:0')
# val_recall: tensor([0.7283, 0.8546, 0.7905, 0.6158], device='cuda:0')
# Learning rate: 0.0001
# epoch 56 time:  3.811525797666642
# --------------------------------
# ========================================
# EPOCH: 57
# train_loss: 0.5714582644402981
# train_precision: tensor([0.7269, 0.7979, 0.7740, 0.7197], device='cuda:0')
# train_recall: tensor([0.7052, 0.8419, 0.7709, 0.5661], device='cuda:0')
# val_loss: 0.5328855342335171
# val_precision: tensor([0.7443, 0.8241, 0.7921, 0.6996], device='cuda:0')
# val_recall: tensor([0.7195, 0.8554, 0.7955, 0.6374], device='cuda:0')
# Learning rate: 0.0001
# epoch 57 time:  3.8118286404000172
# --------------------------------
# ========================================
# EPOCH: 58
# train_loss: 0.5719679824653126
# train_precision: tensor([0.7280, 0.7976, 0.7736, 0.7263], device='cuda:0')
# train_recall: tensor([0.7055, 0.8414, 0.7715, 0.5726], device='cuda:0')
# val_loss: 0.5319273503290283
# val_precision: tensor([0.7464, 0.8223, 0.7952, 0.6839], device='cuda:0')
# val_recall: tensor([0.7182, 0.8563, 0.7942, 0.6680], device='cuda:0')
# Learning rate: 0.0001
# epoch 58 time:  3.8098096427833297
# --------------------------------
# ========================================
# EPOCH: 59
# train_loss: 0.5696131472786268
# train_precision: tensor([0.7286, 0.7979, 0.7756, 0.7250], device='cuda:0')
# train_recall: tensor([0.7054, 0.8431, 0.7722, 0.5778], device='cuda:0')
# val_loss: 0.5320715709692903
# val_precision: tensor([0.7390, 0.8271, 0.7929, 0.7264], device='cuda:0')
# val_recall: tensor([0.7246, 0.8518, 0.7962, 0.6212], device='cuda:0')
# Learning rate: 0.0001
# epoch 59 time:  3.7695168772500134
# --------------------------------
# ========================================
# EPOCH: 60
# train_loss: 0.5688775266565028
# train_precision: tensor([0.7273, 0.8003, 0.7752, 0.7236], device='cuda:0')
# train_recall: tensor([0.7070, 0.8428, 0.7721, 0.5697], device='cuda:0')
# val_loss: 0.533611511439085
# val_precision: tensor([0.7515, 0.8293, 0.7793, 0.7004], device='cuda:0')
# val_recall: tensor([0.7075, 0.8494, 0.8121, 0.6461], device='cuda:0')
# Learning rate: 0.0001
# epoch 60 time:  3.771159123583311
# --------------------------------
# ========================================
# EPOCH: 61
# train_loss: 0.5659660745234717
# train_precision: tensor([0.7309, 0.8007, 0.7770, 0.7244], device='cuda:0')
# train_recall: tensor([0.7090, 0.8439, 0.7735, 0.5828], device='cuda:0')
# val_loss: 0.5330077311231031
# val_precision: tensor([0.7298, 0.8350, 0.8004, 0.6903], device='cuda:0')
# val_recall: tensor([0.7432, 0.8399, 0.7862, 0.6461], device='cuda:0')
# Learning rate: 0.0001
# epoch 61 time:  3.7683218775833365
# --------------------------------
# ========================================
# EPOCH: 62
# train_loss: 0.5644787905826455
# train_precision: tensor([0.7309, 0.8009, 0.7775, 0.7255], device='cuda:0')
# train_recall: tensor([0.7075, 0.8451, 0.7748, 0.5827], device='cuda:0')
# val_loss: 0.5322956047952175
# val_precision: tensor([0.7356, 0.8413, 0.7890, 0.7006], device='cuda:0')
# val_recall: tensor([0.7335, 0.8361, 0.8033, 0.6367], device='cuda:0')
# Learning rate: 1e-05
# epoch 62 time:  3.7708725047166807
# --------------------------------
# ========================================
# EPOCH: 63
# train_loss: 0.5636686012858436
# train_precision: tensor([0.7315, 0.8020, 0.7755, 0.7281], device='cuda:0')
# train_recall: tensor([0.7067, 0.8439, 0.7769, 0.5812], device='cuda:0')
# val_loss: 0.528604868799448
# val_precision: tensor([0.7469, 0.8306, 0.7885, 0.7120], device='cuda:0')
# val_recall: tensor([0.7207, 0.8501, 0.8059, 0.6377], device='cuda:0')
# Learning rate: 1e-05
# epoch 63 time:  3.809480144349982
# --------------------------------
# ========================================
# EPOCH: 64
# train_loss: 0.559504711769876
# train_precision: tensor([0.7339, 0.8026, 0.7790, 0.7380], device='cuda:0')
# train_recall: tensor([0.7095, 0.8453, 0.7784, 0.5962], device='cuda:0')
# val_loss: 0.5289962724679046
# val_precision: tensor([0.7413, 0.8251, 0.8009, 0.7110], device='cuda:0')
# val_recall: tensor([0.7308, 0.8559, 0.7906, 0.6370], device='cuda:0')
# Learning rate: 1e-05
# epoch 64 time:  3.7684613223166705
# --------------------------------
# ========================================
# EPOCH: 65
# train_loss: 0.5589731722715355
# train_precision: tensor([0.7336, 0.8024, 0.7793, 0.7331], device='cuda:0')
# train_recall: tensor([0.7108, 0.8463, 0.7759, 0.5918], device='cuda:0')
# val_loss: 0.5285567624701394
# val_precision: tensor([0.7496, 0.8281, 0.7885, 0.7027], device='cuda:0')
# val_recall: tensor([0.7163, 0.8532, 0.8062, 0.6431], device='cuda:0')
# Learning rate: 1e-05
# epoch 65 time:  3.81376173351667
# --------------------------------
# ========================================
# EPOCH: 66
# train_loss: 0.5592040371327173
# train_precision: tensor([0.7330, 0.8026, 0.7791, 0.7348], device='cuda:0')
# train_recall: tensor([0.7110, 0.8459, 0.7756, 0.5918], device='cuda:0')
# val_loss: 0.5273290775716305
# val_precision: tensor([0.7458, 0.8242, 0.7988, 0.7015], device='cuda:0')
# val_recall: tensor([0.7248, 0.8585, 0.7938, 0.6512], device='cuda:0')
# Learning rate: 1e-05
# epoch 66 time:  3.811080536033326
# --------------------------------
# ========================================
# EPOCH: 67
# train_loss: 0.5595193881009306
# train_precision: tensor([0.7336, 0.8030, 0.7795, 0.7288], device='cuda:0')
# train_recall: tensor([0.7113, 0.8455, 0.7763, 0.5951], device='cuda:0')
# val_loss: 0.529076871358686
# val_precision: tensor([0.7492, 0.8264, 0.7910, 0.7117], device='cuda:0')
# val_recall: tensor([0.7173, 0.8548, 0.8057, 0.6374], device='cuda:0')
# Learning rate: 1e-05
# epoch 67 time:  3.7690458982166697
# --------------------------------
# ========================================
# EPOCH: 68
# train_loss: 0.5597094063247953
# train_precision: tensor([0.7335, 0.8020, 0.7804, 0.7351], device='cuda:0')
# train_recall: tensor([0.7128, 0.8449, 0.7770, 0.5811], device='cuda:0')
# val_loss: 0.5285271463294824
# val_precision: tensor([0.7562, 0.8204, 0.7909, 0.7018], device='cuda:0')
# val_recall: tensor([0.7080, 0.8624, 0.8066, 0.6498], device='cuda:0')
# Learning rate: 1e-05
# epoch 68 time:  3.7677337546666725
# --------------------------------
# ========================================
# EPOCH: 69
# train_loss: 0.5578561940008686
# train_precision: tensor([0.7340, 0.8039, 0.7796, 0.7365], device='cuda:0')
# train_recall: tensor([0.7129, 0.8450, 0.7766, 0.6014], device='cuda:0')
# val_loss: 0.5288640898134973
# val_precision: tensor([0.7456, 0.8272, 0.7955, 0.6974], device='cuda:0')
# val_recall: tensor([0.7227, 0.8541, 0.7987, 0.6566], device='cuda:0')
# Learning rate: 1e-05
# epoch 69 time:  3.7692044606333486
# --------------------------------
# ========================================
# EPOCH: 70
# train_loss: 0.5587020298199994
# train_precision: tensor([0.7342, 0.8028, 0.7809, 0.7263], device='cuda:0')
# train_recall: tensor([0.7118, 0.8471, 0.7760, 0.5928], device='cuda:0')
# val_loss: 0.5300653701027235
# val_precision: tensor([0.7456, 0.8343, 0.7857, 0.7095], device='cuda:0')
# val_recall: tensor([0.7209, 0.8456, 0.8091, 0.6374], device='cuda:0')
# Learning rate: 5e-06
# epoch 70 time:  3.7687019167499782
# --------------------------------
# ========================================
# EPOCH: 71
# train_loss: 0.5577098647753398
# train_precision: tensor([0.7339, 0.8022, 0.7799, 0.7389], device='cuda:0')
# train_recall: tensor([0.7106, 0.8454, 0.7779, 0.5941], device='cuda:0')
# val_loss: 0.5285000920295715
# val_precision: tensor([0.7432, 0.8266, 0.7970, 0.7052], device='cuda:0')
# val_recall: tensor([0.7268, 0.8549, 0.7947, 0.6394], device='cuda:0')
# Learning rate: 5e-06
# Early stopping at epoch 71 with best validation loss 0.5273290775716305
# training_checkpoints/resnet50_64x64_padding_2024-05-05 02:37:19.086272.pth
# <All keys matched successfully>
