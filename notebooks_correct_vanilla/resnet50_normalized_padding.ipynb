# %%
import time
import sys
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from dataset import ImageDataset
import torch.nn.functional as F
from torchmetrics import Precision, Recall
from torchvision.models import resnet50
import warnings
from collections import defaultdict
import wandb
import datetime
import os
warnings.filterwarnings('ignore')
torch.set_float32_matmul_precision('high')
#intecubic interpol

run_name = f'resnet50_normalize_batch_512_padd_Adam_{datetime.datetime.now()}'
run_path = f'training_checkpoints/{run_name}'

wandb.init(project="cells", 
           entity="adamsoja",
          name=run_name)

import random
random.seed(2233)
torch.manual_seed(2233)

#After /255 so in loading dataset there are no division by 255 just this normalization
mean = [0.5006, 0.3526, 0.5495]
std = [0.1493, 0.1341, 0.1124]


from albumentations import (
    Compose,
    Resize,
    OneOf,
    RandomBrightness,
    RandomContrast,
    MotionBlur,
    MedianBlur,
    GaussianBlur,
    VerticalFlip,
    HorizontalFlip,
    ShiftScaleRotate,
    Normalize,
)

transform = Compose(
    [
        Normalize(mean=mean, std=std),
        OneOf([RandomBrightness(limit=0.4, p=1), RandomContrast(limit=0.4, p=0.8)]),
        OneOf([MotionBlur(blur_limit=3), MedianBlur(blur_limit=3), GaussianBlur(blur_limit=3),], p=0.7,),
        VerticalFlip(p=0.5),
        HorizontalFlip(p=0.5),
    ]
)

transform_test = Compose(
    [Normalize(mean=mean, std=std)]
)

class MyModel(nn.Module):
    def __init__(self, model, learning_rate, weight_decay):
        super(MyModel, self).__init__()
        self.model = model
        self.learning_rate = learning_rate
        self.weight_decay = weight_decay
        self.criterion = nn.CrossEntropyLoss()
        self.metric_precision = Precision(task="multiclass", num_classes=4, average=None).to('cuda')
        self.metric_recall = Recall(task="multiclass", num_classes=4, average=None).to('cuda')
        self.train_loss = []
        self.valid_loss = []
        self.precision_per_epochs = []
        self.recall_per_epochs = []

        self.optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, mode="min", factor=0.1, patience=3, min_lr=5e-6, verbose=True)
        self.step = 0

    
    def forward(self, x):
        return self.model(x)

    def train_one_epoch(self, trainloader):
        self.step += 1
        self.train()
        for batch_idx, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()
            _, preds = torch.max(outputs, 1)
            _, labels = torch.max(labels, 1)
            self.metric_precision(preds, labels)
            self.metric_recall(preds, labels)
            self.train_loss.append(loss.item())


        

        
        avg_loss = np.mean(self.train_loss)
        self.train_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        self.precision_per_epochs.append(precision)
        self.recall_per_epochs.append(recall)
        print(f'train_loss: {avg_loss}')
        print(f'train_precision: {precision}')
        print(f'train_recall: {recall}')

        wandb.log({'loss': avg_loss},step=self.step)
        wandb.log({'Normal precision': precision[0].item()},step=self.step)
        wandb.log({'Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'Other precision': precision[3].item()},step=self.step)


        wandb.log({'Normal recall': recall[0].item()},step=self.step)
        wandb.log({'Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'Other recall': recall[3].item()},step=self.step)
        
        
        self.metric_precision.reset()
        self.metric_recall.reset()


    

    def evaluate(self, testloader):
        self.eval()
        with torch.no_grad():
            for batch_idx, (inputs, labels) in enumerate(testloader):
                inputs, labels = inputs.to('cuda'), labels.to('cuda')
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)
                _, labels = torch.max(labels, 1)
                self.metric_precision(preds, labels)
                self.metric_recall(preds, labels)
                self.valid_loss.append(loss.item())
    
        avg_loss = np.mean(self.valid_loss)
        self.scheduler.step(avg_loss)
        self.valid_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        print(f'val_loss: {avg_loss}')
        print(f'val_precision: {precision}')
        print(f'val_recall: {recall}')
        self.metric_precision.reset()
        self.metric_recall.reset()

        wandb.log({'val_loss': avg_loss}, step=self.step)
        
        wandb.log({'val_Normal precision': precision[0].item()},step=self.step)
        wandb.log({'val_Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'val_Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'val_Other precision': precision[3].item()},step=self.step)


        wandb.log({'val_Normal recall': recall[0].item()},step=self.step)
        wandb.log({'val_Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'val_Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'val_Other recall': recall[3].item()},step=self.step)


        for param_group in self.optimizer.param_groups:
            print(f"Learning rate: {param_group['lr']}")
        return avg_loss

torch.cuda.empty_cache()
batch_size = 512

trainset = ImageDataset(data_path='train_data', transform=transform)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=3)

testset = ImageDataset(data_path='validation_data', transform=transform_test)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)


learning_rate = 0.001
weight_decay = 0.00005

model = resnet50()
model.conv1 = nn.Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
num_classes = 4
model.fc = nn.Sequential(
    nn.Dropout(0.4),
    nn.Linear(model.fc.in_features, num_classes))
model = model.to('cuda')


my_model = MyModel(model=model, learning_rate=learning_rate, weight_decay=weight_decay)
my_model = my_model.to('cuda')

num_epochs = 100
early_stop_patience = 10
best_val_loss = float('inf')
best_model_state_dict = None

for epoch in range(num_epochs):
    print('========================================')
    print(f'EPOCH: {epoch}') 
    time_start = time.perf_counter()
    my_model.train_one_epoch(trainloader)
    val_loss = my_model.evaluate(testloader)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_state_dict = my_model.state_dict()
        torch.save(best_model_state_dict, f'{run_path}.pth')
        
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch} with best validation loss {best_val_loss}")
        break
    time_epoch = time.perf_counter() - time_start
    print(f'epoch {epoch} time:  {time_epoch/60}')
    print('--------------------------------')

# Load the best model state dict
print(f'{run_path}.pth')
my_model.load_state_dict(torch.load(f'{run_path}.pth'))
# Out:
# wandb: Currently logged in as: adamsoja. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/adam/Desktop/cells_master_thesis/wandb/run-20240428_232425-gm191j9v</code>
# Syncing run <strong><a href='https://wandb.ai/adamsoja/cells/runs/gm191j9v' target="_blank">resnet50_normalize_batch_512_padd_Adam_2024-04-28 23:24:24.952387</a></strong> to <a href='https://wandb.ai/adamsoja/cells' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adamsoja/cells' target="_blank">https://wandb.ai/adamsoja/cells</a>
#  View run at <a href='https://wandb.ai/adamsoja/cells/runs/gm191j9v' target="_blank">https://wandb.ai/adamsoja/cells/runs/gm191j9v</a>
# ========================================
# EPOCH: 0
# train_loss: 1.0020880998600097
# train_precision: tensor([0.5272, 0.6263, 0.5984, 0.1007], device='cuda:0')
# train_recall: tensor([0.5259, 0.7426, 0.5473, 0.0020], device='cuda:0')
# val_loss: 0.9214089999596278
# val_precision: tensor([0.5837, 0.6321, 0.6011, 0.0000], device='cuda:0')
# val_recall: tensor([0.4554, 0.7866, 0.6465, 0.0000], device='cuda:0')
# Learning rate: 0.001
# epoch 0 time:  1.0686190824833375
# --------------------------------
# ========================================
# EPOCH: 1
# train_loss: 0.899259281300363
# train_precision: tensor([0.5656, 0.6621, 0.6363, 0.4414], device='cuda:0')
# train_recall: tensor([0.5547, 0.7630, 0.6128, 0.0163], device='cuda:0')
# val_loss: 0.8303777156604661
# val_precision: tensor([0.6051, 0.7623, 0.6098, 0.9268], device='cuda:0')
# val_recall: tensor([0.4972, 0.7423, 0.7921, 0.0512], device='cuda:0')
# Learning rate: 0.001
# epoch 1 time:  1.0934240099333237
# --------------------------------
# ========================================
# EPOCH: 2
# train_loss: 0.8368499703350522
# train_precision: tensor([0.5939, 0.6924, 0.6609, 0.5711], device='cuda:0')
# train_recall: tensor([0.5805, 0.7813, 0.6496, 0.0644], device='cuda:0')
# val_loss: 0.8029995133479436
# val_precision: tensor([0.6034, 0.7421, 0.6474, 0.8920], device='cuda:0')
# val_recall: tensor([0.5595, 0.7620, 0.7365, 0.0751], device='cuda:0')
# Learning rate: 0.001
# epoch 2 time:  1.1403395372666636
# --------------------------------
# ========================================
# EPOCH: 3
# train_loss: 0.826184352238973
# train_precision: tensor([0.6028, 0.6987, 0.6634, 0.5345], device='cuda:0')
# train_recall: tensor([0.5816, 0.7855, 0.6588, 0.0949], device='cuda:0')
# val_loss: 0.7631382880939378
# val_precision: tensor([0.6489, 0.6990, 0.7160, 0.5714], device='cuda:0')
# val_recall: tensor([0.5959, 0.8415, 0.6635, 0.2923], device='cuda:0')
# Learning rate: 0.001
# epoch 3 time:  1.1542843319166727
# --------------------------------
# ========================================
# EPOCH: 4
# train_loss: 0.7987157851457596
# train_precision: tensor([0.6151, 0.7076, 0.6714, 0.5721], device='cuda:0')
# train_recall: tensor([0.5880, 0.7915, 0.6694, 0.1620], device='cuda:0')
# val_loss: 0.763433990544743
# val_precision: tensor([0.6855, 0.7772, 0.6398, 0.3703], device='cuda:0')
# val_recall: tensor([0.5295, 0.7659, 0.7920, 0.3865], device='cuda:0')
# Learning rate: 0.001
# epoch 4 time:  1.0839512253000065
# --------------------------------
# ========================================
# EPOCH: 5
# train_loss: 0.7850029435895738
# train_precision: tensor([0.6241, 0.7144, 0.6776, 0.5772], device='cuda:0')
# train_recall: tensor([0.5955, 0.7934, 0.6795, 0.1866], device='cuda:0')
# val_loss: 0.7264700896210141
# val_precision: tensor([0.6705, 0.7104, 0.7123, 0.8043], device='cuda:0')
# val_recall: tensor([0.5806, 0.8574, 0.7096, 0.2492], device='cuda:0')
# Learning rate: 0.001
# epoch 5 time:  1.1409632045166593
# --------------------------------
# ========================================
# EPOCH: 6
# train_loss: 0.7774400269701367
# train_precision: tensor([0.6277, 0.7175, 0.6807, 0.5919], device='cuda:0')
# train_recall: tensor([0.5978, 0.7948, 0.6840, 0.2068], device='cuda:0')
# val_loss: 0.7294697728421953
# val_precision: tensor([0.6789, 0.7222, 0.6988, 0.6495], device='cuda:0')
# val_recall: tensor([0.5791, 0.8428, 0.7217, 0.3064], device='cuda:0')
# Learning rate: 0.001
# epoch 6 time:  1.0698064128499936
# --------------------------------
# ========================================
# EPOCH: 7
# train_loss: 0.7701800594727198
# train_precision: tensor([0.6300, 0.7205, 0.6840, 0.6027], device='cuda:0')
# train_recall: tensor([0.6036, 0.7941, 0.6864, 0.2180], device='cuda:0')
# val_loss: 0.7221655675106579
# val_precision: tensor([0.7001, 0.7220, 0.6944, 0.7256], device='cuda:0')
# val_recall: tensor([0.5578, 0.8539, 0.7495, 0.2973], device='cuda:0')
# Learning rate: 0.001
# epoch 7 time:  1.131610429516665
# --------------------------------
# ========================================
# EPOCH: 8
# train_loss: 0.75856751033238
# train_precision: tensor([0.6375, 0.7253, 0.6901, 0.6122], device='cuda:0')
# train_recall: tensor([0.6097, 0.7998, 0.6923, 0.2310], device='cuda:0')
# val_loss: 0.6880343920654721
# val_precision: tensor([0.6626, 0.7634, 0.7159, 0.7064], device='cuda:0')
# val_recall: tensor([0.6113, 0.8198, 0.7537, 0.3589], device='cuda:0')
# Learning rate: 0.001
# epoch 8 time:  1.1301682710333352
# --------------------------------
# ========================================
# EPOCH: 9
# train_loss: 0.7594956175202415
# train_precision: tensor([0.6352, 0.7263, 0.6908, 0.6103], device='cuda:0')
# train_recall: tensor([0.6114, 0.7971, 0.6911, 0.2411], device='cuda:0')
# val_loss: 0.6925051669279735
# val_precision: tensor([0.6503, 0.7514, 0.7466, 0.8107], device='cuda:0')
# val_recall: tensor([0.6768, 0.8214, 0.6955, 0.2798], device='cuda:0')
# Learning rate: 0.001
# epoch 9 time:  1.0901731637666672
# --------------------------------
# ========================================
# EPOCH: 10
# train_loss: 0.7478313203368868
# train_precision: tensor([0.6396, 0.7291, 0.6952, 0.6123], device='cuda:0')
# train_recall: tensor([0.6150, 0.8018, 0.6934, 0.2521], device='cuda:0')
# val_loss: 0.696298593779405
# val_precision: tensor([0.6440, 0.7701, 0.7321, 0.7425], device='cuda:0')
# val_recall: tensor([0.6672, 0.8028, 0.7135, 0.3485], device='cuda:0')
# Learning rate: 0.001
# epoch 10 time:  1.063945082383331
# --------------------------------
# ========================================
# EPOCH: 11
# train_loss: 0.7428276733273551
# train_precision: tensor([0.6449, 0.7324, 0.6983, 0.6187], device='cuda:0')
# train_recall: tensor([0.6203, 0.8022, 0.6976, 0.2714], device='cuda:0')
# val_loss: 0.6876429311103291
# val_precision: tensor([0.6626, 0.7371, 0.7498, 0.7988], device='cuda:0')
# val_recall: tensor([0.6579, 0.8507, 0.6857, 0.3074], device='cuda:0')
# Learning rate: 0.001
# epoch 11 time:  1.116169898750013
# --------------------------------
# ========================================
# EPOCH: 12
# train_loss: 0.7365266157048089
# train_precision: tensor([0.6481, 0.7333, 0.6991, 0.6342], device='cuda:0')
# train_recall: tensor([0.6196, 0.8043, 0.7019, 0.2732], device='cuda:0')
# val_loss: 0.6866292650500934
# val_precision: tensor([0.6920, 0.8036, 0.6694, 0.8146], device='cuda:0')
# val_recall: tensor([0.6110, 0.7725, 0.8168, 0.2899], device='cuda:0')
# Learning rate: 0.001
# epoch 12 time:  1.1188089478000014
# --------------------------------
# ========================================
# EPOCH: 13
# train_loss: 0.7325423592612856
# train_precision: tensor([0.6486, 0.7332, 0.7038, 0.6255], device='cuda:0')
# train_recall: tensor([0.6225, 0.8053, 0.7026, 0.2733], device='cuda:0')
# val_loss: 0.6714987930324342
# val_precision: tensor([0.7022, 0.7692, 0.7054, 0.6581], device='cuda:0')
# val_recall: tensor([0.6099, 0.8186, 0.7825, 0.3811], device='cuda:0')
# Learning rate: 0.001
# epoch 13 time:  1.1321044303833332
# --------------------------------
# ========================================
# EPOCH: 14
# train_loss: 0.7261741973104932
# train_precision: tensor([0.6523, 0.7362, 0.7074, 0.6261], device='cuda:0')
# train_recall: tensor([0.6291, 0.8062, 0.7032, 0.2899], device='cuda:0')
# val_loss: 0.6748606552680333
# val_precision: tensor([0.6379, 0.7540, 0.7893, 0.7146], device='cuda:0')
# val_recall: tensor([0.7116, 0.8355, 0.6460, 0.4131], device='cuda:0')
# Learning rate: 0.001
# epoch 14 time:  1.0783720465166728
# --------------------------------
# ========================================
# EPOCH: 15
# train_loss: 0.723211503596533
# train_precision: tensor([0.6504, 0.7379, 0.7074, 0.6345], device='cuda:0')
# train_recall: tensor([0.6268, 0.8077, 0.7027, 0.3066], device='cuda:0')
# val_loss: 0.6699928161170747
# val_precision: tensor([0.6279, 0.8077, 0.7516, 0.7944], device='cuda:0')
# val_recall: tensor([0.7420, 0.7639, 0.6973, 0.3566], device='cuda:0')
# Learning rate: 0.001
# epoch 15 time:  1.1059961168666783
# --------------------------------
# ========================================
# EPOCH: 16
# train_loss: 0.7168262241851716
# train_precision: tensor([0.6558, 0.7411, 0.7103, 0.6275], device='cuda:0')
# train_recall: tensor([0.6318, 0.8081, 0.7078, 0.3121], device='cuda:0')
# val_loss: 0.664166334271431
# val_precision: tensor([0.6851, 0.7446, 0.7591, 0.6277], device='cuda:0')
# val_recall: tensor([0.6507, 0.8560, 0.7118, 0.3946], device='cuda:0')
# Learning rate: 0.001
# epoch 16 time:  1.120012210566665
# --------------------------------
# ========================================
# EPOCH: 17
# train_loss: 0.711694798724992
# train_precision: tensor([0.6582, 0.7442, 0.7129, 0.6346], device='cuda:0')
# train_recall: tensor([0.6364, 0.8100, 0.7081, 0.3260], device='cuda:0')
# val_loss: 0.6565102368593216
# val_precision: tensor([0.6787, 0.8230, 0.7079, 0.5834], device='cuda:0')
# val_recall: tensor([0.6517, 0.7629, 0.7976, 0.5017], device='cuda:0')
# Learning rate: 0.001
# epoch 17 time:  1.107825762183332
# --------------------------------
# ========================================
# EPOCH: 18
# train_loss: 0.7115535388390223
# train_precision: tensor([0.6602, 0.7418, 0.7145, 0.6334], device='cuda:0')
# train_recall: tensor([0.6350, 0.8101, 0.7109, 0.3231], device='cuda:0')
# val_loss: 0.710246391263273
# val_precision: tensor([0.6786, 0.8285, 0.6510, 0.7195], device='cuda:0')
# val_recall: tensor([0.6543, 0.6904, 0.8100, 0.4205], device='cuda:0')
# Learning rate: 0.001
# epoch 18 time:  1.0882372559166622
# --------------------------------
# ========================================
# EPOCH: 19
# train_loss: 0.7053844007707778
# train_precision: tensor([0.6637, 0.7443, 0.7157, 0.6427], device='cuda:0')
# train_recall: tensor([0.6382, 0.8098, 0.7155, 0.3263], device='cuda:0')
# val_loss: 0.655863315363725
# val_precision: tensor([0.6733, 0.8094, 0.7128, 0.8268], device='cuda:0')
# val_recall: tensor([0.6719, 0.7672, 0.7898, 0.3808], device='cuda:0')
# Learning rate: 0.001
# epoch 19 time:  1.1176093749833247
# --------------------------------
# ========================================
# EPOCH: 20
# train_loss: 0.7030130634705226
# train_precision: tensor([0.6651, 0.7456, 0.7201, 0.6415], device='cuda:0')
# train_recall: tensor([0.6425, 0.8126, 0.7145, 0.3333], device='cuda:0')
# val_loss: 0.6521469339728355
# val_precision: tensor([0.6798, 0.8103, 0.7132, 0.7662], device='cuda:0')
# val_recall: tensor([0.6718, 0.7776, 0.7826, 0.4192], device='cuda:0')
# Learning rate: 0.001
# epoch 20 time:  1.1163551162333383
# --------------------------------
# ========================================
# EPOCH: 21
# train_loss: 0.7011745833215259
# train_precision: tensor([0.6650, 0.7447, 0.7193, 0.6441], device='cuda:0')
# train_recall: tensor([0.6417, 0.8112, 0.7131, 0.3508], device='cuda:0')
# val_loss: 0.6478986226850085
# val_precision: tensor([0.7066, 0.7939, 0.7117, 0.7681], device='cuda:0')
# val_recall: tensor([0.6380, 0.8208, 0.7914, 0.3936], device='cuda:0')
# Learning rate: 0.001
# epoch 21 time:  1.1096609186833273
# --------------------------------
# ========================================
# EPOCH: 22
# train_loss: 0.6946690247172401
# train_precision: tensor([0.6668, 0.7494, 0.7233, 0.6433], device='cuda:0')
# train_recall: tensor([0.6468, 0.8127, 0.7159, 0.3592], device='cuda:0')
# val_loss: 0.6684665482905175
# val_precision: tensor([0.6963, 0.8330, 0.6770, 0.8034], device='cuda:0')
# val_recall: tensor([0.6447, 0.7464, 0.8329, 0.3838], device='cuda:0')
# Learning rate: 0.001
# epoch 22 time:  1.0731329317333347
# --------------------------------
# ========================================
# EPOCH: 23
# train_loss: 0.6912499231951578
# train_precision: tensor([0.6689, 0.7500, 0.7259, 0.6421], device='cuda:0')
# train_recall: tensor([0.6502, 0.8152, 0.7154, 0.3570], device='cuda:0')
# val_loss: 0.6509367396434148
# val_precision: tensor([0.7052, 0.7390, 0.7554, 0.6715], device='cuda:0')
# val_recall: tensor([0.6298, 0.8668, 0.7244, 0.5037], device='cuda:0')
# Learning rate: 0.001
# epoch 23 time:  1.090965805383333
# --------------------------------
# ========================================
# EPOCH: 24
# train_loss: 0.6881828512464251
# train_precision: tensor([0.6712, 0.7518, 0.7263, 0.6544], device='cuda:0')
# train_recall: tensor([0.6502, 0.8151, 0.7200, 0.3661], device='cuda:0')
# val_loss: 0.6308934999836816
# val_precision: tensor([0.7225, 0.7930, 0.7224, 0.6874], device='cuda:0')
# val_recall: tensor([0.6496, 0.8170, 0.7941, 0.4916], device='cuda:0')
# Learning rate: 0.001
# epoch 24 time:  1.1326692253333326
# --------------------------------
# ========================================
# EPOCH: 25
# train_loss: 0.6858884394168854
# train_precision: tensor([0.6728, 0.7510, 0.7271, 0.6553], device='cuda:0')
# train_recall: tensor([0.6480, 0.8149, 0.7230, 0.3753], device='cuda:0')
# val_loss: 0.6535693362355233
# val_precision: tensor([0.6929, 0.7992, 0.7140, 0.8005], device='cuda:0')
# val_recall: tensor([0.6581, 0.8123, 0.7777, 0.3579], device='cuda:0')
# Learning rate: 0.001
# epoch 25 time:  1.0825355949499984
# --------------------------------
# ========================================
# EPOCH: 26
# train_loss: 0.6822741993835995
# train_precision: tensor([0.6745, 0.7535, 0.7285, 0.6545], device='cuda:0')
# train_recall: tensor([0.6531, 0.8173, 0.7209, 0.3762], device='cuda:0')
# val_loss: 0.6234766244888306
# val_precision: tensor([0.6814, 0.8132, 0.7472, 0.7174], device='cuda:0')
# val_recall: tensor([0.6897, 0.8040, 0.7710, 0.4828], device='cuda:0')
# Learning rate: 0.001
# epoch 26 time:  1.1311590137500085
# --------------------------------
# ========================================
# EPOCH: 27
# train_loss: 0.6800763642504102
# train_precision: tensor([0.6739, 0.7535, 0.7291, 0.6590], device='cuda:0')
# train_recall: tensor([0.6525, 0.8163, 0.7228, 0.3756], device='cuda:0')
# val_loss: 0.6372122559282515
# val_precision: tensor([0.7062, 0.7750, 0.7377, 0.6200], device='cuda:0')
# val_recall: tensor([0.6320, 0.8353, 0.7651, 0.5582], device='cuda:0')
# Learning rate: 0.001
# epoch 27 time:  1.0890292047666663
# --------------------------------
# ========================================
# EPOCH: 28
# train_loss: 0.6769808492490224
# train_precision: tensor([0.6762, 0.7551, 0.7309, 0.6577], device='cuda:0')
# train_recall: tensor([0.6542, 0.8180, 0.7242, 0.3825], device='cuda:0')
# val_loss: 0.6150065703524483
# val_precision: tensor([0.7040, 0.8257, 0.7274, 0.7385], device='cuda:0')
# val_recall: tensor([0.6834, 0.7957, 0.8004, 0.4832], device='cuda:0')
# Learning rate: 0.001
# epoch 28 time:  1.1297582246166713
# --------------------------------
# ========================================
# EPOCH: 29
# train_loss: 0.6734474444673175
# train_precision: tensor([0.6784, 0.7580, 0.7319, 0.6530], device='cuda:0')
# train_recall: tensor([0.6569, 0.8187, 0.7264, 0.3864], device='cuda:0')
# val_loss: 0.6242709201243188
# val_precision: tensor([0.7199, 0.7952, 0.7240, 0.7836], device='cuda:0')
# val_recall: tensor([0.6448, 0.8334, 0.7959, 0.4461], device='cuda:0')
# Learning rate: 0.001
# epoch 29 time:  1.0780819849833279
# --------------------------------
# ========================================
# EPOCH: 30
# train_loss: 0.6726258628425144
# train_precision: tensor([0.6790, 0.7574, 0.7308, 0.6579], device='cuda:0')
# train_recall: tensor([0.6594, 0.8167, 0.7249, 0.3863], device='cuda:0')
# val_loss: 0.6265076158775224
# val_precision: tensor([0.6807, 0.8485, 0.7163, 0.7315], device='cuda:0')
# val_recall: tensor([0.6993, 0.7508, 0.8027, 0.4926], device='cuda:0')
# Learning rate: 0.001
# epoch 30 time:  1.0893068336333271
# --------------------------------
# ========================================
# EPOCH: 31
# train_loss: 0.6705498987720127
# train_precision: tensor([0.6788, 0.7563, 0.7344, 0.6650], device='cuda:0')
# train_recall: tensor([0.6614, 0.8161, 0.7251, 0.3945], device='cuda:0')
# val_loss: 0.6173853405647808
# val_precision: tensor([0.6978, 0.7879, 0.7598, 0.7262], device='cuda:0')
# val_recall: tensor([0.6795, 0.8470, 0.7468, 0.4956], device='cuda:0')
# Learning rate: 0.001
# epoch 31 time:  1.0659653163000107
# --------------------------------
# ========================================
# EPOCH: 32
# train_loss: 0.6673297122830436
# train_precision: tensor([0.6820, 0.7577, 0.7343, 0.6605], device='cuda:0')
# train_recall: tensor([0.6598, 0.8192, 0.7278, 0.3973], device='cuda:0')
# val_loss: 0.6163675457239151
# val_precision: tensor([0.7280, 0.7751, 0.7588, 0.5471], device='cuda:0')
# val_recall: tensor([0.6477, 0.8485, 0.7638, 0.5963], device='cuda:0')
# Learning rate: 0.0001
# epoch 32 time:  1.0885289336499986
# --------------------------------
# ========================================
# EPOCH: 33
# train_loss: 0.6325132622605278
# train_precision: tensor([0.6992, 0.7710, 0.7497, 0.6899], device='cuda:0')
# train_recall: tensor([0.6753, 0.8290, 0.7441, 0.4580], device='cuda:0')
# val_loss: 0.5677464854386117
# val_precision: tensor([0.7246, 0.8216, 0.7713, 0.7129], device='cuda:0')
# val_recall: tensor([0.7093, 0.8328, 0.7922, 0.5734], device='cuda:0')
# Learning rate: 0.0001
# epoch 33 time:  1.1458574240500032
# --------------------------------
# ========================================
# EPOCH: 34
# train_loss: 0.6233402700651259
# train_precision: tensor([0.7044, 0.7752, 0.7565, 0.6961], device='cuda:0')
# train_recall: tensor([0.6832, 0.8323, 0.7472, 0.4784], device='cuda:0')
# val_loss: 0.565085369348526
# val_precision: tensor([0.7450, 0.8158, 0.7572, 0.7249], device='cuda:0')
# val_recall: tensor([0.6826, 0.8425, 0.8119, 0.5724], device='cuda:0')
# Learning rate: 0.0001
# epoch 34 time:  1.1581664784500088
# --------------------------------
# ========================================
# EPOCH: 35
# train_loss: 0.6184678155751455
# train_precision: tensor([0.7059, 0.7771, 0.7560, 0.6920], device='cuda:0')
# train_recall: tensor([0.6837, 0.8326, 0.7490, 0.4808], device='cuda:0')
# val_loss: 0.557953078382545
# val_precision: tensor([0.7310, 0.8157, 0.7784, 0.7226], device='cuda:0')
# val_recall: tensor([0.7095, 0.8423, 0.7911, 0.5815], device='cuda:0')
# Learning rate: 0.0001
# epoch 35 time:  1.1444163595833288
# --------------------------------
# ========================================
# EPOCH: 36
# train_loss: 0.6142206440369288
# train_precision: tensor([0.7086, 0.7790, 0.7589, 0.6960], device='cuda:0')
# train_recall: tensor([0.6884, 0.8326, 0.7508, 0.4899], device='cuda:0')
# val_loss: 0.5576156159241994
# val_precision: tensor([0.7352, 0.8206, 0.7690, 0.7127], device='cuda:0')
# val_recall: tensor([0.7026, 0.8368, 0.7992, 0.6081], device='cuda:0')
# Learning rate: 0.0001
# epoch 36 time:  1.163146527133343
# --------------------------------
# ========================================
# EPOCH: 37
# train_loss: 0.6107358511005129
# train_precision: tensor([0.7109, 0.7804, 0.7607, 0.6887], device='cuda:0')
# train_recall: tensor([0.6896, 0.8339, 0.7529, 0.4935], device='cuda:0')
# val_loss: 0.5548054279552566
# val_precision: tensor([0.7400, 0.8129, 0.7774, 0.7164], device='cuda:0')
# val_recall: tensor([0.6977, 0.8498, 0.7983, 0.6074], device='cuda:0')
# Learning rate: 0.0001
# epoch 37 time:  1.151146408166657
# --------------------------------
# ========================================
# EPOCH: 38
# train_loss: 0.6087050863674709
# train_precision: tensor([0.7112, 0.7803, 0.7608, 0.6915], device='cuda:0')
# train_recall: tensor([0.6883, 0.8348, 0.7529, 0.5030], device='cuda:0')
# val_loss: 0.5577003391252624
# val_precision: tensor([0.7369, 0.8152, 0.7706, 0.7382], device='cuda:0')
# val_recall: tensor([0.6951, 0.8457, 0.8029, 0.5707], device='cuda:0')
# Learning rate: 0.0001
# epoch 38 time:  1.1057268495666601
# --------------------------------
# ========================================
# EPOCH: 39
# train_loss: 0.6063964681965964
# train_precision: tensor([0.7131, 0.7820, 0.7612, 0.7016], device='cuda:0')
# train_recall: tensor([0.6908, 0.8345, 0.7561, 0.4978], device='cuda:0')
# val_loss: 0.5527873610456785
# val_precision: tensor([0.7324, 0.8072, 0.7918, 0.7291], device='cuda:0')
# val_recall: tensor([0.7144, 0.8558, 0.7779, 0.5980], device='cuda:0')
# Learning rate: 0.0001
# epoch 39 time:  1.1444781881333257
# --------------------------------
# ========================================
# EPOCH: 40
# train_loss: 0.604435206878753
# train_precision: tensor([0.7129, 0.7828, 0.7628, 0.6929], device='cuda:0')
# train_recall: tensor([0.6924, 0.8350, 0.7541, 0.5089], device='cuda:0')
# val_loss: 0.5506373564402263
# val_precision: tensor([0.7324, 0.8158, 0.7889, 0.7176], device='cuda:0')
# val_recall: tensor([0.7163, 0.8489, 0.7853, 0.6185], device='cuda:0')
# Learning rate: 0.0001
# epoch 40 time:  1.129982116083329
# --------------------------------
# ========================================
# EPOCH: 41
# train_loss: 0.6018438062497548
# train_precision: tensor([0.7134, 0.7823, 0.7637, 0.7014], device='cuda:0')
# train_recall: tensor([0.6926, 0.8356, 0.7541, 0.5156], device='cuda:0')
# val_loss: 0.5523457452654839
# val_precision: tensor([0.7253, 0.8263, 0.7880, 0.7256], device='cuda:0')
# val_recall: tensor([0.7333, 0.8340, 0.7860, 0.5973], device='cuda:0')
# Learning rate: 0.0001
# epoch 41 time:  1.1011155122000067
# --------------------------------
# ========================================
# EPOCH: 42
# train_loss: 0.6000262183092889
# train_precision: tensor([0.7157, 0.7843, 0.7628, 0.7029], device='cuda:0')
# train_recall: tensor([0.6920, 0.8357, 0.7572, 0.5258], device='cuda:0')
# val_loss: 0.5489484015438292
# val_precision: tensor([0.7318, 0.8222, 0.7833, 0.7215], device='cuda:0')
# val_recall: tensor([0.7202, 0.8382, 0.7926, 0.6098], device='cuda:0')
# Learning rate: 0.0001
# epoch 42 time:  1.1512850996666657
# --------------------------------
# ========================================
# EPOCH: 43
# train_loss: 0.5976340452829997
# train_precision: tensor([0.7168, 0.7843, 0.7652, 0.7048], device='cuda:0')
# train_recall: tensor([0.6953, 0.8381, 0.7563, 0.5153], device='cuda:0')
# val_loss: 0.5467465304666095
# val_precision: tensor([0.7375, 0.8099, 0.7926, 0.7235], device='cuda:0')
# val_recall: tensor([0.7145, 0.8544, 0.7864, 0.6071], device='cuda:0')
# Learning rate: 0.0001
# epoch 43 time:  1.160158622450005
# --------------------------------
# ========================================
# EPOCH: 44
# train_loss: 0.5972742781043052
# train_precision: tensor([0.7154, 0.7868, 0.7658, 0.7046], device='cuda:0')
# train_recall: tensor([0.6962, 0.8372, 0.7571, 0.5228], device='cuda:0')
# val_loss: 0.5489020455214713
# val_precision: tensor([0.7426, 0.8123, 0.7792, 0.7303], device='cuda:0')
# val_recall: tensor([0.7019, 0.8511, 0.7996, 0.5899], device='cuda:0')
# Learning rate: 0.0001
# epoch 44 time:  1.111509188033339
# --------------------------------
# ========================================
# EPOCH: 45
# train_loss: 0.5931248082291513
# train_precision: tensor([0.7187, 0.7873, 0.7687, 0.7060], device='cuda:0')
# train_recall: tensor([0.6993, 0.8375, 0.7602, 0.5244], device='cuda:0')
# val_loss: 0.5453769895765517
# val_precision: tensor([0.7386, 0.8204, 0.7853, 0.7215], device='cuda:0')
# val_recall: tensor([0.7162, 0.8448, 0.7967, 0.6212], device='cuda:0')
# Learning rate: 0.0001
# epoch 45 time:  1.1506229214833334
# --------------------------------
# ========================================
# EPOCH: 46
# train_loss: 0.5931807198694774
# train_precision: tensor([0.7188, 0.7861, 0.7670, 0.7072], device='cuda:0')
# train_recall: tensor([0.6981, 0.8373, 0.7585, 0.5299], device='cuda:0')
# val_loss: 0.5479782005151113
# val_precision: tensor([0.7348, 0.8231, 0.7839, 0.7095], device='cuda:0')
# val_recall: tensor([0.7211, 0.8390, 0.7939, 0.6135], device='cuda:0')
# Learning rate: 0.0001
# epoch 46 time:  1.1169147362833427
# --------------------------------
# ========================================
# EPOCH: 47
# train_loss: 0.5896763205528259
# train_precision: tensor([0.7174, 0.7889, 0.7677, 0.7080], device='cuda:0')
# train_recall: tensor([0.6990, 0.8373, 0.7590, 0.5358], device='cuda:0')
# val_loss: 0.5458138972520828
# val_precision: tensor([0.7449, 0.8178, 0.7817, 0.7445], device='cuda:0')
# val_recall: tensor([0.7104, 0.8534, 0.7992, 0.5993], device='cuda:0')
# Learning rate: 0.0001
# epoch 47 time:  1.1117856764000105
# --------------------------------
# ========================================
# EPOCH: 48
# train_loss: 0.5885882066119285
# train_precision: tensor([0.7204, 0.7886, 0.7684, 0.7108], device='cuda:0')
# train_recall: tensor([0.7000, 0.8380, 0.7610, 0.5356], device='cuda:0')
# val_loss: 0.5448880574769444
# val_precision: tensor([0.7394, 0.8162, 0.7905, 0.7106], device='cuda:0')
# val_recall: tensor([0.7134, 0.8510, 0.7934, 0.6316], device='cuda:0')
# Learning rate: 0.0001
# epoch 48 time:  1.1491649177499919
# --------------------------------
# ========================================
# EPOCH: 49
# train_loss: 0.5870143823680424
# train_precision: tensor([0.7211, 0.7890, 0.7710, 0.7108], device='cuda:0')
# train_recall: tensor([0.7017, 0.8388, 0.7614, 0.5416], device='cuda:0')
# val_loss: 0.5432369334830178
# val_precision: tensor([0.7378, 0.8129, 0.7929, 0.7716], device='cuda:0')
# val_recall: tensor([0.7213, 0.8559, 0.7883, 0.5791], device='cuda:0')
# Learning rate: 0.0001
# epoch 49 time:  1.162694985633334
# --------------------------------
# ========================================
# EPOCH: 50
# train_loss: 0.5852350507463727
# train_precision: tensor([0.7221, 0.7899, 0.7711, 0.7073], device='cuda:0')
# train_recall: tensor([0.7016, 0.8410, 0.7616, 0.5369], device='cuda:0')
# val_loss: 0.542732247710228
# val_precision: tensor([0.7450, 0.8201, 0.7863, 0.7271], device='cuda:0')
# val_recall: tensor([0.7150, 0.8501, 0.8019, 0.6108], device='cuda:0')
# Learning rate: 0.0001
# epoch 50 time:  1.1078780386999976
# --------------------------------
# ========================================
# EPOCH: 51
# train_loss: 0.5843525076196308
# train_precision: tensor([0.7225, 0.7901, 0.7697, 0.7142], device='cuda:0')
# train_recall: tensor([0.7015, 0.8393, 0.7622, 0.5466], device='cuda:0')
# val_loss: 0.542842747271061
# val_precision: tensor([0.7431, 0.8215, 0.7858, 0.6929], device='cuda:0')
# val_recall: tensor([0.7108, 0.8492, 0.7985, 0.6488], device='cuda:0')
# Learning rate: 0.0001
# epoch 51 time:  1.0444936260000153
# --------------------------------
# ========================================
# EPOCH: 52
# train_loss: 0.5831610146022979
# train_precision: tensor([0.7223, 0.7904, 0.7714, 0.7109], device='cuda:0')
# train_recall: tensor([0.7027, 0.8385, 0.7631, 0.5476], device='cuda:0')
# val_loss: 0.544992273218102
# val_precision: tensor([0.7313, 0.8287, 0.7863, 0.7485], device='cuda:0')
# val_recall: tensor([0.7271, 0.8356, 0.8001, 0.5983], device='cuda:0')
# Learning rate: 0.0001
# epoch 52 time:  1.0438546744000026
# --------------------------------
# ========================================
# EPOCH: 53
# train_loss: 0.5787669286131859
# train_precision: tensor([0.7250, 0.7916, 0.7735, 0.7133], device='cuda:0')
# train_recall: tensor([0.7068, 0.8407, 0.7618, 0.5569], device='cuda:0')
# val_loss: 0.5421385375989808
# val_precision: tensor([0.7381, 0.8131, 0.8037, 0.7115], device='cuda:0')
# val_recall: tensor([0.7266, 0.8576, 0.7822, 0.6229], device='cuda:0')
# Learning rate: 0.0001
# epoch 53 time:  1.0877765224833336
# --------------------------------
# ========================================
# EPOCH: 54
# train_loss: 0.5788362207157272
# train_precision: tensor([0.7254, 0.7907, 0.7748, 0.7080], device='cuda:0')
# train_recall: tensor([0.7063, 0.8416, 0.7626, 0.5494], device='cuda:0')
# val_loss: 0.5435751583841112
# val_precision: tensor([0.7399, 0.8302, 0.7784, 0.7470], device='cuda:0')
# val_recall: tensor([0.7181, 0.8380, 0.8093, 0.6003], device='cuda:0')
# Learning rate: 0.0001
# epoch 54 time:  1.0436432577666588
# --------------------------------
# ========================================
# EPOCH: 55
# train_loss: 0.5773681392981893
# train_precision: tensor([0.7267, 0.7924, 0.7735, 0.7132], device='cuda:0')
# train_recall: tensor([0.7061, 0.8426, 0.7639, 0.5530], device='cuda:0')
# val_loss: 0.5409736764099863
# val_precision: tensor([0.7440, 0.8273, 0.7817, 0.6900], device='cuda:0')
# val_recall: tensor([0.7124, 0.8424, 0.8051, 0.6505], device='cuda:0')
# Learning rate: 0.0001
# epoch 55 time:  1.086240574233337
# --------------------------------
# ========================================
# EPOCH: 56
# train_loss: 0.5753564357757568
# train_precision: tensor([0.7246, 0.7927, 0.7745, 0.7154], device='cuda:0')
# train_recall: tensor([0.7058, 0.8414, 0.7634, 0.5639], device='cuda:0')
# val_loss: 0.5385812615354856
# val_precision: tensor([0.7521, 0.8212, 0.7823, 0.7147], device='cuda:0')
# val_recall: tensor([0.7067, 0.8520, 0.8087, 0.6367], device='cuda:0')
# Learning rate: 0.0001
# epoch 56 time:  1.0865055777333206
# --------------------------------
# ========================================
# EPOCH: 57
# train_loss: 0.5743758165410586
# train_precision: tensor([0.7277, 0.7921, 0.7748, 0.7176], device='cuda:0')
# train_recall: tensor([0.7073, 0.8416, 0.7649, 0.5609], device='cuda:0')
# val_loss: 0.5367314936386214
# val_precision: tensor([0.7415, 0.8239, 0.7936, 0.7267], device='cuda:0')
# val_recall: tensor([0.7257, 0.8497, 0.7975, 0.6178], device='cuda:0')
# Learning rate: 0.0001
# epoch 57 time:  1.0852641694833438
# --------------------------------
# ========================================
# EPOCH: 58
# train_loss: 0.571597161250455
# train_precision: tensor([0.7282, 0.7954, 0.7763, 0.7236], device='cuda:0')
# train_recall: tensor([0.7095, 0.8433, 0.7660, 0.5693], device='cuda:0')
# val_loss: 0.5404370496670405
# val_precision: tensor([0.7491, 0.8138, 0.7922, 0.6707], device='cuda:0')
# val_recall: tensor([0.7094, 0.8561, 0.7932, 0.6687], device='cuda:0')
# Learning rate: 0.0001
# epoch 58 time:  1.0463671170166586
# --------------------------------
# ========================================
# EPOCH: 59
# train_loss: 0.5710564167017028
# train_precision: tensor([0.7299, 0.7945, 0.7769, 0.7174], device='cuda:0')
# train_recall: tensor([0.7095, 0.8437, 0.7657, 0.5771], device='cuda:0')
# val_loss: 0.5446586181720098
# val_precision: tensor([0.7268, 0.8239, 0.7997, 0.7567], device='cuda:0')
# val_recall: tensor([0.7395, 0.8440, 0.7843, 0.5865], device='cuda:0')
# Learning rate: 0.0001
# epoch 59 time:  1.0414735328333335
# --------------------------------
# ========================================
# EPOCH: 60
# train_loss: 0.5695417553895996
# train_precision: tensor([0.7294, 0.7961, 0.7779, 0.7280], device='cuda:0')
# train_recall: tensor([0.7108, 0.8436, 0.7678, 0.5734], device='cuda:0')
# val_loss: 0.5391985595226287
# val_precision: tensor([0.7516, 0.8215, 0.7814, 0.7265], device='cuda:0')
# val_recall: tensor([0.7053, 0.8521, 0.8106, 0.6313], device='cuda:0')
# Learning rate: 0.0001
# epoch 60 time:  1.041298000583356
# --------------------------------
# ========================================
# EPOCH: 61
# train_loss: 0.5670286759024574
# train_precision: tensor([0.7316, 0.7951, 0.7764, 0.7293], device='cuda:0')
# train_recall: tensor([0.7106, 0.8452, 0.7656, 0.5804], device='cuda:0')
# val_loss: 0.539049711326758
# val_precision: tensor([0.7277, 0.8303, 0.8026, 0.7237], device='cuda:0')
# val_recall: tensor([0.7463, 0.8398, 0.7821, 0.6411], device='cuda:0')
# Learning rate: 1e-05
# epoch 61 time:  1.0425172035833383
# --------------------------------
# ========================================
# EPOCH: 62
# train_loss: 0.5591090028484662
# train_precision: tensor([0.7331, 0.7993, 0.7833, 0.7413], device='cuda:0')
# train_recall: tensor([0.7194, 0.8450, 0.7690, 0.5913], device='cuda:0')
# val_loss: 0.5339431040816837
# val_precision: tensor([0.7377, 0.8268, 0.7987, 0.7314], device='cuda:0')
# val_recall: tensor([0.7343, 0.8480, 0.7915, 0.6438], device='cuda:0')
# Learning rate: 1e-05
# epoch 62 time:  1.0827435286000158
# --------------------------------
# ========================================
# EPOCH: 63
# train_loss: 0.5576753629105432
# train_precision: tensor([0.7339, 0.7981, 0.7836, 0.7370], device='cuda:0')
# train_recall: tensor([0.7187, 0.8453, 0.7696, 0.5863], device='cuda:0')
# val_loss: 0.5343282520771027
# val_precision: tensor([0.7466, 0.8223, 0.7919, 0.7303], device='cuda:0')
# val_recall: tensor([0.7197, 0.8538, 0.8001, 0.6380], device='cuda:0')
# Learning rate: 1e-05
# epoch 63 time:  1.041407102033342
# --------------------------------
# ========================================
# EPOCH: 64
# train_loss: 0.5574811525997662
# train_precision: tensor([0.7359, 0.7997, 0.7828, 0.7294], device='cuda:0')
# train_recall: tensor([0.7170, 0.8470, 0.7721, 0.5847], device='cuda:0')
# val_loss: 0.5355114749736256
# val_precision: tensor([0.7441, 0.8228, 0.7937, 0.7322], device='cuda:0')
# val_recall: tensor([0.7234, 0.8531, 0.7972, 0.6343], device='cuda:0')
# Learning rate: 1e-05
# epoch 64 time:  1.0417961204999908
# --------------------------------
# ========================================
# EPOCH: 65
# train_loss: 0.5546515037616094
# train_precision: tensor([0.7362, 0.8014, 0.7832, 0.7320], device='cuda:0')
# train_recall: tensor([0.7176, 0.8486, 0.7728, 0.5824], device='cuda:0')
# val_loss: 0.5347989694939719
# val_precision: tensor([0.7446, 0.8263, 0.7892, 0.7292], device='cuda:0')
# val_recall: tensor([0.7216, 0.8484, 0.8023, 0.6391], device='cuda:0')
# Learning rate: 1e-05
# epoch 65 time:  1.0416218304666471
# --------------------------------
# ========================================
# EPOCH: 66
# train_loss: 0.5543461438445818
# train_precision: tensor([0.7358, 0.8007, 0.7831, 0.7440], device='cuda:0')
# train_recall: tensor([0.7186, 0.8473, 0.7714, 0.5949], device='cuda:0')
# val_loss: 0.5336545603142844
# val_precision: tensor([0.7460, 0.8240, 0.7946, 0.7146], device='cuda:0')
# val_recall: tensor([0.7234, 0.8519, 0.7985, 0.6542], device='cuda:0')
# Learning rate: 1e-05
# epoch 66 time:  1.0840886992666432
# --------------------------------
# ========================================
# EPOCH: 67
# train_loss: 0.5537753352806681
# train_precision: tensor([0.7360, 0.8002, 0.7839, 0.7340], device='cuda:0')
# train_recall: tensor([0.7175, 0.8471, 0.7721, 0.5997], device='cuda:0')
# val_loss: 0.5349717045823733
# val_precision: tensor([0.7469, 0.8284, 0.7861, 0.7260], device='cuda:0')
# val_recall: tensor([0.7187, 0.8475, 0.8078, 0.6327], device='cuda:0')
# Learning rate: 1e-05
# epoch 67 time:  1.0419608322000082
# --------------------------------
# ========================================
# EPOCH: 68
# train_loss: 0.5541631700737136
# train_precision: tensor([0.7353, 0.8005, 0.7844, 0.7346], device='cuda:0')
# train_recall: tensor([0.7191, 0.8471, 0.7720, 0.5851], device='cuda:0')
# val_loss: 0.5337495138247808
# val_precision: tensor([0.7476, 0.8193, 0.7959, 0.7303], device='cuda:0')
# val_recall: tensor([0.7188, 0.8579, 0.7990, 0.6380], device='cuda:0')
# Learning rate: 1e-05
# epoch 68 time:  1.0412438262666608
# --------------------------------
# ========================================
# EPOCH: 69
# train_loss: 0.5527672356792859
# train_precision: tensor([0.7361, 0.8013, 0.7847, 0.7273], device='cuda:0')
# train_recall: tensor([0.7196, 0.8479, 0.7711, 0.5947], device='cuda:0')
# val_loss: 0.5357350365983116
# val_precision: tensor([0.7499, 0.8241, 0.7883, 0.7196], device='cuda:0')
# val_recall: tensor([0.7160, 0.8515, 0.8054, 0.6488], device='cuda:0')
# Learning rate: 1e-05
# epoch 69 time:  1.0416340817166807
# --------------------------------
# ========================================
# EPOCH: 70
# train_loss: 0.5540606724364417
# train_precision: tensor([0.7364, 0.8010, 0.7831, 0.7370], device='cuda:0')
# train_recall: tensor([0.7190, 0.8462, 0.7725, 0.5960], device='cuda:0')
# val_loss: 0.5355035273565186
# val_precision: tensor([0.7447, 0.8282, 0.7885, 0.7306], device='cuda:0')
# val_recall: tensor([0.7227, 0.8474, 0.8038, 0.6347], device='cuda:0')
# Learning rate: 5e-06
# epoch 70 time:  1.0418292994500007
# --------------------------------
# ========================================
# EPOCH: 71
# train_loss: 0.5530505812593869
# train_precision: tensor([0.7374, 0.8011, 0.7840, 0.7359], device='cuda:0')
# train_recall: tensor([0.7179, 0.8463, 0.7752, 0.5984], device='cuda:0')
# val_loss: 0.5335455127888256
# val_precision: tensor([0.7449, 0.8232, 0.7975, 0.7195], device='cuda:0')
# val_recall: tensor([0.7251, 0.8538, 0.7965, 0.6522], device='cuda:0')
# Learning rate: 5e-06
# epoch 71 time:  1.0829585899666503
# --------------------------------
# ========================================
# EPOCH: 72
# train_loss: 0.5506606756931259
# train_precision: tensor([0.7373, 0.8022, 0.7861, 0.7383], device='cuda:0')
# train_recall: tensor([0.7197, 0.8489, 0.7737, 0.5996], device='cuda:0')
# val_loss: 0.5349119378460778
# val_precision: tensor([0.7446, 0.8274, 0.7926, 0.7180], device='cuda:0')
# val_recall: tensor([0.7240, 0.8490, 0.8017, 0.6465], device='cuda:0')
# Learning rate: 5e-06
# epoch 72 time:  1.041752156516668
# --------------------------------
# ========================================
# EPOCH: 73
# train_loss: 0.5522086471319199
# train_precision: tensor([0.7369, 0.8017, 0.7830, 0.7374], device='cuda:0')
# train_recall: tensor([0.7185, 0.8455, 0.7741, 0.6030], device='cuda:0')
# val_loss: 0.5343467043505774
# val_precision: tensor([0.7429, 0.8262, 0.7954, 0.7168], device='cuda:0')
# val_recall: tensor([0.7265, 0.8502, 0.7975, 0.6485], device='cuda:0')
# Learning rate: 5e-06
# epoch 73 time:  1.0415851527666746
# --------------------------------
# ========================================
# EPOCH: 74
