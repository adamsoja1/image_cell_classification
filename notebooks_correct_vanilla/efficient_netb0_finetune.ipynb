# %%
import time
import sys
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from dataset import ImageDataset
import torch.nn.functional as F
from torchmetrics import Precision, Recall
from torchvision.models import resnet18
import warnings
from collections import defaultdict
import wandb
import datetime
import os
import torchvision.models as models
import torch.nn as nn
#intecubic interpol

class EfficientNetB0(nn.Module):
    def __init__(self, num_classes=4):
        super(EfficientNetB0, self).__init__()
        self.base_model = models.efficientnet_b0(pretrained=False)
        num_ftrs = self.base_model.classifier[1].in_features
        self.base_model.classifier[1] = nn.Linear(num_ftrs, num_classes)

    def forward(self, x):
        return self.base_model(x)


warnings.filterwarnings('ignore')
torch.set_float32_matmul_precision('high')


run_name = f'efficient_net_b0_no_small_images{datetime.datetime.now()}'
run_path = f'training_checkpoints/{run_name}'

wandb.init(project="cells", 
           entity="adamsoja",
          name=run_name)

import random
random.seed(2233)
torch.manual_seed(2233)

mean = [0.5006, 0.3526, 0.5495]
std = [0.1493, 0.1341, 0.1124]

from albumentations import (
    Compose,
    Resize,
    OneOf,
    RandomBrightness,
    RandomContrast,
    MotionBlur,
    MedianBlur,
    GaussianBlur,
    VerticalFlip,
    HorizontalFlip,
    ShiftScaleRotate,
    Normalize,
)

transform = Compose(
    [
        Normalize(mean=mean, std=std),
        OneOf([RandomBrightness(limit=0.1, p=1), RandomContrast(limit=0.1, p=0.8)]),
        OneOf([MotionBlur(blur_limit=3), MedianBlur(blur_limit=3), GaussianBlur(blur_limit=3),], p=0.7,),
        VerticalFlip(p=0.5),
        HorizontalFlip(p=0.5),
    ]
)

transform_test = Compose(
    [Normalize(mean=mean, std=std)]
)


class MyModel(nn.Module):
    def __init__(self, model, learning_rate, weight_decay):
        super(MyModel, self).__init__()
        self.model = model
        self.learning_rate = learning_rate
        self.weight_decay = weight_decay
        self.criterion = nn.CrossEntropyLoss()
        self.metric_precision = Precision(task="multiclass", num_classes=4, average=None).to('cuda')
        self.metric_recall = Recall(task="multiclass", num_classes=4, average=None).to('cuda')
        self.train_loss = []
        self.valid_loss = []
        self.precision_per_epochs = []
        self.recall_per_epochs = []

        self.optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, mode="min", factor=0.1, patience=3, min_lr=5e-6, verbose=True)
        self.step = 0

    
    def forward(self, x):
        return self.model(x)

    def train_one_epoch(self, trainloader):
        self.step += 1
        self.train()
        for batch_idx, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()
            _, preds = torch.max(outputs, 1)
            _, labels = torch.max(labels, 1)
            self.metric_precision(preds, labels)
            self.metric_recall(preds, labels)
            self.train_loss.append(loss.item())


        

        
        avg_loss = np.mean(self.train_loss)
        self.train_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        self.precision_per_epochs.append(precision)
        self.recall_per_epochs.append(recall)
        print(f'train_loss: {avg_loss}')
        print(f'train_precision: {precision}')
        print(f'train_recall: {recall}')

        wandb.log({'loss': avg_loss},step=self.step)
        wandb.log({'Normal precision': precision[0].item()},step=self.step)
        wandb.log({'Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'Other precision': precision[3].item()},step=self.step)


        wandb.log({'Normal recall': recall[0].item()},step=self.step)
        wandb.log({'Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'Other recall': recall[3].item()},step=self.step)
        
        
        self.metric_precision.reset()
        self.metric_recall.reset()


    

    def evaluate(self, testloader):
        self.eval()
        with torch.no_grad():
            for batch_idx, (inputs, labels) in enumerate(testloader):
                inputs, labels = inputs.to('cuda'), labels.to('cuda')
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)
                _, labels = torch.max(labels, 1)
                self.metric_precision(preds, labels)
                self.metric_recall(preds, labels)
                self.valid_loss.append(loss.item())
    
        avg_loss = np.mean(self.valid_loss)
        self.scheduler.step(avg_loss)
        self.valid_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        print(f'val_loss: {avg_loss}')
        print(f'val_precision: {precision}')
        print(f'val_recall: {recall}')
        self.metric_precision.reset()
        self.metric_recall.reset()

        wandb.log({'val_loss': avg_loss}, step=self.step)
        
        wandb.log({'val_Normal precision': precision[0].item()},step=self.step)
        wandb.log({'val_Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'val_Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'val_Other precision': precision[3].item()},step=self.step)


        wandb.log({'val_Normal recall': recall[0].item()},step=self.step)
        wandb.log({'val_Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'val_Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'val_Other recall': recall[3].item()},step=self.step)


        for param_group in self.optimizer.param_groups:
            print(f"Learning rate: {param_group['lr']}")
        return avg_loss

torch.cuda.empty_cache()
batch_size = 128
trainset = ImageDataset(data_path='train_data', transform=transform, reduce=True)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=5)

testset = ImageDataset(data_path='validation_data', transform=transform_test, reduce=True)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=3)

learning_rate = 0.001
weight_decay = 0.00001

model = EfficientNetB0()
model = model.to('cuda')


my_model = MyModel(model=model, learning_rate=learning_rate, weight_decay=weight_decay)
my_model = my_model.to('cuda')

num_epochs = 200
early_stop_patience = 15
best_val_loss = float('inf')
best_model_state_dict = None

for epoch in range(num_epochs):
    print('========================================')
    print(f'EPOCH: {epoch}') 
    time_start = time.perf_counter()
    my_model.train_one_epoch(trainloader)
    val_loss = my_model.evaluate(testloader)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_state_dict = my_model.state_dict()
        torch.save(best_model_state_dict, f'{run_path}.pth')
        
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch} with best validation loss {best_val_loss}")
        break
    time_epoch = time.perf_counter() - time_start
    print(f'epoch {epoch} time:  {time_epoch/60}')
    print('--------------------------------')

# Load the best model state dict
print(f'{run_path}.pth')
my_model.load_state_dict(torch.load(f'{run_path}.pth'))
# Out:
# wandb: Currently logged in as: adamsoja. Use `wandb login --relogin` to force relogin
# wandb version 0.17.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/adam/Desktop/cells_master_thesis/wandb/run-20240525_220041-9678gili</code>
# Syncing run <strong><a href='https://wandb.ai/adamsoja/cells/runs/9678gili' target="_blank">efficient_net_b0_no_small_images2024-05-25 22:00:40.772399</a></strong> to <a href='https://wandb.ai/adamsoja/cells' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adamsoja/cells' target="_blank">https://wandb.ai/adamsoja/cells</a>
#  View run at <a href='https://wandb.ai/adamsoja/cells/runs/9678gili' target="_blank">https://wandb.ai/adamsoja/cells/runs/9678gili</a>
# ========================================
# EPOCH: 0
# train_loss: 0.987603885786874
# train_precision: tensor([0.5085, 0.6059, 0.5615, 0.0424], device='cuda:0')
# train_recall: tensor([0.4619, 0.7353, 0.5328, 0.0014], device='cuda:0')
# val_loss: 0.8799686301219929
# val_precision: tensor([0.5984, 0.6788, 0.6506, 0.0000], device='cuda:0')
# val_recall: tensor([0.5233, 0.8064, 0.6558, 0.0000], device='cuda:0')
# Learning rate: 0.001
# epoch 0 time:  0.39677783261666566
# --------------------------------
# ========================================
# EPOCH: 1
# train_loss: 0.889328564839627
# train_precision: tensor([0.5738, 0.6607, 0.6366, 0.4136], device='cuda:0')
# train_recall: tensor([0.5366, 0.7642, 0.6228, 0.0186], device='cuda:0')
# val_loss: 0.8053250111438133
# val_precision: tensor([0.6361, 0.7056, 0.6454, 0.5007], device='cuda:0')
# val_recall: tensor([0.5233, 0.8029, 0.6977, 0.1808], device='cuda:0')
# Learning rate: 0.001
# epoch 1 time:  0.39709690698333966
# --------------------------------
# ========================================
# EPOCH: 2
# train_loss: 0.8752807688682389
# train_precision: tensor([0.5859, 0.6683, 0.6467, 0.5263], device='cuda:0')
# train_recall: tensor([0.5469, 0.7698, 0.6343, 0.0512], device='cuda:0')
# val_loss: 0.788891090734585
# val_precision: tensor([0.6358, 0.7322, 0.6533, 1.0000], device='cuda:0')
# val_recall: tensor([0.5540, 0.7894, 0.7313, 0.0015], device='cuda:0')
# Learning rate: 0.001
# epoch 2 time:  0.4014897210499991
# --------------------------------
# ========================================
# EPOCH: 3
# train_loss: 0.8475593048479874
# train_precision: tensor([0.5999, 0.6845, 0.6536, 0.5530], device='cuda:0')
# train_recall: tensor([0.5542, 0.7779, 0.6551, 0.0781], device='cuda:0')
# val_loss: 0.765189370951495
# val_precision: tensor([0.6593, 0.7472, 0.6574, 0.7352], device='cuda:0')
# val_recall: tensor([0.5517, 0.7888, 0.7570, 0.2363], device='cuda:0')
# Learning rate: 0.001
# epoch 3 time:  0.39832909116667
# --------------------------------
# ========================================
# EPOCH: 4
# train_loss: 0.8172046979421814
# train_precision: tensor([0.6145, 0.6940, 0.6663, 0.6290], device='cuda:0')
# train_recall: tensor([0.5658, 0.7838, 0.6706, 0.1358], device='cuda:0')
# val_loss: 0.7563012775716123
# val_precision: tensor([0.6905, 0.7832, 0.6217, 0.7327], device='cuda:0')
# val_recall: tensor([0.5157, 0.7514, 0.8284, 0.2426], device='cuda:0')
# Learning rate: 0.001
# epoch 4 time:  0.40006329810000046
# --------------------------------
# ========================================
# EPOCH: 5
# train_loss: 0.8080636980143907
# train_precision: tensor([0.6197, 0.6953, 0.6690, 0.6692], device='cuda:0')
# train_recall: tensor([0.5700, 0.7866, 0.6729, 0.1442], device='cuda:0')
# val_loss: 0.7202335584450055
# val_precision: tensor([0.6774, 0.7721, 0.6638, 0.7291], device='cuda:0')
# val_recall: tensor([0.5565, 0.7839, 0.7984, 0.2669], device='cuda:0')
# Learning rate: 0.001
# epoch 5 time:  0.40158719719999375
# --------------------------------
# ========================================
# EPOCH: 6
# train_loss: 0.7835300785310787
# train_precision: tensor([0.6320, 0.7069, 0.6790, 0.6667], device='cuda:0')
# train_recall: tensor([0.5843, 0.7927, 0.6842, 0.1737], device='cuda:0')
# val_loss: 0.7097159111284995
# val_precision: tensor([0.6764, 0.7819, 0.6711, 0.8543], device='cuda:0')
# val_recall: tensor([0.5843, 0.7784, 0.7977, 0.2309], device='cuda:0')
# Learning rate: 0.001
# epoch 6 time:  0.39946304884999034
# --------------------------------
# ========================================
# EPOCH: 7
# train_loss: 0.7734439909995139
# train_precision: tensor([0.6390, 0.7104, 0.6809, 0.6455], device='cuda:0')
# train_recall: tensor([0.5836, 0.7977, 0.6907, 0.1899], device='cuda:0')
# val_loss: 0.6977019049562849
# val_precision: tensor([0.6698, 0.7732, 0.7076, 0.6899], device='cuda:0')
# val_recall: tensor([0.6263, 0.8048, 0.7516, 0.3126], device='cuda:0')
# Learning rate: 0.001
# epoch 7 time:  0.40657336224999197
# --------------------------------
# ========================================
# EPOCH: 8
# train_loss: 0.7553267764692294
# train_precision: tensor([0.6489, 0.7208, 0.6887, 0.6599], device='cuda:0')
# train_recall: tensor([0.5940, 0.8024, 0.7025, 0.2135], device='cuda:0')
# val_loss: 0.6848251987863947
# val_precision: tensor([0.7268, 0.7905, 0.6578, 0.8340], device='cuda:0')
# val_recall: tensor([0.5397, 0.8033, 0.8412, 0.2956], device='cuda:0')
# Learning rate: 0.001
# epoch 8 time:  0.41954677866666923
# --------------------------------
# ========================================
# EPOCH: 9
# train_loss: 0.781822519144343
# train_precision: tensor([0.6332, 0.7085, 0.6785, 0.6549], device='cuda:0')
# train_recall: tensor([0.5799, 0.7946, 0.6885, 0.1827], device='cuda:0')
# val_loss: 0.6998714013500614
# val_precision: tensor([0.7121, 0.8017, 0.6522, 0.7047], device='cuda:0')
# val_recall: tensor([0.5521, 0.7825, 0.8364, 0.2946], device='cuda:0')
# Learning rate: 0.001
# epoch 9 time:  0.41312420821667123
# --------------------------------
# ========================================
# EPOCH: 10
# train_loss: 0.7511801989689143
# train_precision: tensor([0.6504, 0.7247, 0.6883, 0.6626], device='cuda:0')
# train_recall: tensor([0.5958, 0.8015, 0.7056, 0.2245], device='cuda:0')
# val_loss: 0.6761383186499994
# val_precision: tensor([0.6624, 0.8242, 0.6953, 0.8974], device='cuda:0')
# val_recall: tensor([0.6599, 0.7591, 0.7874, 0.2722], device='cuda:0')
# Learning rate: 0.001
# epoch 10 time:  0.42193243363334054
# --------------------------------
# ========================================
# EPOCH: 11
# train_loss: 0.7557008887043024
# train_precision: tensor([0.6480, 0.7247, 0.6867, 0.6656], device='cuda:0')
# train_recall: tensor([0.5996, 0.7997, 0.7008, 0.2112], device='cuda:0')
# val_loss: 0.7184354711223293
# val_precision: tensor([0.6672, 0.7862, 0.6696, 0.7540], device='cuda:0')
# val_recall: tensor([0.6087, 0.7798, 0.7626, 0.2756], device='cuda:0')
# Learning rate: 0.001
# epoch 11 time:  0.41407043896667045
# --------------------------------
# ========================================
# EPOCH: 12
# train_loss: 0.7695712056706158
# train_precision: tensor([0.6386, 0.7228, 0.6760, 0.5981], device='cuda:0')
# train_recall: tensor([0.5881, 0.7988, 0.6938, 0.1643], device='cuda:0')
# val_loss: 0.6659443062525969
# val_precision: tensor([0.6884, 0.7879, 0.7070, 0.7150], device='cuda:0')
# val_recall: tensor([0.6139, 0.8193, 0.7807, 0.3281], device='cuda:0')
# Learning rate: 0.001
# epoch 12 time:  0.42196838268332615
# --------------------------------
# ========================================
# EPOCH: 13
# train_loss: 0.7259363120894021
# train_precision: tensor([0.6610, 0.7390, 0.6982, 0.6606], device='cuda:0')
# train_recall: tensor([0.6094, 0.8114, 0.7162, 0.2385], device='cuda:0')
# val_loss: 0.6633957910824109
# val_precision: tensor([0.6975, 0.7973, 0.7006, 0.5766], device='cuda:0')
# val_recall: tensor([0.6202, 0.8095, 0.7856, 0.3422], device='cuda:0')
# Learning rate: 0.001
# epoch 13 time:  0.42021220181665436
# --------------------------------
# ========================================
# EPOCH: 14
# train_loss: 0.7198342761094352
# train_precision: tensor([0.6642, 0.7396, 0.7013, 0.6853], device='cuda:0')
# train_recall: tensor([0.6130, 0.8130, 0.7168, 0.2610], device='cuda:0')
# val_loss: 0.6467680592347194
# val_precision: tensor([0.7299, 0.7871, 0.6963, 0.8849], device='cuda:0')
# val_recall: tensor([0.5903, 0.8398, 0.8147, 0.2504], device='cuda:0')
# Learning rate: 0.001
# epoch 14 time:  0.42201043076665884
# --------------------------------
# ========================================
# EPOCH: 15
# train_loss: 0.7213885393688885
# train_precision: tensor([0.6645, 0.7410, 0.6975, 0.6728], device='cuda:0')
# train_recall: tensor([0.6120, 0.8099, 0.7183, 0.2608], device='cuda:0')
# val_loss: 0.6379805508408103
# val_precision: tensor([0.6908, 0.7867, 0.7339, 0.8200], device='cuda:0')
# val_recall: tensor([0.6591, 0.8303, 0.7581, 0.3301], device='cuda:0')
# Learning rate: 0.001
# epoch 15 time:  0.4194640610000079
# --------------------------------
# ========================================
# EPOCH: 16
# train_loss: 0.7077798159886511
# train_precision: tensor([0.6690, 0.7436, 0.7049, 0.6888], device='cuda:0')
# train_recall: tensor([0.6181, 0.8127, 0.7233, 0.2758], device='cuda:0')
# val_loss: 0.6434857589346511
# val_precision: tensor([0.7080, 0.8186, 0.6991, 0.7729], device='cuda:0')
# val_recall: tensor([0.6400, 0.7962, 0.8092, 0.3690], device='cuda:0')
# Learning rate: 0.001
# epoch 16 time:  0.41298314031666145
# --------------------------------
# ========================================
# EPOCH: 17
# train_loss: 0.7228668001090851
# train_precision: tensor([0.6589, 0.7397, 0.6967, 0.6704], device='cuda:0')
# train_recall: tensor([0.6112, 0.8098, 0.7120, 0.2563], device='cuda:0')
# val_loss: 0.6623941511363238
# val_precision: tensor([0.7295, 0.8031, 0.6693, 0.7884], device='cuda:0')
# val_recall: tensor([0.5620, 0.8086, 0.8397, 0.3515], device='cuda:0')
# Learning rate: 0.001
# epoch 17 time:  0.4126518471333232
# --------------------------------
# ========================================
# EPOCH: 18
# train_loss: 0.7047871636607932
# train_precision: tensor([0.6699, 0.7479, 0.7061, 0.6897], device='cuda:0')
# train_recall: tensor([0.6212, 0.8158, 0.7241, 0.2696], device='cuda:0')
# val_loss: 0.6515717063401196
# val_precision: tensor([0.6912, 0.8369, 0.6949, 0.6804], device='cuda:0')
# val_recall: tensor([0.6462, 0.7787, 0.8063, 0.4108], device='cuda:0')
# Learning rate: 0.001
# epoch 18 time:  0.41418714226665543
# --------------------------------
# ========================================
# EPOCH: 19
# train_loss: 0.7080551132540599
# train_precision: tensor([0.6685, 0.7437, 0.7052, 0.6742], device='cuda:0')
# train_recall: tensor([0.6251, 0.8105, 0.7188, 0.2629], device='cuda:0')
# val_loss: 0.6808057325380342
# val_precision: tensor([0.7180, 0.7748, 0.6882, 0.6286], device='cuda:0')
# val_recall: tensor([0.5662, 0.8218, 0.8078, 0.3670], device='cuda:0')
# Learning rate: 0.0001
# epoch 19 time:  0.4146404987666604
# --------------------------------
# ========================================
# EPOCH: 20
# train_loss: 0.7035896828352561
# train_precision: tensor([0.6805, 0.7414, 0.7053, 0.7095], device='cuda:0')
# train_recall: tensor([0.6151, 0.8190, 0.7296, 0.2762], device='cuda:0')
# val_loss: 0.6355101486315599
# val_precision: tensor([0.7134, 0.8060, 0.7090, 0.7215], device='cuda:0')
# val_recall: tensor([0.6277, 0.8149, 0.8059, 0.4054], device='cuda:0')
# Learning rate: 0.0001
# epoch 20 time:  0.4186173221500061
# --------------------------------
# ========================================
# EPOCH: 21
# train_loss: 0.6886642125927803
# train_precision: tensor([0.6804, 0.7520, 0.7149, 0.7022], device='cuda:0')
# train_recall: tensor([0.6297, 0.8203, 0.7325, 0.2999], device='cuda:0')
# val_loss: 0.621077403739408
# val_precision: tensor([0.7134, 0.8106, 0.7219, 0.7709], device='cuda:0')
# val_recall: tensor([0.6476, 0.8212, 0.8028, 0.3894], device='cuda:0')
# Learning rate: 0.0001
# epoch 21 time:  0.42187234090000253
# --------------------------------
# ========================================
# EPOCH: 22
# train_loss: 0.6806954394359539
# train_precision: tensor([0.6828, 0.7557, 0.7162, 0.6889], device='cuda:0')
# train_recall: tensor([0.6340, 0.8210, 0.7337, 0.3094], device='cuda:0')
# val_loss: 0.6145369069085823
# val_precision: tensor([0.7186, 0.8074, 0.7277, 0.7828], device='cuda:0')
# val_recall: tensor([0.6479, 0.8299, 0.8032, 0.3889], device='cuda:0')
# Learning rate: 0.0001
# epoch 22 time:  0.4210308196666574
# --------------------------------
# ========================================
# EPOCH: 23
# train_loss: 0.6762196573127958
# train_precision: tensor([0.6838, 0.7577, 0.7201, 0.7142], device='cuda:0')
# train_recall: tensor([0.6371, 0.8218, 0.7366, 0.3245], device='cuda:0')
# val_loss: 0.607224003464968
# val_precision: tensor([0.7151, 0.8074, 0.7325, 0.8117], device='cuda:0')
# val_recall: tensor([0.6535, 0.8334, 0.7984, 0.3792], device='cuda:0')
# Learning rate: 0.0001
# epoch 23 time:  0.4195773623333328
# --------------------------------
# ========================================
# EPOCH: 24
# train_loss: 0.6724910130640408
# train_precision: tensor([0.6871, 0.7585, 0.7217, 0.7065], device='cuda:0')
# train_recall: tensor([0.6382, 0.8234, 0.7393, 0.3235], device='cuda:0')
# val_loss: 0.6107965001204351
# val_precision: tensor([0.7165, 0.8284, 0.7138, 0.8058], device='cuda:0')
# val_recall: tensor([0.6517, 0.8067, 0.8212, 0.3913], device='cuda:0')
# Learning rate: 0.0001
# epoch 24 time:  0.41551458416667325
# --------------------------------
# ========================================
# EPOCH: 25
# train_loss: 0.6693507654249592
# train_precision: tensor([0.6859, 0.7608, 0.7239, 0.7119], device='cuda:0')
# train_recall: tensor([0.6413, 0.8238, 0.7384, 0.3362], device='cuda:0')
# val_loss: 0.6025031171850972
# val_precision: tensor([0.7095, 0.8167, 0.7377, 0.8077], device='cuda:0')
# val_recall: tensor([0.6716, 0.8261, 0.7952, 0.3899], device='cuda:0')
# Learning rate: 0.0001
# epoch 25 time:  0.4191070074500052
# --------------------------------
# ========================================
# EPOCH: 26
# train_loss: 0.6663618093905455
# train_precision: tensor([0.6859, 0.7607, 0.7239, 0.7123], device='cuda:0')
# train_recall: tensor([0.6417, 0.8238, 0.7385, 0.3286], device='cuda:0')
# val_loss: 0.6024452435809213
# val_precision: tensor([0.7201, 0.8243, 0.7222, 0.8119], device='cuda:0')
# val_recall: tensor([0.6524, 0.8212, 0.8170, 0.3986], device='cuda:0')
# Learning rate: 0.0001
# epoch 26 time:  0.41832920443333327
# --------------------------------
# ========================================
# EPOCH: 27
# train_loss: 0.6654042114468922
# train_precision: tensor([0.6870, 0.7618, 0.7246, 0.7062], device='cuda:0')
# train_recall: tensor([0.6436, 0.8241, 0.7385, 0.3339], device='cuda:0')
# val_loss: 0.5971497359487029
# val_precision: tensor([0.7090, 0.8203, 0.7403, 0.7884], device='cuda:0')
# val_recall: tensor([0.6780, 0.8250, 0.7932, 0.4093], device='cuda:0')
# Learning rate: 0.0001
# epoch 27 time:  0.4204180622166556
# --------------------------------
# ========================================
# EPOCH: 28
# train_loss: 0.6643844887595073
# train_precision: tensor([0.6868, 0.7634, 0.7259, 0.6994], device='cuda:0')
# train_recall: tensor([0.6443, 0.8244, 0.7397, 0.3385], device='cuda:0')
# val_loss: 0.5988229087165168
# val_precision: tensor([0.7323, 0.8065, 0.7291, 0.7781], device='cuda:0')
# val_recall: tensor([0.6419, 0.8419, 0.8094, 0.4074], device='cuda:0')
# Learning rate: 0.0001
# epoch 28 time:  0.4117935661833296
# --------------------------------
# ========================================
# EPOCH: 29
# train_loss: 0.6618059322410569
# train_precision: tensor([0.6887, 0.7632, 0.7273, 0.7136], device='cuda:0')
# train_recall: tensor([0.6458, 0.8246, 0.7410, 0.3467], device='cuda:0')
# val_loss: 0.6005304085689264
# val_precision: tensor([0.7178, 0.8312, 0.7230, 0.7742], device='cuda:0')
# val_recall: tensor([0.6611, 0.8129, 0.8178, 0.4200], device='cuda:0')
# Learning rate: 0.0001
# epoch 29 time:  0.41558327009999324
# --------------------------------
# ========================================
# EPOCH: 30
# train_loss: 0.6621268941245331
# train_precision: tensor([0.6879, 0.7646, 0.7257, 0.7134], device='cuda:0')
# train_recall: tensor([0.6450, 0.8248, 0.7408, 0.3428], device='cuda:0')
# val_loss: 0.5997208323296126
# val_precision: tensor([0.7280, 0.8209, 0.7237, 0.7753], device='cuda:0')
# val_recall: tensor([0.6511, 0.8242, 0.8190, 0.4142], device='cuda:0')
# Learning rate: 0.0001
# epoch 30 time:  0.41128971423333194
# --------------------------------
# ========================================
# EPOCH: 31
# train_loss: 0.6610227290114227
# train_precision: tensor([0.6897, 0.7650, 0.7255, 0.7156], device='cuda:0')
# train_recall: tensor([0.6453, 0.8265, 0.7408, 0.3434], device='cuda:0')
# val_loss: 0.5950003001872484
# val_precision: tensor([0.7347, 0.8164, 0.7272, 0.7453], device='cuda:0')
# val_recall: tensor([0.6425, 0.8381, 0.8177, 0.4395], device='cuda:0')
# Learning rate: 0.0001
# epoch 31 time:  0.4228638620500078
# --------------------------------
# ========================================
# EPOCH: 32
# train_loss: 0.6569721401696653
# train_precision: tensor([0.6946, 0.7663, 0.7273, 0.7041], device='cuda:0')
# train_recall: tensor([0.6457, 0.8288, 0.7458, 0.3417], device='cuda:0')
# val_loss: 0.5965931701499063
# val_precision: tensor([0.7220, 0.8347, 0.7207, 0.7812], device='cuda:0')
# val_recall: tensor([0.6618, 0.8124, 0.8216, 0.4254], device='cuda:0')
# Learning rate: 0.0001
# epoch 32 time:  0.41494569863333103
# --------------------------------
# ========================================
# EPOCH: 33
# train_loss: 0.6587114788620628
# train_precision: tensor([0.6911, 0.7646, 0.7264, 0.7332], device='cuda:0')
# train_recall: tensor([0.6455, 0.8260, 0.7424, 0.3591], device='cuda:0')
# val_loss: 0.5958863250665121
# val_precision: tensor([0.7309, 0.8193, 0.7257, 0.7343], device='cuda:0')
# val_recall: tensor([0.6471, 0.8288, 0.8193, 0.4327], device='cuda:0')
# Learning rate: 0.0001
# epoch 33 time:  0.4154641447666715
# --------------------------------
# ========================================
# EPOCH: 34
# train_loss: 0.6561302251183695
# train_precision: tensor([0.6905, 0.7652, 0.7288, 0.7066], device='cuda:0')
# train_recall: tensor([0.6470, 0.8262, 0.7426, 0.3542], device='cuda:0')
# val_loss: 0.5912043769527842
# val_precision: tensor([0.7332, 0.8166, 0.7298, 0.7981], device='cuda:0')
# val_recall: tensor([0.6483, 0.8371, 0.8187, 0.4132], device='cuda:0')
# Learning rate: 0.0001
# epoch 34 time:  0.42004814899999776
# --------------------------------
# ========================================
# EPOCH: 35
# train_loss: 0.6553796793081279
# train_precision: tensor([0.6917, 0.7661, 0.7291, 0.7199], device='cuda:0')
# train_recall: tensor([0.6478, 0.8265, 0.7445, 0.3534], device='cuda:0')
# val_loss: 0.58871731851194
# val_precision: tensor([0.7270, 0.8180, 0.7374, 0.7916], device='cuda:0')
# val_recall: tensor([0.6625, 0.8356, 0.8098, 0.4210], device='cuda:0')
# Learning rate: 0.0001
# epoch 35 time:  0.41948855673332824
# --------------------------------
# ========================================
# EPOCH: 36
# train_loss: 0.6548881527309712
# train_precision: tensor([0.6898, 0.7673, 0.7290, 0.7155], device='cuda:0')
# train_recall: tensor([0.6509, 0.8264, 0.7409, 0.3493], device='cuda:0')
# val_loss: 0.5912412277034095
# val_precision: tensor([0.7342, 0.8250, 0.7236, 0.8061], device='cuda:0')
# val_recall: tensor([0.6525, 0.8287, 0.8239, 0.4084], device='cuda:0')
# Learning rate: 0.0001
# epoch 36 time:  0.4146277068666677
# --------------------------------
# ========================================
# EPOCH: 37
# train_loss: 0.651414321426259
# train_precision: tensor([0.6928, 0.7674, 0.7309, 0.7168], device='cuda:0')
# train_recall: tensor([0.6516, 0.8275, 0.7439, 0.3505], device='cuda:0')
# val_loss: 0.5879527336663312
# val_precision: tensor([0.7240, 0.8284, 0.7335, 0.7929], device='cuda:0')
# val_recall: tensor([0.6682, 0.8257, 0.8151, 0.4244], device='cuda:0')
# Learning rate: 0.0001
# epoch 37 time:  0.4199717212166585
# --------------------------------
# ========================================
# EPOCH: 38
# train_loss: 0.6513042254145694
# train_precision: tensor([0.6927, 0.7655, 0.7294, 0.7279], device='cuda:0')
# train_recall: tensor([0.6500, 0.8262, 0.7432, 0.3579], device='cuda:0')
# val_loss: 0.5909891143754438
# val_precision: tensor([0.7161, 0.8425, 0.7249, 0.7958], device='cuda:0')
# val_recall: tensor([0.6746, 0.8055, 0.8213, 0.4283], device='cuda:0')
# Learning rate: 0.0001
# epoch 38 time:  0.4159948080666709
# --------------------------------
# ========================================
# EPOCH: 39
# train_loss: 0.6502782603488465
# train_precision: tensor([0.6942, 0.7673, 0.7328, 0.7263], device='cuda:0')
# train_recall: tensor([0.6515, 0.8284, 0.7460, 0.3616], device='cuda:0')
# val_loss: 0.5867345726883805
# val_precision: tensor([0.7234, 0.8224, 0.7408, 0.7644], device='cuda:0')
# val_recall: tensor([0.6726, 0.8334, 0.8046, 0.4322], device='cuda:0')
# Learning rate: 0.0001
# epoch 39 time:  0.42217614288333605
# --------------------------------
# ========================================
# EPOCH: 40
# train_loss: 0.6489853423419606
# train_precision: tensor([0.6940, 0.7683, 0.7314, 0.7212], device='cuda:0')
# train_recall: tensor([0.6516, 0.8277, 0.7452, 0.3673], device='cuda:0')
# val_loss: 0.5824582035298104
# val_precision: tensor([0.7306, 0.8131, 0.7443, 0.8163], device='cuda:0')
# val_recall: tensor([0.6649, 0.8433, 0.8078, 0.4191], device='cuda:0')
# Learning rate: 0.0001
# epoch 40 time:  0.41850087148333537
# --------------------------------
# ========================================
# EPOCH: 41
# train_loss: 0.6502341279613773
# train_precision: tensor([0.6963, 0.7676, 0.7323, 0.7184], device='cuda:0')
# train_recall: tensor([0.6547, 0.8269, 0.7459, 0.3569], device='cuda:0')
# val_loss: 0.5877364910132176
# val_precision: tensor([0.7190, 0.8376, 0.7359, 0.7655], device='cuda:0')
# val_recall: tensor([0.6789, 0.8137, 0.8183, 0.4507], device='cuda:0')
# Learning rate: 0.0001
# epoch 41 time:  0.41018376228333486
# --------------------------------
# ========================================
# EPOCH: 42
# train_loss: 0.6483744089054172
# train_precision: tensor([0.6956, 0.7692, 0.7338, 0.7279], device='cuda:0')
# train_recall: tensor([0.6548, 0.8284, 0.7466, 0.3645], device='cuda:0')
# val_loss: 0.5819911781821523
# val_precision: tensor([0.7325, 0.8103, 0.7465, 0.7827], device='cuda:0')
# val_recall: tensor([0.6619, 0.8491, 0.8049, 0.4307], device='cuda:0')
# Learning rate: 0.0001
# epoch 42 time:  0.4209201420833324
# --------------------------------
# ========================================
# EPOCH: 43
# train_loss: 0.6486936365200285
# train_precision: tensor([0.6934, 0.7681, 0.7313, 0.7257], device='cuda:0')
# train_recall: tensor([0.6499, 0.8273, 0.7472, 0.3600], device='cuda:0')
# val_loss: 0.5875345192424528
# val_precision: tensor([0.7406, 0.8228, 0.7235, 0.7864], device='cuda:0')
# val_recall: tensor([0.6387, 0.8322, 0.8344, 0.4385], device='cuda:0')
# Learning rate: 0.0001
# epoch 43 time:  0.4155887241999911
# --------------------------------
# ========================================
# EPOCH: 44
# train_loss: 0.6468105254601327
# train_precision: tensor([0.6936, 0.7694, 0.7326, 0.7191], device='cuda:0')
# train_recall: tensor([0.6533, 0.8278, 0.7454, 0.3661], device='cuda:0')
# val_loss: 0.5795549716319408
# val_precision: tensor([0.7404, 0.8049, 0.7438, 0.8144], device='cuda:0')
# val_recall: tensor([0.6535, 0.8544, 0.8095, 0.4118], device='cuda:0')
# Learning rate: 0.0001
# epoch 44 time:  0.4178314855833226
# --------------------------------
# ========================================
# EPOCH: 45
# train_loss: 0.6445162505141556
# train_precision: tensor([0.6962, 0.7704, 0.7340, 0.7170], device='cuda:0')
# train_recall: tensor([0.6543, 0.8284, 0.7484, 0.3696], device='cuda:0')
# val_loss: 0.5824346055050154
# val_precision: tensor([0.7162, 0.8345, 0.7418, 0.7859], device='cuda:0')
# val_recall: tensor([0.6828, 0.8193, 0.8124, 0.4390], device='cuda:0')
# Learning rate: 0.0001
# epoch 45 time:  0.41437804941667006
# --------------------------------
# ========================================
# EPOCH: 46
# train_loss: 0.6468803938022758
# train_precision: tensor([0.6958, 0.7690, 0.7326, 0.7175], device='cuda:0')
# train_recall: tensor([0.6523, 0.8284, 0.7477, 0.3626], device='cuda:0')
# val_loss: 0.5806886249028884
# val_precision: tensor([0.7291, 0.8105, 0.7501, 0.8059], device='cuda:0')
# val_recall: tensor([0.6714, 0.8478, 0.8000, 0.4118], device='cuda:0')
# Learning rate: 0.0001
# epoch 46 time:  0.41491967163333354
# --------------------------------
# ========================================
# EPOCH: 47
# train_loss: 0.6432388647144212
# train_precision: tensor([0.6982, 0.7719, 0.7324, 0.7289], device='cuda:0')
# train_recall: tensor([0.6548, 0.8289, 0.7499, 0.3653], device='cuda:0')
# val_loss: 0.5787723110513286
# val_precision: tensor([0.7293, 0.8175, 0.7476, 0.8122], device='cuda:0')
# val_recall: tensor([0.6730, 0.8426, 0.8064, 0.4268], device='cuda:0')
# Learning rate: 0.0001
# epoch 47 time:  0.42043001628333815
# --------------------------------
# ========================================
# EPOCH: 48
# train_loss: 0.6436418607888534
# train_precision: tensor([0.6953, 0.7703, 0.7340, 0.7157], device='cuda:0')
# train_recall: tensor([0.6548, 0.8284, 0.7466, 0.3729], device='cuda:0')
# val_loss: 0.5918811019565966
# val_precision: tensor([0.7326, 0.8394, 0.7156, 0.8287], device='cuda:0')
# val_recall: tensor([0.6524, 0.8109, 0.8416, 0.4045], device='cuda:0')
# Learning rate: 0.0001
# epoch 48 time:  0.4146890662499876
# --------------------------------
# ========================================
# EPOCH: 49
# train_loss: 0.642506853762434
# train_precision: tensor([0.6971, 0.7717, 0.7345, 0.7162], device='cuda:0')
# train_recall: tensor([0.6563, 0.8285, 0.7490, 0.3671], device='cuda:0')
# val_loss: 0.5784597457708182
# val_precision: tensor([0.7253, 0.8323, 0.7392, 0.8184], device='cuda:0')
# val_recall: tensor([0.6809, 0.8250, 0.8148, 0.4293], device='cuda:0')
# Learning rate: 0.0001
# epoch 49 time:  0.42002026398333026
# --------------------------------
# ========================================
# EPOCH: 50
# train_loss: 0.6411959972314086
# train_precision: tensor([0.6990, 0.7719, 0.7364, 0.7269], device='cuda:0')
# train_recall: tensor([0.6582, 0.8294, 0.7495, 0.3817], device='cuda:0')
# val_loss: 0.5774742799388753
# val_precision: tensor([0.7244, 0.8290, 0.7427, 0.8095], device='cuda:0')
# val_recall: tensor([0.6784, 0.8279, 0.8144, 0.4317], device='cuda:0')
# Learning rate: 0.0001
# epoch 50 time:  0.41810940350001147
# --------------------------------
# ========================================
# EPOCH: 51
# train_loss: 0.6414872693279075
# train_precision: tensor([0.6975, 0.7726, 0.7342, 0.7234], device='cuda:0')
# train_recall: tensor([0.6584, 0.8277, 0.7482, 0.3768], device='cuda:0')
# val_loss: 0.5810807278832874
# val_precision: tensor([0.7462, 0.8225, 0.7295, 0.7710], device='cuda:0')
# val_recall: tensor([0.6451, 0.8388, 0.8325, 0.4516], device='cuda:0')
# Learning rate: 0.0001
# epoch 51 time:  0.41525755730000735
# --------------------------------
# ========================================
# EPOCH: 52
# train_loss: 0.6398627745368766
# train_precision: tensor([0.6973, 0.7722, 0.7353, 0.7217], device='cuda:0')
# train_recall: tensor([0.6573, 0.8295, 0.7478, 0.3809], device='cuda:0')
# val_loss: 0.5771214980799872
# val_precision: tensor([0.7324, 0.8230, 0.7433, 0.7767], device='cuda:0')
# val_recall: tensor([0.6692, 0.8387, 0.8132, 0.4599], device='cuda:0')
# Learning rate: 0.0001
# epoch 52 time:  0.4220044595833315
# --------------------------------
# ========================================
# EPOCH: 53
# train_loss: 0.6399792165446312
# train_precision: tensor([0.6986, 0.7713, 0.7345, 0.7265], device='cuda:0')
# train_recall: tensor([0.6574, 0.8287, 0.7479, 0.3848], device='cuda:0')
# val_loss: 0.575757404392188
# val_precision: tensor([0.7248, 0.8252, 0.7464, 0.8304], device='cuda:0')
# val_recall: tensor([0.6820, 0.8338, 0.8081, 0.4191], device='cuda:0')
# Learning rate: 0.0001
# epoch 53 time:  0.4178199907499978
# --------------------------------
# ========================================
# EPOCH: 54
# train_loss: 0.6386956364645154
# train_precision: tensor([0.6998, 0.7728, 0.7354, 0.7193], device='cuda:0')
# train_recall: tensor([0.6586, 0.8318, 0.7473, 0.3807], device='cuda:0')
# val_loss: 0.5719722458818653
# val_precision: tensor([0.7373, 0.8141, 0.7491, 0.8075], device='cuda:0')
# val_recall: tensor([0.6683, 0.8501, 0.8085, 0.4424], device='cuda:0')
# Learning rate: 0.0001
# epoch 54 time:  0.42171481463333294
# --------------------------------
# ========================================
# EPOCH: 55
# train_loss: 0.6382581302980045
# train_precision: tensor([0.6975, 0.7720, 0.7365, 0.7246], device='cuda:0')
# train_recall: tensor([0.6563, 0.8306, 0.7490, 0.3821], device='cuda:0')
# val_loss: 0.5749123687590206
# val_precision: tensor([0.7337, 0.8276, 0.7382, 0.8119], device='cuda:0')
# val_recall: tensor([0.6679, 0.8348, 0.8200, 0.4448], device='cuda:0')
# Learning rate: 0.0001
# epoch 55 time:  0.4118501350333342
# --------------------------------
# ========================================
# EPOCH: 56
# train_loss: 0.6379003011006646
# train_precision: tensor([0.6999, 0.7724, 0.7352, 0.7235], device='cuda:0')
# train_recall: tensor([0.6588, 0.8288, 0.7495, 0.3823], device='cuda:0')
# val_loss: 0.5737642675817192
# val_precision: tensor([0.7082, 0.8326, 0.7616, 0.8219], device='cuda:0')
# val_recall: tensor([0.7149, 0.8283, 0.7854, 0.4263], device='cuda:0')
# Learning rate: 0.0001
# epoch 56 time:  0.41442604775000597
# --------------------------------
# ========================================
# EPOCH: 57
# train_loss: 0.6374508118690825
# train_precision: tensor([0.6995, 0.7740, 0.7388, 0.7112], device='cuda:0')
# train_recall: tensor([0.6635, 0.8299, 0.7487, 0.3729], device='cuda:0')
# val_loss: 0.5729874666030701
# val_precision: tensor([0.7279, 0.8220, 0.7498, 0.7893], device='cuda:0')
# val_recall: tensor([0.6813, 0.8389, 0.8042, 0.4516], device='cuda:0')
# Learning rate: 0.0001
# epoch 57 time:  0.41334525801667044
# --------------------------------
# ========================================
# EPOCH: 58
# train_loss: 0.6355191204346898
# train_precision: tensor([0.7012, 0.7730, 0.7386, 0.7204], device='cuda:0')
# train_recall: tensor([0.6606, 0.8325, 0.7493, 0.3827], device='cuda:0')
# val_loss: 0.5745284534968413
# val_precision: tensor([0.7274, 0.8294, 0.7430, 0.7925], device='cuda:0')
# val_recall: tensor([0.6784, 0.8312, 0.8129, 0.4511], device='cuda:0')
# Learning rate: 1e-05
# epoch 58 time:  0.41518172991665475
# --------------------------------
# ========================================
# EPOCH: 59
# train_loss: 0.6319465763780602
# train_precision: tensor([0.7015, 0.7756, 0.7410, 0.7224], device='cuda:0')
# train_recall: tensor([0.6632, 0.8327, 0.7516, 0.3870], device='cuda:0')
# val_loss: 0.5717898025079532
# val_precision: tensor([0.7338, 0.8266, 0.7424, 0.8218], device='cuda:0')
# val_recall: tensor([0.6751, 0.8357, 0.8171, 0.4327], device='cuda:0')
# Learning rate: 1e-05
# epoch 59 time:  0.4224101421333368
# --------------------------------
# ========================================
# EPOCH: 60
# train_loss: 0.6333368383779489
# train_precision: tensor([0.7017, 0.7754, 0.7389, 0.7315], device='cuda:0')
# train_recall: tensor([0.6636, 0.8302, 0.7514, 0.3907], device='cuda:0')
# val_loss: 0.5724580852656035
# val_precision: tensor([0.7290, 0.8347, 0.7413, 0.8028], device='cuda:0')
# val_recall: tensor([0.6817, 0.8261, 0.8189, 0.4492], device='cuda:0')
# Learning rate: 1e-05
# epoch 60 time:  0.4158648496499912
# --------------------------------
# ========================================
# EPOCH: 61
# train_loss: 0.6323917898969147
# train_precision: tensor([0.7023, 0.7722, 0.7401, 0.7202], device='cuda:0')
# train_recall: tensor([0.6607, 0.8329, 0.7505, 0.3850], device='cuda:0')
# val_loss: 0.5710432072570016
# val_precision: tensor([0.7300, 0.8324, 0.7450, 0.8047], device='cuda:0')
# val_recall: tensor([0.6830, 0.8307, 0.8168, 0.4468], device='cuda:0')
# Learning rate: 1e-05
# epoch 61 time:  0.41584297338334486
# --------------------------------
# ========================================
# EPOCH: 62
# train_loss: 0.633125463565344
# train_precision: tensor([0.6996, 0.7747, 0.7384, 0.7233], device='cuda:0')
# train_recall: tensor([0.6614, 0.8304, 0.7506, 0.3835], device='cuda:0')
# val_loss: 0.5685419064384323
# val_precision: tensor([0.7157, 0.8325, 0.7599, 0.7886], device='cuda:0')
# val_recall: tensor([0.7076, 0.8290, 0.7946, 0.4570], device='cuda:0')
# Learning rate: 1e-05
# epoch 62 time:  0.4211126913000044
# --------------------------------
# ========================================
# EPOCH: 63
# train_loss: 0.6308989127860566
# train_precision: tensor([0.7037, 0.7746, 0.7394, 0.7342], device='cuda:0')
# train_recall: tensor([0.6601, 0.8325, 0.7542, 0.3966], device='cuda:0')
# val_loss: 0.5691735531474735
# val_precision: tensor([0.7308, 0.8237, 0.7500, 0.8117], device='cuda:0')
# val_recall: tensor([0.6829, 0.8391, 0.8081, 0.4443], device='cuda:0')
# Learning rate: 1e-05
# epoch 63 time:  0.4153465394500017
# --------------------------------
# ========================================
# EPOCH: 64
# train_loss: 0.6318827626251039
# train_precision: tensor([0.7022, 0.7746, 0.7394, 0.7317], device='cuda:0')
# train_recall: tensor([0.6637, 0.8309, 0.7510, 0.3895], device='cuda:0')
# val_loss: 0.5738606687870111
# val_precision: tensor([0.7298, 0.8364, 0.7382, 0.8329], device='cuda:0')
# val_recall: tensor([0.6785, 0.8247, 0.8245, 0.4288], device='cuda:0')
# Learning rate: 1e-05
# epoch 64 time:  0.41271093643332885
# --------------------------------
# ========================================
# EPOCH: 65
# train_loss: 0.6313252370981943
# train_precision: tensor([0.7013, 0.7748, 0.7406, 0.7372], device='cuda:0')
# train_recall: tensor([0.6625, 0.8328, 0.7508, 0.3970], device='cuda:0')
# val_loss: 0.568075680025705
# val_precision: tensor([0.7334, 0.8186, 0.7519, 0.7832], device='cuda:0')
# val_recall: tensor([0.6767, 0.8456, 0.8059, 0.4618], device='cuda:0')
# Learning rate: 1e-05
# epoch 65 time:  0.420519197500001
# --------------------------------
# ========================================
# EPOCH: 66
# train_loss: 0.631342743181814
# train_precision: tensor([0.7023, 0.7753, 0.7395, 0.7386], device='cuda:0')
# train_recall: tensor([0.6627, 0.8321, 0.7523, 0.3862], device='cuda:0')
# val_loss: 0.5700826246638198
# val_precision: tensor([0.7322, 0.8283, 0.7448, 0.8094], device='cuda:0')
# val_recall: tensor([0.6786, 0.8348, 0.8161, 0.4458], device='cuda:0')
# Learning rate: 1e-05
# epoch 66 time:  0.41115859794999776
# --------------------------------
# ========================================
# EPOCH: 67
# train_loss: 0.6305828398067211
# train_precision: tensor([0.7020, 0.7748, 0.7398, 0.7384], device='cuda:0')
# train_recall: tensor([0.6620, 0.8314, 0.7525, 0.3950], device='cuda:0')
# val_loss: 0.5687542758635931
# val_precision: tensor([0.7328, 0.8272, 0.7479, 0.7750], device='cuda:0')
# val_recall: tensor([0.6787, 0.8385, 0.8130, 0.4604], device='cuda:0')
# Learning rate: 1e-05
# epoch 67 time:  0.41743727341666576
# --------------------------------
# ========================================
# EPOCH: 68
# train_loss: 0.6299429958353018
# train_precision: tensor([0.7031, 0.7769, 0.7399, 0.7386], device='cuda:0')
# train_recall: tensor([0.6645, 0.8306, 0.7533, 0.4065], device='cuda:0')
# val_loss: 0.5689457980720131
# val_precision: tensor([0.7293, 0.8299, 0.7479, 0.7801], device='cuda:0')
# val_recall: tensor([0.6828, 0.8328, 0.8127, 0.4725], device='cuda:0')
# Learning rate: 1e-05
# epoch 68 time:  0.41661584868332585
# --------------------------------
# ========================================
# EPOCH: 69
# train_loss: 0.6306073839753444
# train_precision: tensor([0.7016, 0.7753, 0.7411, 0.7220], device='cuda:0')
# train_recall: tensor([0.6648, 0.8306, 0.7512, 0.3954], device='cuda:0')
# val_loss: 0.5686686957652146
# val_precision: tensor([0.7287, 0.8306, 0.7477, 0.7897], device='cuda:0')
# val_recall: tensor([0.6842, 0.8339, 0.8114, 0.4618], device='cuda:0')
# Learning rate: 5e-06
# epoch 69 time:  0.41401285568332846
# --------------------------------
# ========================================
# EPOCH: 70
# train_loss: 0.6299496583228252
# train_precision: tensor([0.7038, 0.7750, 0.7403, 0.7189], device='cuda:0')
# train_recall: tensor([0.6641, 0.8316, 0.7526, 0.3862], device='cuda:0')
# val_loss: 0.5710766633620133
# val_precision: tensor([0.7258, 0.8363, 0.7439, 0.8002], device='cuda:0')
# val_recall: tensor([0.6855, 0.8252, 0.8168, 0.4555], device='cuda:0')
# Learning rate: 5e-06
# epoch 70 time:  0.4181208468499941
# --------------------------------
# ========================================
# EPOCH: 71
# train_loss: 0.6304449885508269
# train_precision: tensor([0.7029, 0.7773, 0.7387, 0.7214], device='cuda:0')
# train_recall: tensor([0.6632, 0.8303, 0.7543, 0.3889], device='cuda:0')
# val_loss: 0.5705399969676593
# val_precision: tensor([0.7370, 0.8259, 0.7422, 0.8205], device='cuda:0')
# val_recall: tensor([0.6701, 0.8380, 0.8214, 0.4400], device='cuda:0')
# Learning rate: 5e-06
# epoch 71 time:  0.4138557425166558
# --------------------------------
# ========================================
# EPOCH: 72
# train_loss: 0.6283106610006347
# train_precision: tensor([0.7044, 0.7770, 0.7422, 0.7230], device='cuda:0')
# train_recall: tensor([0.6638, 0.8335, 0.7549, 0.3968], device='cuda:0')
# val_loss: 0.5703820783544231
# val_precision: tensor([0.7347, 0.8301, 0.7431, 0.8093], device='cuda:0')
# val_recall: tensor([0.6756, 0.8342, 0.8211, 0.4497], device='cuda:0')
# Learning rate: 5e-06
# epoch 72 time:  0.4138759928999965
# --------------------------------
# ========================================
# EPOCH: 73
# train_loss: 0.6277021766284258
# train_precision: tensor([0.7028, 0.7767, 0.7399, 0.7274], device='cuda:0')
# train_recall: tensor([0.6642, 0.8332, 0.7514, 0.3886], device='cuda:0')
# val_loss: 0.5672514109282164
# val_precision: tensor([0.7317, 0.8249, 0.7498, 0.8201], device='cuda:0')
# val_recall: tensor([0.6808, 0.8395, 0.8120, 0.4434], device='cuda:0')
# Learning rate: 5e-06
# epoch 73 time:  0.4206323624500025
# --------------------------------
# ========================================
# EPOCH: 74
# train_loss: 0.6300107835189103
# train_precision: tensor([0.7046, 0.7757, 0.7417, 0.7246], device='cuda:0')
# train_recall: tensor([0.6653, 0.8337, 0.7523, 0.3897], device='cuda:0')
# val_loss: 0.5705514389115411
# val_precision: tensor([0.7296, 0.8354, 0.7420, 0.8010], device='cuda:0')
# val_recall: tensor([0.6802, 0.8270, 0.8208, 0.4579], device='cuda:0')
# Learning rate: 5e-06
# epoch 74 time:  0.41491381838333535
# --------------------------------
# ========================================
# EPOCH: 75
# train_loss: 0.6290116088999438
# train_precision: tensor([0.7038, 0.7751, 0.7407, 0.7209], device='cuda:0')
# train_recall: tensor([0.6614, 0.8329, 0.7537, 0.3968], device='cuda:0')
# val_loss: 0.5683777853622809
# val_precision: tensor([0.7325, 0.8283, 0.7468, 0.8050], device='cuda:0')
# val_recall: tensor([0.6807, 0.8367, 0.8139, 0.4536], device='cuda:0')
# Learning rate: 5e-06
# epoch 75 time:  0.4111676935999943
# --------------------------------
# ========================================
# EPOCH: 76
# train_loss: 0.6287668709819382
# train_precision: tensor([0.7028, 0.7769, 0.7431, 0.7174], device='cuda:0')
# train_recall: tensor([0.6638, 0.8333, 0.7546, 0.3932], device='cuda:0')
# val_loss: 0.5698044853614973
# val_precision: tensor([0.7291, 0.8334, 0.7429, 0.8250], device='cuda:0')
# val_recall: tensor([0.6820, 0.8287, 0.8188, 0.4356], device='cuda:0')
# Learning rate: 5e-06
# epoch 76 time:  0.4160592794833216
# --------------------------------
# ========================================
# EPOCH: 77
# train_loss: 0.6279145058249261
# train_precision: tensor([0.7046, 0.7763, 0.7418, 0.7258], device='cuda:0')
# train_recall: tensor([0.6638, 0.8319, 0.7558, 0.3942], device='cuda:0')
# val_loss: 0.571741554561678
# val_precision: tensor([0.7207, 0.8404, 0.7456, 0.8133], device='cuda:0')
# val_recall: tensor([0.6937, 0.8199, 0.8147, 0.4511], device='cuda:0')
# Learning rate: 5e-06
# epoch 77 time:  0.415891846383344
# --------------------------------
# ========================================
# EPOCH: 78
# train_loss: 0.6287749042612245
# train_precision: tensor([0.7032, 0.7754, 0.7418, 0.7331], device='cuda:0')
# train_recall: tensor([0.6642, 0.8312, 0.7536, 0.4001], device='cuda:0')
# val_loss: 0.5665734929365439
# val_precision: tensor([0.7291, 0.8258, 0.7519, 0.7981], device='cuda:0')
# val_recall: tensor([0.6854, 0.8389, 0.8071, 0.4536], device='cuda:0')
# Learning rate: 5e-06
# epoch 78 time:  0.4211864781666615
# --------------------------------
# ========================================
# EPOCH: 79
# train_loss: 0.6302886520688599
# train_precision: tensor([0.7041, 0.7759, 0.7414, 0.7240], device='cuda:0')
# train_recall: tensor([0.6633, 0.8334, 0.7536, 0.3934], device='cuda:0')
# val_loss: 0.5698329238472758
# val_precision: tensor([0.7409, 0.8216, 0.7416, 0.7885], device='cuda:0')
# val_recall: tensor([0.6650, 0.8420, 0.8191, 0.4584], device='cuda:0')
# Learning rate: 5e-06
# epoch 79 time:  0.4127149424833381
# --------------------------------
# ========================================
# EPOCH: 80
# train_loss: 0.6299750634026804
# train_precision: tensor([0.7036, 0.7757, 0.7405, 0.7166], device='cuda:0')
# train_recall: tensor([0.6641, 0.8324, 0.7521, 0.3907], device='cuda:0')
# val_loss: 0.5702223341028254
# val_precision: tensor([0.7341, 0.8346, 0.7406, 0.7938], device='cuda:0')
# val_recall: tensor([0.6753, 0.8299, 0.8244, 0.4623], device='cuda:0')
# Learning rate: 5e-06
# epoch 80 time:  0.411322131416667
# --------------------------------
# ========================================
# EPOCH: 81
# train_loss: 0.6291887636273678
# train_precision: tensor([0.7035, 0.7771, 0.7408, 0.7322], device='cuda:0')
# train_recall: tensor([0.6639, 0.8333, 0.7533, 0.3960], device='cuda:0')
# val_loss: 0.571509228096352
# val_precision: tensor([0.7371, 0.8343, 0.7360, 0.8005], device='cuda:0')
# val_recall: tensor([0.6696, 0.8288, 0.8288, 0.4565], device='cuda:0')
# Learning rate: 5e-06
# epoch 81 time:  0.4128911928333461
# --------------------------------
# ========================================
# EPOCH: 82
# train_loss: 0.6278250497817379
# train_precision: tensor([0.7043, 0.7765, 0.7409, 0.7235], device='cuda:0')
# train_recall: tensor([0.6641, 0.8330, 0.7533, 0.3962], device='cuda:0')
# val_loss: 0.5660212874502033
# val_precision: tensor([0.7248, 0.8245, 0.7584, 0.8226], device='cuda:0')
# val_recall: tensor([0.6952, 0.8403, 0.7999, 0.4351], device='cuda:0')
# Learning rate: 5e-06
# epoch 82 time:  0.42119554294999945
# --------------------------------
# ========================================
# EPOCH: 83
# train_loss: 0.6286466495449172
# train_precision: tensor([0.7034, 0.7770, 0.7420, 0.7410], device='cuda:0')
# train_recall: tensor([0.6666, 0.8314, 0.7536, 0.3981], device='cuda:0')
# val_loss: 0.5668219896676662
# val_precision: tensor([0.7292, 0.8260, 0.7527, 0.8049], device='cuda:0')
# val_recall: tensor([0.6881, 0.8387, 0.8063, 0.4511], device='cuda:0')
# Learning rate: 5e-06
# epoch 83 time:  0.41473516328334575
# --------------------------------
# ========================================
# EPOCH: 84
# train_loss: 0.6300849266148902
# train_precision: tensor([0.7015, 0.7762, 0.7386, 0.7246], device='cuda:0')
# train_recall: tensor([0.6630, 0.8312, 0.7509, 0.3962], device='cuda:0')
# val_loss: 0.5670731911609123
# val_precision: tensor([0.7326, 0.8238, 0.7518, 0.8128], device='cuda:0')
# val_recall: tensor([0.6842, 0.8418, 0.8079, 0.4497], device='cuda:0')
# Learning rate: 5e-06
# epoch 84 time:  0.412999719849995
# --------------------------------
# ========================================
# EPOCH: 85
# train_loss: 0.6290094871625324
# train_precision: tensor([0.7040, 0.7766, 0.7402, 0.7302], device='cuda:0')
# train_recall: tensor([0.6629, 0.8332, 0.7535, 0.3987], device='cuda:0')
# val_loss: 0.5712102886076804
# val_precision: tensor([0.7454, 0.8258, 0.7366, 0.7915], device='cuda:0')
# val_recall: tensor([0.6586, 0.8382, 0.8307, 0.4594], device='cuda:0')
# Learning rate: 5e-06
# epoch 85 time:  0.4118448096166655
# --------------------------------
# ========================================
# EPOCH: 86
# train_loss: 0.6288622449532132
# train_precision: tensor([0.7028, 0.7753, 0.7417, 0.7258], device='cuda:0')
# train_recall: tensor([0.6609, 0.8333, 0.7544, 0.3970], device='cuda:0')
# val_loss: 0.5663317244153123
# val_precision: tensor([0.7313, 0.8257, 0.7509, 0.7924], device='cuda:0')
# val_recall: tensor([0.6829, 0.8389, 0.8101, 0.4565], device='cuda:0')
# Learning rate: 5e-06
# epoch 86 time:  0.4162874782166606
# --------------------------------
# ========================================
# EPOCH: 87
# train_loss: 0.6298344871137133
# train_precision: tensor([0.7032, 0.7764, 0.7413, 0.7262], device='cuda:0')
# train_recall: tensor([0.6669, 0.8318, 0.7513, 0.3897], device='cuda:0')
# val_loss: 0.5695033713325008
# val_precision: tensor([0.7298, 0.8272, 0.7470, 0.8256], device='cuda:0')
# val_recall: tensor([0.6819, 0.8364, 0.8121, 0.4302], device='cuda:0')
# Learning rate: 5e-06
# epoch 87 time:  0.4140386291666649
# --------------------------------
# ========================================
# EPOCH: 88
# train_loss: 0.6286218892998677
# train_precision: tensor([0.7048, 0.7761, 0.7398, 0.7343], device='cuda:0')
# train_recall: tensor([0.6645, 0.8313, 0.7543, 0.3901], device='cuda:0')
# val_loss: 0.5661177419506394
# val_precision: tensor([0.7325, 0.8243, 0.7503, 0.7910], device='cuda:0')
# val_recall: tensor([0.6824, 0.8403, 0.8082, 0.4599], device='cuda:0')
# Learning rate: 5e-06
# epoch 88 time:  0.41418248498333315
# --------------------------------
# ========================================
# EPOCH: 89
# train_loss: 0.627593808192544
# train_precision: tensor([0.7033, 0.7774, 0.7412, 0.7332], device='cuda:0')
# train_recall: tensor([0.6648, 0.8339, 0.7526, 0.3930], device='cuda:0')
# val_loss: 0.5735587052575819
# val_precision: tensor([0.7343, 0.8389, 0.7332, 0.7889], device='cuda:0')
# val_recall: tensor([0.6716, 0.8231, 0.8294, 0.4614], device='cuda:0')
# Learning rate: 5e-06
# epoch 89 time:  0.4130643753499953
# --------------------------------
# ========================================
# EPOCH: 90
# train_loss: 0.6301132157886044
# train_precision: tensor([0.7028, 0.7752, 0.7417, 0.7214], device='cuda:0')
# train_recall: tensor([0.6638, 0.8319, 0.7526, 0.3958], device='cuda:0')
# val_loss: 0.5685363456204131
# val_precision: tensor([0.7256, 0.8329, 0.7483, 0.8178], device='cuda:0')
# val_recall: tensor([0.6889, 0.8296, 0.8127, 0.4429], device='cuda:0')
# Learning rate: 5e-06
# epoch 90 time:  0.4152188991833403
# --------------------------------
# ========================================
# EPOCH: 91
# train_loss: 0.6300778104570075
# train_precision: tensor([0.7036, 0.7759, 0.7387, 0.7283], device='cuda:0')
# train_recall: tensor([0.6610, 0.8330, 0.7531, 0.3964], device='cuda:0')
# val_loss: 0.5696606548340829
# val_precision: tensor([0.7430, 0.8186, 0.7425, 0.7937], device='cuda:0')
# val_recall: tensor([0.6622, 0.8459, 0.8191, 0.4507], device='cuda:0')
# Learning rate: 5e-06
# epoch 91 time:  0.41678080351666724
# --------------------------------
# ========================================
# EPOCH: 92
# train_loss: 0.6280936146948481
# train_precision: tensor([0.7034, 0.7763, 0.7417, 0.7328], device='cuda:0')
# train_recall: tensor([0.6637, 0.8342, 0.7529, 0.3944], device='cuda:0')
# val_loss: 0.5679534403411476
# val_precision: tensor([0.7279, 0.8304, 0.7486, 0.7992], device='cuda:0')
# val_recall: tensor([0.6862, 0.8337, 0.8103, 0.4584], device='cuda:0')
# Learning rate: 5e-06
# epoch 92 time:  0.41304551423333274
# --------------------------------
# ========================================
# EPOCH: 93
# train_loss: 0.629433409683646
# train_precision: tensor([0.7011, 0.7760, 0.7414, 0.7395], device='cuda:0')
# train_recall: tensor([0.6643, 0.8320, 0.7515, 0.3973], device='cuda:0')
# val_loss: 0.5677743593493739
# val_precision: tensor([0.7410, 0.8246, 0.7441, 0.7901], device='cuda:0')
# val_recall: tensor([0.6691, 0.8417, 0.8211, 0.4594], device='cuda:0')
# Learning rate: 5e-06
# epoch 93 time:  0.4136630327999986
# --------------------------------
# ========================================
# EPOCH: 94
# train_loss: 0.6299865061328525
# train_precision: tensor([0.7023, 0.7749, 0.7404, 0.7326], device='cuda:0')
# train_recall: tensor([0.6622, 0.8334, 0.7515, 0.3923], device='cuda:0')
# val_loss: 0.5655932846638534
# val_precision: tensor([0.7365, 0.8189, 0.7520, 0.7831], device='cuda:0')
# val_recall: tensor([0.6759, 0.8466, 0.8089, 0.4633], device='cuda:0')
# Learning rate: 5e-06
# epoch 94 time:  0.41778227760000847
# --------------------------------
# ========================================
# EPOCH: 95
# train_loss: 0.6278960619845753
# train_precision: tensor([0.7047, 0.7762, 0.7403, 0.7344], device='cuda:0')
# train_recall: tensor([0.6622, 0.8329, 0.7552, 0.3960], device='cuda:0')
# val_loss: 0.5659184929755356
# val_precision: tensor([0.7224, 0.8298, 0.7568, 0.7893], device='cuda:0')
# val_recall: tensor([0.6976, 0.8334, 0.8012, 0.4662], device='cuda:0')
# Learning rate: 5e-06
# epoch 95 time:  0.4166017094499997
# --------------------------------
# ========================================
# EPOCH: 96
# train_loss: 0.6279970973423242
# train_precision: tensor([0.7051, 0.7771, 0.7412, 0.7158], device='cuda:0')
# train_recall: tensor([0.6657, 0.8320, 0.7541, 0.3952], device='cuda:0')
# val_loss: 0.5673353046894789
# val_precision: tensor([0.7378, 0.8240, 0.7461, 0.7785], device='cuda:0')
# val_recall: tensor([0.6717, 0.8416, 0.8163, 0.4682], device='cuda:0')
# Learning rate: 5e-06
# epoch 96 time:  0.4121773277166691
# --------------------------------
# ========================================
# EPOCH: 97
# train_loss: 0.6296825245348796
# train_precision: tensor([0.7027, 0.7771, 0.7403, 0.7139], device='cuda:0')
# train_recall: tensor([0.6625, 0.8308, 0.7559, 0.3860], device='cuda:0')
# val_loss: 0.5669470474168703
# val_precision: tensor([0.7369, 0.8224, 0.7473, 0.8016], device='cuda:0')
# val_recall: tensor([0.6739, 0.8432, 0.8138, 0.4516], device='cuda:0')
# Learning rate: 5e-06
# epoch 97 time:  0.4153973697333337
# --------------------------------
# ========================================
# EPOCH: 98
# train_loss: 0.6278793054274457
# train_precision: tensor([0.7034, 0.7759, 0.7404, 0.7325], device='cuda:0')
# train_recall: tensor([0.6618, 0.8353, 0.7524, 0.3876], device='cuda:0')
# val_loss: 0.5715099446050398
# val_precision: tensor([0.7470, 0.8269, 0.7323, 0.8077], device='cuda:0')
# val_recall: tensor([0.6532, 0.8377, 0.8350, 0.4492], device='cuda:0')
# Learning rate: 5e-06
# epoch 98 time:  0.4143569821500023
# --------------------------------
# ========================================
# EPOCH: 99
# train_loss: 0.6282954214085636
# train_precision: tensor([0.7017, 0.7764, 0.7409, 0.7348], device='cuda:0')
# train_recall: tensor([0.6651, 0.8317, 0.7514, 0.3962], device='cuda:0')
# val_loss: 0.5702397671637235
# val_precision: tensor([0.7368, 0.8311, 0.7395, 0.8120], device='cuda:0')
# val_recall: tensor([0.6708, 0.8315, 0.8270, 0.4492], device='cuda:0')
# Learning rate: 5e-06
# epoch 99 time:  0.4147800240333405
# --------------------------------
# ========================================
# EPOCH: 100
# train_loss: 0.6272320563843812
# train_precision: tensor([0.7030, 0.7754, 0.7426, 0.7175], device='cuda:0')
# train_recall: tensor([0.6638, 0.8319, 0.7540, 0.3903], device='cuda:0')
# val_loss: 0.5679115517898364
# val_precision: tensor([0.7290, 0.8315, 0.7474, 0.8216], device='cuda:0')
# val_recall: tensor([0.6844, 0.8328, 0.8154, 0.4434], device='cuda:0')
# Learning rate: 5e-06
# epoch 100 time:  0.41767803210000237
# --------------------------------
# ========================================
# EPOCH: 101
# train_loss: 0.6284872911189667
# train_precision: tensor([0.7033, 0.7758, 0.7401, 0.7144], device='cuda:0')
# train_recall: tensor([0.6615, 0.8325, 0.7536, 0.3946], device='cuda:0')
# val_loss: 0.5674362497197257
# val_precision: tensor([0.7341, 0.8287, 0.7457, 0.7919], device='cuda:0')
# val_recall: tensor([0.6780, 0.8356, 0.8167, 0.4662], device='cuda:0')
# Learning rate: 5e-06
# epoch 101 time:  0.41354453239999506
# --------------------------------
# ========================================
# EPOCH: 102
# train_loss: 0.6287974519810928
# train_precision: tensor([0.7025, 0.7777, 0.7413, 0.7285], device='cuda:0')
# train_recall: tensor([0.6658, 0.8316, 0.7533, 0.3913], device='cuda:0')
# val_loss: 0.5701147423939662
# val_precision: tensor([0.7267, 0.8387, 0.7425, 0.8000], device='cuda:0')
# val_recall: tensor([0.6850, 0.8236, 0.8200, 0.4550], device='cuda:0')
# Learning rate: 5e-06
# epoch 102 time:  0.41728909260000363
# --------------------------------
# ========================================
# EPOCH: 103
# train_loss: 0.6276068979708844
# train_precision: tensor([0.7045, 0.7758, 0.7412, 0.7241], device='cuda:0')
# train_recall: tensor([0.6641, 0.8329, 0.7530, 0.3995], device='cuda:0')
# val_loss: 0.5729805564468687
# val_precision: tensor([0.7412, 0.8322, 0.7313, 0.8292], device='cuda:0')
# val_recall: tensor([0.6592, 0.8313, 0.8358, 0.4273], device='cuda:0')
# Learning rate: 5e-06
# epoch 103 time:  0.41368327810000666
# --------------------------------
# ========================================
# EPOCH: 104
# train_loss: 0.6281434514079162
# train_precision: tensor([0.7010, 0.7774, 0.7409, 0.7211], device='cuda:0')
# train_recall: tensor([0.6644, 0.8327, 0.7510, 0.3952], device='cuda:0')
# val_loss: 0.567563878344344
# val_precision: tensor([0.7316, 0.8290, 0.7474, 0.7924], device='cuda:0')
# val_recall: tensor([0.6827, 0.8356, 0.8120, 0.4657], device='cuda:0')
# Learning rate: 5e-06
# epoch 104 time:  0.41352747061666073
# --------------------------------
# ========================================
# EPOCH: 105
# train_loss: 0.6283120402881691
# train_precision: tensor([0.7028, 0.7770, 0.7413, 0.7306], device='cuda:0')
# train_recall: tensor([0.6640, 0.8328, 0.7539, 0.3878], device='cuda:0')
# val_loss: 0.5684693705391239
# val_precision: tensor([0.7347, 0.8281, 0.7434, 0.8175], device='cuda:0')
# val_recall: tensor([0.6759, 0.8368, 0.8183, 0.4356], device='cuda:0')
# Learning rate: 5e-06
# epoch 105 time:  0.4159273930833327
# --------------------------------
# ========================================
# EPOCH: 106
# train_loss: 0.6282280571327247
# train_precision: tensor([0.7033, 0.7780, 0.7410, 0.7298], device='cuda:0')
# train_recall: tensor([0.6658, 0.8326, 0.7529, 0.3956], device='cuda:0')
# val_loss: 0.5680365037989688
# val_precision: tensor([0.7266, 0.8320, 0.7487, 0.8261], device='cuda:0')
# val_recall: tensor([0.6907, 0.8316, 0.8105, 0.4341], device='cuda:0')
# Learning rate: 5e-06
# epoch 106 time:  0.4153526019499926
# --------------------------------
# ========================================
# EPOCH: 107
# train_loss: 0.6279930310321438
# train_precision: tensor([0.7038, 0.7775, 0.7407, 0.7167], device='cuda:0')
# train_recall: tensor([0.6644, 0.8327, 0.7534, 0.3950], device='cuda:0')
# val_loss: 0.5700272268003171
# val_precision: tensor([0.7438, 0.8235, 0.7399, 0.7993], device='cuda:0')
# val_recall: tensor([0.6625, 0.8414, 0.8250, 0.4570], device='cuda:0')
# Learning rate: 5e-06
# epoch 107 time:  0.4136358487333382
# --------------------------------
# ========================================
# EPOCH: 108
# train_loss: 0.627578360521195
# train_precision: tensor([0.7041, 0.7763, 0.7416, 0.7436], device='cuda:0')
# train_recall: tensor([0.6643, 0.8345, 0.7526, 0.4011], device='cuda:0')
# val_loss: 0.5710291038225362
# val_precision: tensor([0.7465, 0.8247, 0.7345, 0.7814], device='cuda:0')
# val_recall: tensor([0.6524, 0.8405, 0.8307, 0.4745], device='cuda:0')
# Learning rate: 5e-06
# epoch 108 time:  0.41366229271667787
# --------------------------------
# ========================================
# EPOCH: 109
# train_loss: 0.628420538059226
# train_precision: tensor([0.7026, 0.7768, 0.7401, 0.7267], device='cuda:0')
# train_recall: tensor([0.6640, 0.8315, 0.7530, 0.3950], device='cuda:0')
# val_loss: 0.5665991739020333
# val_precision: tensor([0.7370, 0.8228, 0.7469, 0.8064], device='cuda:0')
# val_recall: tensor([0.6739, 0.8417, 0.8155, 0.4516], device='cuda:0')
# Learning rate: 5e-06
# Early stopping at epoch 109 with best validation loss 0.5655932846638534
# training_checkpoints/efficient_net_b0_no_small_images2024-05-25 22:00:40.772399.pth
# <All keys matched successfully>
