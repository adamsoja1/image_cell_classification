# %%
import time
import sys
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from dataset import ImageDataset
import torch.nn.functional as F
from torchmetrics import Precision, Recall
from torchvision.models import resnet18
import warnings
from collections import defaultdict
import wandb
import datetime
import os
warnings.filterwarnings('ignore')
torch.set_float32_matmul_precision('high')
#intecubic interpol

run_name = f'resnet18_base_norm_padding_resize_minlr0.0001_1024_batch_{datetime.datetime.now()}'
run_path = f'training_checkpoints/{run_name}'

wandb.init(project="cells", 
           entity="adamsoja",
          name=run_name)

import random
random.seed(2233)
torch.manual_seed(2233)

#After /255 so in loading dataset there are no division by 255 just this normalization
mean = [0.5006, 0.3526, 0.5495]
std = [0.1493, 0.1341, 0.1124]


from albumentations import (
    Compose,
    Resize,
    OneOf,
    RandomBrightness,
    RandomContrast,
    MotionBlur,
    MedianBlur,
    GaussianBlur,
    VerticalFlip,
    HorizontalFlip,
    ShiftScaleRotate,
    Normalize,
)

transform = Compose(
    [
        Normalize(mean=mean, std=std),
        OneOf([RandomBrightness(limit=0.1, p=1), RandomContrast(limit=0.1, p=0.8)]),
        OneOf([MotionBlur(blur_limit=3), MedianBlur(blur_limit=3), GaussianBlur(blur_limit=3),], p=0.7,),
        VerticalFlip(p=0.5),
        HorizontalFlip(p=0.5),
    ]
)

transform_test = Compose(
    [Normalize(mean=mean, std=std)]
)

class MyModel(nn.Module):
    def __init__(self, model, learning_rate, weight_decay):
        super(MyModel, self).__init__()
        self.model = model
        self.learning_rate = learning_rate
        self.weight_decay = weight_decay
        self.criterion = nn.CrossEntropyLoss()
        self.metric_precision = Precision(task="multiclass", num_classes=4, average=None).to('cuda')
        self.metric_recall = Recall(task="multiclass", num_classes=4, average=None).to('cuda')
        self.train_loss = []
        self.valid_loss = []
        self.precision_per_epochs = []
        self.recall_per_epochs = []

        self.optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, mode="min", factor=0.01, patience=3, min_lr=0.0001, verbose=True)
        self.step = 0

    
    def forward(self, x):
        return self.model(x)

    def train_one_epoch(self, trainloader):
        self.step += 1
        self.train()
        for batch_idx, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()
            _, preds = torch.max(outputs, 1)
            _, labels = torch.max(labels, 1)
            self.metric_precision(preds, labels)
            self.metric_recall(preds, labels)
            self.train_loss.append(loss.item())


        

        
        avg_loss = np.mean(self.train_loss)
        self.train_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        self.precision_per_epochs.append(precision)
        self.recall_per_epochs.append(recall)
        print(f'train_loss: {avg_loss}')
        print(f'train_precision: {precision}')
        print(f'train_recall: {recall}')

        wandb.log({'loss': avg_loss},step=self.step)
        wandb.log({'Normal precision': precision[0].item()},step=self.step)
        wandb.log({'Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'Other precision': precision[3].item()},step=self.step)


        wandb.log({'Normal recall': recall[0].item()},step=self.step)
        wandb.log({'Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'Other recall': recall[3].item()},step=self.step)
        
        
        self.metric_precision.reset()
        self.metric_recall.reset()


    

    def evaluate(self, testloader):
        self.eval()
        with torch.no_grad():
            for batch_idx, (inputs, labels) in enumerate(testloader):
                inputs, labels = inputs.to('cuda'), labels.to('cuda')
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)
                _, labels = torch.max(labels, 1)
                self.metric_precision(preds, labels)
                self.metric_recall(preds, labels)
                self.valid_loss.append(loss.item())
    
        avg_loss = np.mean(self.valid_loss)
        self.scheduler.step(avg_loss)
        self.valid_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        print(f'val_loss: {avg_loss}')
        print(f'val_precision: {precision}')
        print(f'val_recall: {recall}')
        self.metric_precision.reset()
        self.metric_recall.reset()

        wandb.log({'val_loss': avg_loss}, step=self.step)
        
        wandb.log({'val_Normal precision': precision[0].item()},step=self.step)
        wandb.log({'val_Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'val_Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'val_Other precision': precision[3].item()},step=self.step)


        wandb.log({'val_Normal recall': recall[0].item()},step=self.step)
        wandb.log({'val_Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'val_Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'val_Other recall': recall[3].item()},step=self.step)


        for param_group in self.optimizer.param_groups:
            print(f"Learning rate: {param_group['lr']}")
        return avg_loss

torch.cuda.empty_cache()
batch_size = 1024

trainset = ImageDataset(data_path='train_data', transform=transform)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=3)

testset = ImageDataset(data_path='validation_data', transform=transform_test)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)


learning_rate = 0.001
weight_decay = 0.00001

model = resnet18()
model.conv1 = nn.Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
num_classes = 4
model.fc = nn.Sequential(
    nn.Dropout(0.4),
    nn.Linear(model.fc.in_features, num_classes))
model = model.to('cuda')


my_model = MyModel(model=model, learning_rate=learning_rate, weight_decay=weight_decay)
my_model = my_model.to('cuda')

num_epochs = 100
early_stop_patience = 10
best_val_loss = float('inf')
best_model_state_dict = None

for epoch in range(num_epochs):
    print('========================================')
    print(f'EPOCH: {epoch}') 
    time_start = time.perf_counter()
    my_model.train_one_epoch(trainloader)
    val_loss = my_model.evaluate(testloader)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_state_dict = my_model.state_dict()
        torch.save(best_model_state_dict, f'{run_path}.pth')
        
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch} with best validation loss {best_val_loss}")
        break
    time_epoch = time.perf_counter() - time_start
    print(f'epoch {epoch} time:  {time_epoch}')
    print('--------------------------------')

# Load the best model state dict
print(f'{run_path}.pth')
my_model.load_state_dict(torch.load(f'{run_path}.pth'))
# Out:
# wandb: Currently logged in as: adamsoja. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/adam/Desktop/cells_master_thesis/wandb/run-20240425_102553-826wo15g</code>
# Syncing run <strong><a href='https://wandb.ai/adamsoja/cells/runs/826wo15g' target="_blank">resnet18_base_norm_padding_resize_2024-04-25 10:25:52.881424</a></strong> to <a href='https://wandb.ai/adamsoja/cells' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adamsoja/cells' target="_blank">https://wandb.ai/adamsoja/cells</a>
#  View run at <a href='https://wandb.ai/adamsoja/cells/runs/826wo15g' target="_blank">https://wandb.ai/adamsoja/cells/runs/826wo15g</a>
# ========================================
# EPOCH: 0
# train_loss: 0.9150045945530846
# train_precision: tensor([0.5554, 0.6508, 0.6306, 0.4689], device='cuda:0')
# train_recall: tensor([0.5513, 0.7576, 0.5913, 0.0261], device='cuda:0')
# val_loss: 0.8966880588895745
# val_precision: tensor([0.6188, 0.8013, 0.5310, 0.8226], device='cuda:0')
# val_recall: tensor([0.5435, 0.5708, 0.7937, 0.1202], device='cuda:0')
# Learning rate: 0.001
# epoch 0 time:  0.36138990603334
# --------------------------------
# ========================================
# EPOCH: 1
# train_loss: 0.8291148541938691
# train_precision: tensor([0.5997, 0.6924, 0.6613, 0.5410], device='cuda:0')
# train_recall: tensor([0.5837, 0.7804, 0.6458, 0.1255], device='cuda:0')
# val_loss: 0.7673877441220813
# val_precision: tensor([0.5923, 0.7499, 0.7334, 0.6453], device='cuda:0')
# val_recall: tensor([0.6913, 0.7814, 0.6209, 0.2842], device='cuda:0')
# Learning rate: 0.001
# epoch 1 time:  0.3818566307666818
# --------------------------------
# ========================================
# EPOCH: 2
# train_loss: 0.7967284755337806
# train_precision: tensor([0.6179, 0.7072, 0.6744, 0.5658], device='cuda:0')
# train_recall: tensor([0.5986, 0.7852, 0.6660, 0.1898], device='cuda:0')
# val_loss: 0.7346200465328163
# val_precision: tensor([0.6563, 0.7659, 0.6882, 0.6309], device='cuda:0')
# val_recall: tensor([0.6149, 0.7925, 0.7465, 0.2751], device='cuda:0')
# Learning rate: 0.001
# epoch 2 time:  0.3847775050333439
# --------------------------------
# ========================================
# EPOCH: 3
# train_loss: 0.7741575969826607
# train_precision: tensor([0.6311, 0.7165, 0.6863, 0.5929], device='cuda:0')
# train_recall: tensor([0.6043, 0.7955, 0.6812, 0.2349], device='cuda:0')
# val_loss: 0.7183990363445547
# val_precision: tensor([0.6827, 0.7673, 0.6650, 0.7369], device='cuda:0')
# val_recall: tensor([0.5805, 0.7966, 0.7782, 0.3027], device='cuda:0')
# Learning rate: 0.001
# epoch 3 time:  0.38517298409994205
# --------------------------------
# ========================================
# EPOCH: 4
# train_loss: 0.7568282963264557
# train_precision: tensor([0.6410, 0.7230, 0.6913, 0.6254], device='cuda:0')
# train_recall: tensor([0.6136, 0.7981, 0.6901, 0.2541], device='cuda:0')
# val_loss: 0.712295576516125
# val_precision: tensor([0.6615, 0.7398, 0.7413, 0.6218], device='cuda:0')
# val_recall: tensor([0.6400, 0.8368, 0.6913, 0.4279], device='cuda:0')
# Learning rate: 0.001
# epoch 4 time:  0.3824468270666936
# --------------------------------
# ========================================
# EPOCH: 5
# train_loss: 0.7417604498210407
# train_precision: tensor([0.6498, 0.7279, 0.7010, 0.6261], device='cuda:0')
# train_recall: tensor([0.6224, 0.8035, 0.6971, 0.2758], device='cuda:0')
# val_loss: 0.6985538365940253
# val_precision: tensor([0.6642, 0.7863, 0.6911, 0.6414], device='cuda:0')
# val_recall: tensor([0.6234, 0.7753, 0.7660, 0.4306], device='cuda:0')
# Learning rate: 0.001
# epoch 5 time:  0.37914592084998733
# --------------------------------
# ========================================
# EPOCH: 6
# train_loss: 0.7302196953268278
# train_precision: tensor([0.6548, 0.7348, 0.7056, 0.6330], device='cuda:0')
# train_recall: tensor([0.6297, 0.8044, 0.7031, 0.2984], device='cuda:0')
# val_loss: 0.7262407893935839
# val_precision: tensor([0.6913, 0.7966, 0.6456, 0.7080], device='cuda:0')
# val_recall: tensor([0.5314, 0.7868, 0.8328, 0.3805], device='cuda:0')
# Learning rate: 0.001
# epoch 6 time:  0.3618142946666921
# --------------------------------
# ========================================
# EPOCH: 7
# train_loss: 0.7184073392124403
# train_precision: tensor([0.6637, 0.7375, 0.7127, 0.6455], device='cuda:0')
# train_recall: tensor([0.6345, 0.8087, 0.7115, 0.3159], device='cuda:0')
# val_loss: 0.6535674367513922
# val_precision: tensor([0.7105, 0.7570, 0.7350, 0.6711], device='cuda:0')
# val_recall: tensor([0.6225, 0.8506, 0.7590, 0.4549], device='cuda:0')
# Learning rate: 0.001
# epoch 7 time:  0.3821799626333814
# --------------------------------
# ========================================
# EPOCH: 8
# train_loss: 0.709633198522386
# train_precision: tensor([0.6670, 0.7417, 0.7163, 0.6529], device='cuda:0')
# train_recall: tensor([0.6380, 0.8115, 0.7151, 0.3333], device='cuda:0')
# val_loss: 0.6739001686374346
# val_precision: tensor([0.7067, 0.7203, 0.7686, 0.6527], device='cuda:0')
# val_recall: tensor([0.6230, 0.8802, 0.7114, 0.4620], device='cuda:0')
# Learning rate: 0.001
# epoch 8 time:  0.3639884375498999
# --------------------------------
# ========================================
# EPOCH: 9
# train_loss: 0.6978526025300934
# train_precision: tensor([0.6695, 0.7464, 0.7204, 0.6540], device='cuda:0')
# train_recall: tensor([0.6454, 0.8110, 0.7183, 0.3423], device='cuda:0')
# val_loss: 0.6499000859757265
# val_precision: tensor([0.6892, 0.8188, 0.7106, 0.7191], device='cuda:0')
# val_recall: tensor([0.6584, 0.7739, 0.8068, 0.4620], device='cuda:0')
# Learning rate: 0.001
# epoch 9 time:  0.3859775176999392
# --------------------------------
# ========================================
# EPOCH: 10
# train_loss: 0.689505136864526
# train_precision: tensor([0.6752, 0.7503, 0.7244, 0.6597], device='cuda:0')
# train_recall: tensor([0.6504, 0.8137, 0.7226, 0.3618], device='cuda:0')
# val_loss: 0.6475539199180074
# val_precision: tensor([0.7176, 0.7654, 0.7298, 0.7518], device='cuda:0')
# val_recall: tensor([0.6140, 0.8564, 0.7797, 0.4283], device='cuda:0')
# Learning rate: 0.001
# epoch 10 time:  0.3828268404834186
# --------------------------------
# ========================================
# EPOCH: 11
# train_loss: 0.6809888604141418
# train_precision: tensor([0.6807, 0.7528, 0.7280, 0.6660], device='cuda:0')
# train_recall: tensor([0.6532, 0.8183, 0.7254, 0.3789], device='cuda:0')
# val_loss: 0.6579048112034798
# val_precision: tensor([0.6917, 0.8010, 0.7054, 0.7307], device='cuda:0')
# val_recall: tensor([0.6712, 0.7822, 0.7692, 0.4586], device='cuda:0')
# Learning rate: 0.001
# epoch 11 time:  0.3628928850167237
# --------------------------------
# ========================================
# EPOCH: 12
# train_loss: 0.6735917237542924
# train_precision: tensor([0.6811, 0.7557, 0.7322, 0.6707], device='cuda:0')
# train_recall: tensor([0.6558, 0.8187, 0.7280, 0.3991], device='cuda:0')
# val_loss: 0.6192768348587884
# val_precision: tensor([0.7310, 0.7743, 0.7435, 0.6727], device='cuda:0')
# val_recall: tensor([0.6362, 0.8531, 0.7809, 0.5219], device='cuda:0')
# Learning rate: 0.001
# epoch 12 time:  0.38124123276672134
# --------------------------------
# ========================================
# EPOCH: 13
# train_loss: 0.6645259244810967
# train_precision: tensor([0.6889, 0.7599, 0.7354, 0.6668], device='cuda:0')
# train_recall: tensor([0.6611, 0.8212, 0.7347, 0.4052], device='cuda:0')
# val_loss: 0.6165586297710737
# val_precision: tensor([0.7085, 0.8350, 0.7205, 0.7013], device='cuda:0')
# val_recall: tensor([0.6850, 0.7837, 0.8079, 0.5138], device='cuda:0')
# Learning rate: 0.001
# epoch 13 time:  0.3946740962333327
# --------------------------------
# ========================================
# EPOCH: 14
# train_loss: 0.6578991586253756
# train_precision: tensor([0.6897, 0.7610, 0.7381, 0.6773], device='cuda:0')
# train_recall: tensor([0.6658, 0.8238, 0.7306, 0.4206], device='cuda:0')
# val_loss: 0.6217455809315046
# val_precision: tensor([0.7542, 0.7523, 0.7551, 0.6920], device='cuda:0')
# val_recall: tensor([0.6162, 0.8846, 0.7760, 0.5492], device='cuda:0')
# Learning rate: 0.001
# epoch 14 time:  0.3757317248666368
# --------------------------------
# ========================================
# EPOCH: 15
# train_loss: 0.6498979633053144
# train_precision: tensor([0.6929, 0.7639, 0.7425, 0.6728], device='cuda:0')
# train_recall: tensor([0.6681, 0.8267, 0.7348, 0.4303], device='cuda:0')
# val_loss: 0.6045114004777538
# val_precision: tensor([0.6864, 0.8341, 0.7620, 0.6567], device='cuda:0')
# val_recall: tensor([0.7220, 0.7861, 0.7741, 0.5892], device='cuda:0')
# Learning rate: 0.001
# epoch 15 time:  0.3939687861167234
# --------------------------------
# ========================================
# EPOCH: 16
# train_loss: 0.6428508682265168
# train_precision: tensor([0.6996, 0.7663, 0.7446, 0.6853], device='cuda:0')
# train_recall: tensor([0.6747, 0.8267, 0.7387, 0.4430], device='cuda:0')
# val_loss: 0.6024139113724232
# val_precision: tensor([0.7088, 0.8323, 0.7340, 0.7215], device='cuda:0')
# val_recall: tensor([0.6922, 0.8003, 0.7981, 0.5374], device='cuda:0')
# Learning rate: 0.001
# epoch 16 time:  0.39592447371663486
# --------------------------------
# ========================================
# EPOCH: 17
# train_loss: 0.6349458548639502
# train_precision: tensor([0.7010, 0.7697, 0.7467, 0.6823], device='cuda:0')
# train_recall: tensor([0.6762, 0.8275, 0.7411, 0.4623], device='cuda:0')
# val_loss: 0.6173630906475915
# val_precision: tensor([0.7147, 0.7834, 0.7596, 0.7505], device='cuda:0')
# val_recall: tensor([0.6797, 0.8448, 0.7637, 0.4892], device='cuda:0')
# Learning rate: 0.001
# epoch 17 time:  0.3716903106332514
# --------------------------------
# ========================================
# EPOCH: 18
# train_loss: 0.6280837900227024
# train_precision: tensor([0.7051, 0.7704, 0.7512, 0.6857], device='cuda:0')
# train_recall: tensor([0.6794, 0.8312, 0.7424, 0.4745], device='cuda:0')
# val_loss: 0.605884487595823
# val_precision: tensor([0.6950, 0.8074, 0.7741, 0.6338], device='cuda:0')
# val_recall: tensor([0.7086, 0.8113, 0.7628, 0.5710], device='cuda:0')
# Learning rate: 0.001
# epoch 18 time:  0.3572800553500807
# --------------------------------
# ========================================
# EPOCH: 19
# train_loss: 0.6187841192597434
# train_precision: tensor([0.7089, 0.7763, 0.7564, 0.6973], device='cuda:0')
# train_recall: tensor([0.6863, 0.8342, 0.7458, 0.4983], device='cuda:0')
# val_loss: 0.6126468764411078
# val_precision: tensor([0.7047, 0.7980, 0.7534, 0.7047], device='cuda:0')
# val_recall: tensor([0.6804, 0.8287, 0.7663, 0.5569], device='cuda:0')
# Learning rate: 5e-05
# epoch 19 time:  0.36134355133338736
# --------------------------------
# ========================================
# EPOCH: 20
# train_loss: 0.5864321047706264
# train_precision: tensor([0.7218, 0.7902, 0.7682, 0.7345], device='cuda:0')
# train_recall: tensor([0.7024, 0.8393, 0.7616, 0.5385], device='cuda:0')
# val_loss: 0.5645912306176292
# val_precision: tensor([0.7333, 0.8214, 0.7721, 0.7401], device='cuda:0')
# val_recall: tensor([0.7077, 0.8394, 0.8001, 0.5677], device='cuda:0')
# Learning rate: 5e-05
# epoch 20 time:  0.3776042846167305
# --------------------------------
# ========================================
# EPOCH: 21
# train_loss: 0.5758381869821322
# train_precision: tensor([0.7302, 0.7899, 0.7753, 0.7370], device='cuda:0')
# train_recall: tensor([0.7076, 0.8455, 0.7637, 0.5563], device='cuda:0')
# val_loss: 0.5603346691363388
# val_precision: tensor([0.7295, 0.8290, 0.7779, 0.7154], device='cuda:0')
# val_recall: tensor([0.7211, 0.8338, 0.7956, 0.5943], device='cuda:0')
# Learning rate: 5e-05
# epoch 21 time:  0.3779175850834387
# --------------------------------
# ========================================
# EPOCH: 22
# train_loss: 0.5709474515702043
# train_precision: tensor([0.7302, 0.7941, 0.7767, 0.7408], device='cuda:0')
# train_recall: tensor([0.7106, 0.8453, 0.7656, 0.5674], device='cuda:0')
# val_loss: 0.5572465460333559
# val_precision: tensor([0.7392, 0.8178, 0.7841, 0.7048], device='cuda:0')
# val_recall: tensor([0.7109, 0.8507, 0.7938, 0.6037], device='cuda:0')
# Learning rate: 5e-05
# epoch 22 time:  0.37428775505007555
# --------------------------------
# ========================================
# EPOCH: 23
# train_loss: 0.5651541751765069
# train_precision: tensor([0.7309, 0.7952, 0.7782, 0.7452], device='cuda:0')
# train_recall: tensor([0.7121, 0.8455, 0.7652, 0.5900], device='cuda:0')
# val_loss: 0.5548400646282567
# val_precision: tensor([0.7384, 0.8149, 0.7877, 0.7158], device='cuda:0')
# val_recall: tensor([0.7149, 0.8522, 0.7891, 0.6030], device='cuda:0')
# Learning rate: 5e-05
# epoch 23 time:  0.3717728704000668
# --------------------------------
# ========================================
# EPOCH: 24
# train_loss: 0.5633026105307397
# train_precision: tensor([0.7344, 0.7944, 0.7805, 0.7424], device='cuda:0')
# train_recall: tensor([0.7129, 0.8480, 0.7668, 0.5882], device='cuda:0')
# val_loss: 0.5559191916551854
# val_precision: tensor([0.7405, 0.8188, 0.7802, 0.7133], device='cuda:0')
# val_recall: tensor([0.7082, 0.8489, 0.7983, 0.5963], device='cuda:0')
# Learning rate: 5e-05
# epoch 24 time:  0.35555550110002515
# --------------------------------
# ========================================
# EPOCH: 25
# train_loss: 0.5594663399316016
# train_precision: tensor([0.7351, 0.7971, 0.7815, 0.7435], device='cuda:0')
# train_recall: tensor([0.7165, 0.8478, 0.7671, 0.5951], device='cuda:0')
# val_loss: 0.5556793373492029
# val_precision: tensor([0.7473, 0.8144, 0.7770, 0.7076], device='cuda:0')
# val_recall: tensor([0.6968, 0.8531, 0.8035, 0.6088], device='cuda:0')
# Learning rate: 5e-05
# epoch 25 time:  0.35871257726673017
# --------------------------------
# ========================================
# EPOCH: 26
# train_loss: 0.5583137003084023
# train_precision: tensor([0.7370, 0.7986, 0.7822, 0.7446], device='cuda:0')
# train_recall: tensor([0.7174, 0.8480, 0.7696, 0.6016], device='cuda:0')
# val_loss: 0.5554939053952694
# val_precision: tensor([0.7395, 0.8244, 0.7804, 0.7114], device='cuda:0')
# val_recall: tensor([0.7148, 0.8434, 0.8000, 0.6067], device='cuda:0')
# Learning rate: 5e-06
# epoch 26 time:  0.3563292672333773
# --------------------------------
# ========================================
# EPOCH: 27
# train_loss: 0.5549170789264497
# train_precision: tensor([0.7360, 0.7968, 0.7852, 0.7511], device='cuda:0')
# train_recall: tensor([0.7179, 0.8498, 0.7679, 0.6017], device='cuda:0')
# val_loss: 0.5552210366560353
# val_precision: tensor([0.7364, 0.8276, 0.7802, 0.7114], device='cuda:0')
# val_recall: tensor([0.7185, 0.8397, 0.7992, 0.6074], device='cuda:0')
# Learning rate: 5e-06
# epoch 27 time:  0.35616317485000765
# --------------------------------
# ========================================
# EPOCH: 28
# train_loss: 0.5542768283259301
# train_precision: tensor([0.7381, 0.7982, 0.7853, 0.7440], device='cuda:0')
# train_recall: tensor([0.7177, 0.8498, 0.7714, 0.5994], device='cuda:0')
# val_loss: 0.5552178722288873
# val_precision: tensor([0.7319, 0.8361, 0.7775, 0.7158], device='cuda:0')
# val_recall: tensor([0.7253, 0.8293, 0.8026, 0.6081], device='cuda:0')
# Learning rate: 5e-06
# epoch 28 time:  0.355574756233303
# --------------------------------
# ========================================
# EPOCH: 29
# train_loss: 0.5541964371999105
# train_precision: tensor([0.7393, 0.7984, 0.7830, 0.7547], device='cuda:0')
# train_recall: tensor([0.7183, 0.8502, 0.7698, 0.6072], device='cuda:0')
# val_loss: 0.5537016107804246
# val_precision: tensor([0.7393, 0.8257, 0.7806, 0.7193], device='cuda:0')
# val_recall: tensor([0.7170, 0.8432, 0.8007, 0.5987], device='cuda:0')
# Learning rate: 5e-06
# epoch 29 time:  0.37692679455006634
# --------------------------------
# ========================================
# EPOCH: 30
# train_loss: 0.5524446777644612
# train_precision: tensor([0.7380, 0.7992, 0.7838, 0.7502], device='cuda:0')
# train_recall: tensor([0.7201, 0.8485, 0.7699, 0.6019], device='cuda:0')
# val_loss: 0.5553570789595444
# val_precision: tensor([0.7341, 0.8266, 0.7859, 0.7141], device='cuda:0')
# val_recall: tensor([0.7240, 0.8418, 0.7943, 0.6047], device='cuda:0')
# Learning rate: 5e-06
# epoch 30 time:  0.3547338564333283
# --------------------------------
# ========================================
# EPOCH: 31
# train_loss: 0.5519953049364544
# train_precision: tensor([0.7381, 0.7993, 0.7838, 0.7474], device='cuda:0')
# train_recall: tensor([0.7181, 0.8498, 0.7709, 0.6009], device='cuda:0')
# val_loss: 0.5540268725819057
# val_precision: tensor([0.7380, 0.8264, 0.7813, 0.7175], device='cuda:0')
# val_recall: tensor([0.7186, 0.8415, 0.8001, 0.6030], device='cuda:0')
# Learning rate: 5e-06
# epoch 31 time:  0.3538068253833141
# --------------------------------
# ========================================
# EPOCH: 32
# train_loss: 0.5541984189833914
# train_precision: tensor([0.7395, 0.7984, 0.7821, 0.7443], device='cuda:0')
# train_recall: tensor([0.7163, 0.8491, 0.7716, 0.6045], device='cuda:0')
# val_loss: 0.5534697161780463
# val_precision: tensor([0.7388, 0.8183, 0.7903, 0.7153], device='cuda:0')
# val_recall: tensor([0.7186, 0.8520, 0.7911, 0.6091], device='cuda:0')
# Learning rate: 5e-06
# epoch 32 time:  0.37596244648326926
# --------------------------------
# ========================================
# EPOCH: 33
# train_loss: 0.5535809450561092
# train_precision: tensor([0.7377, 0.7998, 0.7848, 0.7499], device='cuda:0')
# train_recall: tensor([0.7180, 0.8491, 0.7720, 0.6097], device='cuda:0')
# val_loss: 0.5526149460838901
# val_precision: tensor([0.7400, 0.8238, 0.7825, 0.7000], device='cuda:0')
# val_recall: tensor([0.7152, 0.8444, 0.7986, 0.6158], device='cuda:0')
# Learning rate: 5e-06
# epoch 33 time:  0.37328829865000446
# --------------------------------
# ========================================
# EPOCH: 34
# train_loss: 0.5530581776584897
# train_precision: tensor([0.7386, 0.7989, 0.7840, 0.7524], device='cuda:0')
# train_recall: tensor([0.7188, 0.8503, 0.7702, 0.6025], device='cuda:0')
# val_loss: 0.5534378031061755
# val_precision: tensor([0.7360, 0.8283, 0.7837, 0.7104], device='cuda:0')
# val_recall: tensor([0.7229, 0.8402, 0.7973, 0.6128], device='cuda:0')
# Learning rate: 5e-06
# epoch 34 time:  0.35600933755000974
# --------------------------------
# ========================================
# EPOCH: 35
# train_loss: 0.553168683286224
# train_precision: tensor([0.7381, 0.7993, 0.7843, 0.7518], device='cuda:0')
# train_recall: tensor([0.7176, 0.8494, 0.7718, 0.6088], device='cuda:0')
# val_loss: 0.551549967047241
# val_precision: tensor([0.7348, 0.8213, 0.7921, 0.7170], device='cuda:0')
# val_recall: tensor([0.7247, 0.8488, 0.7886, 0.6074], device='cuda:0')
# Learning rate: 5e-06
# epoch 35 time:  0.37539145625002374
# --------------------------------
# ========================================
# EPOCH: 36
# train_loss: 0.5529886969143436
# train_precision: tensor([0.7390, 0.7990, 0.7824, 0.7477], device='cuda:0')
# train_recall: tensor([0.7175, 0.8491, 0.7711, 0.6046], device='cuda:0')
# val_loss: 0.5521013957758745
# val_precision: tensor([0.7425, 0.8240, 0.7799, 0.7030], device='cuda:0')
# val_recall: tensor([0.7130, 0.8449, 0.8007, 0.6168], device='cuda:0')
# Learning rate: 5e-06
# epoch 36 time:  0.3548720461833
# --------------------------------
# ========================================
# EPOCH: 37
# train_loss: 0.5509324756051813
# train_precision: tensor([0.7396, 0.8008, 0.7842, 0.7512], device='cuda:0')
# train_recall: tensor([0.7198, 0.8510, 0.7713, 0.6056], device='cuda:0')
# val_loss: 0.5535239006082217
# val_precision: tensor([0.7360, 0.8221, 0.7882, 0.7222], device='cuda:0')
# val_recall: tensor([0.7210, 0.8474, 0.7928, 0.6047], device='cuda:0')
# Learning rate: 5e-06
# epoch 37 time:  0.35489114005007044
# --------------------------------
# ========================================
# EPOCH: 38
# train_loss: 0.5516008501606328
# train_precision: tensor([0.7403, 0.7987, 0.7858, 0.7505], device='cuda:0')
# train_recall: tensor([0.7190, 0.8504, 0.7728, 0.6048], device='cuda:0')
# val_loss: 0.5542932458221912
# val_precision: tensor([0.7402, 0.8212, 0.7839, 0.7205], device='cuda:0')
# val_recall: tensor([0.7152, 0.8472, 0.7985, 0.6013], device='cuda:0')
# Learning rate: 5e-06
# epoch 38 time:  0.35519119663331367
# --------------------------------
# ========================================
# EPOCH: 39
# train_loss: 0.5511224513607366
# train_precision: tensor([0.7397, 0.7988, 0.7855, 0.7478], device='cuda:0')
# train_recall: tensor([0.7203, 0.8494, 0.7707, 0.6118], device='cuda:0')
# val_loss: 0.555075873931249
# val_precision: tensor([0.7422, 0.8285, 0.7758, 0.7116], device='cuda:0')
# val_recall: tensor([0.7137, 0.8395, 0.8067, 0.6081], device='cuda:0')
# Learning rate: 5e-06
# epoch 39 time:  0.35505640970004604
# --------------------------------
# ========================================
# EPOCH: 40
# train_loss: 0.5509764856880619
# train_precision: tensor([0.7394, 0.7994, 0.7857, 0.7478], device='cuda:0')
# train_recall: tensor([0.7201, 0.8501, 0.7709, 0.6089], device='cuda:0')
# val_loss: 0.5532306629750464
# val_precision: tensor([0.7392, 0.8225, 0.7844, 0.7185], device='cuda:0')
# val_recall: tensor([0.7176, 0.8467, 0.7963, 0.6067], device='cuda:0')
# Learning rate: 5e-06
# epoch 40 time:  0.35567860338330015
# --------------------------------
# ========================================
# EPOCH: 41
# train_loss: 0.5514854096585796
# train_precision: tensor([0.7382, 0.7999, 0.7852, 0.7490], device='cuda:0')
# train_recall: tensor([0.7173, 0.8516, 0.7711, 0.6114], device='cuda:0')
# val_loss: 0.5536554488870833
# val_precision: tensor([0.7427, 0.8176, 0.7844, 0.7092], device='cuda:0')
# val_recall: tensor([0.7106, 0.8531, 0.7947, 0.6141], device='cuda:0')
# Learning rate: 5e-06
# epoch 41 time:  0.3540985859500021
# --------------------------------
# ========================================
# EPOCH: 42
# train_loss: 0.5502526938915253
# train_precision: tensor([0.7404, 0.8003, 0.7857, 0.7521], device='cuda:0')
# train_recall: tensor([0.7205, 0.8516, 0.7715, 0.6078], device='cuda:0')
# val_loss: 0.55483054212398
# val_precision: tensor([0.7327, 0.8284, 0.7851, 0.7224], device='cuda:0')
# val_recall: tensor([0.7266, 0.8395, 0.7946, 0.5983], device='cuda:0')
# Learning rate: 5e-06
# epoch 42 time:  0.35618924694996773
# --------------------------------
# ========================================
# EPOCH: 43
# train_loss: 0.5505342400144964
# train_precision: tensor([0.7405, 0.7984, 0.7857, 0.7557], device='cuda:0')
# train_recall: tensor([0.7210, 0.8490, 0.7720, 0.6066], device='cuda:0')
# val_loss: 0.5552994295954704
# val_precision: tensor([0.7391, 0.8299, 0.7773, 0.7083], device='cuda:0')
# val_recall: tensor([0.7156, 0.8374, 0.8054, 0.6141], device='cuda:0')
# Learning rate: 5e-06
# epoch 43 time:  0.35441500133335163
# --------------------------------
# ========================================
# EPOCH: 44
# train_loss: 0.5506038031762555
# train_precision: tensor([0.7400, 0.8000, 0.7848, 0.7496], device='cuda:0')
# train_recall: tensor([0.7189, 0.8508, 0.7719, 0.6104], device='cuda:0')
# val_loss: 0.5568552411264843
# val_precision: tensor([0.7423, 0.8237, 0.7795, 0.7112], device='cuda:0')
# val_recall: tensor([0.7125, 0.8440, 0.8029, 0.6094], device='cuda:0')
# Learning rate: 5e-06
# epoch 44 time:  0.35559219628327504
# --------------------------------
# ========================================
# EPOCH: 45
# train_loss: 0.549659210266102
# train_precision: tensor([0.7407, 0.8007, 0.7887, 0.7428], device='cuda:0')
# train_recall: tensor([0.7233, 0.8518, 0.7708, 0.6114], device='cuda:0')
# val_loss: 0.5566340728766388
# val_precision: tensor([0.7397, 0.8260, 0.7790, 0.7171], device='cuda:0')
# val_recall: tensor([0.7156, 0.8420, 0.8013, 0.6067], device='cuda:0')
# Learning rate: 5e-06
# Early stopping at epoch 45 with best validation loss 0.551549967047241
# training_checkpoints/resnet18_base_norm_padding_resize_2024-04-25 10:25:52.881424.pth
# <All keys matched successfully>
