# %%
import time
import sys
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from dataset import ImageDataset
import torch.nn.functional as F
from torchmetrics import Precision, Recall
from torchvision.models import resnet18
import warnings
from collections import defaultdict
import wandb
import datetime
import os
warnings.filterwarnings('ignore')
torch.set_float32_matmul_precision('high')
#intecubic interpol

run_name = f'resnet18_1024_weighted_4_3_3_0.5_drop0.5_{datetime.datetime.now()}'
run_path = f'training_checkpoints/{run_name}'

wandb.init(project="cells", 
           entity="adamsoja",
          name=run_name)

import random
random.seed(2233)
torch.manual_seed(2233)

from albumentations import (
    Compose,
    Resize,
    OneOf,
    RandomBrightness,
    RandomContrast,
    MotionBlur,
    MedianBlur,
    GaussianBlur,
    VerticalFlip,
    HorizontalFlip,
    ShiftScaleRotate,
    Normalize,
)

transform = Compose(
    [
        OneOf([RandomBrightness(limit=0.4, p=1), RandomContrast(limit=0.4, p=1)]),
        OneOf([MotionBlur(blur_limit=3), MedianBlur(blur_limit=3), GaussianBlur(blur_limit=3),], p=0.7,),
        VerticalFlip(p=0.5),
        HorizontalFlip(p=0.5),]
)


weights = torch.tensor([4.0, 3.0, 3.0, 0.5])

class MyModel(nn.Module):
    def __init__(self, model, learning_rate, weight_decay):
        super(MyModel, self).__init__()
        self.model = model
        self.learning_rate = learning_rate
        self.weight_decay = weight_decay
        self.criterion = nn.CrossEntropyLoss(weight=weights)
        self.metric_precision = Precision(task="multiclass", num_classes=4, average=None).to('cuda')
        self.metric_recall = Recall(task="multiclass", num_classes=4, average=None).to('cuda')
        self.train_loss = []
        self.valid_loss = []
        self.precision_per_epochs = []
        self.recall_per_epochs = []

        self.optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, mode="min", factor=0.1, patience=3, min_lr=5e-6, verbose=True)
        self.step = 0

    
    def forward(self, x):
        return self.model(x)

    def train_one_epoch(self, trainloader):
        self.step += 1
        self.train()
        for batch_idx, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()
            _, preds = torch.max(outputs, 1)
            _, labels = torch.max(labels, 1)
            self.metric_precision(preds, labels)
            self.metric_recall(preds, labels)
            self.train_loss.append(loss.item())


        

        
        avg_loss = np.mean(self.train_loss)
        self.train_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        self.precision_per_epochs.append(precision)
        self.recall_per_epochs.append(recall)
        print(f'train_loss: {avg_loss}')
        print(f'train_precision: {precision}')
        print(f'train_recall: {recall}')

        wandb.log({'loss': avg_loss},step=self.step)
        wandb.log({'Normal precision': precision[0].item()},step=self.step)
        wandb.log({'Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'Other precision': precision[3].item()},step=self.step)


        wandb.log({'Normal recall': recall[0].item()},step=self.step)
        wandb.log({'Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'Other recall': recall[3].item()},step=self.step)
        
        
        self.metric_precision.reset()
        self.metric_recall.reset()


    

    def evaluate(self, testloader):
        self.eval()
        with torch.no_grad():
            for batch_idx, (inputs, labels) in enumerate(testloader):
                inputs, labels = inputs.to('cuda'), labels.to('cuda')
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)
                _, labels = torch.max(labels, 1)
                self.metric_precision(preds, labels)
                self.metric_recall(preds, labels)
                self.valid_loss.append(loss.item())
    
        avg_loss = np.mean(self.valid_loss)
        self.scheduler.step(avg_loss)
        self.valid_loss.clear()
        precision = self.metric_precision.compute()
        recall = self.metric_recall.compute()
        print(f'val_loss: {avg_loss}')
        print(f'val_precision: {precision}')
        print(f'val_recall: {recall}')
        self.metric_precision.reset()
        self.metric_recall.reset()

        wandb.log({'val_loss': avg_loss}, step=self.step)
        
        wandb.log({'val_Normal precision': precision[0].item()},step=self.step)
        wandb.log({'val_Inflamatory precision': precision[1].item()},step=self.step)
        wandb.log({'val_Tumor precision': precision[2].item()},step=self.step)
        wandb.log({'val_Other precision': precision[3].item()},step=self.step)


        wandb.log({'val_Normal recall': recall[0].item()},step=self.step)
        wandb.log({'val_Inflamatory recall': recall[1].item()},step=self.step)
        wandb.log({'val_Tumor recall': recall[2].item()},step=self.step)
        wandb.log({'val_Other recall': recall[3].item()},step=self.step)


        for param_group in self.optimizer.param_groups:
            print(f"Learning rate: {param_group['lr']}")
        return avg_loss

torch.cuda.empty_cache()
batch_size = 1024
trainset = ImageDataset(data_path='train_data', transform=transform)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=5)

testset = ImageDataset(data_path='validation_data')
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=3)

learning_rate = 0.001
weight_decay = 0.00001

model = resnet18()
model.conv1 = nn.Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
num_classes = 4
model.fc = nn.Sequential(
    nn.Dropout(0.4),
    nn.Linear(model.fc.in_features, num_classes))
model = model.to('cuda')


my_model = MyModel(model=model, learning_rate=learning_rate, weight_decay=weight_decay)
my_model = my_model.to('cuda')

num_epochs = 100
early_stop_patience = 10
best_val_loss = float('inf')
best_model_state_dict = None

for epoch in range(num_epochs):
    print('========================================')
    print(f'EPOCH: {epoch}') 
    time_start = time.perf_counter()
    my_model.train_one_epoch(trainloader)
    val_loss = my_model.evaluate(testloader)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_state_dict = my_model.state_dict()
        torch.save(best_model_state_dict, f'{run_path}.pth')
        
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch} with best validation loss {best_val_loss}")
        break
    time_epoch = time.perf_counter() - time_start
    print(f'epoch {epoch} time:  {time_epoch/60}')
    print('--------------------------------')

# Load the best model state dict
print(f'{run_path}.pth')
my_model.load_state_dict(torch.load(f'{run_path}.pth'))
# Out:
# wandb: Currently logged in as: adamsoja. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/adam/Desktop/cells_master_thesis/wandb/run-20240423_210604-fdrvl9y1</code>
# Syncing run <strong><a href='https://wandb.ai/adamsoja/cells/runs/fdrvl9y1' target="_blank">resnet18_1024_weighted_4_3_3_0.5_drop0.5_2024-04-23 21:06:03.199485</a></strong> to <a href='https://wandb.ai/adamsoja/cells' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adamsoja/cells' target="_blank">https://wandb.ai/adamsoja/cells</a>
#  View run at <a href='https://wandb.ai/adamsoja/cells/runs/fdrvl9y1' target="_blank">https://wandb.ai/adamsoja/cells/runs/fdrvl9y1</a>
# ========================================
# EPOCH: 0
# train_loss: 2.684170937538147
# train_precision: tensor([0.5060, 0.7111, 0.6653, 0.0122], device='cuda:0')
# train_recall: tensor([6.4232e-01, 7.0599e-01, 5.5648e-01, 1.4430e-04], device='cuda:0')
# val_loss: 2.535970327589247
# val_precision: tensor([0.5624, 0.8311, 0.6117, 0.9231], device='cuda:0')
# val_recall: tensor([0.6091, 0.6150, 0.7810, 0.0040], device='cuda:0')
# Learning rate: 0.001
# epoch 0 time:  0.322581465766666
# --------------------------------
# ========================================
# EPOCH: 1
# train_loss: 2.3961838847114927
# train_precision: tensor([0.5562, 0.7438, 0.7147, 0.9128], device='cuda:0')
# train_recall: tensor([0.6832, 0.7464, 0.6190, 0.0196], device='cuda:0')
# val_loss: 2.484946934382121
# val_precision: tensor([0.5460, 0.8573, 0.6349, 1.0000], device='cuda:0')
# val_recall: tensor([0.6703, 0.5615, 0.7708, 0.0320], device='cuda:0')
# Learning rate: 0.001
# epoch 1 time:  0.3426531372333329
# --------------------------------
# ========================================
# EPOCH: 2
# train_loss: 2.3100120306015013
# train_precision: tensor([0.5710, 0.7552, 0.7261, 0.9311], device='cuda:0')
# train_recall: tensor([0.6952, 0.7573, 0.6345, 0.0527], device='cuda:0')
# val_loss: 2.315830261177487
# val_precision: tensor([0.5711, 0.7863, 0.6948, 0.7604], device='cuda:0')
# val_recall: tensor([0.6800, 0.7570, 0.6498, 0.0865], device='cuda:0')
# Learning rate: 0.001
# epoch 2 time:  0.33819167446666826
# --------------------------------
# ========================================
# EPOCH: 3
# train_loss: 2.239086866378784
# train_precision: tensor([0.5838, 0.7613, 0.7376, 0.9246], device='cuda:0')
# train_recall: tensor([0.7031, 0.7675, 0.6481, 0.0814], device='cuda:0')
# val_loss: 2.5031421634886
# val_precision: tensor([0.5519, 0.8367, 0.6158, 0.9553], device='cuda:0')
# val_recall: tensor([0.6414, 0.5627, 0.7698, 0.1438], device='cuda:0')
# Learning rate: 0.001
# epoch 3 time:  0.3190190098499973
# --------------------------------
# ========================================
# EPOCH: 4
# train_loss: 2.17932185786111
# train_precision: tensor([0.5948, 0.7720, 0.7455, 0.9127], device='cuda:0')
# train_recall: tensor([0.7147, 0.7728, 0.6603, 0.1056], device='cuda:0')
# val_loss: 2.256724684768253
# val_precision: tensor([0.6099, 0.7235, 0.7474, 0.8638], device='cuda:0')
# val_recall: tensor([0.6635, 0.8049, 0.6507, 0.2498], device='cuda:0')
# Learning rate: 0.001
# epoch 4 time:  0.33740028428333063
# --------------------------------
# ========================================
# EPOCH: 5
# train_loss: 2.124651945204962
# train_precision: tensor([0.6042, 0.7775, 0.7522, 0.9121], device='cuda:0')
# train_recall: tensor([0.7192, 0.7810, 0.6704, 0.1258], device='cuda:0')
# val_loss: 2.145426646868388
# val_precision: tensor([0.6592, 0.7679, 0.7054, 0.7776], device='cuda:0')
# val_recall: tensor([0.6026, 0.8134, 0.7787, 0.1778], device='cuda:0')
# Learning rate: 0.001
# epoch 5 time:  0.3397275580166668
# --------------------------------
# ========================================
# EPOCH: 6
# train_loss: 2.0941667738414944
# train_precision: tensor([0.6113, 0.7805, 0.7576, 0.9020], device='cuda:0')
# train_recall: tensor([0.7245, 0.7860, 0.6759, 0.1408], device='cuda:0')
# val_loss: 2.064394462108612
# val_precision: tensor([0.6066, 0.8166, 0.7457, 0.9323], device='cuda:0')
# val_recall: tensor([0.7310, 0.7471, 0.7157, 0.1902], device='cuda:0')
# Learning rate: 0.001
# epoch 6 time:  0.33896161995000207
# --------------------------------
# ========================================
# EPOCH: 7
# train_loss: 2.0487842145420254
# train_precision: tensor([0.6205, 0.7874, 0.7630, 0.9085], device='cuda:0')
# train_recall: tensor([0.7322, 0.7899, 0.6858, 0.1633], device='cuda:0')
# val_loss: 2.069686841964722
# val_precision: tensor([0.6446, 0.8029, 0.7081, 0.8563], device='cuda:0')
# val_recall: tensor([0.6579, 0.7809, 0.7676, 0.1946], device='cuda:0')
# Learning rate: 0.001
# epoch 7 time:  0.3206126987500018
# --------------------------------
# ========================================
# EPOCH: 8
# train_loss: 2.024191719577426
# train_precision: tensor([0.6255, 0.7904, 0.7653, 0.9130], device='cuda:0')
# train_recall: tensor([0.7340, 0.7939, 0.6917, 0.1665], device='cuda:0')
# val_loss: 2.141586913002862
# val_precision: tensor([0.6699, 0.8074, 0.6717, 0.9312], device='cuda:0')
# val_recall: tensor([0.5914, 0.7823, 0.8266, 0.1640], device='cuda:0')
# Learning rate: 0.001
# epoch 8 time:  0.31763977856666464
# --------------------------------
# ========================================
# EPOCH: 9
# train_loss: 1.990642556122371
# train_precision: tensor([0.6326, 0.7934, 0.7687, 0.9157], device='cuda:0')
# train_recall: tensor([0.7379, 0.7972, 0.6993, 0.1756], device='cuda:0')
# val_loss: 2.2426535420947604
# val_precision: tensor([0.6020, 0.7290, 0.7571, 0.9303], device='cuda:0')
# val_recall: tensor([0.6608, 0.8687, 0.5980, 0.1933], device='cuda:0')
# Learning rate: 0.001
# epoch 9 time:  0.32112132725000037
# --------------------------------
# ========================================
# EPOCH: 10
# train_loss: 1.9614851781300136
# train_precision: tensor([0.6361, 0.7993, 0.7715, 0.9206], device='cuda:0')
# train_recall: tensor([0.7417, 0.8024, 0.7015, 0.1924], device='cuda:0')
# val_loss: 2.0782511062092253
# val_precision: tensor([0.6546, 0.7379, 0.7717, 0.9203], device='cuda:0')
# val_recall: tensor([0.6638, 0.8636, 0.6854, 0.2529], device='cuda:0')
# Learning rate: 0.0001
# epoch 10 time:  0.32067068051666564
# --------------------------------
# ========================================
# EPOCH: 11
# train_loss: 1.8367941527139573
# train_precision: tensor([0.6635, 0.8118, 0.7888, 0.9308], device='cuda:0')
# train_recall: tensor([0.7584, 0.8191, 0.7281, 0.2330], device='cuda:0')
# val_loss: 1.8276600466834174
# val_precision: tensor([0.6767, 0.8254, 0.7680, 0.9271], device='cuda:0')
# val_recall: tensor([0.7359, 0.8111, 0.7682, 0.2741], device='cuda:0')
# Learning rate: 0.0001
# epoch 11 time:  0.33520336956666674
# --------------------------------
# ========================================
# EPOCH: 12
# train_loss: 1.792044775258927
# train_precision: tensor([0.6684, 0.8173, 0.7957, 0.9356], device='cuda:0')
# train_recall: tensor([0.7660, 0.8235, 0.7325, 0.2391], device='cuda:0')
# val_loss: 1.7982563111517165
# val_precision: tensor([0.6589, 0.8319, 0.7907, 0.9494], device='cuda:0')
# val_recall: tensor([0.7725, 0.8042, 0.7381, 0.2589], device='cuda:0')
# Learning rate: 0.0001
# epoch 12 time:  0.3360230933833312
# --------------------------------
# ========================================
# EPOCH: 13
# train_loss: 1.7701000446364994
# train_precision: tensor([0.6722, 0.8199, 0.7987, 0.9283], device='cuda:0')
# train_recall: tensor([0.7715, 0.8239, 0.7360, 0.2410], device='cuda:0')
# val_loss: 1.8235955476760863
# val_precision: tensor([0.6749, 0.8174, 0.7751, 0.9475], device='cuda:0')
# val_recall: tensor([0.7432, 0.8210, 0.7494, 0.2613], device='cuda:0')
# Learning rate: 0.0001
# epoch 13 time:  0.3187145045999993
# --------------------------------
# ========================================
# EPOCH: 14
# train_loss: 1.7498733963285173
# train_precision: tensor([0.6762, 0.8228, 0.8010, 0.9385], device='cuda:0')
# train_recall: tensor([0.7740, 0.8257, 0.7416, 0.2424], device='cuda:0')
# val_loss: 1.831832183731927
# val_precision: tensor([0.6850, 0.8339, 0.7549, 0.9364], device='cuda:0')
# val_recall: tensor([0.7209, 0.8069, 0.7937, 0.2677], device='cuda:0')
# Learning rate: 0.0001
# epoch 14 time:  0.31688422543333367
# --------------------------------
# ========================================
# EPOCH: 15
# train_loss: 1.7337077123778206
# train_precision: tensor([0.6792, 0.8243, 0.8047, 0.9339], device='cuda:0')
# train_recall: tensor([0.7787, 0.8276, 0.7431, 0.2424], device='cuda:0')
# val_loss: 1.782215540938907
# val_precision: tensor([0.6679, 0.8314, 0.7924, 0.9150], device='cuda:0')
# val_recall: tensor([0.7684, 0.8112, 0.7457, 0.3007], device='cuda:0')
# Learning rate: 0.0001
# epoch 15 time:  0.3385609097499999
# --------------------------------
# ========================================
# EPOCH: 16
# train_loss: 1.7179274195716494
# train_precision: tensor([0.6811, 0.8271, 0.8050, 0.9381], device='cuda:0')
# train_recall: tensor([0.7807, 0.8277, 0.7453, 0.2557], device='cuda:0')
# val_loss: 1.84275041686164
# val_precision: tensor([0.6610, 0.8568, 0.7574, 0.9386], device='cuda:0')
# val_recall: tensor([0.7524, 0.7690, 0.7836, 0.2781], device='cuda:0')
# Learning rate: 0.0001
# epoch 16 time:  0.31670027533333495
# --------------------------------
# ========================================
# EPOCH: 17
# train_loss: 1.7014368971188862
# train_precision: tensor([0.6840, 0.8296, 0.8077, 0.9391], device='cuda:0')
# train_recall: tensor([0.7843, 0.8295, 0.7483, 0.2537], device='cuda:0')
# val_loss: 1.8626135137346056
# val_precision: tensor([0.6868, 0.8440, 0.7362, 0.9659], device='cuda:0')
# val_recall: tensor([0.7058, 0.7923, 0.8163, 0.2387], device='cuda:0')
# Learning rate: 0.0001
# epoch 17 time:  0.31568138556666553
# --------------------------------
# ========================================
# EPOCH: 18
# train_loss: 1.6800795515378317
# train_precision: tensor([0.6876, 0.8293, 0.8118, 0.9343], device='cuda:0')
# train_recall: tensor([0.7867, 0.8330, 0.7498, 0.2587], device='cuda:0')
# val_loss: 1.7784524387783474
# val_precision: tensor([0.6762, 0.8197, 0.7982, 0.9335], device='cuda:0')
# val_recall: tensor([0.7609, 0.8318, 0.7420, 0.2835], device='cuda:0')
# Learning rate: 0.0001
# epoch 18 time:  0.3364351288833329
# --------------------------------
# ========================================
# EPOCH: 19
# train_loss: 1.66612305414109
# train_precision: tensor([0.6900, 0.8328, 0.8140, 0.9469], device='cuda:0')
# train_recall: tensor([0.7901, 0.8327, 0.7537, 0.2752], device='cuda:0')
# val_loss: 1.7943925221761068
# val_precision: tensor([0.6745, 0.8456, 0.7707, 0.9354], device='cuda:0')
# val_recall: tensor([0.7595, 0.7955, 0.7730, 0.2828], device='cuda:0')
# Learning rate: 0.0001
# epoch 19 time:  0.3184761994999993
# --------------------------------
# ========================================
# EPOCH: 20
# train_loss: 1.648634126072838
# train_precision: tensor([0.6929, 0.8337, 0.8154, 0.9380], device='cuda:0')
# train_recall: tensor([0.7903, 0.8358, 0.7574, 0.2641], device='cuda:0')
# val_loss: 1.8050772931840684
# val_precision: tensor([0.6991, 0.8318, 0.7584, 0.9515], device='cuda:0')
# val_recall: tensor([0.7237, 0.8220, 0.7961, 0.2576], device='cuda:0')
# Learning rate: 0.0001
# epoch 20 time:  0.31710759549999923
# --------------------------------
# ========================================
# EPOCH: 21
# train_loss: 1.6247114743505204
# train_precision: tensor([0.6975, 0.8366, 0.8192, 0.9395], device='cuda:0')
# train_recall: tensor([0.7974, 0.8384, 0.7587, 0.2667], device='cuda:0')
# val_loss: 1.7822915315628052
# val_precision: tensor([0.6917, 0.8147, 0.7878, 0.9382], device='cuda:0')
# val_recall: tensor([0.7420, 0.8409, 0.7613, 0.2707], device='cuda:0')
# Learning rate: 0.0001
# epoch 21 time:  0.31680216761666696
# --------------------------------
# ========================================
# EPOCH: 22
# train_loss: 1.6121948293277195
# train_precision: tensor([0.7011, 0.8374, 0.8204, 0.9380], device='cuda:0')
# train_recall: tensor([0.7973, 0.8412, 0.7628, 0.2665], device='cuda:0')
# val_loss: 1.7791764219601949
# val_precision: tensor([0.6871, 0.8278, 0.7859, 0.9153], device='cuda:0')
# val_recall: tensor([0.7496, 0.8275, 0.7667, 0.3091], device='cuda:0')
# Learning rate: 1e-05
# epoch 22 time:  0.31768282438333323
# --------------------------------
# ========================================
# EPOCH: 23
# train_loss: 1.5668040911356609
# train_precision: tensor([0.7076, 0.8416, 0.8287, 0.9446], device='cuda:0')
# train_recall: tensor([0.8055, 0.8467, 0.7677, 0.2753], device='cuda:0')
# val_loss: 1.7575489600499472
# val_precision: tensor([0.6891, 0.8300, 0.7896, 0.9299], device='cuda:0')
# val_recall: tensor([0.7572, 0.8271, 0.7673, 0.3081], device='cuda:0')
# Learning rate: 1e-05
# epoch 23 time:  0.3360221055666633
# --------------------------------
# ========================================
# EPOCH: 24
# train_loss: 1.5555195723261153
# train_precision: tensor([0.7108, 0.8431, 0.8271, 0.9412], device='cuda:0')
# train_recall: tensor([0.8052, 0.8474, 0.7713, 0.2794], device='cuda:0')
# val_loss: 1.774066150188446
# val_precision: tensor([0.6901, 0.8378, 0.7799, 0.9285], device='cuda:0')
# val_recall: tensor([0.7541, 0.8176, 0.7789, 0.3017], device='cuda:0')
# Learning rate: 1e-05
# epoch 24 time:  0.31707851693333095
# --------------------------------
# ========================================
# EPOCH: 25
# train_loss: 1.5512570250601996
# train_precision: tensor([0.7103, 0.8420, 0.8297, 0.9436], device='cuda:0')
# train_recall: tensor([0.8071, 0.8478, 0.7692, 0.2799], device='cuda:0')
# val_loss: 1.764925351407793
# val_precision: tensor([0.6890, 0.8339, 0.7864, 0.9321], device='cuda:0')
# val_recall: tensor([0.7576, 0.8243, 0.7700, 0.3051], device='cuda:0')
# Learning rate: 1e-05
# epoch 25 time:  0.32220923003333535
# --------------------------------
# ========================================
# EPOCH: 26
# train_loss: 1.545550156774975
# train_precision: tensor([0.7112, 0.8447, 0.8299, 0.9376], device='cuda:0')
# train_recall: tensor([0.8092, 0.8455, 0.7730, 0.2797], device='cuda:0')
# val_loss: 1.7720388253529866
# val_precision: tensor([0.6877, 0.8371, 0.7831, 0.9271], device='cuda:0')
# val_recall: tensor([0.7591, 0.8180, 0.7728, 0.2997], device='cuda:0')
# Learning rate: 1e-05
# epoch 26 time:  0.32415608798333245
# --------------------------------
# ========================================
# EPOCH: 27
# train_loss: 1.5381917805898757
# train_precision: tensor([0.7109, 0.8456, 0.8310, 0.9449], device='cuda:0')
# train_recall: tensor([0.8096, 0.8473, 0.7721, 0.2847], device='cuda:0')
# val_loss: 1.7737407392925686
# val_precision: tensor([0.6894, 0.8367, 0.7842, 0.9269], device='cuda:0')
# val_recall: tensor([0.7596, 0.8202, 0.7729, 0.2990], device='cuda:0')
# Learning rate: 5e-06
# epoch 27 time:  0.31826092321666316
# --------------------------------
# ========================================
# EPOCH: 28
# train_loss: 1.5347675959269205
# train_precision: tensor([0.7137, 0.8450, 0.8324, 0.9452], device='cuda:0')
# train_recall: tensor([0.8107, 0.8490, 0.7731, 0.2912], device='cuda:0')
# val_loss: 1.7684320648511251
# val_precision: tensor([0.6819, 0.8409, 0.7895, 0.9263], device='cuda:0')
# val_recall: tensor([0.7704, 0.8139, 0.7650, 0.3088], device='cuda:0')
# Learning rate: 5e-06
# epoch 28 time:  0.3231492161000006
# --------------------------------
# ========================================
# EPOCH: 29
# train_loss: 1.528148127169836
# train_precision: tensor([0.7148, 0.8455, 0.8331, 0.9460], device='cuda:0')
# train_recall: tensor([0.8106, 0.8488, 0.7759, 0.2905], device='cuda:0')
# val_loss: 1.772048646873898
# val_precision: tensor([0.6887, 0.8377, 0.7834, 0.9330], device='cuda:0')
# val_recall: tensor([0.7593, 0.8183, 0.7745, 0.3000], device='cuda:0')
# Learning rate: 5e-06
# epoch 29 time:  0.32242630203333345
# --------------------------------
# ========================================
# EPOCH: 30
# train_loss: 1.530140285264878
# train_precision: tensor([0.7139, 0.8465, 0.8306, 0.9415], device='cuda:0')
# train_recall: tensor([0.8100, 0.8491, 0.7741, 0.2859], device='cuda:0')
# val_loss: 1.7689097285270692
# val_precision: tensor([0.6843, 0.8373, 0.7906, 0.9351], device='cuda:0')
# val_recall: tensor([0.7658, 0.8200, 0.7661, 0.3057], device='cuda:0')
# Learning rate: 5e-06
# epoch 30 time:  0.3219442342500012
# --------------------------------
# ========================================
# EPOCH: 31
# train_loss: 1.523494519506182
# train_precision: tensor([0.7150, 0.8469, 0.8330, 0.9464], device='cuda:0')
# train_recall: tensor([0.8126, 0.8484, 0.7752, 0.2932], device='cuda:0')
# val_loss: 1.7726838178104825
# val_precision: tensor([0.6860, 0.8390, 0.7860, 0.9349], device='cuda:0')
# val_recall: tensor([0.7632, 0.8167, 0.7715, 0.3047], device='cuda:0')
# Learning rate: 5e-06
# epoch 31 time:  0.31877744860000046
# --------------------------------
# ========================================
# EPOCH: 32
# train_loss: 1.5295819850195023
# train_precision: tensor([0.7148, 0.8460, 0.8308, 0.9495], device='cuda:0')
# train_recall: tensor([0.8102, 0.8496, 0.7743, 0.2873], device='cuda:0')
# val_loss: 1.77162117295795
# val_precision: tensor([0.6883, 0.8330, 0.7921, 0.9224], device='cuda:0')
# val_recall: tensor([0.7621, 0.8270, 0.7656, 0.3081], device='cuda:0')
# Learning rate: 5e-06
# epoch 32 time:  0.322803407533335
# --------------------------------
# ========================================
# EPOCH: 33
# train_loss: 1.528343079203651
# train_precision: tensor([0.7142, 0.8470, 0.8325, 0.9452], device='cuda:0')
# train_recall: tensor([0.8130, 0.8477, 0.7744, 0.2889], device='cuda:0')
# val_loss: 1.7729542175928752
# val_precision: tensor([0.6907, 0.8341, 0.7860, 0.9232], device='cuda:0')
# val_recall: tensor([0.7573, 0.8253, 0.7706, 0.3118], device='cuda:0')
# Learning rate: 5e-06
# Early stopping at epoch 33 with best validation loss 1.7575489600499472
# training_checkpoints/resnet18_1024_weighted_4_3_3_0.5_drop0.5_2024-04-23 21:06:03.199485.pth
# <All keys matched successfully>

# %%
from sklearn.metrics import confusion_matrix, classification_report
from torch.utils.data import DataLoader
import numpy as np
import torch 
from torchvision.models import resnet18
import torch.nn as nn


def test_report(model, dataloader):
    """Prints confusion matrix for testing dataset
    dataloader should be of batch_size=1."""

    y_pred = []
    y_test = []
    model.eval()
    with torch.no_grad():
        for data, label in dataloader:
            output = model(data)
            label = label.numpy()
            output = output.numpy()
            y_pred.append(np.argmax(output))
            y_test.append(np.argmax(label))
        print(confusion_matrix(y_test, y_pred))
        print(classification_report(y_test, y_pred))

testset =ImageDataset(data_path='test_data')
dataloader = DataLoader(testset, batch_size=1, shuffle=True)

test_report(my_model.to('cpu'), dataloader)
# Out:
# [[758  81 161   0]
#  [136 824  39   1]
#  [170  37 791   2]
#  [ 29  19  22  30]]
#               precision    recall  f1-score   support
#
#            0       0.69      0.76      0.72      1000
#            1       0.86      0.82      0.84      1000
#            2       0.78      0.79      0.79      1000
#            3       0.91      0.30      0.45       100
#
#     accuracy                           0.78      3100
#    macro avg       0.81      0.67      0.70      3100
# weighted avg       0.78      0.78      0.77      3100
